# %% [markdown]
# ## Figure 4.1: Hypothesis Similarity Across Attention Heads
#
# Compares head-level hypothesis similarity distributions for each model under baseline, single best-fit, and linearly weighted program settings.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ast

# 1. Load your data
df_results = pd.read_csv(r"..\results\replacement_run\shuffles\gpt2_smart_shuffle_8.csv")
df_iou = pd.read_csv(r"..\data\iou_scores_gpt2.csv")

# 2. Process IoU: Aggregate sentences
df_iou_agg = df_iou.groupby(['layer', 'head', 'program_idx'])['iou_score'].mean().reset_index()

# FIX: Map the index to the STRING name of the function
def get_program_name(idx):
    obj = all_programs[idx]
    # Check if it's a function object or already a string
    return obj.__name__ if hasattr(obj, '__name__') else str(obj)

df_iou_agg['program'] = df_iou_agg['program_idx'].apply(get_program_name)

# 3. Standardize Head Keys
def clean_key(h):
    try:
        val = ast.literal_eval(str(h).strip())
        return f"({val[0]}, {val[1]})"
    except:
        return str(h).strip()

df_results['head_key'] = df_results['head'].apply(clean_key)
df_iou_agg['head_key'] = df_iou_agg.apply(lambda x: f"({int(x['layer'])}, {int(x['head'])})", axis=1)

# 4. Merge
df_plot = pd.merge(
    df_results,
    df_iou_agg[['head_key', 'program', 'iou_score']],
    on=['head_key', 'program'],
    how='inner'
)

# 5. Plotting Logic
if df_plot.empty:
    print("!! ERROR: Still no matches. !!")
    print(f"Sample Result Program: {df_results['program'].iloc[0]}")
    print(f"Sample IoU Program: {df_iou_agg['program'].iloc[0]}")
else:
    plt.figure(figsize=(10, 6))
    sns.set_style("whitegrid")
    
    # Main Plot
    sns.regplot(
        data=df_plot,
        x='iou_score',
        y='increase',
        scatter_kws={'alpha':0.6, 'color':'#2c3e50', 's':60},
        line_kws={'color':'#e74c3c', 'label':'Linear Trend'}
    )
    
    # Statistical Annotation
    corr = df_plot['iou_score'].corr(df_plot['increase'], method='spearman')
    plt.text(0.05, 0.95, f'Spearman ρ: {corr:.3f}', transform=plt.gca().transAxes, 
             verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))

    plt.title("Correlation of Program Scores to Perplexity Increase (GPT-2 Shuffle 8)", fontsize=14)
    plt.xlabel("Programmatic Alignment (Mean IoU)", fontsize=12)
    plt.ylabel("Downstream Perplexity Increase %", fontsize=12)
    
    plt.tight_layout()
    plt.savefig(r"..\results\plots\iou_vs_ppl_correlation_fixed.png", dpi=300)
    plt.show()

    print(f"Successfully matched {len(df_plot)} heads.")
    print(f"Spearman Correlation: {corr:.4f}")
# Out:
# Successfully matched 144 heads.
# Spearman Correlation: -0.9232

# %%
# ============================================================
#  FIGURE 4.1 — Self-contained plotting cell (REPAIR VERSION)
# ============================================================

# ... [Steps 1-3 remain the same as previous] ...
import os, sys, random, warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from transformers import AutoModel, AutoTokenizer

warnings.filterwarnings("ignore")
RANDOM_SEED = 42
random.seed(RANDOM_SEED); np.random.seed(RANDOM_SEED); torch.manual_seed(RANDOM_SEED)

DATA_BASE    = "../data"
DATA_DIR     = f"{DATA_BASE}"
RESULTS_DIR  = f"../results"

MODEL_CONFIGS = {
    "bert":      {"display": "BERT-BASE", "arch": "Encoder", "hf_name": "bert-base-uncased"},
    "gpt2":      {"display": "GPT-2",     "arch": "Decoder", "hf_name": "openai-community/gpt2"},
    "tinyllama": {"display": "TinyLlama", "arch": "Decoder", "hf_name": "TinyLlama/TinyLlama-1.1B-intermediate-step-1431k-3T"},
    "llama3b":   {"display": "Llama-3.2-3B", "arch": "Decoder", "hf_name": "meta-llama/Llama-3.2-3B", "hf_token": None},  # set hf_token="hf_..." if needed
}

def iou_score(p, q):
    p = np.clip(p, 1e-12, 1.0); q = np.clip(q, 1e-12, 1.0)
    return float(np.minimum(p, q).sum() / np.maximum(p, q).sum())

def compute_baselines(hf_name, sentences, device="cpu", hf_token=None, use_fp16=False):
    load_kw = dict(output_attentions=True)
    if hf_token: load_kw["token"] = hf_token
    if use_fp16: load_kw["torch_dtype"] = __import__("torch").float16
    model = AutoModel.from_pretrained(hf_name, **load_kw).to(device)
    tok_kw = {"token": hf_token} if hf_token else {}
    tok   = AutoTokenizer.from_pretrained(hf_name, **tok_kw)
    n_layers, n_heads = model.config.num_hidden_layers, model.config.num_attention_heads
    accum_token, accum_col, accum_diag = np.zeros(n_layers * n_heads), np.zeros(n_layers * n_heads), np.zeros(n_layers * n_heads)

    for sent in sentences:
        inputs = tok(sent, return_tensors="pt").to(device)
        with torch.no_grad(): atts = model(**inputs).attentions
        for l in range(n_layers):
            for h in range(n_heads):
                att = atts[l][0, h].to(torch.float32).cpu().numpy()
                n = att.shape[0]
                ref_diag = np.tril(np.ones((n, n))); ref_diag /= ref_diag.sum(axis=1, keepdims=True)
                ref_col = np.zeros((n, n)); ref_col[:, np.random.randint(0, n)] = 1.0
                ref_tok = np.zeros((n, n))
                for i in range(n): ref_tok[i, np.random.randint(0, n)] = 1.0
                idx = l * n_heads + h
                accum_diag[idx] += np.mean([iou_score(att[i], ref_diag[i]) for i in range(n)])
                accum_col[idx] += np.mean([iou_score(att[i], ref_col[i]) for i in range(n)])
                accum_token[idx] += np.mean([iou_score(att[i], ref_tok[i]) for i in range(n)])
    del model, tok
    return (accum_token/len(sentences)*100).tolist(), (accum_col/len(sentences)*100).tolist(), (accum_diag/len(sentences)*100).tolist()

# ── 5. Load Sentences ──
df_json = pd.read_json(f"{DATA_DIR}/generic_sentences.json")
SAMPLE_SENTENCES = df_json[0].sample(5, random_state=RANDOM_SEED).tolist()

# ── 6. Build Data (Diagnostic Fix) ──
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
model_results = {}

for key, cfg in MODEL_CONFIGS.items():
    print(f"\n── {key.upper()} ──────────────────────────────────────────")
    # Try multiple common naming conventions for the CSV
    interp_csv = f"{DATA_DIR}/interpolation_k_{key}.csv"
    if not os.path.exists(interp_csv):
        interp_csv = f"{DATA_DIR}/interpolation_k_{key.upper()}.csv"

    iou_csv = f"{DATA_DIR}/iou_scores_{key}.csv"
    
    _token   = cfg.get("hf_token")
    _fp16    = cfg.get("use_fp16", key == "llama3b")
    b_tok, b_col, b_diag = compute_baselines(
        cfg["hf_name"], SAMPLE_SENTENCES, device=DEVICE,
        hf_token=_token, use_fp16=_fp16)
    print(f"  Baseline (Diag): {np.mean(b_diag):.1f}%")

    best_single = []
    if os.path.exists(iou_csv):
        iou_df = pd.read_csv(iou_csv)
        best_single = (iou_df.groupby(["layer", "head"])["iou_score"].max().dropna() * 100).tolist()
        print(f"  Best-single: mean={np.mean(best_single):.1f}%")

    all_weighted, k_sweep = [], {}
    if os.path.exists(interp_csv):
        interp_df = pd.read_csv(interp_csv)
        # Ensure k and iou_score are numeric and drop NaNs
        interp_df["k"] = pd.to_numeric(interp_df["k"], errors='coerce')
        interp_df["iou_score"] = pd.to_numeric(interp_df["iou_score"], errors='coerce')
        interp_df = interp_df.dropna(subset=["k", "iou_score"])
        
        interp_df["iou_val"] = interp_df["iou_score"] * 100
        max_k = interp_df["k"].max()
        
        all_weighted = interp_df[interp_df["k"] == max_k]["iou_val"].tolist()
        
        for kval, grp in interp_df.groupby("k"):
            k_sweep[int(kval)] = grp["iou_val"].tolist()
        
        print(f"  Interpolation: Found k-values {sorted(k_sweep.keys())}")
        print(f"  All-weighted (k={max_k}): mean={np.mean(all_weighted):.1f}%")
    else:
        print(f"  [ERROR] CSV NOT FOUND: {interp_csv}")

    model_results[key] = {"box_data": [b_tok, b_col, b_diag, best_single, all_weighted], "k_sweep": k_sweep}

# ── 7. Plotting ──
def styled_boxplot(ax, data, labels, colors, positions):
    valid = [(d, l, p) for d, l, p in zip(data, labels, positions) if len(d) > 0]
    if not valid: return
    vdata, vlabels, vpos = zip(*valid)
    bp = ax.boxplot(vdata, positions=list(vpos), patch_artist=True, widths=0.5,
                    medianprops=dict(color="black", linewidth=1.2),
                    flierprops=dict(marker="o", markersize=2, alpha=0.2))
    for patch, color in zip(bp["boxes"], colors):
        patch.set_facecolor(color); patch.set_edgecolor("black"); patch.set_linewidth(0.6)
    ax.set_xticks(list(vpos)); ax.set_xticklabels(list(vlabels))

ROW_COLORS = {
    "bert":      {"box": "#f0a868", "line": "#d4681a", "base": "#fdebd0"},
    "gpt2":      {"box": "#e07070", "line": "#c0392b", "base": "#f5caca"},
    "tinyllama": {"box": "#7fb3d5", "line": "#1f77b4", "base": "#d6eaf8"},
    "llama3b":   {"box": "#b5ead7", "line": "#2a9d8f", "base": "#d4f5ec"},
}

fig = plt.figure(figsize=(13, 15)) 
gs  = fig.add_gridspec(4, 2, hspace=0.4, wspace=0.25, width_ratios=[1.4, 1])

for row, key in enumerate(["bert", "gpt2", "tinyllama", "llama3b"]):
    cfg, res, c = MODEL_CONFIGS[key], model_results[key], ROW_COLORS[key]
    colors = [c["base"], c["base"], c["base"], c["box"], c["box"]]

    ax_box = fig.add_subplot(gs[row, 0])
    labels = ["Random\nToken", "Random\nColumn", "Lower\nDiagonal", f"Single Best\nFit {cfg['arch']}", f"Weighted\n{cfg['arch']} Ensem."]
    styled_boxplot(ax_box, res["box_data"], labels, colors, positions=[1, 2, 3, 4, 5])
    ax_box.set_title(f"Program IoU Similarity: {cfg['display']}", fontweight="bold", pad=9)
    ax_box.set_ylabel("Similarity (%)"); ax_box.set_ylim(0, 100); ax_box.set_xlim(0.4, 5.6)

    ax_line = fig.add_subplot(gs[row, 1])
    ax_line.set_title("Linearly Interpolation Similarity", fontweight="bold", pad=9)
    ax_line.set_xlabel("Programs Utilized (k)"); ax_line.set_ylabel("Similarity (%)"); ax_line.set_ylim(0, 100)
    
    if res["k_sweep"]:
        ks = sorted(res["k_sweep"].keys())
        means = [np.mean(res["k_sweep"][k]) for k in ks]
        p25, p75 = [np.percentile(res["k_sweep"][k], 25) for k in ks], [np.percentile(res["k_sweep"][k], 75) for k in ks]
        ax_line.plot(ks, means, color=c["line"], linewidth=2, marker="o", markersize=3)
        ax_line.fill_between(ks, p25, p75, color=c["line"], alpha=0.1)
        ax_line.set_xticks(range(0, max(ks) + 2, 2))
    else:
        ax_line.text(0.5, 0.5, "(check GPT-2 CSV path)", transform=ax_line.transAxes, ha="center", color="red")

# for ax in fig.axes:
    # ax.spines["top"].set_visible(False); ax.spines["right"].set_visible(False)

plt.savefig(f"{RESULTS_DIR}/plots/figure_4_1.pdf", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# Sentences loaded: ['The rhythmic crash of the waves, breaking against the shore, provided a soothing soundtrack to the quiet evening.', 'He contemplated, for a moment, the vastness of the universe, its endless possibilities, and his tiny place within it.'] ...
# Device: cpu
#
# ── bert ──────────────────────────────────────────
#   Computing baseline for bert...
#   Baseline: n=144  mean=14.3%
#   Best-single: n=144  mean=48.9%
#   All-weighted (k=20): n=144  mean=51.1%
#
# ── gpt2 ──────────────────────────────────────────
#   Computing baseline for gpt2...
#   Baseline: n=144  mean=30.1%
#   Best-single: n=144  mean=67.6%
#   All-weighted (k=20): n=143  mean=65.4%
#
# ── tinyllama ──────────────────────────────────────────
#   Computing baseline for tinyllama...
#   Baseline: n=704  mean=24.6%
#   Best-single: n=704  mean=73.7%
#   All-weighted (k=20): n=654  mean=70.9%
#
# All data loaded.
# Saved to ../results/plots/figure_4_1.pdf

# %% [markdown]
# ## Figure 4.2: Best-Fit Program Mapping by Head
#
# Maps each attention head to its highest-IoU hypothesis program and visualizes category-aware patterns across layers and heads.

# %%
import inspect
import json
from typing import List, Callable

# ============================================================
# Figure 4.2 data prep: build/read best-fit CSVs per model
# Expected paths:
#   ../data/iou_scores_{model}.csv
#   ../results/program_categories.json
# ============================================================

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from data import golden_programs
all_programs: List[Callable] = [
    obj for name, obj in inspect.getmembers(golden_programs, inspect.isfunction)
]

# Program categories prepared offline
with open("../results/program_categories.json", "r") as f:
    attention_head_categories = json.load(f)

# Verification of programs
total_count = sum(len(v) for v in attention_head_categories.values())
print(f"[INFO] Programs loaded: {len(all_programs)}")
print(f"[INFO] Programs categorized: {total_count}")

for model_key in MODEL_CONFIGS.keys():
    iou_csv = f"{DATA_DIR}/iou_scores_{model_key}.csv"
    if not os.path.exists(iou_csv):
        print(f"[WARN] Missing: {iou_csv}. Skipping best-fit generation for {model_key}.")
        continue

    # Skip if best-fit CSV already exists
    out_csv = f"{RESULTS_DIR}/best_fits_{model_key}.csv"
    if os.path.exists(out_csv):
        print(f"[INFO] Already exists: {out_csv}. Skipping best-fit generation for {model_key}.")
        continue

    iou_df = pd.read_csv(iou_csv)
    iou_df = iou_df.groupby(["layer", "head", "program_idx"])["iou_score"].mean().reset_index()

    n_best_programs = 1
    best_fits = (
        iou_df.groupby(["layer", "head"])
        .apply(lambda g: g.nlargest(n_best_programs, "iou_score"))
        .reset_index(drop=True)
    )

    best_fits["iou_score"] = best_fits["iou_score"].round(3)
    best_fits.to_csv(out_csv, index=False)
    print(f"[DONE] Saved best fits for {model_key} to {out_csv}")

best_fits_bert = []
best_fits_gpt2 = []
best_fits_tinyllama = []
best_fits_llama3b = []

for model_key in MODEL_CONFIGS.keys():
    best_fits_csv = f"{RESULTS_DIR}/best_fits_{model_key}.csv"
    if os.path.exists(best_fits_csv):
        df = pd.read_csv(best_fits_csv)
        _names = [all_programs[int(i)].__name__ for i in df["program_idx"]]
        _tuples = list(zip(df["layer"].astype(int), df["head"].astype(int), _names, df["iou_score"]))
        if model_key == "bert":      best_fits_bert      = _tuples
        elif model_key == "gpt2":    best_fits_gpt2      = _tuples
        elif model_key == "tinyllama": best_fits_tinyllama = _tuples
        elif model_key == "llama3b": best_fits_llama3b   = _tuples
        print(f"[INFO] Loaded best fits for {model_key} from {best_fits_csv}")
    else:
        print(f"[WARN] Missing: {best_fits_csv}. Cannot load best fits for {model_key}.")
# Out:
# [INFO] Programs loaded: 71
# [INFO] Programs categorized: 71
# [INFO] Already exists: ../results/best_fits_bert.csv. Skipping best-fit generation for bert.
# [INFO] Already exists: ../results/best_fits_gpt2.csv. Skipping best-fit generation for gpt2.
# [INFO] Already exists: ../results/best_fits_tinyllama.csv. Skipping best-fit generation for tinyllama.
# [INFO] Loaded best fits for bert from ../results/best_fits_bert.csv
# [INFO] Loaded best fits for gpt2 from ../results/best_fits_gpt2.csv
# [INFO] Loaded best fits for tinyllama from ../results/best_fits_tinyllama.csv

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.colors as mcolors
import seaborn as sns
import numpy as np

# Standardized Colormap: 0-40% White, 40-100% transitions to Dark Charcoal
colors = [(1, 1, 1), (1, 1, 1), (0.15, 0.15, 0.15)]
nodes = [0.0, 0.4, 1.0]
standard_prec_map = mcolors.LinearSegmentedColormap.from_list("custom_gray", list(zip(nodes, colors)))

CATEGORY_COLORS = {
    "initiation_and_anchoring":      "#001D3D",
    "relational_and_semantic":       "#4A90E2",
    "special_tokens_and_boundaries": "#7FF1F5",
    "linguistic_and_syntactic":      "#274C77",
    "sequential_and_induction":      "#0077B6",
    "uniformity_and_global":         "#95D5EE",
}

CATEGORY_COLORS = {
    "initiation_and_anchoring":      "#4285F4",
    "relational_and_semantic":       "#EA4335", 
    "special_tokens_and_boundaries": "#FBBC05",
    "linguistic_and_syntactic":      "#FF6D00",
    "sequential_and_induction":      "#34A853",
    "uniformity_and_global":         "#A142F4", 
}

all_names = [func.__name__ for func in all_programs]
os.makedirs("../results/plots/figure_4_2", exist_ok=True)

def save_heatmap(data, title, best_fits, all_names, filename, categories=None):
    n_rows, n_cols = data.shape
    fig_w = n_cols * 0.45 + 1.2
    fig_h = n_rows * 0.45 + 1.0
    fig, ax = plt.subplots(figsize=(fig_w, fig_h))

    reversed_data = data[::-1]
    sns.heatmap(reversed_data, ax=ax, cmap=standard_prec_map, cbar=False,
                linewidths=0.5, linecolor='#EEEEEE', vmin=0, vmax=1, square=True)

    name_to_cat = get_name_to_category(categories) if categories else {}

    if best_fits is not None:
        for i, (head_id, name, score) in enumerate(best_fits):
            layer_val = i // n_cols
            x = i % n_cols
            y_pos = (n_rows - 1) - layer_val
            cell_value = data[layer_val, x] # The accuracy value for this cell

            if name:
                legend_idx = all_names.index(name) if name in all_names else head_id
                cat = name_to_cat.get(name, None)
                color = CATEGORY_COLORS.get(cat, "#333333")

                # Change 1: Text color dependent on background accuracy
                # If accuracy is high (dark background), use white text for visibility
                text_color = "white" if cell_value > 0.7 else "black"

                ax.add_patch(plt.Circle((x + 0.5, y_pos + 0.5), radius=0.3,
                                        facecolor='none', edgecolor=color,
                                        linewidth=3.5, zorder=3))

                ax.text(x + 0.5, y_pos + 0.5, str(legend_idx),
                        ha='center', va='center', color=text_color,
                        fontweight='bold', fontsize=8, zorder=4)

    # Change 2: Precision spacing beneath title using 'pad'
    ax.set_title(title, fontweight='bold', fontsize=11, color='#001D3D', pad=5)
    ax.set_yticklabels(range(n_rows - 1, -1, -1), rotation=0, fontsize=7)
    ax.set_xticklabels(range(n_cols), fontsize=7)

    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.close()

def save_shared_colorbar(filename):
    # Change 3: Significantly thinner plot and removed helper text
    fig, ax = plt.subplots(figsize=(10, 0.15))
    norm = mcolors.Normalize(vmin=0, vmax=1)
    cb = plt.colorbar(plt.cm.ScalarMappable(norm=norm, cmap=standard_prec_map),
                      cax=ax, orientation='horizontal')
    cb.outline.set_linewidth(0.5)
    cb.ax.tick_params(labelsize=7)
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.close()

def get_name_to_category(categories):
    return {m: cat for cat, members in categories.items() for m in members}

# 1. Build heatmap matrices — use (layer, head) from tuples directly
# best_fits_* are now (layer, head, name, score) so coordinates are exact.
def _build_matrix(best_fits, n_layers, n_heads):
    data = np.zeros((n_layers, n_heads))
    for layer, head, name, score in best_fits:
        if score is not None and layer < n_layers and head < n_heads:
            data[layer, head] = float(score)
    return data

bert_data      = _build_matrix(best_fits_bert,      12, 12)
gpt2_data      = _build_matrix(best_fits_gpt2,      12, 12)
tinyllama_data = _build_matrix(best_fits_tinyllama, 22, 32)
llama3b_data   = _build_matrix(best_fits_llama3b,   28, 24)

# Rebuild annotation lists in (program_idx_or_name, name, score) format
# save_heatmap iterates enumerate() and uses i // n_cols to place circles,
# so we reconstruct ordered flat lists (sorted by layer, head) for it.
def _ordered_fits(best_fits, n_layers, n_heads):
    grid = {}
    for layer, head, name, score in best_fits:
        grid[(layer, head)] = (name, score)
    result = []
    for l in range(n_layers):
        for h in range(n_heads):
            if (l, h) in grid:
                name, score = grid[(l, h)]
                result.append((h, name, score))
            else:
                result.append((h, None, 0.0))
    return result

best_fits_bert_ordered      = _ordered_fits(best_fits_bert,      12, 12)
best_fits_gpt2_ordered      = _ordered_fits(best_fits_gpt2,      12, 12)
best_fits_tinyllama_ordered = _ordered_fits(best_fits_tinyllama, 22, 32)
best_fits_llama3b_ordered   = _ordered_fits(best_fits_llama3b,   28, 24)

save_heatmap(bert_data, "BERT-BASE",
             best_fits_bert_ordered, all_names, "../results/plots/figure_4_2/fig_bert.png",
             categories=attention_head_categories)

save_heatmap(gpt2_data, "GPT-2",
             best_fits_gpt2_ordered, all_names, "../results/plots/figure_4_2/fig_gpt.png",
             categories=attention_head_categories)

save_heatmap(tinyllama_data, "TINY LLAMA",
             best_fits_tinyllama_ordered, all_names, "../results/plots/figure_4_2/fig_tinyllama.png",
             categories=attention_head_categories)

save_heatmap(llama3b_data, "LLAMA-3.2-3B",
             best_fits_llama3b_ordered, all_names, "../results/plots/figure_4_2/fig_llama3b.png",
             categories=attention_head_categories)

# 2. Generate the Ultra-Thin Shared Colorbar
# Place this at the very bottom of your figure grid in your document
save_shared_colorbar("../results/plots/figure_4_2/fig_shared_colorbar.png")
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import matplotlib.colors as mcolors

def get_text_color(hex_color):
    """Returns 'black' for light colors and 'white' for dark colors."""
    rgb = mcolors.to_rgb(hex_color)
    # Standard formula for relative luminance
    luminance = 0.2126 * rgb[0] + 0.7152 * rgb[1] + 0.0722 * rgb[2]
    return 'black' if luminance > 0.5 else 'white'

def save_category_boxes(filename):
    n_cats = len(CATEGORY_COLORS)
    fig, axes = plt.subplots(1, n_cats, figsize=(14, 1.2))
    fig.subplots_adjust(wspace=0.15)

    for ax, (group, color) in zip(axes, CATEGORY_COLORS.items()):
        ax.axis('off')

        # Draw the rounded box
        rect = mpatches.FancyBboxPatch(
            (0.05, 0.1), 0.9, 0.8,
            boxstyle="round,pad=0,rounding_size=0.15",
            color=color, transform=ax.transAxes, clip_on=False
        )
        ax.add_patch(rect)

        # 1. ADD LOGIC HERE: Determine text color based on background luminance
        t_color = get_text_color(color)

        clean_name = group.replace('_', ' ').title().replace(' And', '\nAnd')

        # 2. UPDATE TEXT CALL: Use the dynamic t_color
        ax.text(0.5, 0.5, clean_name,
                color=t_color, ha='center', va='center',
                fontweight='bold', fontsize=10, transform=ax.transAxes,
                linespacing=1.5)

    plt.savefig(filename, dpi=300, bbox_inches='tight', transparent=True)
    plt.close()

# 2. Filtered Legend Only including programs present in the matrices
def save_filtered_legend(all_names, filename, categories, best_fits_list):
    """
    best_fits_list: list of lists, e.g., [best_fits_bert, best_fits_gpt, best_fits_tinyllama]
    """
    # Identify unique names that actually appeared in the matrices
    appeared_names = set()
    for fits in best_fits_list:
        if fits is not None:
            for head_id, name, score in fits:
                if name is not None:
                    appeared_names.add(name)

    # Filter and sort by original index to keep numbering consistent
    filtered_programs = [(i, name) for i, name in enumerate(all_names) if name in appeared_names]

    if not filtered_programs:
        print("No programs found in matrices. Skipping legend.")
        return

    n_cols = 4
    n_rows = int(np.ceil(len(filtered_programs) / n_cols))
    fig, ax = plt.subplots(figsize=(14, n_rows * 0.3))
    ax.axis('off')

    # Set the title with consistent professional blue and padding
    ax.set_title("Executable Programs:\n",
                 fontweight='bold', fontsize=18, color='black', pad=15)

    name_to_cat = get_name_to_category(categories)

    for i, (original_idx, name) in enumerate(filtered_programs):
        col, row = i // n_rows, i % n_rows
        x, y = col * (1/n_cols), 1 - (row * (1/n_rows))
        cat = name_to_cat.get(name)
        color = CATEGORY_COLORS.get(cat, "#333333")

        # Consistent numbering based on the original all_names list
        ax.text(x, y, f"○ {original_idx}: {name}", color=color, fontsize=8,
                fontfamily='monospace', transform=ax.transAxes)

    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.close()
    print(f"Saved {filename} with {len(filtered_programs)} programs.")

# --- Call sequence ---
save_category_boxes("../results/plots/figure_4_2/fig_group_map.png")

# Pass all three best_fits lists to filter the legend
save_filtered_legend(
    all_names,
    "../results/plots/figure_4_2/fig_program_index.png",
    attention_head_categories,
    [best_fits_bert_ordered, best_fits_gpt2_ordered, best_fits_tinyllama_ordered, best_fits_llama3b_ordered]
)
# Out:
# Saved ../results/plots/figure_4_2/fig_program_index.png with 22 programs.

# %% [markdown]
# ## Figure 4.3: Perplexity Impact of Head Replacement
#
# Shows normalized perplexity increase as progressively more attention heads are replaced with symbolic hypothesis programs.

# %%
def prepare_sentence(sent, mode="random"):
    words = sent.split()
    if len(words) <= 3:
        return sent
        
    if mode == "random":
        idx = np.random.randint(3, len(words))
        return " ".join(words[:idx])
    elif mode == "last_word":
        return " ".join(words[:-1])
    else:
        return sent

def run_replacement_experiment_gpt2(
    sentences,
    best_fits_df,
    all_programs,
    strategy="baseline",
    max_heads=144,
    num_sentences=5,
    spike_threshold=50.0,
    skip_spikes=True,
    save_file=""
):
    import pathlib
    import numpy as np
    import pandas as pd
    import torch
    import torch.nn.functional as F
    import ast
    from transformers import GPT2LMHeadModel, GPT2Tokenizer

    device = "cuda" if torch.cuda.is_available() else "cpu"
    tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
    eval_sentences = sentences[:num_sentences]
    experiment_results = []
    skipped_programs = []

    # --- Baseline ---
    print("Calculating baseline perplexities...")
    base_model = GPT2LMHeadModel.from_pretrained("gpt2").to(device)
    base_model.eval()
    baseline_ppls, baseline_logits = [], []

    for sent in eval_sentences:
        active_sent = prepare_sentence(sent, mode="last_word")
        toks = tokenizer(active_sent, return_tensors="pt").to(device)
        with torch.no_grad():
            outputs = base_model(**toks, labels=toks["input_ids"])
            baseline_ppls.append(torch.exp(outputs.loss).item())
            baseline_logits.append(outputs.logits[:, -1, :])

    del base_model
    torch.cuda.empty_cache()
    print(f"Baseline complete. Mean PPL: {np.mean(baseline_ppls):.2f}")

    # --- Robust DataFrame Parsing ---
    unique_heads_mapping = []
    seen_heads = set()
    for _, row in best_fits_df.iterrows():
        if 'layer' in row and 'head' in row:
            head_tuple = (int(row['layer']), int(row['head']))
        else:
            raw_head = row['head']
            if isinstance(raw_head, str):
                head_tuple = tuple(ast.literal_eval(raw_head))
            elif hasattr(raw_head, "__iter__"):
                head_tuple = tuple(raw_head)
            else:
                head_tuple = (0, int(raw_head))
            
        if head_tuple not in seen_heads:
            try:
                p_idx = int(row['program_idx'])
                prog_name = all_programs[p_idx].__name__
                unique_heads_mapping.append((head_tuple, [prog_name]))
                seen_heads.add(head_tuple)
            except (KeyError, IndexError, ValueError):
                continue

    # --- Hook factories ---
    def make_baseline_hook(lookup):
        def compound_hook(module, input, output):
            context_layer = output[0]
            batch, seq_len, hidden_dim = context_layer.shape
            num_heads, head_dim = 12, hidden_dim // 12
            modified_layer = context_layer.view(batch, seq_len, num_heads, head_dim).clone()
            mask = torch.tril(torch.ones((seq_len, seq_len), device=device))
            for head_idx in range(num_heads):
                if (module.layer_id, head_idx) in lookup:
                    modified_layer[:, :, head_idx, :] = torch.matmul(mask, modified_layer[:, :, head_idx, :])
            return (modified_layer.view(batch, seq_len, hidden_dim),) + output[1:]
        return compound_hook

    def make_smart_hook(lookup, programs_list):
        def compound_hook(module, input, output):
            context_layer = output[0]
            batch, seq_len, hidden_dim = context_layer.shape
            num_heads, head_dim = 12, hidden_dim // 12
            modified_layer = context_layer.view(batch, seq_len, num_heads, head_dim).clone()
            current_sent = getattr(module, '_current_sentence', None)
            if current_sent is None: return output
            for head_idx in range(num_heads):
                key = (module.layer_id, head_idx)
                if key in lookup:
                    prog_name = lookup[key]
                    prog = next((p for p in programs_list if p.__name__ == prog_name), None)
                    if prog:
                        try:
                            _, hypo_mat = prog(current_sent, tokenizer)
                            if hypo_mat is not None:
                                hypo_tensor = torch.tensor(hypo_mat).to(device, dtype=modified_layer.dtype)
                                modified_layer[:, :, head_idx, :] = torch.matmul(hypo_tensor, modified_layer[:, :, head_idx, :])
                        except Exception: pass
            return (modified_layer.view(batch, seq_len, hidden_dim),) + output[1:]
        return compound_hook

    def make_sanity_check_hook(lookup):
        def compound_hook(module, input, output):
            context_layer = output[0]
            batch, seq_len, hidden_dim = context_layer.shape
            num_heads, head_dim = 12, hidden_dim // 12
            modified_layer = context_layer.view(batch, seq_len, num_heads, head_dim).clone()
            identity = torch.eye(seq_len, device=device, dtype=modified_layer.dtype)
            for head_idx in range(num_heads):
                if (module.layer_id, head_idx) in lookup:
                    modified_layer[:, :, head_idx, :] = torch.matmul(identity, modified_layer[:, :, head_idx, :])
            return (modified_layer.view(batch, seq_len, hidden_dim),) + output[1:]
        return compound_hook

    # --- Main loop ---
    print(f"Running with strategy='{strategy}', skip_spikes={skip_spikes}")
    accepted_heads_mapping = []
    k = 0

    for candidate in unique_heads_mapping:
        if k >= max_heads: break

        trial_mapping = accepted_heads_mapping + [candidate]
        trial_lookup = {tuple(map(int, item[0])): item[1][0] for item in trial_mapping}
        relevant_layers = set(idx[0] for idx in trial_lookup)

        model_k = GPT2LMHeadModel.from_pretrained("gpt2").to(device)
        model_k.eval()

        if strategy == "baseline": hook_fn = make_baseline_hook(trial_lookup)
        elif strategy == "smart": hook_fn = make_smart_hook(trial_lookup, all_programs)
        elif strategy == "sanity_check": hook_fn = make_sanity_check_hook(trial_lookup)
        else: raise ValueError(f"Unknown strategy: '{strategy}'.")

        hook_handles = []
        for l_idx in range(12):
            target = model_k.transformer.h[l_idx].attn
            target.layer_id = l_idx
            if l_idx in relevant_layers:
                hook_handles.append(target.register_forward_hook(hook_fn))

        replaced_ppls, kl_divergences = [], []
        for i, sent in enumerate(eval_sentences):
            active_sent = prepare_sentence(sent, mode="last_word")
            for l_idx in relevant_layers:
                model_k.transformer.h[l_idx].attn._current_sentence = active_sent
            toks = tokenizer(active_sent, return_tensors="pt").to(device)
            with torch.no_grad():
                out_rep = model_k(**toks, labels=toks["input_ids"])
                replaced_ppls.append(torch.exp(out_rep.loss).item())
                log_probs_new = F.log_softmax(out_rep.logits[:, -1, :], dim=-1)
                probs_baseline = F.softmax(baseline_logits[i], dim=-1)
                kl_divergences.append(F.kl_div(log_probs_new, probs_baseline, reduction='batchmean').item())

        for handle in hook_handles: handle.remove()
        del model_k
        torch.cuda.empty_cache()

        mean_pct = np.mean([(r - b) / b * 100 for r, b in zip(replaced_ppls, baseline_ppls)])
        prev_mean = experiment_results[-1]["increase"] if experiment_results else 0.0
        marginal = mean_pct - prev_mean
        is_spike = marginal > spike_threshold

        if is_spike and skip_spikes:
            skipped_programs.append({"head": candidate[0], "program": candidate[1][0], "marginal": marginal})
            print(f"  [SKIP] Spike detected for head {candidate[0]} with marginal increase of {marginal:.2f}%.")
            continue

        if mean_pct > 1000.0:
            print(f"Perplexity increase exceeded 1000% ({mean_pct:.2f}%). Stopping early.")
            break

        k += 1
        accepted_heads_mapping.append(candidate)
        experiment_results.append({
            "k": k, "head": str(candidate[0]), "program": candidate[1][0],
            "strategy": strategy, "increase": mean_pct, "kl_div": np.mean(kl_divergences),
            "spike": is_spike,
        })
        print(f"k={k:02d} | Head: {candidate[0]} | Program: {candidate[1][0]} | Mean PPL Inc: {mean_pct:.4f}%")

    results_df = pd.DataFrame(experiment_results)
    if save_file:
        results_df.to_csv(save_file, index=False)
    else:
        pathlib.Path("../results/replacement_run").mkdir(exist_ok=True)
        results_df.to_csv(f"../results/replacement_run/gpt2_{strategy}.csv", index=False)
    return results_df


import pathlib
import numpy as np
import pandas as pd
import torch
import torch.nn.functional as F
from transformers import BertForMaskedLM, AutoTokenizer, logging as hf_logging

def full_perplexity(sentence, bert_model, tokenizer, device):
    inputs = tokenizer(sentence, return_tensors="pt").to(device)
    input_ids = inputs["input_ids"]
    seq_len = input_ids.shape[1]
    log_probs = []
    for i in range(1, seq_len - 1):  # skip [CLS] and [SEP]
        masked = input_ids.clone()
        masked[0, i] = tokenizer.mask_token_id
        with torch.no_grad():
            logits = bert_model(masked).logits
        prob = torch.log_softmax(logits[0, i], dim=-1)[input_ids[0, i]]
        log_probs.append(prob)
    return torch.exp(-torch.stack(log_probs).mean()).item()

def run_replacement_experiment_bert(
    sentences,
    best_fits_df,
    all_programs,
    strategy="smart",
    max_heads=144,
    num_sentences=5,
    bert_model_name="bert-base-uncased",
    spike_threshold=50.0,
    skip_spikes=True,
    save_file=""
):
    import ast
    hf_logging.set_verbosity_error()

    device = "cuda" if torch.cuda.is_available() else "cpu"
    tokenizer = AutoTokenizer.from_pretrained(bert_model_name)
    eval_sentences = sentences[:num_sentences]
    experiment_results = []
    skipped_programs = []
    models = {}

    # --- Baseline ---
    print("Calculating baseline pseudo-perplexities...")
    base_model = BertForMaskedLM.from_pretrained(bert_model_name).to(device)
    base_model.eval()
    baseline_ppls = [full_perplexity(s, base_model, tokenizer, device) for s in eval_sentences]
    del base_model
    torch.cuda.empty_cache()
    print(f"Baseline complete. Mean pseudo-PPL: {np.mean(baseline_ppls):.2f}")

    print(f"\n=== STRATEGY: {strategy.upper()} ===\n")

    # --- Robust DataFrame Parsing ---
    unique_heads_mapping = []
    seen_heads = set()
    for _, row in best_fits_df.iterrows():
        if 'layer' in row and 'head' in row:
            head_tuple = (int(row['layer']), int(row['head']))
        else:
            raw_head = row['head']
            if isinstance(raw_head, str):
                head_tuple = tuple(ast.literal_eval(raw_head))
            elif hasattr(raw_head, "__iter__"):
                head_tuple = tuple(raw_head)
            else:
                head_tuple = (0, int(raw_head))
            
        if head_tuple not in seen_heads:
            try:
                p_idx = int(row['program_idx'])
                prog_name = all_programs[p_idx].__name__
            except (KeyError, IndexError, ValueError) as e:
                print(f"  [WARN] Could not resolve program for head {head_tuple}: {e}")
                prog_name = None

            if prog_name:
                unique_heads_mapping.append((head_tuple, [prog_name]))
                seen_heads.add(head_tuple)

    print(f"Total heads to replace: {len(unique_heads_mapping)}")

    # --- Hook factories ---
    def make_baseline_hook(lookup):
        def compound_hook(module, input, output):
            context_layer = output[0]
            batch, seq_len, hidden_dim = context_layer.shape
            num_heads, head_dim = 12, hidden_dim // 12
            modified_layer = context_layer.view(batch, seq_len, num_heads, head_dim).clone()
            attn_mask = torch.tril(torch.ones((seq_len, seq_len), device=device))
            for head_idx in range(num_heads):
                if (module.layer_id, head_idx) in lookup:
                    modified_layer[:, :, head_idx, :] = torch.matmul(attn_mask, modified_layer[:, :, head_idx, :])
            return (modified_layer.view(batch, seq_len, hidden_dim),) + output[1:]
        return compound_hook

    def make_smart_hook(lookup, programs_list):
        def compound_hook(module, input, output):
            context_layer = output[0]
            batch, seq_len, hidden_dim = context_layer.shape
            num_heads, head_dim = 12, hidden_dim // 12
            modified_layer = context_layer.view(batch, seq_len, num_heads, head_dim).clone()
            current_sent = getattr(module, '_current_sentence', None)
            if current_sent is None:
                return output
            for head_idx in range(num_heads):
                key = (module.layer_id, head_idx)
                if key in lookup:
                    prog_name = lookup[key]
                    prog = next((p for p in programs_list if p.__name__ == prog_name), None)
                    if prog:
                        try:
                            _, hypo_mat = prog(current_sent, tokenizer)
                            if hypo_mat is not None:
                                hypo_tensor = torch.tensor(hypo_mat).to(device, dtype=modified_layer.dtype)
                                if hypo_tensor.shape == (seq_len, seq_len):
                                    modified_layer[:, :, head_idx, :] = torch.matmul(hypo_tensor, modified_layer[:, :, head_idx, :])
                        except Exception:
                            pass
            return (modified_layer.view(batch, seq_len, hidden_dim),) + output[1:]
        return compound_hook

    def make_sanity_check_hook(lookup):
        def compound_hook(module, input, output):
            context_layer = output[0]
            batch, seq_len, hidden_dim = context_layer.shape
            num_heads, head_dim = 12, hidden_dim // 12
            modified_layer = context_layer.view(batch, seq_len, num_heads, head_dim).clone()
            identity = torch.eye(seq_len, device=device, dtype=modified_layer.dtype)
            for head_idx in range(num_heads):
                if (module.layer_id, head_idx) in lookup:
                    modified_layer[:, :, head_idx, :] = torch.matmul(identity, modified_layer[:, :, head_idx, :])
            return (modified_layer.view(batch, seq_len, hidden_dim),) + output[1:]
        return compound_hook

    # --- Main loop ---
    print(f"Running with strategy='{strategy}', skip_spikes={skip_spikes}")
    accepted_heads_mapping = []
    k = 0

    for candidate in unique_heads_mapping:
        if k >= max_heads:
            break

        trial_mapping = accepted_heads_mapping + [candidate]
        trial_lookup = {tuple(map(int, item[0])): item[1][0] for item in trial_mapping}
        relevant_layers = set(idx[0] for idx in trial_lookup)

        model_key = f"model_v{k}"
        models[model_key] = BertForMaskedLM.from_pretrained(bert_model_name).to(device)
        models[model_key].eval()

        if strategy == "baseline":
            hook_fn = make_baseline_hook(trial_lookup)
        elif strategy == "sanity_check":
            hook_fn = make_sanity_check_hook(trial_lookup)
        else:
            hook_fn = make_smart_hook(trial_lookup, all_programs)

        hook_handles = []
        for l_idx in range(12):
            target = models[model_key].bert.encoder.layer[l_idx].attention.self
            target.layer_id = l_idx
            if l_idx in relevant_layers:
                hook_handles.append(target.register_forward_hook(hook_fn))

        replaced_ppls = []
        for sent in eval_sentences:
            for l_idx in relevant_layers:
                models[model_key].bert.encoder.layer[l_idx].attention.self._current_sentence = sent
            replaced_ppls.append(full_perplexity(sent, models[model_key], tokenizer, device))

        for handle in hook_handles:
            handle.remove()
        del models[model_key]
        torch.cuda.empty_cache()

        mean_pct = np.mean([(r - b) / b * 100 for r, b in zip(replaced_ppls, baseline_ppls)])
        prev_mean = experiment_results[-1]["increase"] if experiment_results else 0.0
        marginal = mean_pct - prev_mean
        is_spike = marginal > spike_threshold

        if is_spike and skip_spikes:
            skipped_programs.append({"head": candidate[0], "program": candidate[1][0], "marginal": marginal})
            print(f"  [SKIP] Spike detected for head {candidate[0]} with marginal increase of {marginal:.2f}%.")
            continue

        if mean_pct > 1000.0:
            print(f"Perplexity increase exceeded 1000% ({mean_pct:.2f}%). Stopping early.")
            break

        k += 1
        accepted_heads_mapping.append(candidate)
        experiment_results.append({
            "k": k,
            "head": str(candidate[0]),
            "program": candidate[1][0],
            "strategy": strategy,
            "increase": mean_pct,
            "spike": is_spike,
        })
        print(f"k={k:02d} | New Head: {candidate[0]} | Program: {candidate[1][0]} | Mean PPL Inc: {mean_pct:.4f}%")

    results_df = pd.DataFrame(experiment_results)
    if save_file:
        results_df.to_csv(save_file, index=False)
    else:
        pathlib.Path("../results/replacement_run").mkdir(exist_ok=True)
        results_df.to_csv(f"../results/replacement_run/bert_{strategy}.csv", index=False)
    return results_df


def run_replacement_experiment_llama(
    sentences,
    best_fits_df,
    all_programs,
    strategy="smart",
    max_heads=250,
    num_sentences=5,
    spike_threshold=50.0,
    skip_spikes=True,
    save_file=""
):
    import copy
    import pathlib
    import numpy as np
    import pandas as pd
    import torch
    import torch.nn.functional as F
    import ast
    from transformers import AutoTokenizer, AutoModelForCausalLM

    MODEL_ID = "TinyLlama/TinyLlama-1.1B-intermediate-step-1431k-3T"
    NUM_LAYERS, NUM_HEADS, HIDDEN_SIZE = 22, 32, 2048
    HEAD_DIM = HIDDEN_SIZE // NUM_HEADS

    device = "cuda" if torch.cuda.is_available() else "cpu"
    tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
    eval_sentences = sentences[:num_sentences]
    experiment_results = []
    skipped_programs = []

    print("Loading reference model...")
    ref_model = AutoModelForCausalLM.from_pretrained(MODEL_ID).to(device)
    ref_model.eval()

    print("Calculating baseline perplexities...")
    baseline_ppls, baseline_logits = [], []
    for sent in eval_sentences:
        active_sent = prepare_sentence(sent, mode="last_word")
        toks = tokenizer(active_sent, return_tensors="pt").to(device)
        with torch.no_grad():
            outputs = ref_model(**toks, labels=toks["input_ids"])
            baseline_ppls.append(torch.exp(outputs.loss).item())
            baseline_logits.append(outputs.logits[:, -1, :])
    print(f"Baseline complete. Mean PPL: {np.mean(baseline_ppls):.2f}")

    # --- Robust DataFrame Parsing ---
    unique_heads_mapping = []
    seen_heads = set()
    for _, row in best_fits_df.iterrows():
        if 'layer' in row and 'head' in row:
            head_tuple = (int(row['layer']), int(row['head']))
        else:
            raw_head = row['head']
            if isinstance(raw_head, str):
                head_tuple = tuple(ast.literal_eval(raw_head))
            elif hasattr(raw_head, "__iter__"):
                head_tuple = tuple(raw_head)
            else:
                head_tuple = (0, int(raw_head))
            
        if head_tuple not in seen_heads:
            try:
                p_idx = int(row['program_idx'])
                prog_name = all_programs[p_idx].__name__
                unique_heads_mapping.append((head_tuple, [prog_name]))
                seen_heads.add(head_tuple)
            except (KeyError, IndexError, ValueError):
                continue

    # --- Hook factories ---
    def make_baseline_hook(lookup):
        def compound_hook(module, input, output):
            context_layer = output[0].contiguous()
            batch, seq_len, hidden_dim = context_layer.shape
            modified_layer = context_layer.view(batch, seq_len, NUM_HEADS, HEAD_DIM).clone()
            mask = torch.tril(torch.ones((seq_len, seq_len), device=device))
            for head_idx in range(NUM_HEADS):
                if (module.layer_id, head_idx) in lookup:
                    modified_layer[:, :, head_idx, :] = torch.matmul(mask, modified_layer[:, :, head_idx, :])
            return (modified_layer.view(batch, seq_len, hidden_dim),) + output[1:]
        return compound_hook

    def make_smart_hook(lookup, programs_list):
        def compound_hook(module, input, output):
            context_layer = output[0].contiguous()
            batch, seq_len, hidden_dim = context_layer.shape
            modified_layer = context_layer.view(batch, seq_len, NUM_HEADS, HEAD_DIM).clone()
            current_sent = getattr(module, '_current_sentence', None)
            if current_sent is None: return output
            for head_idx in range(NUM_HEADS):
                key = (module.layer_id, head_idx)
                if key in lookup:
                    prog_name = lookup[key]
                    prog = next((p for p in programs_list if p.__name__ == prog_name), None)
                    if prog:
                        try:
                            _, hypo_mat = prog(current_sent, tokenizer)
                            if hypo_mat is not None:
                                hypo_tensor = torch.tensor(hypo_mat).to(device, dtype=modified_layer.dtype)
                                modified_layer[:, :, head_idx, :] = torch.matmul(hypo_tensor, modified_layer[:, :, head_idx, :])
                        except Exception: pass
            return (modified_layer.view(batch, seq_len, hidden_dim),) + output[1:]
        return compound_hook

    def make_sanity_check_hook(lookup):
        def compound_hook(module, input, output):
            context_layer = output[0].contiguous()
            batch, seq_len, hidden_dim = context_layer.shape
            modified_layer = context_layer.view(batch, seq_len, NUM_HEADS, HEAD_DIM).clone()
            identity = torch.eye(seq_len, device=device, dtype=modified_layer.dtype)
            for head_idx in range(NUM_HEADS):
                if (module.layer_id, head_idx) in lookup:
                    modified_layer[:, :, head_idx, :] = torch.matmul(identity, modified_layer[:, :, head_idx, :])
            return (modified_layer.view(batch, seq_len, hidden_dim),) + output[1:]
        return compound_hook

    # --- Main loop ---
    print(f"Running with strategy='{strategy}', skip_spikes={skip_spikes}")
    accepted_heads_mapping = []
    k = 0

    for candidate in unique_heads_mapping:
        if k >= max_heads:
            break

        trial_mapping = accepted_heads_mapping + [candidate]
        iteration_lookup = {tuple(map(int, item[0])): item[1][0] for item in trial_mapping}
        relevant_layers = set(idx[0] for idx in iteration_lookup)

        iter_model = copy.deepcopy(ref_model)
        iter_model.eval()

        if strategy == "smart": hook_fn = make_smart_hook(iteration_lookup, all_programs)
        elif strategy == "baseline": hook_fn = make_baseline_hook(iteration_lookup)
        elif strategy == "sanity_check": hook_fn = make_sanity_check_hook(iteration_lookup)
        else: raise ValueError(f"Unknown strategy: '{strategy}'.")

        hook_handles = []
        for l_idx in range(NUM_LAYERS):
            target = iter_model.model.layers[l_idx].self_attn
            target.layer_id = l_idx
            if l_idx in relevant_layers:
                hook_handles.append(target.register_forward_hook(hook_fn))

        replaced_ppls, kl_divergences = [], []
        for i, sent in enumerate(eval_sentences):
            active_sent = prepare_sentence(sent, mode="last_word")
            for l_idx in relevant_layers:
                iter_model.model.layers[l_idx].self_attn._current_sentence = active_sent
            toks = tokenizer(active_sent, return_tensors="pt").to(device)
            with torch.no_grad():
                out_rep = iter_model(**toks, labels=toks["input_ids"])
                replaced_ppls.append(torch.exp(out_rep.loss).item())
                kl_divergences.append(F.kl_div(
                    F.log_softmax(out_rep.logits[:, -1, :], dim=-1),
                    F.softmax(baseline_logits[i], dim=-1),
                    reduction='batchmean'
                ).item())

        for handle in hook_handles: handle.remove()
        del iter_model
        torch.cuda.empty_cache()

        mean_pct = np.mean([(r - b) / b * 100 for r, b in zip(replaced_ppls, baseline_ppls)])
        prev_mean = experiment_results[-1]["increase"] if experiment_results else 0.0
        marginal = mean_pct - prev_mean
        is_spike = marginal > spike_threshold

        if mean_pct > 1000.0:
            print(f"Perplexity increase exceeded 1000% ({mean_pct:.2f}%). Stopping early.")
            break

        if is_spike and skip_spikes:
            skipped_programs.append({"head": candidate[0], "program": candidate[1][0], "marginal": marginal})
            print(f"  [SKIP] Spike detected for head {candidate[0]} with marginal increase of {marginal:.2f}%.")
            continue

        k += 1
        accepted_heads_mapping.append(candidate)
        experiment_results.append({
            "k": k, "head": str(candidate[0]), "program": candidate[1][0],
            "strategy": strategy, "increase": mean_pct, "kl_div": np.mean(kl_divergences),
            "spike": is_spike,
        })
        print(f"k={k:02d} | Head: {candidate[0]} | Program: {candidate[1][0]} | Mean PPL Inc: {mean_pct:.4f}%")

    if save_file:
        pd.DataFrame(experiment_results).to_csv(save_file, index=False)
    else:
        pathlib.Path("../results/replacement_run").mkdir(exist_ok=True)
        pd.DataFrame(experiment_results).to_csv(f"../results/replacement_run/tinyllama_{strategy}.csv", index=False)
    del ref_model
    return pd.DataFrame(experiment_results)


def run_replacement_experiment_llama3b(
    sentences,
    best_fits_df,
    all_programs,
    strategy="smart",
    max_heads=250,
    num_sentences=5,
    spike_threshold=50.0,
    skip_spikes=True,
    save_file=""
):
    """Replacement experiment for Llama-3.2-3B.
    Architecture: 28 layers, 24 Q-heads, 8 KV-heads (GQA), hidden=3072, head_dim=128.
    HF expands KV→Q before returning attentions, so hook shape is always
    (batch, seq_len, hidden_dim) = (1, seq, 3072) and the head reshape is
    (batch, seq, 24, 128) — same pattern as TinyLlama, different constants.
    """
    import copy
    import pathlib
    import numpy as np
    import pandas as pd
    import torch
    import torch.nn.functional as F
    import ast
    from transformers import AutoTokenizer, AutoModelForCausalLM

    MODEL_ID   = "meta-llama/Llama-3.2-3B"
    NUM_LAYERS = 28
    NUM_HEADS  = 24        # Q-heads (GQA: 8 KV-heads, but output is Q-head shaped)
    HIDDEN_SIZE = 3072
    HEAD_DIM   = HIDDEN_SIZE // NUM_HEADS  # 128

    device = "cuda" if torch.cuda.is_available() else "cpu"
    tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
    eval_sentences = sentences[:num_sentences]
    experiment_results = []
    skipped_programs = []

    print("Loading reference model (Llama-3.2-3B)...")
    ref_model = AutoModelForCausalLM.from_pretrained(
        MODEL_ID,
        torch_dtype=torch.float16,
        device_map="auto",
        attn_implementation="eager",
    )
    ref_model.eval()

    print("Calculating baseline perplexities...")
    baseline_ppls, baseline_logits = [], []
    for sent in eval_sentences:
        active_sent = prepare_sentence(sent, mode="last_word")
        toks = tokenizer(active_sent, return_tensors="pt").to(device)
        with torch.no_grad():
            outputs = ref_model(**toks, labels=toks["input_ids"])
            baseline_ppls.append(torch.exp(outputs.loss).item())
            baseline_logits.append(outputs.logits[:, -1, :].float())
    print(f"Baseline complete. Mean PPL: {np.mean(baseline_ppls):.2f}")

    # --- Parse best_fits_df ---
    unique_heads_mapping = []
    seen_heads = set()
    for _, row in best_fits_df.iterrows():
        if "layer" in row and "head" in row:
            head_tuple = (int(row["layer"]), int(row["head"]))
        else:
            raw = row["head"]
            head_tuple = tuple(ast.literal_eval(raw)) if isinstance(raw, str) else (0, int(raw))
        if head_tuple not in seen_heads:
            try:
                p_idx = int(row["program_idx"])
                prog_name = all_programs[p_idx].__name__
                unique_heads_mapping.append((head_tuple, [prog_name]))
                seen_heads.add(head_tuple)
            except (KeyError, IndexError, ValueError):
                continue

    # --- Hook factories (same structure as TinyLlama, different constants) ---
    def make_baseline_hook(lookup):
        def hook(module, input, output):
            ctx = output[0].contiguous().float()
            b, s, _ = ctx.shape
            mod = ctx.view(b, s, NUM_HEADS, HEAD_DIM).clone()
            mask = torch.tril(torch.ones((s, s), device=device))
            for h in range(NUM_HEADS):
                if (module.layer_id, h) in lookup:
                    mod[:, :, h, :] = torch.matmul(mask, mod[:, :, h, :])
            return (mod.view(b, s, HIDDEN_SIZE).to(output[0].dtype),) + output[1:]
        return hook

    def make_smart_hook(lookup, programs_list):
        def hook(module, input, output):
            ctx = output[0].contiguous().float()
            b, s, _ = ctx.shape
            mod = ctx.view(b, s, NUM_HEADS, HEAD_DIM).clone()
            cur = getattr(module, "_current_sentence", None)
            if cur is None:
                return output
            for h in range(NUM_HEADS):
                key = (module.layer_id, h)
                if key in lookup:
                    prog = next((p for p in programs_list if p.__name__ == lookup[key]), None)
                    if prog:
                        try:
                            import inspect as _insp
                            n_p = len(_insp.signature(prog).parameters)
                            _, mat = prog(cur) if n_p == 1 else prog(cur, tokenizer)
                            if mat is not None:
                                t = torch.tensor(mat, device=device, dtype=mod.dtype)
                                mod[:, :, h, :] = torch.matmul(t, mod[:, :, h, :])
                        except Exception:
                            pass
            return (mod.view(b, s, HIDDEN_SIZE).to(output[0].dtype),) + output[1:]
        return hook

    def make_sanity_check_hook(lookup):
        def hook(module, input, output):
            ctx = output[0].contiguous().float()
            b, s, _ = ctx.shape
            mod = ctx.view(b, s, NUM_HEADS, HEAD_DIM).clone()
            eye = torch.eye(s, device=device, dtype=mod.dtype)
            for h in range(NUM_HEADS):
                if (module.layer_id, h) in lookup:
                    mod[:, :, h, :] = torch.matmul(eye, mod[:, :, h, :])
            return (mod.view(b, s, HIDDEN_SIZE).to(output[0].dtype),) + output[1:]
        return hook

    # --- Main loop ---
    print(f"Running with strategy='{strategy}', skip_spikes={skip_spikes}")
    accepted_heads_mapping = []
    k = 0

    for candidate in unique_heads_mapping:
        if k >= max_heads:
            break

        trial_mapping    = accepted_heads_mapping + [candidate]
        iteration_lookup = {tuple(map(int, item[0])): item[1][0] for item in trial_mapping}
        relevant_layers  = set(idx[0] for idx in iteration_lookup)

        iter_model = copy.deepcopy(ref_model)
        iter_model.eval()

        if   strategy == "smart":         hook_fn = make_smart_hook(iteration_lookup, all_programs)
        elif strategy == "baseline":      hook_fn = make_baseline_hook(iteration_lookup)
        elif strategy == "sanity_check":  hook_fn = make_sanity_check_hook(iteration_lookup)
        else: raise ValueError(f"Unknown strategy: '{strategy}'.")

        hook_handles = []
        for l_idx in range(NUM_LAYERS):
            target = iter_model.model.layers[l_idx].self_attn
            target.layer_id = l_idx
            if l_idx in relevant_layers:
                hook_handles.append(target.register_forward_hook(hook_fn))

        replaced_ppls, kl_divs = [], []
        for i, sent in enumerate(eval_sentences):
            active_sent = prepare_sentence(sent, mode="last_word")
            for l_idx in relevant_layers:
                iter_model.model.layers[l_idx].self_attn._current_sentence = active_sent
            toks = tokenizer(active_sent, return_tensors="pt").to(device)
            with torch.no_grad():
                out = iter_model(**toks, labels=toks["input_ids"])
                replaced_ppls.append(torch.exp(out.loss).item())
                kl_divs.append(F.kl_div(
                    F.log_softmax(out.logits[:, -1, :].float(), dim=-1),
                    F.softmax(baseline_logits[i], dim=-1),
                    reduction="batchmean",
                ).item())

        for h in hook_handles: h.remove()
        del iter_model
        torch.cuda.empty_cache()

        mean_pct = np.mean([(r - b) / b * 100 for r, b in zip(replaced_ppls, baseline_ppls)])
        prev_mean = experiment_results[-1]["increase"] if experiment_results else 0.0
        marginal  = mean_pct - prev_mean
        is_spike  = marginal > spike_threshold

        if mean_pct > 1000.0:
            print(f"Perplexity increase exceeded 1000% ({mean_pct:.2f}%). Stopping early.")
            break

        if is_spike and skip_spikes:
            skipped_programs.append({"head": candidate[0], "program": candidate[1][0], "marginal": marginal})
            print(f"  [SKIP] Spike for head {candidate[0]} with marginal {marginal:.2f}%.")
            continue

        k += 1
        accepted_heads_mapping.append(candidate)
        experiment_results.append({
            "k": k, "head": str(candidate[0]), "program": candidate[1][0],
            "strategy": strategy, "increase": mean_pct, "kl_div": np.mean(kl_divs),
            "spike": is_spike,
        })
        print(f"k={k:02d} | Head: {candidate[0]} | Program: {candidate[1][0]} | Mean PPL Inc: {mean_pct:.4f}%")

    pathlib.Path("../results/replacement_run").mkdir(exist_ok=True)
    out_path = save_file or f"../results/replacement_run/llama3b_{strategy}.csv"
    pd.DataFrame(experiment_results).to_csv(out_path, index=False)
    del ref_model
    return pd.DataFrame(experiment_results)

# %%
# ============================================================
# Run head replacement experiments per model
# Expected paths:
#   ../results/best_fits_{model}.csv
#   ../data/generic_sentences.json
# ============================================================

df_generic = pd.read_json("../data/generic_sentences.json")
generic_sentences = df_generic[0].tolist()

for model_key, cfg in MODEL_CONFIGS.items():
    print(f"\n[INFO] Running replacement for {model_key}")
    best_fits_csv = f"{RESULTS_DIR}/best_fits_{model_key}.csv"
    if not os.path.exists(best_fits_csv):
        print(f"[WARN] Missing: {best_fits_csv}. Skipping {model_key}.")
        continue

    existing_files = [f for f in os.listdir("../results/replacement_run") if f.startswith(model_key)]
    if existing_files:
        print(f"[INFO] Found existing replacement results for {model_key}: {existing_files}. Skipping to avoid overwrite.")
        continue

    best_fits_df = pd.read_csv(best_fits_csv)
    best_fits_df = best_fits_df.sort_values(by="iou_score", ascending=False).reset_index(drop=True)

    if model_key == "bert":
        bert_smart = run_replacement_experiment_bert(generic_sentences, best_fits_df, all_programs, strategy="smart")
        bert_baseline = run_replacement_experiment_bert(generic_sentences, best_fits_df, all_programs, strategy="baseline")
    elif model_key == "gpt2":
        gpt2_smart = run_replacement_experiment_gpt2(generic_sentences, best_fits_df, all_programs, strategy="smart")
        gpt2_baseline = run_replacement_experiment_gpt2(generic_sentences, best_fits_df, all_programs, strategy="baseline")
    elif model_key == "tinyllama":
        tinyllama_smart = run_replacement_experiment_llama(generic_sentences, best_fits_df, all_programs, strategy="smart")
        tinyllama_baseline = run_replacement_experiment_llama(generic_sentences, best_fits_df, all_programs, strategy="baseline")
    elif model_key == "llama3b":
        llama3b_smart = run_replacement_experiment_llama3b(generic_sentences, best_fits_df, all_programs, strategy="smart")
        llama3b_baseline = run_replacement_experiment_llama3b(generic_sentences, best_fits_df, all_programs, strategy="baseline")
    else:
        print(f"[WARN] No replacement function defined for {model_key}. Skipping.")

print("\n[DONE] Replacement experiment sweep complete.")
# Out:
# [INFO] Running replacement for bert
# [INFO] Found existing replacement results for bert: ['bert_baseline.csv', 'bert_smart.csv']. Skipping to avoid overwrite.
#
# [INFO] Running replacement for gpt2
# [INFO] Found existing replacement results for gpt2: ['gpt2_baseline.csv', 'gpt2_smart.csv']. Skipping to avoid overwrite.
#
# [INFO] Running replacement for tinyllama
# [INFO] Found existing replacement results for tinyllama: ['tinyllama_baseline.csv', 'tinyllama_smart.csv']. Skipping to avoid overwrite.
#
# [DONE] Replacement experiment sweep complete.

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rcParams

# Set publication-quality parameters
rcParams['font.size'] = 11
rcParams['axes.labelsize'] = 12
rcParams['axes.titlesize'] = 12
rcParams['xtick.labelsize'] = 10
rcParams['ytick.labelsize'] = 10
rcParams['legend.fontsize'] = 10

# Create figure
fig, ax = plt.subplots(figsize=(7, 5))

# Data points - X-axis: 0 to 35 (36 total)
MAX_X = 128
x = np.arange(MAX_X)

total_heads_bert = 144
total_heads_gpt2 = 144
total_heads_tinyllama = 704

bert_file = "../results/replacement_run/bert_smart.csv"
gpt2_file = "../results/replacement_run/gpt2_smart.csv"
tinyllama_file = "../results/replacement_run/tinyllama_smart.csv"
bert_baseline_file = "../results/replacement_run/bert_baseline.csv"
gpt2_baseline_file = "../results/replacement_run/gpt2_baseline.csv"
tinyllama_baseline_file = "../results/replacement_run/tinyllama_baseline.csv"

bert = np.pad(np.array(pd.read_csv(bert_file)["increase"])[:MAX_X], (0, MAX_X - len(np.array(pd.read_csv(bert_file)["increase"])[:MAX_X])), constant_values=1050)
gpt2 = np.pad(np.array(pd.read_csv(gpt2_file)["increase"])[:MAX_X], (0, MAX_X - len(np.array(pd.read_csv(gpt2_file)["increase"])[:MAX_X])), constant_values=1050)
tiny_llama = np.pad(np.array(pd.read_csv(tinyllama_file)["increase"])[:MAX_X], (0, MAX_X - len(np.array(pd.read_csv(tinyllama_file)["increase"])[:MAX_X])), constant_values=1050)
bert_baseline = np.pad(np.array(pd.read_csv(bert_baseline_file)["increase"])[:MAX_X], (0, MAX_X - len(np.array(pd.read_csv(bert_baseline_file)["increase"])[:MAX_X])), constant_values=1050)
gpt2_baseline = np.pad(np.array(pd.read_csv(gpt2_baseline_file)["increase"])[:MAX_X], (0, MAX_X - len(np.array(pd.read_csv(gpt2_baseline_file)["increase"])[:MAX_X])), constant_values=1050)
tinyllama_baseline = np.pad(np.array(pd.read_csv(tinyllama_baseline_file)["increase"])[:MAX_X], (0, MAX_X - len(np.array(pd.read_csv(tinyllama_baseline_file)["increase"])[:MAX_X])), constant_values=1050)

# Plotting lines
ax.plot(x, bert, color='#1E90FF', linewidth=2.5, label='BERT', marker='o',
        markersize=2, markerfacecolor='#1E90FF', markeredgewidth=1.5,
        markeredgecolor='#104E8B', alpha=0.9)

ax.plot(x, gpt2, color='#2F4F4F', linewidth=2.5, label='GPT-2', marker='s',
        markersize=2, markerfacecolor='#2F4F4F', markeredgewidth=1.5,
        markeredgecolor='#1C1C1C', alpha=0.9)

# TinyLlama (dark dark blue)
ax.plot(x, tiny_llama, color='#000033', linewidth=2.5, label='TinyLlama', marker='^',
        markersize=2, markerfacecolor='#000033', markeredgewidth=1.5,
        markeredgecolor='#000011', alpha=0.9)

# Baselines
ax.plot(x, bert_baseline, color='#87CEEB', linestyle='--', linewidth=2, label='BERT Baseline', alpha=0.8)
ax.plot(x, gpt2_baseline, color='#A9A9A9', linestyle='--', linewidth=2, label='GPT-2 Baseline', alpha=0.8)
ax.plot(x, tinyllama_baseline, color='#000080', linestyle='--', linewidth=2, label='TinyLlama Baseline', alpha=0.8)

# Labels and Title
ax.set_xlabel('Number of Heads Replaced', fontweight='bold')
ax.set_ylabel('Normalized Perplexity Increase (%)', fontweight='bold')
ax.set_title('Impact of Attention Head Replacement on Model Perplexity', fontweight='bold', pad=15)

# Limits and Grid
Y_LIM = 250
ax.set_xlim(-1, 36)
ax.set_ylim(-50, Y_LIM)
ax.grid(True, alpha=0.3, linestyle=':', linewidth=0.8)
ax.set_axisbelow(True)

# Ticks
ax.set_xticks(np.arange(0, MAX_X + 1, 12))
ax.set_yticks(np.arange(-50, Y_LIM + 100, 50))

# Legend and background
ax.legend(loc='upper left', frameon=True, shadow=True, fancybox=True)
ax.set_facecolor('#FAFAFA')

plt.tight_layout()
plt.savefig('../results/plots/figure_4_3.pdf', dpi=300, bbox_inches='tight', facecolor='white')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib import rcParams

# Set publication-quality parameters
rcParams['font.size'] = 11
rcParams['axes.labelsize'] = 12
rcParams['axes.titlesize'] = 12
rcParams['xtick.labelsize'] = 10
rcParams['ytick.labelsize'] = 10
rcParams['legend.fontsize'] = 10

# Color mapping (consistent with Figure 4.1)
ROW_COLORS = {
    "bert":       {"box": "#f0a868", "line": "#d4681a"},
    "gpt2":       {"box": "#e07070", "line": "#c0392b"},
    "tinyllama":  {"box": "#7fb3d5", "line": "#1f77b4"},
}
# Create figure
fig, ax = plt.subplots(figsize=(7, 5))

# Constants
MAX_X = 250
x_raw = np.arange(MAX_X)

total_heads_bert = 144
total_heads_gpt2 = 144
total_heads_tinyllama = 704

# Calculate percentage X-axes for each model
x_bert_pct = (x_raw / total_heads_bert) * 100
x_gpt2_pct = (x_raw / total_heads_gpt2) * 100
x_tinyllama_pct = (x_raw / total_heads_tinyllama) * 100

# File paths
bert_file = "../results/replacement_run/bert_smart.csv"
gpt2_file = "../results/replacement_run/gpt2_smart.csv"
tinyllama_file = "../results/replacement_run/tinyllama_smart.csv"
bert_baseline_file = "../results/replacement_run/bert_baseline.csv"
gpt2_baseline_file = "../results/replacement_run/gpt2_baseline.csv"
tinyllama_baseline_file = "../results/replacement_run/tinyllama_baseline.csv"

# Helper function to load data
def load_data(file):
    data = pd.read_csv(file)["increase"].values[:MAX_X]
    return np.pad(data, (0, MAX_X - len(data)), constant_values=1050)

# load in all csv shuffles in ../results/replacement_run/shuffles
all_shuffles = {} # model_key => [[]]
for f in os.listdir("../results/replacement_run/shuffles"):
    if f.startswith("bert_smart_shuffle") and f.endswith(".csv"):
        if all_shuffles.get("bert") is None: 
            all_shuffles["bert"] = []
        all_shuffles["bert"].append(load_data(os.path.join("../results/replacement_run/shuffles", f)))
    elif f.startswith("gpt2_smart_shuffle") and f.endswith(".csv"):
        if all_shuffles.get("gpt2") is None: 
            all_shuffles["gpt2"] = []
        all_shuffles["gpt2"].append(load_data(os.path.join("../results/replacement_run/shuffles", f)))
    elif f.startswith("tinyllama_smart_shuffle") and f.endswith(".csv"):
        if all_shuffles.get("tinyllama") is None: 
            all_shuffles["tinyllama"] = []
        all_shuffles["tinyllama"].append(load_data(os.path.join("../results/replacement_run/shuffles", f)))

bert = load_data(bert_file)
gpt2 = load_data(gpt2_file)
tiny_llama = load_data(tinyllama_file)
bert_baseline = load_data(bert_baseline_file)
gpt2_baseline = load_data(gpt2_baseline_file)
tinyllama_baseline = load_data(tinyllama_baseline_file)

# Plotting lines with individual percentage x-coordinates
ax.plot(x_bert_pct, bert, color=ROW_COLORS["bert"]["line"], linewidth=2.5, label='BERT', marker='o',
        markersize=2, markerfacecolor=ROW_COLORS["bert"]["line"], markeredgewidth=1.5,
        markeredgecolor=ROW_COLORS["bert"]["box"], alpha=0.9)

ax.plot(x_gpt2_pct, gpt2, color=ROW_COLORS["gpt2"]["line"], linewidth=2.5, label='GPT-2', marker='s',
        markersize=2, markerfacecolor=ROW_COLORS["gpt2"]["line"], markeredgewidth=1.5,
        markeredgecolor=ROW_COLORS["gpt2"]["box"], alpha=0.9)

ax.plot(x_tinyllama_pct, tiny_llama, color=ROW_COLORS["tinyllama"]["line"], linewidth=2.5, label='TinyLlama', marker='^',
        markersize=2, markerfacecolor=ROW_COLORS["tinyllama"]["line"], markeredgewidth=1.5,
        markeredgecolor=ROW_COLORS["tinyllama"]["box"], alpha=0.9)

# Baselines (lighter/dashed version using box color)
ax.plot(x_bert_pct, bert_baseline, color=ROW_COLORS["bert"]["box"], linestyle='--', linewidth=2, label='BERT Baseline', alpha=0.8)
ax.plot(x_gpt2_pct, gpt2_baseline, color=ROW_COLORS["gpt2"]["box"], linestyle='--', linewidth=2, label='GPT-2 Baseline', alpha=0.8)
ax.plot(x_tinyllama_pct, tinyllama_baseline, color=ROW_COLORS["tinyllama"]["box"], linestyle='--', linewidth=2, label='TinyLlama Baseline', alpha=0.8)

# Labels and Title
ax.set_xlabel('Percentage of Total Heads Replaced (%)', fontweight='bold')
ax.set_ylabel('Normalized Perplexity Increase (%)', fontweight='bold')
ax.set_title('Impact of Attention Head Replacement on Model Perplexity', fontweight='bold', pad=15)

# Limits and Grid
ax.set_xlim(-1, 30) 
ax.set_ylim(0, 150)
ax.grid(True, alpha=0.3, linestyle=':', linewidth=0.8)
ax.set_axisbelow(True)

# Ticks (every 5%)
ax.set_xticks(np.arange(0, 31, 5))
ax.set_yticks(np.arange(-10, 151, 20))

# Legend and background
ax.legend(loc='upper right', frameon=True, shadow=True, fancybox=True)
ax.set_facecolor('#FAFAFA')

plt.tight_layout()
plt.savefig('../results/plots/figure_4_3.pdf', dpi=300, bbox_inches='tight', facecolor='white')

# %% [markdown]
# ## Figure 4.4: Downstream Evaluation Accuracy Under Head Replacement
#
# Reports benchmark performance across replacement settings to quantify downstream behavior changes after hypothesis-based head substitution.

# %%
# ============================================================
#  Run head replacement experiments
#  Assumes local data directory structure:
#    data/iou_scores_{model}.csv
#    data/generic_sentences.json
#    data/interpolation_k_{model}.csv
# ============================================================

np.random.seed(42)

def constrained_shuffle_df(df, sigma=2.0):
    """
    Shuffles the rows of a DataFrame based on their original 
    index position plus some Gaussian noise.
    """
    temp_df = df.copy().reset_index(drop=True)
    noise = np.random.normal(0, sigma, size=len(temp_df))
    temp_df['shuffle_pos'] = temp_df.index + noise
    shuffled_df = temp_df.sort_values('shuffle_pos').drop(columns=['shuffle_pos'])
    return shuffled_df.reset_index(drop=True)

n_shuffles = 10
os.makedirs("../results/replacement_run/shuffles", exist_ok=True)

for model_key in MODEL_CONFIGS.keys():
    if model_key == "bert": continue
    best_fits_csv = f"{RESULTS_DIR}/best_fits_{model_key}.csv"
    
    if not os.path.exists(best_fits_csv):
        print(f"  [WARN] Missing: {best_fits_csv} — skipping shuffle for {model_key}")
        continue

    original_best_fits = pd.read_csv(best_fits_csv)
    # sort original best fits by best (highest) iou score to bias towards good programs
    original_best_fits = original_best_fits.sort_values(by="iou_score", ascending=False).reset_index(drop=True)
    
    for idx in range(n_shuffles):
        print(f"\n── Running replacement for {model_key} with shuffle {idx+1} ──")
        shuffled_best_fits_df = constrained_shuffle_df(original_best_fits, sigma=2.0)

        save_path = f"../results/replacement_run/shuffles/{model_key}_smart_shuffle_{idx+1}.csv"

        if model_key == "bert":
            run_replacement_experiment_bert(generic_sentences, shuffled_best_fits_df, all_programs, strategy="smart", save_file=save_path)
        elif model_key == "gpt2":
            run_replacement_experiment_gpt2(generic_sentences, shuffled_best_fits_df, all_programs, strategy="smart", save_file=save_path)
        elif model_key == "tinyllama":
            run_replacement_experiment_llama(generic_sentences, shuffled_best_fits_df, all_programs, strategy="smart", save_file=save_path)
# Out:
# ── Running replacement for gpt2 with shuffle 1 ──
# Calculating baseline perplexities...
# Baseline complete. Mean PPL: 43.41
# Running with strategy='smart', skip_spikes=True
# k=01 | Head: (7, 2) | Program: initial_element_reinforcement | Mean PPL Inc: 0.0000%
# k=02 | Head: (5, 1) | Program: cls_attention | Mean PPL Inc: 0.5649%
# k=03 | Head: (6, 9) | Program: initial_element_reinforcement | Mean PPL Inc: 0.5649%
# k=04 | Head: (9, 9) | Program: sentence_beginning_salience | Mean PPL Inc: 0.5127%
# k=05 | Head: (7, 10) | Program: sentence_beginning_salience | Mean PPL Inc: 1.2943%
# k=06 | Head: (4, 11) | Program: previous_attention | Mean PPL Inc: 2.1236%
# k=07 | Head: (10, 10) | Program: sentence_beginning_salience | Mean PPL Inc: 2.6371%
# k=08 | Head: (10, 8) | Program: sentence_beginning_salience | Mean PPL Inc: 2.5862%
# k=09 | Head: (9, 11) | Program: sentence_beginning_salience | Mean PPL Inc: 2.6843%
# k=10 | Head: (9, 6) | Program: sentence_beginning_salience | Mean PPL Inc: 2.8924%
# k=11 | Head: (8, 1) | Program: sentence_beginning_salience | Mean PPL Inc: 3.9708%
#   [SKIP] Spike detected for head (11, 6) with marginal increase of 1861.25%.
# k=12 | Head: (10, 1) | Program: sentence_beginning_salience | Mean PPL Inc: 4.7130%
# k=13 | Head: (10, 6) | Program: sentence_beginning_salience | Mean PPL Inc: 5.1860%
# k=14 | Head: (3, 0) | Program: sentence_beginning_salience | Mean PPL Inc: 5.7965%
# k=15 | Head: (7, 11) | Program: sentence_beginning_salience | Mean PPL Inc: 6.7904%
# k=16 | Head: (9, 4) | Program: sentence_beginning_salience | Mean PPL Inc: 6.3573%
# k=17 | Head: (5, 5) | Program: sentence_beginning_salience | Mean PPL Inc: 6.2132%
# k=18 | Head: (11, 9) | Program: sentence_beginning_salience | Mean PPL Inc: 6.8143%
# k=19 | Head: (9, 1) | Program: sentence_beginning_salience | Mean PPL Inc: 7.7400%
# k=20 | Head: (0, 1) | Program: lexical_diversity_focus | Mean PPL Inc: 7.7464%
# k=21 | Head: (6, 10) | Program: sentence_beginning_salience | Mean PPL Inc: 7.8161%
# k=22 | Head: (10, 2) | Program: sentence_beginning_salience | Mean PPL Inc: 7.9255%
# k=23 | Head: (11, 5) | Program: sentence_beginning_salience | Mean PPL Inc: 7.7261%
#   [SKIP] Spike detected for head (11, 2) with marginal increase of 159.38%.
# k=24 | Head: (7, 7) | Program: sentence_beginning_salience | Mean PPL Inc: 8.0485%
# k=25 | Head: (3, 4) | Program: sentence_beginning_salience | Mean PPL Inc: 8.5856%
# k=26 | Head: (10, 0) | Program: sentence_beginning_salience | Mean PPL Inc: 8.7777%
# k=27 | Head: (5, 9) | Program: sentence_beginning_salience | Mean PPL Inc: 9.3115%
# k=28 | Head: (5, 0) | Program: sentence_beginning_salience | Mean PPL Inc: 10.4988%
# k=29 | Head: (7, 1) | Program: sentence_beginning_salience | Mean PPL Inc: 11.1237%
# k=30 | Head: (9, 5) | Program: token_reinforcement | Mean PPL Inc: 11.1536%
# k=31 | Head: (8, 11) | Program: sentence_beginning_salience | Mean PPL Inc: 11.5633%
# k=32 | Head: (10, 3) | Program: sentence_beginning_salience | Mean PPL Inc: 11.3831%
# k=33 | Head: (8, 3) | Program: token_reinforcement | Mean PPL Inc: 11.1350%
# k=34 | Head: (4, 10) | Program: token_reinforcement | Mean PPL Inc: 11.9596%
# k=35 | Head: (9, 8) | Program: sentence_beginning_salience | Mean PPL Inc: 12.1421%
# k=36 | Head: (6, 6) | Program: token_reinforcement | Mean PPL Inc: 12.2132%
# k=37 | Head: (0, 9) | Program: uniform_lower_diagonal | Mean PPL Inc: 12.6234%
# k=38 | Head: (11, 1) | Program: token_reinforcement | Mean PPL Inc: 12.0683%
# k=39 | Head: (6, 2) | Program: token_reinforcement | Mean PPL Inc: 11.6702%
# k=40 | Head: (7, 6) | Program: token_reinforcement | Mean PPL Inc: 12.4541%
# k=41 | Head: (11, 7) | Program: token_reinforcement | Mean PPL Inc: 12.7199%
# k=42 | Head: (8, 0) | Program: token_reinforcement | Mean PPL Inc: 13.4584%
# k=43 | Head: (0, 5) | Program: lexical_diversity_focus | Mean PPL Inc: 13.4116%
# k=44 | Head: (0, 3) | Program: rare_word_dominance | Mean PPL Inc: 13.4115%
# k=45 | Head: (0, 11) | Program: uniform_lower_diagonal | Mean PPL Inc: 12.4611%
# k=46 | Head: (10, 11) | Program: token_reinforcement | Mean PPL Inc: 12.8298%
# k=47 | Head: (4, 4) | Program: token_reinforcement | Mean PPL Inc: 13.6515%
# k=48 | Head: (8, 6) | Program: sentence_beginning_salience | Mean PPL Inc: 14.4817%
# k=49 | Head: (4, 2) | Program: token_reinforcement | Mean PPL Inc: 14.2024%
# k=50 | Head: (4, 8) | Program: token_reinforcement | Mean PPL Inc: 15.3628%
# k=51 | Head: (9, 0) | Program: token_reinforcement | Mean PPL Inc: 16.3853%
# k=52 | Head: (10, 7) | Program: token_reinforcement | Mean PPL Inc: 17.0514%
# k=53 | Head: (5, 11) | Program: initial_token_reference_attention | Mean PPL Inc: 17.7856%
# k=54 | Head: (9, 2) | Program: token_reinforcement | Mean PPL Inc: 17.3190%
# k=55 | Head: (11, 4) | Program: token_reinforcement | Mean PPL Inc: 17.0774%
# k=56 | Head: (8, 9) | Program: token_reinforcement | Mean PPL Inc: 17.5612%
# k=57 | Head: (5, 8) | Program: token_reinforcement | Mean PPL Inc: 18.9389%
# k=58 | Head: (10, 5) | Program: sentence_beginning_salience | Mean PPL Inc: 18.7459%
# k=59 | Head: (6, 3) | Program: token_reinforcement | Mean PPL Inc: 18.9375%
# k=60 | Head: (9, 7) | Program: token_reinforcement | Mean PPL Inc: 18.9861%
# k=61 | Head: (0, 10) | Program: uniform_lower_diagonal | Mean PPL Inc: 19.1953%
# k=62 | Head: (5, 6) | Program: token_reinforcement | Mean PPL Inc: 20.3109%
# k=63 | Head: (7, 4) | Program: sentence_beginning_salience | Mean PPL Inc: 21.6675%
# k=64 | Head: (3, 10) | Program: initial_token_reference_attention | Mean PPL Inc: 22.5267%
#   [SKIP] Spike detected for head (1, 2) with marginal increase of 55.46%.
# k=65 | Head: (1, 10) | Program: uniform_lower_diagonal | Mean PPL Inc: 22.6309%
# k=66 | Head: (6, 1) | Program: token_reinforcement | Mean PPL Inc: 23.7433%
# k=67 | Head: (0, 2) | Program: uniform_lower_diagonal | Mean PPL Inc: 23.8433%
# k=68 | Head: (11, 0) | Program: uniform_lower_diagonal | Mean PPL Inc: 24.0984%
# k=69 | Head: (8, 10) | Program: token_reinforcement | Mean PPL Inc: 25.5105%
# k=70 | Head: (2, 11) | Program: token_reinforcement | Mean PPL Inc: 24.7483%
# k=71 | Head: (2, 7) | Program: uniform_lower_diagonal | Mean PPL Inc: 24.6427%
# k=72 | Head: (6, 5) | Program: token_reinforcement | Mean PPL Inc: 24.2374%
# k=73 | Head: (5, 7) | Program: token_reinforcement | Mean PPL Inc: 24.2060%
# k=74 | Head: (7, 9) | Program: token_reinforcement | Mean PPL Inc: 25.2954%
# k=75 | Head: (1, 8) | Program: uniform_lower_diagonal | Mean PPL Inc: 25.4804%
# k=76 | Head: (6, 4) | Program: initial_token_reference_attention | Mean PPL Inc: 26.1022%
# k=77 | Head: (1, 7) | Program: uniform_lower_diagonal | Mean PPL Inc: 26.0371%
# k=78 | Head: (7, 3) | Program: token_reinforcement | Mean PPL Inc: 26.2165%
# k=79 | Head: (1, 11) | Program: lexical_diversity_focus | Mean PPL Inc: 26.1052%
# k=80 | Head: (11, 10) | Program: initial_token_reference_attention | Mean PPL Inc: 26.9502%
# k=81 | Head: (2, 1) | Program: token_reinforcement | Mean PPL Inc: 27.6490%
# k=82 | Head: (2, 10) | Program: uniform_lower_diagonal | Mean PPL Inc: 28.2877%
# k=83 | Head: (10, 9) | Program: token_reinforcement | Mean PPL Inc: 30.0924%
# k=84 | Head: (0, 0) | Program: uniform_lower_diagonal | Mean PPL Inc: 30.1160%
# k=85 | Head: (1, 4) | Program: uniform_lower_diagonal | Mean PPL Inc: 30.7760%
# k=86 | Head: (10, 4) | Program: token_reinforcement | Mean PPL Inc: 31.9041%
# k=87 | Head: (8, 4) | Program: token_reinforcement | Mean PPL Inc: 33.2817%
# k=88 | Head: (11, 3) | Program: token_reinforcement | Mean PPL Inc: 33.2246%
# k=89 | Head: (7, 5) | Program: token_reinforcement | Mean PPL Inc: 35.0002%
# k=90 | Head: (0, 8) | Program: uniform_lower_diagonal | Mean PPL Inc: 34.9120%
# k=91 | Head: (5, 10) | Program: token_reinforcement | Mean PPL Inc: 37.1661%
# k=92 | Head: (9, 10) | Program: token_reinforcement | Mean PPL Inc: 38.8790%
# k=93 | Head: (8, 2) | Program: token_reinforcement | Mean PPL Inc: 38.7995%
# k=94 | Head: (8, 8) | Program: token_reinforcement | Mean PPL Inc: 42.0248%
# k=95 | Head: (1, 6) | Program: uniform_lower_diagonal | Mean PPL Inc: 42.1501%
# k=96 | Head: (11, 11) | Program: initial_token_reference_attention | Mean PPL Inc: 41.8284%
# k=97 | Head: (7, 0) | Program: token_reinforcement | Mean PPL Inc: 44.1815%
# k=98 | Head: (0, 6) | Program: uniform_lower_diagonal | Mean PPL Inc: 45.5642%
# k=99 | Head: (2, 2) | Program: previous_attention | Mean PPL Inc: 45.0781%
# k=100 | Head: (4, 7) | Program: first_token_dominance | Mean PPL Inc: 45.9634%
# k=101 | Head: (8, 7) | Program: token_reinforcement | Mean PPL Inc: 47.9651%
# k=102 | Head: (4, 5) | Program: token_reinforcement | Mean PPL Inc: 47.9338%
# k=103 | Head: (7, 8) | Program: token_reinforcement | Mean PPL Inc: 50.5009%
# k=104 | Head: (4, 6) | Program: token_reinforcement | Mean PPL Inc: 51.6515%
# k=105 | Head: (1, 5) | Program: uniform_lower_diagonal | Mean PPL Inc: 52.2576%
# k=106 | Head: (3, 3) | Program: initial_token_reference_attention | Mean PPL Inc: 53.3961%
# k=107 | Head: (9, 3) | Program: initial_token_reference_attention | Mean PPL Inc: 55.0478%
# k=108 | Head: (1, 3) | Program: initial_token_reference_attention | Mean PPL Inc: 56.2480%
# k=109 | Head: (3, 5) | Program: token_reinforcement | Mean PPL Inc: 57.4537%
# k=110 | Head: (6, 7) | Program: token_reinforcement | Mean PPL Inc: 60.4925%
# k=111 | Head: (1, 9) | Program: uniform_lower_diagonal | Mean PPL Inc: 61.6090%
# k=112 | Head: (11, 8) | Program: uniform_lower_diagonal | Mean PPL Inc: 61.6528%
# k=113 | Head: (0, 7) | Program: uniform_lower_diagonal | Mean PPL Inc: 62.5033%
# k=114 | Head: (2, 0) | Program: uniform_lower_diagonal | Mean PPL Inc: 62.1905%
# k=115 | Head: (1, 1) | Program: uniform_lower_diagonal | Mean PPL Inc: 63.9345%
# k=116 | Head: (1, 0) | Program: uniform_lower_diagonal | Mean PPL Inc: 64.7687%
# k=117 | Head: (6, 8) | Program: token_reinforcement | Mean PPL Inc: 67.4480%
# k=118 | Head: (3, 1) | Program: initial_token_reference_attention | Mean PPL Inc: 70.8523%
# k=119 | Head: (6, 11) | Program: token_reinforcement | Mean PPL Inc: 72.9429%
# k=120 | Head: (2, 6) | Program: initial_token_reference_attention | Mean PPL Inc: 74.6717%
# k=121 | Head: (4, 0) | Program: initial_token_reference_attention | Mean PPL Inc: 78.7733%
# k=122 | Head: (5, 3) | Program: uniform_lower_diagonal | Mean PPL Inc: 83.4410%
# k=123 | Head: (5, 4) | Program: token_reinforcement | Mean PPL Inc: 86.3426%
# k=124 | Head: (5, 2) | Program: token_reinforcement | Mean PPL Inc: 86.6239%
# k=125 | Head: (0, 4) | Program: lexical_diversity_focus | Mean PPL Inc: 86.3816%
# k=126 | Head: (4, 9) | Program: sentence_position_preference | Mean PPL Inc: 90.9039%
# k=127 | Head: (3, 6) | Program: uniform_lower_diagonal | Mean PPL Inc: 97.4268%
# k=128 | Head: (8, 5) | Program: token_reinforcement | Mean PPL Inc: 101.9315%
# k=129 | Head: (2, 8) | Program: uniform_lower_diagonal | Mean PPL Inc: 106.0429%
# k=130 | Head: (6, 0) | Program: sentence_position_preference | Mean PPL Inc: 111.3649%
# k=131 | Head: (2, 3) | Program: uniform_lower_diagonal | Mean PPL Inc: 118.2994%
# k=132 | Head: (3, 11) | Program: uniform_lower_diagonal | Mean PPL Inc: 131.0433%
# k=133 | Head: (3, 9) | Program: initial_token_reference_attention | Mean PPL Inc: 140.5102%
# k=134 | Head: (2, 5) | Program: uniform_lower_diagonal | Mean PPL Inc: 156.0866%
# k=135 | Head: (4, 1) | Program: initial_token_reference_attention | Mean PPL Inc: 168.3303%
# k=136 | Head: (2, 9) | Program: uniform_lower_diagonal | Mean PPL Inc: 193.4345%
# k=137 | Head: (3, 7) | Program: previous_attention | Mean PPL Inc: 212.1680%
# k=138 | Head: (4, 3) | Program: initial_token_reference_attention | Mean PPL Inc: 228.5326%
# k=139 | Head: (2, 4) | Program: uniform_lower_diagonal | Mean PPL Inc: 270.2350%
# k=140 | Head: (3, 8) | Program: uniform_lower_diagonal | Mean PPL Inc: 310.2603%
# k=141 | Head: (3, 2) | Program: uniform_lower_diagonal | Mean PPL Inc: 336.0162%
#
# ── Running replacement for gpt2 with shuffle 2 ──
# Calculating baseline perplexities...
# Baseline complete. Mean PPL: 43.41
# Running with strategy='smart', skip_spikes=True
# k=01 | Head: (6, 9) | Program: initial_element_reinforcement | Mean PPL Inc: 0.0000%
# k=02 | Head: (4, 11) | Program: previous_attention | Mean PPL Inc: 0.8622%
# k=03 | Head: (5, 1) | Program: cls_attention | Mean PPL Inc: 1.4041%
# k=04 | Head: (7, 2) | Program: initial_element_reinforcement | Mean PPL Inc: 1.4041%
# k=05 | Head: (9, 9) | Program: sentence_beginning_salience | Mean PPL Inc: 1.3548%
# k=06 | Head: (7, 10) | Program: sentence_beginning_salience | Mean PPL Inc: 2.1236%
# k=07 | Head: (9, 6) | Program: sentence_beginning_salience | Mean PPL Inc: 2.3724%
# k=08 | Head: (10, 10) | Program: sentence_beginning_salience | Mean PPL Inc: 2.8706%
# k=09 | Head: (10, 8) | Program: sentence_beginning_salience | Mean PPL Inc: 2.8103%
# k=10 | Head: (10, 1) | Program: sentence_beginning_salience | Mean PPL Inc: 3.5498%
#   [SKIP] Spike detected for head (11, 6) with marginal increase of 1853.84%.
# k=11 | Head: (9, 11) | Program: sentence_beginning_salience | Mean PPL Inc: 3.6439%
# k=12 | Head: (10, 6) | Program: sentence_beginning_salience | Mean PPL Inc: 4.0774%
# k=13 | Head: (8, 1) | Program: sentence_beginning_salience | Mean PPL Inc: 5.1860%
# k=14 | Head: (9, 4) | Program: sentence_beginning_salience | Mean PPL Inc: 4.7211%
# k=15 | Head: (3, 0) | Program: sentence_beginning_salience | Mean PPL Inc: 5.3562%
# k=16 | Head: (7, 11) | Program: sentence_beginning_salience | Mean PPL Inc: 6.3573%
# k=17 | Head: (5, 5) | Program: sentence_beginning_salience | Mean PPL Inc: 6.2132%
# k=18 | Head: (9, 1) | Program: sentence_beginning_salience | Mean PPL Inc: 7.1371%
# k=19 | Head: (11, 9) | Program: sentence_beginning_salience | Mean PPL Inc: 7.7400%
# k=20 | Head: (6, 10) | Program: sentence_beginning_salience | Mean PPL Inc: 7.8148%
#   [SKIP] Spike detected for head (11, 2) with marginal increase of 158.66%.
# k=21 | Head: (3, 4) | Program: sentence_beginning_salience | Mean PPL Inc: 8.3268%
# k=22 | Head: (11, 5) | Program: sentence_beginning_salience | Mean PPL Inc: 8.1483%
# k=23 | Head: (10, 2) | Program: sentence_beginning_salience | Mean PPL Inc: 8.2494%
# k=24 | Head: (7, 7) | Program: sentence_beginning_salience | Mean PPL Inc: 8.5935%
# k=25 | Head: (5, 9) | Program: sentence_beginning_salience | Mean PPL Inc: 9.1347%
# k=26 | Head: (0, 1) | Program: lexical_diversity_focus | Mean PPL Inc: 9.1247%
# k=27 | Head: (10, 0) | Program: sentence_beginning_salience | Mean PPL Inc: 9.3115%
# k=28 | Head: (5, 0) | Program: sentence_beginning_salience | Mean PPL Inc: 10.4988%
# k=29 | Head: (7, 1) | Program: sentence_beginning_salience | Mean PPL Inc: 11.1237%
# k=30 | Head: (8, 11) | Program: sentence_beginning_salience | Mean PPL Inc: 11.5747%
# k=31 | Head: (4, 10) | Program: token_reinforcement | Mean PPL Inc: 12.3615%
# k=32 | Head: (6, 6) | Program: token_reinforcement | Mean PPL Inc: 12.4102%
# k=33 | Head: (8, 3) | Program: token_reinforcement | Mean PPL Inc: 12.0878%
# k=34 | Head: (9, 8) | Program: sentence_beginning_salience | Mean PPL Inc: 12.2001%
# k=35 | Head: (9, 5) | Program: token_reinforcement | Mean PPL Inc: 12.2627%
# k=36 | Head: (0, 9) | Program: uniform_lower_diagonal | Mean PPL Inc: 12.6776%
# k=37 | Head: (11, 7) | Program: token_reinforcement | Mean PPL Inc: 12.3393%
# k=38 | Head: (11, 1) | Program: token_reinforcement | Mean PPL Inc: 12.3607%
# k=39 | Head: (10, 3) | Program: sentence_beginning_salience | Mean PPL Inc: 12.4201%
# k=40 | Head: (0, 3) | Program: rare_word_dominance | Mean PPL Inc: 12.4201%
# k=41 | Head: (6, 2) | Program: token_reinforcement | Mean PPL Inc: 11.9846%
# k=42 | Head: (7, 6) | Program: token_reinforcement | Mean PPL Inc: 12.7200%
# k=43 | Head: (0, 5) | Program: lexical_diversity_focus | Mean PPL Inc: 12.6704%
# k=44 | Head: (8, 0) | Program: token_reinforcement | Mean PPL Inc: 13.4115%
# k=45 | Head: (0, 11) | Program: uniform_lower_diagonal | Mean PPL Inc: 12.4611%
# k=46 | Head: (10, 11) | Program: token_reinforcement | Mean PPL Inc: 12.8298%
# k=47 | Head: (4, 4) | Program: token_reinforcement | Mean PPL Inc: 13.6515%
# k=48 | Head: (8, 6) | Program: sentence_beginning_salience | Mean PPL Inc: 14.4817%
# k=49 | Head: (4, 8) | Program: token_reinforcement | Mean PPL Inc: 15.6197%
# k=50 | Head: (9, 0) | Program: token_reinforcement | Mean PPL Inc: 16.6410%
# k=51 | Head: (4, 2) | Program: token_reinforcement | Mean PPL Inc: 16.3853%
# k=52 | Head: (8, 9) | Program: token_reinforcement | Mean PPL Inc: 16.7565%
# k=53 | Head: (10, 7) | Program: token_reinforcement | Mean PPL Inc: 17.4876%
# k=54 | Head: (9, 2) | Program: token_reinforcement | Mean PPL Inc: 17.0344%
# k=55 | Head: (5, 11) | Program: initial_token_reference_attention | Mean PPL Inc: 17.8047%
# k=56 | Head: (10, 5) | Program: sentence_beginning_salience | Mean PPL Inc: 17.5677%
# k=57 | Head: (11, 4) | Program: token_reinforcement | Mean PPL Inc: 17.3586%
# k=58 | Head: (0, 10) | Program: uniform_lower_diagonal | Mean PPL Inc: 17.5313%
# k=59 | Head: (5, 8) | Program: token_reinforcement | Mean PPL Inc: 18.9002%
# k=60 | Head: (5, 6) | Program: token_reinforcement | Mean PPL Inc: 20.0275%
# k=61 | Head: (6, 3) | Program: token_reinforcement | Mean PPL Inc: 20.2249%
# k=62 | Head: (9, 7) | Program: token_reinforcement | Mean PPL Inc: 20.3109%
# k=63 | Head: (7, 4) | Program: sentence_beginning_salience | Mean PPL Inc: 21.6675%
# k=64 | Head: (3, 10) | Program: initial_token_reference_attention | Mean PPL Inc: 22.5267%
# k=65 | Head: (11, 0) | Program: uniform_lower_diagonal | Mean PPL Inc: 22.7629%
# k=66 | Head: (8, 10) | Program: token_reinforcement | Mean PPL Inc: 24.1559%
# k=67 | Head: (6, 1) | Program: token_reinforcement | Mean PPL Inc: 25.2682%
#   [SKIP] Spike detected for head (1, 2) with marginal increase of 55.71%.
# k=68 | Head: (2, 11) | Program: token_reinforcement | Mean PPL Inc: 24.5315%
# k=69 | Head: (2, 7) | Program: uniform_lower_diagonal | Mean PPL Inc: 24.4423%
# k=70 | Head: (5, 7) | Program: token_reinforcement | Mean PPL Inc: 24.4098%
# k=71 | Head: (1, 10) | Program: uniform_lower_diagonal | Mean PPL Inc: 24.4560%
# k=72 | Head: (0, 2) | Program: uniform_lower_diagonal | Mean PPL Inc: 24.5862%
# k=73 | Head: (1, 8) | Program: uniform_lower_diagonal | Mean PPL Inc: 24.7828%
# k=74 | Head: (6, 4) | Program: initial_token_reference_attention | Mean PPL Inc: 25.3984%
# k=75 | Head: (6, 5) | Program: token_reinforcement | Mean PPL Inc: 25.0300%
# k=76 | Head: (7, 3) | Program: token_reinforcement | Mean PPL Inc: 25.0561%
# k=77 | Head: (1, 7) | Program: uniform_lower_diagonal | Mean PPL Inc: 24.9597%
# k=78 | Head: (7, 9) | Program: token_reinforcement | Mean PPL Inc: 26.2165%
# k=79 | Head: (11, 10) | Program: initial_token_reference_attention | Mean PPL Inc: 27.0604%
# k=80 | Head: (10, 9) | Program: token_reinforcement | Mean PPL Inc: 28.8498%
# k=81 | Head: (2, 1) | Program: token_reinforcement | Mean PPL Inc: 29.5763%
# k=82 | Head: (1, 11) | Program: lexical_diversity_focus | Mean PPL Inc: 29.4362%
# k=83 | Head: (10, 4) | Program: token_reinforcement | Mean PPL Inc: 30.5703%
# k=84 | Head: (2, 10) | Program: uniform_lower_diagonal | Mean PPL Inc: 31.2236%
# k=85 | Head: (1, 4) | Program: uniform_lower_diagonal | Mean PPL Inc: 31.9294%
# k=86 | Head: (8, 4) | Program: token_reinforcement | Mean PPL Inc: 33.3652%
# k=87 | Head: (7, 5) | Program: token_reinforcement | Mean PPL Inc: 35.1707%
# k=88 | Head: (0, 0) | Program: uniform_lower_diagonal | Mean PPL Inc: 35.0507%
# k=89 | Head: (9, 10) | Program: token_reinforcement | Mean PPL Inc: 36.7281%
# k=90 | Head: (8, 2) | Program: token_reinforcement | Mean PPL Inc: 36.6139%
# k=91 | Head: (5, 10) | Program: token_reinforcement | Mean PPL Inc: 38.9444%
# k=92 | Head: (11, 3) | Program: token_reinforcement | Mean PPL Inc: 38.8381%
# k=93 | Head: (8, 8) | Program: token_reinforcement | Mean PPL Inc: 42.0771%
# k=94 | Head: (0, 8) | Program: uniform_lower_diagonal | Mean PPL Inc: 42.0248%
# k=95 | Head: (11, 11) | Program: initial_token_reference_attention | Mean PPL Inc: 41.6934%
# k=96 | Head: (1, 6) | Program: uniform_lower_diagonal | Mean PPL Inc: 41.8284%
# k=97 | Head: (7, 0) | Program: token_reinforcement | Mean PPL Inc: 44.1815%
# k=98 | Head: (2, 2) | Program: previous_attention | Mean PPL Inc: 43.7181%
# k=99 | Head: (0, 6) | Program: uniform_lower_diagonal | Mean PPL Inc: 45.0781%
# k=100 | Head: (4, 7) | Program: first_token_dominance | Mean PPL Inc: 45.9634%
# k=101 | Head: (8, 7) | Program: token_reinforcement | Mean PPL Inc: 47.9651%
# k=102 | Head: (1, 3) | Program: initial_token_reference_attention | Mean PPL Inc: 48.7694%
# k=103 | Head: (7, 8) | Program: token_reinforcement | Mean PPL Inc: 51.3276%
# k=104 | Head: (4, 6) | Program: token_reinforcement | Mean PPL Inc: 52.4779%
# k=105 | Head: (4, 5) | Program: token_reinforcement | Mean PPL Inc: 52.4475%
# k=106 | Head: (1, 5) | Program: uniform_lower_diagonal | Mean PPL Inc: 53.1545%
# k=107 | Head: (3, 5) | Program: token_reinforcement | Mean PPL Inc: 54.2312%
# k=108 | Head: (9, 3) | Program: initial_token_reference_attention | Mean PPL Inc: 55.8341%
# k=109 | Head: (3, 1) | Program: initial_token_reference_attention | Mean PPL Inc: 57.8723%
# k=110 | Head: (1, 1) | Program: uniform_lower_diagonal | Mean PPL Inc: 59.2133%
# k=111 | Head: (3, 3) | Program: initial_token_reference_attention | Mean PPL Inc: 61.2345%
# k=112 | Head: (2, 0) | Program: uniform_lower_diagonal | Mean PPL Inc: 61.1207%
# k=113 | Head: (6, 7) | Program: token_reinforcement | Mean PPL Inc: 64.2804%
# k=114 | Head: (1, 9) | Program: uniform_lower_diagonal | Mean PPL Inc: 65.5400%
# k=115 | Head: (0, 7) | Program: uniform_lower_diagonal | Mean PPL Inc: 67.0799%
# k=116 | Head: (11, 8) | Program: uniform_lower_diagonal | Mean PPL Inc: 67.0793%
# k=117 | Head: (6, 11) | Program: token_reinforcement | Mean PPL Inc: 68.8901%
# k=118 | Head: (1, 0) | Program: uniform_lower_diagonal | Mean PPL Inc: 69.8978%
# k=119 | Head: (2, 6) | Program: initial_token_reference_attention | Mean PPL Inc: 71.7560%
# k=120 | Head: (6, 8) | Program: token_reinforcement | Mean PPL Inc: 74.6717%
# k=121 | Head: (5, 4) | Program: token_reinforcement | Mean PPL Inc: 77.2454%
# k=122 | Head: (5, 2) | Program: token_reinforcement | Mean PPL Inc: 77.3017%
# k=123 | Head: (8, 5) | Program: token_reinforcement | Mean PPL Inc: 81.4076%
# k=124 | Head: (5, 3) | Program: uniform_lower_diagonal | Mean PPL Inc: 86.3947%
# k=125 | Head: (0, 4) | Program: lexical_diversity_focus | Mean PPL Inc: 86.1518%
# k=126 | Head: (4, 0) | Program: initial_token_reference_attention | Mean PPL Inc: 90.6314%
# k=127 | Head: (4, 9) | Program: sentence_position_preference | Mean PPL Inc: 95.1899%
# k=128 | Head: (3, 6) | Program: uniform_lower_diagonal | Mean PPL Inc: 101.9315%
# k=129 | Head: (3, 11) | Program: uniform_lower_diagonal | Mean PPL Inc: 109.7659%
# k=130 | Head: (6, 0) | Program: sentence_position_preference | Mean PPL Inc: 115.5967%
# k=131 | Head: (2, 8) | Program: uniform_lower_diagonal | Mean PPL Inc: 122.2881%
# k=132 | Head: (2, 3) | Program: uniform_lower_diagonal | Mean PPL Inc: 131.0433%
# k=133 | Head: (2, 9) | Program: uniform_lower_diagonal | Mean PPL Inc: 147.6038%
# k=134 | Head: (3, 9) | Program: initial_token_reference_attention | Mean PPL Inc: 159.6525%
# k=135 | Head: (4, 1) | Program: initial_token_reference_attention | Mean PPL Inc: 172.6640%
# k=136 | Head: (3, 2) | Program: uniform_lower_diagonal | Mean PPL Inc: 185.0701%
# k=137 | Head: (2, 5) | Program: uniform_lower_diagonal | Mean PPL Inc: 207.9929%
# k=138 | Head: (4, 3) | Program: initial_token_reference_attention | Mean PPL Inc: 224.3607%
# k=139 | Head: (3, 7) | Program: previous_attention | Mean PPL Inc: 248.2167%
# k=140 | Head: (3, 8) | Program: uniform_lower_diagonal | Mean PPL Inc: 286.1215%
# k=141 | Head: (2, 4) | Program: uniform_lower_diagonal | Mean PPL Inc: 336.0162%
#
# ── Running replacement for gpt2 with shuffle 3 ──
# Calculating baseline perplexities...
# Baseline complete. Mean PPL: 43.41
# Running with strategy='smart', skip_spikes=True
# k=01 | Head: (7, 2) | Program: initial_element_reinforcement | Mean PPL Inc: 0.0000%
# k=02 | Head: (5, 1) | Program: cls_attention | Mean PPL Inc: 0.5649%
# k=03 | Head: (6, 9) | Program: initial_element_reinforcement | Mean PPL Inc: 0.5649%
# k=04 | Head: (4, 11) | Program: previous_attention | Mean PPL Inc: 1.4041%
# k=05 | Head: (9, 9) | Program: sentence_beginning_salience | Mean PPL Inc: 1.3548%
# k=06 | Head: (10, 8) | Program: sentence_beginning_salience | Mean PPL Inc: 1.2765%
# k=07 | Head: (7, 10) | Program: sentence_beginning_salience | Mean PPL Inc: 2.0457%
# k=08 | Head: (9, 6) | Program: sentence_beginning_salience | Mean PPL Inc: 2.2844%
# k=09 | Head: (10, 1) | Program: sentence_beginning_salience | Mean PPL Inc: 3.0197%
# k=10 | Head: (10, 10) | Program: sentence_beginning_salience | Mean PPL Inc: 3.5498%
# k=11 | Head: (3, 0) | Program: sentence_beginning_salience | Mean PPL Inc: 4.1346%
# k=12 | Head: (9, 11) | Program: sentence_beginning_salience | Mean PPL Inc: 4.2328%
# k=13 | Head: (8, 1) | Program: sentence_beginning_salience | Mean PPL Inc: 5.3241%
#   [SKIP] Spike detected for head (11, 6) with marginal increase of 1867.37%.
# k=14 | Head: (10, 6) | Program: sentence_beginning_salience | Mean PPL Inc: 5.7965%
# k=15 | Head: (9, 4) | Program: sentence_beginning_salience | Mean PPL Inc: 5.3562%
# k=16 | Head: (7, 11) | Program: sentence_beginning_salience | Mean PPL Inc: 6.3573%
# k=17 | Head: (9, 1) | Program: sentence_beginning_salience | Mean PPL Inc: 7.2805%
# k=18 | Head: (5, 5) | Program: sentence_beginning_salience | Mean PPL Inc: 7.1371%
# k=19 | Head: (11, 9) | Program: sentence_beginning_salience | Mean PPL Inc: 7.7400%
# k=20 | Head: (6, 10) | Program: sentence_beginning_salience | Mean PPL Inc: 7.8148%
#   [SKIP] Spike detected for head (11, 2) with marginal increase of 158.66%.
# k=21 | Head: (10, 2) | Program: sentence_beginning_salience | Mean PPL Inc: 7.9236%
# k=22 | Head: (0, 1) | Program: lexical_diversity_focus | Mean PPL Inc: 7.9255%
# k=23 | Head: (11, 5) | Program: sentence_beginning_salience | Mean PPL Inc: 7.7261%
# k=24 | Head: (3, 4) | Program: sentence_beginning_salience | Mean PPL Inc: 8.2485%
# k=25 | Head: (5, 9) | Program: sentence_beginning_salience | Mean PPL Inc: 8.8045%
# k=26 | Head: (5, 0) | Program: sentence_beginning_salience | Mean PPL Inc: 9.9390%
# k=27 | Head: (7, 7) | Program: sentence_beginning_salience | Mean PPL Inc: 10.3038%
# k=28 | Head: (10, 0) | Program: sentence_beginning_salience | Mean PPL Inc: 10.4988%
# k=29 | Head: (7, 1) | Program: sentence_beginning_salience | Mean PPL Inc: 11.1237%
# k=30 | Head: (4, 10) | Program: token_reinforcement | Mean PPL Inc: 11.9311%
# k=31 | Head: (8, 11) | Program: sentence_beginning_salience | Mean PPL Inc: 12.3615%
# k=32 | Head: (6, 6) | Program: token_reinforcement | Mean PPL Inc: 12.4102%
# k=33 | Head: (0, 9) | Program: uniform_lower_diagonal | Mean PPL Inc: 12.7788%
# k=34 | Head: (9, 5) | Program: token_reinforcement | Mean PPL Inc: 12.8335%
# k=35 | Head: (8, 3) | Program: token_reinforcement | Mean PPL Inc: 12.5359%
# k=36 | Head: (10, 3) | Program: sentence_beginning_salience | Mean PPL Inc: 12.4863%
# k=37 | Head: (9, 8) | Program: sentence_beginning_salience | Mean PPL Inc: 12.6234%
# k=38 | Head: (11, 1) | Program: token_reinforcement | Mean PPL Inc: 12.0683%
# k=39 | Head: (0, 5) | Program: lexical_diversity_focus | Mean PPL Inc: 12.0232%
# k=40 | Head: (11, 7) | Program: token_reinforcement | Mean PPL Inc: 12.3736%
# k=41 | Head: (8, 0) | Program: token_reinforcement | Mean PPL Inc: 13.0492%
# k=42 | Head: (7, 6) | Program: token_reinforcement | Mean PPL Inc: 13.7461%
# k=43 | Head: (0, 3) | Program: rare_word_dominance | Mean PPL Inc: 13.7461%
# k=44 | Head: (6, 2) | Program: token_reinforcement | Mean PPL Inc: 13.4115%
# k=45 | Head: (4, 4) | Program: token_reinforcement | Mean PPL Inc: 14.1941%
# k=46 | Head: (8, 6) | Program: sentence_beginning_salience | Mean PPL Inc: 14.9905%
# k=47 | Head: (0, 11) | Program: uniform_lower_diagonal | Mean PPL Inc: 14.0741%
# k=48 | Head: (10, 11) | Program: token_reinforcement | Mean PPL Inc: 14.4817%
# k=49 | Head: (4, 2) | Program: token_reinforcement | Mean PPL Inc: 14.2024%
# k=50 | Head: (4, 8) | Program: token_reinforcement | Mean PPL Inc: 15.3628%
# k=51 | Head: (9, 0) | Program: token_reinforcement | Mean PPL Inc: 16.3853%
# k=52 | Head: (10, 7) | Program: token_reinforcement | Mean PPL Inc: 17.0514%
# k=53 | Head: (8, 9) | Program: token_reinforcement | Mean PPL Inc: 17.4876%
# k=54 | Head: (9, 2) | Program: token_reinforcement | Mean PPL Inc: 17.0344%
# k=55 | Head: (5, 11) | Program: initial_token_reference_attention | Mean PPL Inc: 17.8047%
# k=56 | Head: (5, 8) | Program: token_reinforcement | Mean PPL Inc: 19.1948%
# k=57 | Head: (5, 6) | Program: token_reinforcement | Mean PPL Inc: 20.2466%
# k=58 | Head: (11, 4) | Program: token_reinforcement | Mean PPL Inc: 20.0075%
# k=59 | Head: (10, 5) | Program: sentence_beginning_salience | Mean PPL Inc: 19.8105%
# k=60 | Head: (0, 10) | Program: uniform_lower_diagonal | Mean PPL Inc: 20.0275%
# k=61 | Head: (6, 3) | Program: token_reinforcement | Mean PPL Inc: 20.2249%
# k=62 | Head: (1, 10) | Program: uniform_lower_diagonal | Mean PPL Inc: 20.3082%
# k=63 | Head: (11, 0) | Program: uniform_lower_diagonal | Mean PPL Inc: 20.5035%
# k=64 | Head: (7, 4) | Program: sentence_beginning_salience | Mean PPL Inc: 21.8705%
# k=65 | Head: (9, 7) | Program: token_reinforcement | Mean PPL Inc: 21.9908%
# k=66 | Head: (3, 10) | Program: initial_token_reference_attention | Mean PPL Inc: 22.8768%
# k=67 | Head: (6, 1) | Program: token_reinforcement | Mean PPL Inc: 23.9793%
#   [SKIP] Spike detected for head (1, 2) with marginal increase of 54.97%.
# k=68 | Head: (2, 7) | Program: uniform_lower_diagonal | Mean PPL Inc: 23.9451%
# k=69 | Head: (8, 10) | Program: token_reinforcement | Mean PPL Inc: 25.2855%
# k=70 | Head: (2, 11) | Program: token_reinforcement | Mean PPL Inc: 24.4950%
# k=71 | Head: (0, 2) | Program: uniform_lower_diagonal | Mean PPL Inc: 24.6427%
# k=72 | Head: (6, 4) | Program: initial_token_reference_attention | Mean PPL Inc: 25.2621%
# k=73 | Head: (5, 7) | Program: token_reinforcement | Mean PPL Inc: 25.1923%
# k=74 | Head: (1, 8) | Program: uniform_lower_diagonal | Mean PPL Inc: 25.3984%
# k=75 | Head: (7, 9) | Program: token_reinforcement | Mean PPL Inc: 26.4824%
# k=76 | Head: (1, 7) | Program: uniform_lower_diagonal | Mean PPL Inc: 26.4216%
# k=77 | Head: (6, 5) | Program: token_reinforcement | Mean PPL Inc: 26.0371%
# k=78 | Head: (1, 11) | Program: lexical_diversity_focus | Mean PPL Inc: 25.9290%
# k=79 | Head: (7, 3) | Program: token_reinforcement | Mean PPL Inc: 26.1052%
# k=80 | Head: (10, 9) | Program: token_reinforcement | Mean PPL Inc: 27.8616%
# k=81 | Head: (11, 10) | Program: initial_token_reference_attention | Mean PPL Inc: 28.7362%
# k=82 | Head: (1, 4) | Program: uniform_lower_diagonal | Mean PPL Inc: 29.4078%
# k=83 | Head: (2, 1) | Program: token_reinforcement | Mean PPL Inc: 30.1307%
# k=84 | Head: (2, 10) | Program: uniform_lower_diagonal | Mean PPL Inc: 30.8080%
# k=85 | Head: (8, 4) | Program: token_reinforcement | Mean PPL Inc: 32.0521%
# k=86 | Head: (9, 10) | Program: token_reinforcement | Mean PPL Inc: 33.5084%
# k=87 | Head: (0, 0) | Program: uniform_lower_diagonal | Mean PPL Inc: 33.4393%
# k=88 | Head: (8, 2) | Program: token_reinforcement | Mean PPL Inc: 33.3731%
# k=89 | Head: (10, 4) | Program: token_reinforcement | Mean PPL Inc: 34.8084%
# k=90 | Head: (7, 5) | Program: token_reinforcement | Mean PPL Inc: 36.6139%
# k=91 | Head: (5, 10) | Program: token_reinforcement | Mean PPL Inc: 38.9444%
# k=92 | Head: (0, 8) | Program: uniform_lower_diagonal | Mean PPL Inc: 38.9140%
# k=93 | Head: (11, 3) | Program: token_reinforcement | Mean PPL Inc: 38.7995%
# k=94 | Head: (8, 8) | Program: token_reinforcement | Mean PPL Inc: 42.0248%
# k=95 | Head: (11, 11) | Program: initial_token_reference_attention | Mean PPL Inc: 41.6934%
# k=96 | Head: (7, 0) | Program: token_reinforcement | Mean PPL Inc: 44.0187%
# k=97 | Head: (2, 2) | Program: previous_attention | Mean PPL Inc: 43.4639%
# k=98 | Head: (4, 7) | Program: first_token_dominance | Mean PPL Inc: 44.2461%
# k=99 | Head: (4, 5) | Program: token_reinforcement | Mean PPL Inc: 44.1622%
# k=100 | Head: (1, 6) | Program: uniform_lower_diagonal | Mean PPL Inc: 44.4931%
# k=101 | Head: (0, 6) | Program: uniform_lower_diagonal | Mean PPL Inc: 45.9142%
# k=102 | Head: (8, 7) | Program: token_reinforcement | Mean PPL Inc: 47.9338%
# k=103 | Head: (3, 3) | Program: initial_token_reference_attention | Mean PPL Inc: 49.1217%
# k=104 | Head: (1, 5) | Program: uniform_lower_diagonal | Mean PPL Inc: 49.7309%
# k=105 | Head: (1, 3) | Program: initial_token_reference_attention | Mean PPL Inc: 50.9207%
# k=106 | Head: (7, 8) | Program: token_reinforcement | Mean PPL Inc: 53.3858%
# k=107 | Head: (6, 7) | Program: token_reinforcement | Mean PPL Inc: 55.9892%
# k=108 | Head: (4, 6) | Program: token_reinforcement | Mean PPL Inc: 57.2486%
# k=109 | Head: (9, 3) | Program: initial_token_reference_attention | Mean PPL Inc: 59.0490%
# k=110 | Head: (1, 1) | Program: uniform_lower_diagonal | Mean PPL Inc: 60.3459%
# k=111 | Head: (3, 5) | Program: token_reinforcement | Mean PPL Inc: 61.8514%
# k=112 | Head: (1, 9) | Program: uniform_lower_diagonal | Mean PPL Inc: 63.0389%
# k=113 | Head: (0, 7) | Program: uniform_lower_diagonal | Mean PPL Inc: 64.1164%
# k=114 | Head: (2, 0) | Program: uniform_lower_diagonal | Mean PPL Inc: 63.9533%
# k=115 | Head: (3, 1) | Program: initial_token_reference_attention | Mean PPL Inc: 67.0799%
# k=116 | Head: (11, 8) | Program: uniform_lower_diagonal | Mean PPL Inc: 67.0793%
# k=117 | Head: (6, 11) | Program: token_reinforcement | Mean PPL Inc: 68.8901%
# k=118 | Head: (2, 6) | Program: initial_token_reference_attention | Mean PPL Inc: 70.7136%
# k=119 | Head: (6, 8) | Program: token_reinforcement | Mean PPL Inc: 73.5717%
# k=120 | Head: (5, 4) | Program: token_reinforcement | Mean PPL Inc: 76.0067%
# k=121 | Head: (1, 0) | Program: uniform_lower_diagonal | Mean PPL Inc: 77.2454%
# k=122 | Head: (5, 3) | Program: uniform_lower_diagonal | Mean PPL Inc: 82.0855%
# k=123 | Head: (5, 2) | Program: token_reinforcement | Mean PPL Inc: 82.1764%
# k=124 | Head: (4, 0) | Program: initial_token_reference_attention | Mean PPL Inc: 86.6239%
# k=125 | Head: (8, 5) | Program: token_reinforcement | Mean PPL Inc: 90.8195%
# k=126 | Head: (4, 9) | Program: sentence_position_preference | Mean PPL Inc: 95.3883%
# k=127 | Head: (3, 6) | Program: uniform_lower_diagonal | Mean PPL Inc: 102.0648%
# k=128 | Head: (6, 0) | Program: sentence_position_preference | Mean PPL Inc: 107.1166%
# k=129 | Head: (0, 4) | Program: lexical_diversity_focus | Mean PPL Inc: 106.9803%
# k=130 | Head: (2, 3) | Program: uniform_lower_diagonal | Mean PPL Inc: 111.9568%
# k=131 | Head: (4, 3) | Program: initial_token_reference_attention | Mean PPL Inc: 117.8761%
# k=132 | Head: (2, 8) | Program: uniform_lower_diagonal | Mean PPL Inc: 125.3875%
# k=133 | Head: (3, 11) | Program: uniform_lower_diagonal | Mean PPL Inc: 139.5115%
# k=134 | Head: (2, 9) | Program: uniform_lower_diagonal | Mean PPL Inc: 157.5243%
# k=135 | Head: (3, 9) | Program: initial_token_reference_attention | Mean PPL Inc: 171.1864%
# k=136 | Head: (3, 2) | Program: uniform_lower_diagonal | Mean PPL Inc: 183.5043%
# k=137 | Head: (3, 8) | Program: uniform_lower_diagonal | Mean PPL Inc: 209.3177%
# k=138 | Head: (3, 7) | Program: previous_attention | Mean PPL Inc: 231.1089%
# k=139 | Head: (2, 5) | Program: uniform_lower_diagonal | Mean PPL Inc: 261.2088%
# k=140 | Head: (4, 1) | Program: initial_token_reference_attention | Mean PPL Inc: 286.1215%
# k=141 | Head: (2, 4) | Program: uniform_lower_diagonal | Mean PPL Inc: 336.0162%
#
# ── Running replacement for gpt2 with shuffle 4 ──
# Calculating baseline perplexities...
# Baseline complete. Mean PPL: 43.41
# Running with strategy='smart', skip_spikes=True
# k=01 | Head: (5, 1) | Program: cls_attention | Mean PPL Inc: 0.5649%
# k=02 | Head: (7, 10) | Program: sentence_beginning_salience | Mean PPL Inc: 1.3425%
# k=03 | Head: (7, 2) | Program: initial_element_reinforcement | Mean PPL Inc: 1.3425%
# k=04 | Head: (9, 6) | Program: sentence_beginning_salience | Mean PPL Inc: 1.6157%
# k=05 | Head: (4, 11) | Program: previous_attention | Mean PPL Inc: 2.4261%
# k=06 | Head: (6, 9) | Program: initial_element_reinforcement | Mean PPL Inc: 2.4261%
# k=07 | Head: (9, 11) | Program: sentence_beginning_salience | Mean PPL Inc: 2.5289%
# k=08 | Head: (10, 8) | Program: sentence_beginning_salience | Mean PPL Inc: 2.4663%
# k=09 | Head: (9, 9) | Program: sentence_beginning_salience | Mean PPL Inc: 2.3616%
# k=10 | Head: (10, 10) | Program: sentence_beginning_salience | Mean PPL Inc: 2.8924%
# k=11 | Head: (10, 1) | Program: sentence_beginning_salience | Mean PPL Inc: 3.6439%
# k=12 | Head: (3, 0) | Program: sentence_beginning_salience | Mean PPL Inc: 4.2328%
#   [SKIP] Spike detected for head (11, 6) with marginal increase of 1866.05%.
# k=13 | Head: (7, 11) | Program: sentence_beginning_salience | Mean PPL Inc: 5.2359%
# k=14 | Head: (8, 1) | Program: sentence_beginning_salience | Mean PPL Inc: 6.2910%
# k=15 | Head: (10, 6) | Program: sentence_beginning_salience | Mean PPL Inc: 6.7904%
# k=16 | Head: (9, 1) | Program: sentence_beginning_salience | Mean PPL Inc: 7.7067%
# k=17 | Head: (9, 4) | Program: sentence_beginning_salience | Mean PPL Inc: 7.2805%
# k=18 | Head: (11, 9) | Program: sentence_beginning_salience | Mean PPL Inc: 7.9166%
#   [SKIP] Spike detected for head (11, 2) with marginal increase of 158.86%.
# k=19 | Head: (5, 5) | Program: sentence_beginning_salience | Mean PPL Inc: 7.7400%
# k=20 | Head: (10, 2) | Program: sentence_beginning_salience | Mean PPL Inc: 7.9004%
# k=21 | Head: (0, 1) | Program: lexical_diversity_focus | Mean PPL Inc: 7.9077%
# k=22 | Head: (6, 10) | Program: sentence_beginning_salience | Mean PPL Inc: 7.9255%
# k=23 | Head: (3, 4) | Program: sentence_beginning_salience | Mean PPL Inc: 8.4545%
# k=24 | Head: (11, 5) | Program: sentence_beginning_salience | Mean PPL Inc: 8.2485%
# k=25 | Head: (5, 9) | Program: sentence_beginning_salience | Mean PPL Inc: 8.8045%
# k=26 | Head: (7, 7) | Program: sentence_beginning_salience | Mean PPL Inc: 9.1247%
# k=27 | Head: (7, 1) | Program: sentence_beginning_salience | Mean PPL Inc: 9.7698%
# k=28 | Head: (5, 0) | Program: sentence_beginning_salience | Mean PPL Inc: 10.9026%
# k=29 | Head: (4, 10) | Program: token_reinforcement | Mean PPL Inc: 11.7076%
# k=30 | Head: (8, 11) | Program: sentence_beginning_salience | Mean PPL Inc: 12.0992%
# k=31 | Head: (10, 0) | Program: sentence_beginning_salience | Mean PPL Inc: 12.3615%
# k=32 | Head: (9, 5) | Program: token_reinforcement | Mean PPL Inc: 12.3765%
# k=33 | Head: (11, 1) | Program: token_reinforcement | Mean PPL Inc: 11.8410%
# k=34 | Head: (0, 9) | Program: uniform_lower_diagonal | Mean PPL Inc: 12.2005%
# k=35 | Head: (6, 6) | Program: token_reinforcement | Mean PPL Inc: 12.2803%
# k=36 | Head: (8, 3) | Program: token_reinforcement | Mean PPL Inc: 11.9762%
# k=37 | Head: (10, 3) | Program: sentence_beginning_salience | Mean PPL Inc: 11.9586%
# k=38 | Head: (11, 7) | Program: token_reinforcement | Mean PPL Inc: 12.3513%
# k=39 | Head: (9, 8) | Program: sentence_beginning_salience | Mean PPL Inc: 12.4201%
# k=40 | Head: (0, 5) | Program: lexical_diversity_focus | Mean PPL Inc: 12.3736%
# k=41 | Head: (7, 6) | Program: token_reinforcement | Mean PPL Inc: 13.0493%
# k=42 | Head: (6, 2) | Program: token_reinforcement | Mean PPL Inc: 12.6704%
# k=43 | Head: (8, 0) | Program: token_reinforcement | Mean PPL Inc: 13.4116%
# k=44 | Head: (0, 3) | Program: rare_word_dominance | Mean PPL Inc: 13.4115%
# k=45 | Head: (9, 0) | Program: token_reinforcement | Mean PPL Inc: 14.4231%
# k=46 | Head: (10, 11) | Program: token_reinforcement | Mean PPL Inc: 14.7654%
# k=47 | Head: (4, 4) | Program: token_reinforcement | Mean PPL Inc: 15.5843%
# k=48 | Head: (8, 6) | Program: sentence_beginning_salience | Mean PPL Inc: 16.4197%
# k=49 | Head: (10, 7) | Program: token_reinforcement | Mean PPL Inc: 17.0581%
# k=50 | Head: (4, 8) | Program: token_reinforcement | Mean PPL Inc: 18.2376%
# k=51 | Head: (4, 2) | Program: token_reinforcement | Mean PPL Inc: 17.9988%
# k=52 | Head: (0, 11) | Program: uniform_lower_diagonal | Mean PPL Inc: 17.0514%
# k=53 | Head: (9, 2) | Program: token_reinforcement | Mean PPL Inc: 16.5689%
# k=54 | Head: (8, 9) | Program: token_reinforcement | Mean PPL Inc: 17.0344%
# k=55 | Head: (5, 8) | Program: token_reinforcement | Mean PPL Inc: 18.3805%
# k=56 | Head: (11, 4) | Program: token_reinforcement | Mean PPL Inc: 18.1228%
# k=57 | Head: (0, 10) | Program: uniform_lower_diagonal | Mean PPL Inc: 18.2357%
# k=58 | Head: (5, 11) | Program: initial_token_reference_attention | Mean PPL Inc: 19.0849%
# k=59 | Head: (10, 5) | Program: sentence_beginning_salience | Mean PPL Inc: 18.9002%
# k=60 | Head: (7, 4) | Program: sentence_beginning_salience | Mean PPL Inc: 20.0885%
# k=61 | Head: (5, 6) | Program: token_reinforcement | Mean PPL Inc: 21.3387%
# k=62 | Head: (9, 7) | Program: token_reinforcement | Mean PPL Inc: 21.4348%
# k=63 | Head: (11, 0) | Program: uniform_lower_diagonal | Mean PPL Inc: 21.6376%
# k=64 | Head: (3, 10) | Program: initial_token_reference_attention | Mean PPL Inc: 22.4914%
# k=65 | Head: (1, 10) | Program: uniform_lower_diagonal | Mean PPL Inc: 22.6116%
# k=66 | Head: (6, 3) | Program: token_reinforcement | Mean PPL Inc: 22.8768%
# k=67 | Head: (8, 10) | Program: token_reinforcement | Mean PPL Inc: 24.2456%
# k=68 | Head: (6, 1) | Program: token_reinforcement | Mean PPL Inc: 25.3660%
# k=69 | Head: (2, 11) | Program: token_reinforcement | Mean PPL Inc: 24.5684%
# k=70 | Head: (5, 7) | Program: token_reinforcement | Mean PPL Inc: 24.4948%
# k=71 | Head: (2, 7) | Program: uniform_lower_diagonal | Mean PPL Inc: 24.4560%
# k=72 | Head: (0, 2) | Program: uniform_lower_diagonal | Mean PPL Inc: 24.5862%
#   [SKIP] Spike detected for head (1, 2) with marginal increase of 56.56%.
# k=73 | Head: (6, 4) | Program: initial_token_reference_attention | Mean PPL Inc: 25.1923%
# k=74 | Head: (1, 8) | Program: uniform_lower_diagonal | Mean PPL Inc: 25.3984%
# k=75 | Head: (7, 9) | Program: token_reinforcement | Mean PPL Inc: 26.4824%
# k=76 | Head: (1, 7) | Program: uniform_lower_diagonal | Mean PPL Inc: 26.4216%
# k=77 | Head: (6, 5) | Program: token_reinforcement | Mean PPL Inc: 26.0371%
# k=78 | Head: (1, 11) | Program: lexical_diversity_focus | Mean PPL Inc: 25.9290%
# k=79 | Head: (7, 3) | Program: token_reinforcement | Mean PPL Inc: 26.1052%
# k=80 | Head: (10, 9) | Program: token_reinforcement | Mean PPL Inc: 27.8616%
# k=81 | Head: (2, 10) | Program: uniform_lower_diagonal | Mean PPL Inc: 28.3911%
# k=82 | Head: (11, 10) | Program: initial_token_reference_attention | Mean PPL Inc: 29.2909%
# k=83 | Head: (0, 0) | Program: uniform_lower_diagonal | Mean PPL Inc: 29.3023%
# k=84 | Head: (2, 1) | Program: token_reinforcement | Mean PPL Inc: 30.1160%
# k=85 | Head: (10, 4) | Program: token_reinforcement | Mean PPL Inc: 31.2561%
# k=86 | Head: (1, 4) | Program: uniform_lower_diagonal | Mean PPL Inc: 31.9041%
# k=87 | Head: (11, 3) | Program: token_reinforcement | Mean PPL Inc: 31.8928%
# k=88 | Head: (5, 10) | Program: token_reinforcement | Mean PPL Inc: 34.1110%
# k=89 | Head: (8, 4) | Program: token_reinforcement | Mean PPL Inc: 35.4850%
# k=90 | Head: (7, 5) | Program: token_reinforcement | Mean PPL Inc: 37.2396%
# k=91 | Head: (8, 2) | Program: token_reinforcement | Mean PPL Inc: 37.1054%
# k=92 | Head: (9, 10) | Program: token_reinforcement | Mean PPL Inc: 38.8381%
# k=93 | Head: (0, 8) | Program: uniform_lower_diagonal | Mean PPL Inc: 38.7995%
# k=94 | Head: (11, 11) | Program: initial_token_reference_attention | Mean PPL Inc: 38.4217%
# k=95 | Head: (0, 6) | Program: uniform_lower_diagonal | Mean PPL Inc: 39.5580%
# k=96 | Head: (8, 8) | Program: token_reinforcement | Mean PPL Inc: 42.9371%
# k=97 | Head: (2, 2) | Program: previous_attention | Mean PPL Inc: 42.3149%
# k=98 | Head: (7, 0) | Program: token_reinforcement | Mean PPL Inc: 44.6295%
# k=99 | Head: (1, 6) | Program: uniform_lower_diagonal | Mean PPL Inc: 45.0781%
# k=100 | Head: (4, 7) | Program: first_token_dominance | Mean PPL Inc: 45.9634%
# k=101 | Head: (4, 5) | Program: token_reinforcement | Mean PPL Inc: 45.9142%
# k=102 | Head: (8, 7) | Program: token_reinforcement | Mean PPL Inc: 47.9338%
# k=103 | Head: (7, 8) | Program: token_reinforcement | Mean PPL Inc: 50.5009%
# k=104 | Head: (1, 5) | Program: uniform_lower_diagonal | Mean PPL Inc: 51.0557%
# k=105 | Head: (9, 3) | Program: initial_token_reference_attention | Mean PPL Inc: 52.7116%
# k=106 | Head: (6, 7) | Program: token_reinforcement | Mean PPL Inc: 55.2790%
# k=107 | Head: (1, 3) | Program: initial_token_reference_attention | Mean PPL Inc: 56.1632%
# k=108 | Head: (3, 3) | Program: initial_token_reference_attention | Mean PPL Inc: 57.8865%
# k=109 | Head: (4, 6) | Program: token_reinforcement | Mean PPL Inc: 59.0490%
# k=110 | Head: (1, 1) | Program: uniform_lower_diagonal | Mean PPL Inc: 60.3459%
# k=111 | Head: (3, 5) | Program: token_reinforcement | Mean PPL Inc: 61.8514%
# k=112 | Head: (0, 7) | Program: uniform_lower_diagonal | Mean PPL Inc: 62.9470%
# k=113 | Head: (1, 9) | Program: uniform_lower_diagonal | Mean PPL Inc: 64.1164%
# k=114 | Head: (11, 8) | Program: uniform_lower_diagonal | Mean PPL Inc: 64.1209%
# k=115 | Head: (2, 0) | Program: uniform_lower_diagonal | Mean PPL Inc: 63.9345%
# k=116 | Head: (3, 1) | Program: initial_token_reference_attention | Mean PPL Inc: 67.0793%
# k=117 | Head: (6, 11) | Program: token_reinforcement | Mean PPL Inc: 68.8901%
# k=118 | Head: (1, 0) | Program: uniform_lower_diagonal | Mean PPL Inc: 69.8978%
# k=119 | Head: (6, 8) | Program: token_reinforcement | Mean PPL Inc: 72.9429%
# k=120 | Head: (2, 6) | Program: initial_token_reference_attention | Mean PPL Inc: 74.6717%
# k=121 | Head: (5, 3) | Program: uniform_lower_diagonal | Mean PPL Inc: 79.4208%
# k=122 | Head: (5, 4) | Program: token_reinforcement | Mean PPL Inc: 82.0855%
# k=123 | Head: (8, 5) | Program: token_reinforcement | Mean PPL Inc: 86.2812%
# k=124 | Head: (5, 2) | Program: token_reinforcement | Mean PPL Inc: 86.3947%
# k=125 | Head: (4, 0) | Program: initial_token_reference_attention | Mean PPL Inc: 90.8195%
# k=126 | Head: (3, 6) | Program: uniform_lower_diagonal | Mean PPL Inc: 96.9574%
# k=127 | Head: (2, 3) | Program: uniform_lower_diagonal | Mean PPL Inc: 100.8404%
# k=128 | Head: (6, 0) | Program: sentence_position_preference | Mean PPL Inc: 105.7565%
# k=129 | Head: (0, 4) | Program: lexical_diversity_focus | Mean PPL Inc: 105.4862%
# k=130 | Head: (3, 11) | Program: uniform_lower_diagonal | Mean PPL Inc: 113.9780%
# k=131 | Head: (3, 9) | Program: initial_token_reference_attention | Mean PPL Inc: 120.8851%
# k=132 | Head: (2, 9) | Program: uniform_lower_diagonal | Mean PPL Inc: 133.5376%
# k=133 | Head: (4, 9) | Program: sentence_position_preference | Mean PPL Inc: 144.9276%
# k=134 | Head: (2, 8) | Program: uniform_lower_diagonal | Mean PPL Inc: 159.6525%
# k=135 | Head: (2, 5) | Program: uniform_lower_diagonal | Mean PPL Inc: 178.4442%
# k=136 | Head: (4, 3) | Program: initial_token_reference_attention | Mean PPL Inc: 191.8799%
# k=137 | Head: (3, 8) | Program: uniform_lower_diagonal | Mean PPL Inc: 218.8353%
# k=138 | Head: (3, 2) | Program: uniform_lower_diagonal | Mean PPL Inc: 236.1455%
# k=139 | Head: (2, 4) | Program: uniform_lower_diagonal | Mean PPL Inc: 277.8002%
# k=140 | Head: (4, 1) | Program: initial_token_reference_attention | Mean PPL Inc: 304.5318%
# k=141 | Head: (3, 7) | Program: previous_attention | Mean PPL Inc: 336.0162%
#
# ── Running replacement for gpt2 with shuffle 5 ──
# Calculating baseline perplexities...
# Baseline complete. Mean PPL: 43.41
# Running with strategy='smart', skip_spikes=True
# k=01 | Head: (6, 9) | Program: initial_element_reinforcement | Mean PPL Inc: 0.0000%
# k=02 | Head: (5, 1) | Program: cls_attention | Mean PPL Inc: 0.5649%
# k=03 | Head: (7, 2) | Program: initial_element_reinforcement | Mean PPL Inc: 0.5649%
# k=04 | Head: (7, 10) | Program: sentence_beginning_salience | Mean PPL Inc: 1.3425%
# k=05 | Head: (9, 9) | Program: sentence_beginning_salience | Mean PPL Inc: 1.2943%
# k=06 | Head: (4, 11) | Program: previous_attention | Mean PPL Inc: 2.1236%
# k=07 | Head: (9, 6) | Program: sentence_beginning_salience | Mean PPL Inc: 2.3724%
# k=08 | Head: (10, 10) | Program: sentence_beginning_salience | Mean PPL Inc: 2.8706%
# k=09 | Head: (9, 11) | Program: sentence_beginning_salience | Mean PPL Inc: 2.9444%
# ...
# k=65 | Head: (6, 11) | Program: sentence_beginning_salience | Mean PPL Inc: 3.3479%
# k=66 | Head: (3, 16) | Program: sentence_beginning_salience | Mean PPL Inc: 3.5678%
# k=67 | Head: (6, 15) | Program: sentence_beginning_salience | Mean PPL Inc: 3.6578%
# k=68 | Head: (14, 15) | Program: sentence_beginning_salience | Mean PPL Inc: 3.9727%
# k=69 | Head: (4, 12) | Program: sentence_beginning_salience | Mean PPL Inc: 4.0052%
# k=70 | Head: (3, 2) | Program: sentence_beginning_salience | Mean PPL Inc: 3.9030%
# k=71 | Head: (10, 16) | Program: sentence_beginning_salience | Mean PPL Inc: 4.1439%
# k=72 | Head: (19, 6) | Program: sentence_beginning_salience | Mean PPL Inc: 4.3153%
# k=73 | Head: (11, 6) | Program: sentence_beginning_salience | Mean PPL Inc: 4.9731%
# k=74 | Head: (8, 18) | Program: sentence_beginning_salience | Mean PPL Inc: 5.0300%
# k=75 | Head: (18, 4) | Program: sentence_beginning_salience | Mean PPL Inc: 5.1388%
# k=76 | Head: (18, 23) | Program: sentence_beginning_salience | Mean PPL Inc: 4.7732%
# k=77 | Head: (8, 17) | Program: sentence_beginning_salience | Mean PPL Inc: 4.6942%
# k=78 | Head: (8, 15) | Program: sentence_beginning_salience | Mean PPL Inc: 4.9265%
# k=79 | Head: (17, 15) | Program: sentence_beginning_salience | Mean PPL Inc: 5.4121%
# k=80 | Head: (7, 0) | Program: sentence_beginning_salience | Mean PPL Inc: 5.6279%
# k=81 | Head: (17, 22) | Program: sentence_beginning_salience | Mean PPL Inc: 5.2941%
# k=82 | Head: (19, 25) | Program: sentence_beginning_salience | Mean PPL Inc: 5.4236%
# k=83 | Head: (17, 12) | Program: sentence_beginning_salience | Mean PPL Inc: 5.1882%
# k=84 | Head: (5, 9) | Program: sentence_beginning_salience | Mean PPL Inc: 5.6804%
# k=85 | Head: (19, 15) | Program: sentence_beginning_salience | Mean PPL Inc: 5.2336%
# k=86 | Head: (8, 19) | Program: sentence_beginning_salience | Mean PPL Inc: 5.0878%
# k=87 | Head: (16, 13) | Program: sentence_beginning_salience | Mean PPL Inc: 5.1446%
# k=88 | Head: (4, 9) | Program: sentence_beginning_salience | Mean PPL Inc: 5.2694%
# k=89 | Head: (5, 22) | Program: sentence_beginning_salience | Mean PPL Inc: 5.7325%
# k=90 | Head: (21, 23) | Program: sentence_beginning_salience | Mean PPL Inc: 5.6610%
# k=91 | Head: (15, 15) | Program: sentence_beginning_salience | Mean PPL Inc: 5.9777%
# k=92 | Head: (12, 5) | Program: sentence_beginning_salience | Mean PPL Inc: 5.9154%
# k=93 | Head: (15, 17) | Program: sentence_beginning_salience | Mean PPL Inc: 5.7857%
# k=94 | Head: (18, 19) | Program: sentence_beginning_salience | Mean PPL Inc: 5.8734%
# k=95 | Head: (6, 3) | Program: sentence_beginning_salience | Mean PPL Inc: 5.9270%
# k=96 | Head: (11, 1) | Program: sentence_beginning_salience | Mean PPL Inc: 6.1631%
# k=97 | Head: (6, 17) | Program: sentence_beginning_salience | Mean PPL Inc: 6.2787%
# k=98 | Head: (4, 23) | Program: sentence_beginning_salience | Mean PPL Inc: 6.0604%
# k=99 | Head: (16, 30) | Program: sentence_beginning_salience | Mean PPL Inc: 6.3937%
# k=100 | Head: (18, 6) | Program: sentence_beginning_salience | Mean PPL Inc: 6.5690%
# k=101 | Head: (17, 21) | Program: sentence_beginning_salience | Mean PPL Inc: 6.9965%
# k=102 | Head: (4, 27) | Program: sentence_beginning_salience | Mean PPL Inc: 7.1320%
# k=103 | Head: (19, 13) | Program: sentence_beginning_salience | Mean PPL Inc: 7.4680%
# k=104 | Head: (7, 25) | Program: sentence_beginning_salience | Mean PPL Inc: 7.8172%
# k=105 | Head: (7, 14) | Program: sentence_beginning_salience | Mean PPL Inc: 8.3533%
# k=106 | Head: (5, 25) | Program: sentence_beginning_salience | Mean PPL Inc: 9.0983%
# k=107 | Head: (8, 13) | Program: sentence_beginning_salience | Mean PPL Inc: 8.6843%
# k=108 | Head: (4, 20) | Program: sentence_beginning_salience | Mean PPL Inc: 8.4566%
# k=109 | Head: (4, 29) | Program: sentence_beginning_salience | Mean PPL Inc: 8.8442%
# k=110 | Head: (6, 0) | Program: sentence_beginning_salience | Mean PPL Inc: 9.2827%
# k=111 | Head: (4, 5) | Program: sentence_beginning_salience | Mean PPL Inc: 9.8366%
# k=112 | Head: (5, 29) | Program: sentence_beginning_salience | Mean PPL Inc: 10.1507%
# k=113 | Head: (8, 26) | Program: sentence_beginning_salience | Mean PPL Inc: 10.0925%
# k=114 | Head: (6, 13) | Program: sentence_beginning_salience | Mean PPL Inc: 10.4968%
# k=115 | Head: (5, 8) | Program: sentence_beginning_salience | Mean PPL Inc: 10.1613%
# k=116 | Head: (16, 25) | Program: sentence_beginning_salience | Mean PPL Inc: 9.9529%
# k=117 | Head: (18, 2) | Program: sentence_beginning_salience | Mean PPL Inc: 9.7824%
# k=118 | Head: (8, 8) | Program: sentence_beginning_salience | Mean PPL Inc: 9.6168%
# k=119 | Head: (5, 17) | Program: sentence_beginning_salience | Mean PPL Inc: 9.9008%
# k=120 | Head: (4, 30) | Program: sentence_beginning_salience | Mean PPL Inc: 9.7185%
# k=121 | Head: (4, 11) | Program: sentence_beginning_salience | Mean PPL Inc: 9.6074%
# k=122 | Head: (19, 16) | Program: sentence_beginning_salience | Mean PPL Inc: 9.5352%
# k=123 | Head: (7, 17) | Program: sentence_beginning_salience | Mean PPL Inc: 9.4779%
# k=124 | Head: (8, 28) | Program: sentence_beginning_salience | Mean PPL Inc: 9.3766%
# k=125 | Head: (5, 28) | Program: sentence_beginning_salience | Mean PPL Inc: 9.5617%
# k=126 | Head: (19, 23) | Program: sentence_beginning_salience | Mean PPL Inc: 9.6146%
# k=127 | Head: (5, 11) | Program: sentence_beginning_salience | Mean PPL Inc: 10.0109%
# k=128 | Head: (11, 2) | Program: sentence_beginning_salience | Mean PPL Inc: 10.1495%
# k=129 | Head: (7, 21) | Program: sentence_beginning_salience | Mean PPL Inc: 10.4284%
# k=130 | Head: (4, 13) | Program: sentence_beginning_salience | Mean PPL Inc: 10.6454%
# k=131 | Head: (4, 24) | Program: sentence_beginning_salience | Mean PPL Inc: 10.8282%
# k=132 | Head: (13, 24) | Program: sentence_beginning_salience | Mean PPL Inc: 11.0820%
# k=133 | Head: (20, 26) | Program: sentence_beginning_salience | Mean PPL Inc: 11.2218%
# k=134 | Head: (9, 6) | Program: sentence_beginning_salience | Mean PPL Inc: 11.1618%
# k=135 | Head: (4, 16) | Program: sentence_beginning_salience | Mean PPL Inc: 11.4548%
# k=136 | Head: (8, 20) | Program: sentence_beginning_salience | Mean PPL Inc: 11.7246%
# k=137 | Head: (3, 22) | Program: sentence_beginning_salience | Mean PPL Inc: 11.9650%
# k=138 | Head: (4, 18) | Program: sentence_beginning_salience | Mean PPL Inc: 11.9501%
# k=139 | Head: (11, 13) | Program: sentence_beginning_salience | Mean PPL Inc: 12.0053%
# k=140 | Head: (5, 10) | Program: sentence_beginning_salience | Mean PPL Inc: 11.9649%
# k=141 | Head: (11, 5) | Program: sentence_beginning_salience | Mean PPL Inc: 11.9939%
# k=142 | Head: (5, 18) | Program: sentence_beginning_salience | Mean PPL Inc: 12.0898%
# k=143 | Head: (8, 23) | Program: sentence_beginning_salience | Mean PPL Inc: 12.2556%
# k=144 | Head: (10, 26) | Program: sentence_beginning_salience | Mean PPL Inc: 12.7713%
# k=145 | Head: (11, 0) | Program: sentence_beginning_salience | Mean PPL Inc: 12.6897%
# k=146 | Head: (3, 19) | Program: sentence_beginning_salience | Mean PPL Inc: 12.9002%
# k=147 | Head: (18, 9) | Program: sentence_beginning_salience | Mean PPL Inc: 13.2773%
# k=148 | Head: (17, 17) | Program: sentence_beginning_salience | Mean PPL Inc: 13.6314%
# k=149 | Head: (15, 22) | Program: sentence_beginning_salience | Mean PPL Inc: 13.6507%
# k=150 | Head: (17, 7) | Program: sentence_beginning_salience | Mean PPL Inc: 13.9399%
# k=151 | Head: (4, 3) | Program: sentence_beginning_salience | Mean PPL Inc: 14.3679%
# k=152 | Head: (8, 16) | Program: sentence_beginning_salience | Mean PPL Inc: 14.2596%
# k=153 | Head: (7, 3) | Program: sentence_beginning_salience | Mean PPL Inc: 14.2148%
# k=154 | Head: (4, 19) | Program: sentence_beginning_salience | Mean PPL Inc: 14.2329%
# k=155 | Head: (20, 17) | Program: sentence_beginning_salience | Mean PPL Inc: 15.0870%
# k=156 | Head: (8, 24) | Program: sentence_beginning_salience | Mean PPL Inc: 15.0135%
# k=157 | Head: (6, 22) | Program: sentence_beginning_salience | Mean PPL Inc: 15.3352%
# k=158 | Head: (15, 23) | Program: sentence_beginning_salience | Mean PPL Inc: 14.8423%
# k=159 | Head: (10, 12) | Program: sentence_beginning_salience | Mean PPL Inc: 15.2573%
# k=160 | Head: (5, 26) | Program: sentence_beginning_salience | Mean PPL Inc: 14.9887%
# k=161 | Head: (20, 12) | Program: sentence_beginning_salience | Mean PPL Inc: 15.3522%
# k=162 | Head: (6, 10) | Program: sentence_beginning_salience | Mean PPL Inc: 15.0428%
# k=163 | Head: (21, 29) | Program: sentence_beginning_salience | Mean PPL Inc: 14.6253%
# k=164 | Head: (6, 20) | Program: initial_token_reference_attention | Mean PPL Inc: 15.1765%
# k=165 | Head: (16, 26) | Program: sentence_beginning_salience | Mean PPL Inc: 14.8756%
# k=166 | Head: (6, 16) | Program: sentence_beginning_salience | Mean PPL Inc: 14.8141%
# k=167 | Head: (6, 24) | Program: sentence_beginning_salience | Mean PPL Inc: 15.1493%
# k=168 | Head: (4, 0) | Program: sentence_beginning_salience | Mean PPL Inc: 15.1936%
# k=169 | Head: (17, 19) | Program: sentence_beginning_salience | Mean PPL Inc: 15.5325%
# k=170 | Head: (3, 12) | Program: sentence_beginning_salience | Mean PPL Inc: 15.3567%
# k=171 | Head: (18, 18) | Program: sentence_beginning_salience | Mean PPL Inc: 15.3318%
# k=172 | Head: (13, 12) | Program: sentence_beginning_salience | Mean PPL Inc: 16.4230%
# k=173 | Head: (17, 20) | Program: sentence_beginning_salience | Mean PPL Inc: 16.6029%
# k=174 | Head: (7, 15) | Program: sentence_beginning_salience | Mean PPL Inc: 16.6999%
# k=175 | Head: (3, 11) | Program: sentence_beginning_salience | Mean PPL Inc: 16.9106%
# k=176 | Head: (5, 19) | Program: sentence_beginning_salience | Mean PPL Inc: 17.0318%
# k=177 | Head: (11, 31) | Program: sentence_beginning_salience | Mean PPL Inc: 17.0606%
# k=178 | Head: (5, 23) | Program: sentence_beginning_salience | Mean PPL Inc: 16.7061%
# k=179 | Head: (8, 7) | Program: sentence_beginning_salience | Mean PPL Inc: 17.2666%
# k=180 | Head: (10, 14) | Program: sentence_beginning_salience | Mean PPL Inc: 17.9235%
# k=181 | Head: (0, 4) | Program: sentence_position_preference | Mean PPL Inc: 17.9396%
# k=182 | Head: (0, 7) | Program: sentence_position_preference | Mean PPL Inc: 16.7637%
# k=183 | Head: (3, 3) | Program: sentence_beginning_salience | Mean PPL Inc: 17.3418%
# k=184 | Head: (0, 5) | Program: sentence_position_preference | Mean PPL Inc: 17.5465%
# k=185 | Head: (6, 9) | Program: sentence_beginning_salience | Mean PPL Inc: 17.6370%
# k=186 | Head: (0, 15) | Program: sentence_position_preference | Mean PPL Inc: 17.4001%
# k=187 | Head: (4, 14) | Program: sentence_beginning_salience | Mean PPL Inc: 17.4865%
# k=188 | Head: (5, 31) | Program: sentence_beginning_salience | Mean PPL Inc: 17.0447%
# k=189 | Head: (3, 18) | Program: sentence_beginning_salience | Mean PPL Inc: 17.4647%
# k=190 | Head: (5, 21) | Program: sentence_beginning_salience | Mean PPL Inc: 16.9177%
# k=191 | Head: (18, 22) | Program: sentence_beginning_salience | Mean PPL Inc: 16.3347%
# k=192 | Head: (4, 15) | Program: sentence_beginning_salience | Mean PPL Inc: 16.2061%
# k=193 | Head: (6, 7) | Program: sentence_beginning_salience | Mean PPL Inc: 17.0341%
# k=194 | Head: (0, 3) | Program: sentence_position_preference | Mean PPL Inc: 16.5923%
# k=195 | Head: (17, 6) | Program: sentence_beginning_salience | Mean PPL Inc: 17.2561%
# k=196 | Head: (9, 31) | Program: sentence_beginning_salience | Mean PPL Inc: 17.5338%
# k=197 | Head: (4, 26) | Program: sentence_beginning_salience | Mean PPL Inc: 18.0658%
# k=198 | Head: (19, 5) | Program: sentence_beginning_salience | Mean PPL Inc: 17.5384%
# k=199 | Head: (0, 2) | Program: sentence_position_preference | Mean PPL Inc: 17.7298%
# k=200 | Head: (19, 20) | Program: sentence_beginning_salience | Mean PPL Inc: 17.4012%
# k=201 | Head: (5, 4) | Program: sentence_beginning_salience | Mean PPL Inc: 17.5821%
# k=202 | Head: (7, 5) | Program: initial_token_reference_attention | Mean PPL Inc: 17.5113%
# k=203 | Head: (3, 29) | Program: sentence_beginning_salience | Mean PPL Inc: 17.8854%
# k=204 | Head: (7, 22) | Program: sentence_beginning_salience | Mean PPL Inc: 17.8325%
# k=205 | Head: (3, 20) | Program: sentence_beginning_salience | Mean PPL Inc: 17.5270%
# k=206 | Head: (3, 9) | Program: sentence_beginning_salience | Mean PPL Inc: 18.0627%
# k=207 | Head: (4, 7) | Program: sentence_beginning_salience | Mean PPL Inc: 18.7657%
# k=208 | Head: (10, 13) | Program: sentence_beginning_salience | Mean PPL Inc: 18.6113%
# k=209 | Head: (15, 3) | Program: sentence_beginning_salience | Mean PPL Inc: 18.6296%
# k=210 | Head: (4, 6) | Program: sentence_beginning_salience | Mean PPL Inc: 18.6698%
# k=211 | Head: (16, 27) | Program: sentence_beginning_salience | Mean PPL Inc: 18.2564%
# k=212 | Head: (9, 25) | Program: sentence_beginning_salience | Mean PPL Inc: 18.4174%
# k=213 | Head: (0, 9) | Program: sentence_position_preference | Mean PPL Inc: 18.7592%
# k=214 | Head: (14, 14) | Program: sentence_beginning_salience | Mean PPL Inc: 19.1536%
# k=215 | Head: (9, 12) | Program: sentence_beginning_salience | Mean PPL Inc: 19.7390%
# k=216 | Head: (12, 26) | Program: sentence_beginning_salience | Mean PPL Inc: 19.3287%
# k=217 | Head: (0, 1) | Program: sentence_position_preference | Mean PPL Inc: 15.4146%
# k=218 | Head: (0, 6) | Program: sentence_position_preference | Mean PPL Inc: 7.6847%
# k=219 | Head: (19, 24) | Program: initial_token_reference_attention | Mean PPL Inc: 8.2787%
# k=220 | Head: (19, 27) | Program: initial_token_reference_attention | Mean PPL Inc: 8.5308%
# k=221 | Head: (14, 9) | Program: sentence_beginning_salience | Mean PPL Inc: 8.0255%
# k=222 | Head: (18, 10) | Program: sentence_beginning_salience | Mean PPL Inc: 7.9072%
# k=223 | Head: (14, 29) | Program: initial_token_reference_attention | Mean PPL Inc: 7.8891%
# k=224 | Head: (3, 17) | Program: sentence_beginning_salience | Mean PPL Inc: 8.1742%
# k=225 | Head: (0, 0) | Program: contextual_anchoring | Mean PPL Inc: 8.0068%
# k=226 | Head: (11, 20) | Program: sentence_beginning_salience | Mean PPL Inc: 8.0011%
# k=227 | Head: (10, 24) | Program: sentence_beginning_salience | Mean PPL Inc: 8.5148%
# k=228 | Head: (7, 30) | Program: initial_token_reference_attention | Mean PPL Inc: 7.8676%
# k=229 | Head: (5, 7) | Program: sentence_beginning_salience | Mean PPL Inc: 8.5811%
# k=230 | Head: (10, 8) | Program: sentence_beginning_salience | Mean PPL Inc: 8.4896%
# k=231 | Head: (4, 10) | Program: sentence_beginning_salience | Mean PPL Inc: 9.0984%
# k=232 | Head: (3, 8) | Program: sentence_beginning_salience | Mean PPL Inc: 9.3117%
# k=233 | Head: (3, 27) | Program: sentence_beginning_salience | Mean PPL Inc: 9.8059%
# k=234 | Head: (6, 18) | Program: sentence_beginning_salience | Mean PPL Inc: 10.5068%
# k=235 | Head: (12, 0) | Program: initial_token_reference_attention | Mean PPL Inc: 10.4772%
# k=236 | Head: (16, 10) | Program: sentence_beginning_salience | Mean PPL Inc: 9.8429%
# k=237 | Head: (16, 31) | Program: sentence_beginning_salience | Mean PPL Inc: 10.3017%
# k=238 | Head: (20, 21) | Program: sentence_beginning_salience | Mean PPL Inc: 10.3939%
# k=239 | Head: (13, 29) | Program: sentence_beginning_salience | Mean PPL Inc: 10.7745%
# k=240 | Head: (5, 6) | Program: initial_token_reference_attention | Mean PPL Inc: 10.6390%
# k=241 | Head: (7, 18) | Program: initial_token_reference_attention | Mean PPL Inc: 10.6126%
# k=242 | Head: (0, 14) | Program: sentence_position_preference | Mean PPL Inc: 14.3002%
# k=243 | Head: (4, 1) | Program: sentence_beginning_salience | Mean PPL Inc: 14.5561%
# k=244 | Head: (3, 26) | Program: sentence_beginning_salience | Mean PPL Inc: 15.6027%
# k=245 | Head: (12, 20) | Program: sentence_beginning_salience | Mean PPL Inc: 15.5081%
# k=246 | Head: (5, 27) | Program: sentence_beginning_salience | Mean PPL Inc: 15.3306%
# k=247 | Head: (6, 29) | Program: sentence_beginning_salience | Mean PPL Inc: 14.9830%
# k=248 | Head: (3, 14) | Program: sentence_beginning_salience | Mean PPL Inc: 15.2512%
# k=249 | Head: (3, 30) | Program: sentence_beginning_salience | Mean PPL Inc: 15.1513%
# k=250 | Head: (10, 11) | Program: sentence_beginning_salience | Mean PPL Inc: 15.9210%

# %%
# print best fits csv for gpt2

best_fits_gpt2 = pd.read_csv("../results/best_fits_gpt2.csv")
best_fits_gpt2 = best_fits_gpt2.sort_values(by="iou_score", ascending=False).reset_index(drop=True)
for idx, row in best_fits_gpt2.iterrows():
    print(f"L{int(row['layer'])}H{int(row['head'])} | Program: {all_programs[int(row['program_idx'])].__name__} | IOU: {row['iou_score']:.4f}")

# %%
# ============================================================
# Smart-Shuffle Top-3 Backtracking Experiment  (GPT-2 only)
#
# Steps 1-42 are hardcoded from the known-good run that goes
# negative. The shuffled backtracking search picks up from k=43,
# seeded with the real accepted_heads_mapping so hooks are correct.
#
# For each shuffle (steps 43+):
#   - constrained_shuffle the REMAINING heads (those not in seed)
#   - For each head try Rank-1 program (highest mean IOU).
#     If marginal PPL > 10% → try Rank-2 → Rank-3 → skip.
#   - Stop shuffle if cumulative increase > 1000%.
#
# Saves each shuffle to:
#   ../results/replacement_run/shuffles/gpt2_top3_shuffle_{idx}.csv
#
# Depends on (already defined in this notebook):
#   prepare_sentence, constrained_shuffle_df, all_programs, DATA_DIR
# ============================================================

import ast
import io
import pathlib
import numpy as np
import pandas as pd
import torch
import torch.nn.functional as F
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# ── Config ────────────────────────────────────────────────────────────────────
N_SHUFFLES      = 32     # shuffles to run overnight
SPIKE_THRESHOLD = 8.0   # marginal % spike cutoff
CUMUL_LIMIT     = 66.0 # cumulative % that stops a shuffle early
TOP_K           = 3      # ranked fallbacks per head
SIGMA           = 30    # constrained-shuffle noise std-dev
NUM_SENTENCES   = 5
MODEL_KEY       = "gpt2"
# ──────────────────────────────────────────────────────────────────────────────

np.random.seed(42)
pathlib.Path("../results/replacement_run/shuffles").mkdir(parents=True, exist_ok=True)

# ── 1. Hardcoded seed — the 42 known-good replacements ───────────────────────
SEED_CSV = """\
k,head,program,strategy,increase,kl_div
1,"(10, 2)",initial_token_attention,smart,0.008307712197430366,0.001065253290653345
2,"(10, 1)",initial_token_attention,smart,0.008615101288974697,0.002011389515728297
3,"(6, 9)",cls_attention,smart,-0.6633480896656324,0.0035132152349979153
4,"(5, 1)",cls_attention,smart,-0.6251862761961215,0.006047547392081469
5,"(7, 2)",cls_attention,smart,-0.46079214514841105,0.007481090293440502
6,"(4, 11)",previous_attention,smart,-0.13227185889340462,0.008721561353304423
7,"(7, 1)",initial_token_attention,smart,0.17710685905574153,0.010167443108512088
8,"(11, 9)",initial_token_attention,smart,-0.21351424777165198,0.012792042766814121
9,"(10, 0)",initial_token_attention,smart,-0.20580384016925668,0.014605110042029992
10,"(11, 2)",initial_token_attention,smart,1.0038506419448705,0.017880274574272336
11,"(7, 7)",initial_token_attention,smart,0.9243134907948786,0.01833117724279873
12,"(5, 5)",initial_token_attention,smart,0.6361639857461907,0.020740094240172768
13,"(6, 6)",initial_token_attention,smart,0.4549912320044895,0.022376552417408675
14,"(10, 8)",initial_token_attention,smart,0.10113471498162603,0.024186684540472923
15,"(3, 0)",initial_token_attention,smart,-0.07333341108278439,0.024121518884785472
16,"(0, 1)",repeated_attention,smart,-0.08229663632499523,0.02414339571725577
17,"(9, 6)",initial_token_attention,smart,0.08397755045552856,0.02528198662563227
18,"(9, 9)",sentence_start_dominance,smart,0.20214879514749776,0.028346376998815686
19,"(9, 5)",sentence_initial_dominance,smart,-1.720343203993684,0.028143282887758688
20,"(8, 1)",initial_token_attention,smart,-1.9935828405133866,0.03228664654074237
21,"(10, 10)",initial_token_attention,smart,-1.8115494947969548,0.033806850896216926
22,"(9, 11)",initial_token_attention,smart,-1.4920480247818013,0.03443914557225071
23,"(3, 4)",initial_token_attention,smart,-1.6696160646077265,0.03623579588253051
24,"(11, 7)",initial_token_attention,smart,-0.7344831094723496,0.039611174650490286
25,"(11, 5)",initial_token_attention,smart,-0.2976022499177347,0.04332037792075425
26,"(9, 4)",initial_token_attention,smart,-0.3462717356001825,0.043809333558892834
27,"(7, 10)",initial_token_attention,smart,-0.1648400476295224,0.04461271269246936
28,"(6, 10)",initial_token_attention,smart,0.02574922911360261,0.04931675942847505
29,"(9, 8)",sentence_initial_dominance,smart,-1.440972483437424,0.0490389868686907
30,"(10, 6)",initial_token_attention,smart,-1.36646972737408,0.0513438879372552
31,"(11, 1)",sentence_initial_dominance,smart,-3.0456133521445476,0.051345947170630096
32,"(7, 11)",initial_token_attention,smart,-2.9486139101015043,0.054554718919098376
33,"(6, 2)",sentence_initial_dominance,smart,-4.1299547629687,0.05475393987959251
34,"(7, 6)",sentence_initial_dominance,smart,-5.068048806331123,0.054423859217204155
35,"(8, 3)",initial_token_attention,smart,-4.902484822870978,0.05675411381525919
36,"(5, 9)",sentence_initial_dominance,smart,-5.571243742067339,0.056279577629175036
37,"(10, 3)",sentence_initial_dominance,smart,-7.450234561946978,0.05592323972377926
38,"(5, 0)",initial_token_attention,smart,-7.127710350251196,0.06024578050011769
39,"(8, 11)",sentence_initial_dominance,smart,-8.657863908075072,0.060319892903789876
40,"(9, 1)",initial_token_attention,smart,-8.464149821736362,0.06372750320471823
41,"(8, 0)",sentence_initial_dominance,smart,-10.026851892198312,0.06297878146870062
42,"(4, 10)",initial_token_attention,smart,-9.929107592011958,0.06535566914826632\
"""

seed_df = pd.read_csv(io.StringIO(SEED_CSV))

# Build the seed accepted_heads_mapping: list of (head_tuple, prog_name)
# This is what the hook lookup is built from — must match original format exactly.
SEED_MAPPING = [
    (tuple(ast.literal_eval(row["head"])), row["program"])
    for _, row in seed_df.iterrows()
]
SEED_HEADS = set(h for h, _ in SEED_MAPPING)
SEED_PREV_CUMULATIVE = float(seed_df.iloc[-1]["increase"])  # -9.929...

print(f"[INFO] Seed loaded: {len(SEED_MAPPING)} hardcoded replacements.")
print(f"[INFO] Seed cumulative PPL increase: {SEED_PREV_CUMULATIVE:.4f}%")

# ── 2. Build top-3 program mapping from IOU scores ───────────────────────────
iou_csv  = f"{DATA_DIR}/iou_scores_{MODEL_KEY}.csv"
iou_df   = pd.read_csv(iou_csv)
mean_iou = (
    iou_df.groupby(["layer", "head", "program_idx"])["iou_score"]
    .mean()
    .reset_index()
)

head_program_map = {}  # (layer, head) -> [(rank, prog_name), ...]
rank1_rows       = []  # for shuffling — only non-seed heads

for (layer, head), grp in mean_iou.groupby(["layer", "head"]):
    top    = grp.nlargest(TOP_K, "iou_score").reset_index(drop=True)
    ranked = []
    for rank_idx, (_, row) in enumerate(top.iterrows(), start=1):
        p_idx     = int(row["program_idx"])
        prog_name = all_programs[p_idx].__name__
        ranked.append((rank_idx, prog_name))
        if rank_idx == 1 and (int(layer), int(head)) not in SEED_HEADS:
            rank1_rows.append({"layer": layer, "head": head, "iou_score": row["iou_score"]})
    head_program_map[(int(layer), int(head))] = ranked

# Remaining heads (not in seed), ordered by rank-1 IOU desc — this is what we shuffle
remaining_rank1_df = pd.DataFrame(rank1_rows).sort_values("iou_score", ascending=False).reset_index(drop=True)

print(f"[INFO] {len(head_program_map)} total unique heads, {len(remaining_rank1_df)} remaining after seed.")

# ── 3. Baseline (computed once, reused across all shuffles) ───────────────────
tokenizer  = GPT2Tokenizer.from_pretrained("gpt2")
eval_sents = pd.read_json("../data/generic_sentences.json")[0].tolist()[:NUM_SENTENCES]

print("Calculating baseline perplexities...")
_base  = GPT2LMHeadModel.from_pretrained("gpt2").to("cuda" if torch.cuda.is_available() else "cpu")
_base.eval()
device          = next(_base.parameters()).device
baseline_ppls   = []
baseline_logits = []

for sent in eval_sents:
    active = prepare_sentence(sent, mode="last_word")
    toks   = tokenizer(active, return_tensors="pt").to(device)
    with torch.no_grad():
        out = _base(**toks, labels=toks["input_ids"])
        baseline_ppls.append(torch.exp(out.loss).item())
        baseline_logits.append(out.logits[:, -1, :])

del _base
torch.cuda.empty_cache()
print(f"Baseline complete. Mean PPL: {np.mean(baseline_ppls):.2f}\n")

# ── 4. Hook factory — copied verbatim from run_replacement_experiment_gpt2 ────
def make_smart_hook(lookup, programs_list):
    def compound_hook(module, input, output):
        context_layer = output[0]
        batch, seq_len, hidden_dim = context_layer.shape
        num_heads, head_dim = 12, hidden_dim // 12
        modified_layer = context_layer.view(batch, seq_len, num_heads, head_dim).clone()
        current_sent = getattr(module, '_current_sentence', None)
        if current_sent is None:
            return output
        for head_idx in range(num_heads):
            key = (module.layer_id, head_idx)
            if key in lookup:
                prog_name = lookup[key]
                prog = next((p for p in programs_list if p.__name__ == prog_name), None)
                if prog:
                    try:
                        _, hypo_mat = prog(current_sent, tokenizer)
                        if hypo_mat is not None:
                            hypo_tensor = torch.tensor(hypo_mat).to(device, dtype=modified_layer.dtype)
                            modified_layer[:, :, head_idx, :] = torch.matmul(hypo_tensor, modified_layer[:, :, head_idx, :])
                    except Exception:
                        pass
        return (modified_layer.view(batch, seq_len, hidden_dim),) + output[1:]
    return compound_hook

# ── 5. Trial evaluator — inner loop from run_replacement_experiment_gpt2 ──────
def evaluate_candidate(accepted_heads_mapping, candidate_head, candidate_prog):
    """
    Loads a fresh GPT-2, registers hooks for all accepted heads + candidate,
    evaluates, cleans up. Returns (mean_pct_increase, mean_kl_div).

    accepted_heads_mapping: list of (head_tuple, prog_name)
    """
    trial_mapping   = accepted_heads_mapping + [(candidate_head, candidate_prog)]
    trial_lookup    = {tuple(map(int, h)): p for h, p in trial_mapping}
    relevant_layers = set(h[0] for h in trial_lookup)

    model_k = GPT2LMHeadModel.from_pretrained("gpt2").to(device)
    model_k.eval()

    hook_fn      = make_smart_hook(trial_lookup, all_programs)
    hook_handles = []
    for l_idx in range(12):
        target          = model_k.transformer.h[l_idx].attn
        target.layer_id = l_idx
        if l_idx in relevant_layers:
            hook_handles.append(target.register_forward_hook(hook_fn))

    replaced_ppls, kl_divergences = [], []
    for i, sent in enumerate(eval_sents):
        active_sent = prepare_sentence(sent, mode="last_word")
        for l_idx in relevant_layers:
            model_k.transformer.h[l_idx].attn._current_sentence = active_sent
        toks = tokenizer(active_sent, return_tensors="pt").to(device)
        with torch.no_grad():
            out_rep = model_k(**toks, labels=toks["input_ids"])
            replaced_ppls.append(torch.exp(out_rep.loss).item())
            log_probs_new  = F.log_softmax(out_rep.logits[:, -1, :], dim=-1)
            probs_baseline = F.softmax(baseline_logits[i], dim=-1)
            kl_divergences.append(F.kl_div(log_probs_new, probs_baseline, reduction='batchmean').item())

    for handle in hook_handles:
        handle.remove()
    del model_k
    torch.cuda.empty_cache()

    mean_pct = float(np.mean([(r - b) / b * 100 for r, b in zip(replaced_ppls, baseline_ppls)]))
    mean_kl  = float(np.mean(kl_divergences))
    return mean_pct, mean_kl

# ── 6. Outer shuffle loop ─────────────────────────────────────────────────────
for shuffle_idx in range(1, N_SHUFFLES + 1):
    print(f"── Shuffle {shuffle_idx}/{N_SHUFFLES} ──────────────────────────────")

    # Seed results are identical across every shuffle — copy them in directly
    shuffle_results = [
        {
            "k":             int(row["k"]),
            "head":          row["head"],
            "program":       row["program"],
            "accepted_rank": 1,          # seed rows are always rank-1 by definition
            "strategy":      "smart",
            "increase":      float(row["increase"]),
            "kl_div":        float(row["kl_div"]),
            "shuffle_idx":   shuffle_idx,
        }
        for _, row in seed_df.iterrows()
    ]
    for row in shuffle_results:
        print(f"  [SEED] k={row['k']:03d} | Head {row['head']} | '{row['program']}' | cumul={row['increase']:.4f}%")

    # Seed the accepted mapping so hooks include all 42 replacements
    accepted_heads_mapping = list(SEED_MAPPING)   # copy — mutated per shuffle
    k               = len(SEED_MAPPING)           # 42
    prev_cumulative = SEED_PREV_CUMULATIVE        # -9.929...

    # Shuffle only the remaining (non-seed) heads
    shuffled_remaining = constrained_shuffle_df(remaining_rank1_df, sigma=SIGMA)
    head_order = [(int(r["layer"]), int(r["head"])) for _, r in shuffled_remaining.iterrows()]

    for head_tuple in head_order:
        candidates = head_program_map.get(head_tuple, [])
        if not candidates:
            print(f"  [WARN] No candidates for head {head_tuple}. Skipping.")
            continue

        accepted_rank = None
        accepted_prog = None
        mean_pct      = None
        mean_kl       = None

        # ── Backtracking: Rank 1 → 2 → 3 ──────────────────────────────────
        for rank, prog_name in candidates:
            mean_pct, mean_kl = evaluate_candidate(accepted_heads_mapping, head_tuple, prog_name)
            marginal          = mean_pct - prev_cumulative

            if marginal > SPIKE_THRESHOLD:
                n_remaining = len(candidates) - rank
                print(
                    f"  [SPIKE] Head {head_tuple} Rank-{rank} '{prog_name}' "
                    f"marginal={marginal:.2f}%. "
                    + (f"Trying Rank-{rank+1}..." if n_remaining > 0 else "All ranks exhausted.")
                )
                torch.cuda.empty_cache()
                continue

            accepted_rank = rank
            accepted_prog = prog_name
            break

        if accepted_rank is None:
            print(f"  [SKIP] Head {head_tuple}: all {len(candidates)} programs spiked.")
            continue

        if mean_pct > CUMUL_LIMIT:
            print(f"  [STOP] Cumulative {mean_pct:.2f}% > {CUMUL_LIMIT}%. Ending shuffle {shuffle_idx} early.")
            break

        k += 1
        accepted_heads_mapping.append((head_tuple, accepted_prog))
        prev_cumulative = mean_pct

        shuffle_results.append({
            "k":             k,
            "head":          str(head_tuple),
            "program":       accepted_prog,
            "accepted_rank": accepted_rank,
            "strategy":      "smart",
            "increase":      round(mean_pct, 6),
            "kl_div":        round(mean_kl, 6),
            "shuffle_idx":   shuffle_idx,
        })
        print(f"  k={k:03d} | Head {head_tuple} | Rank-{accepted_rank} '{accepted_prog}' | cumul={mean_pct:.4f}%")

    # Save this shuffle
    save_path = f"../results/replacement_run/shuffles/{MODEL_KEY}_top3_shuffle_{shuffle_idx}.csv"
    pd.DataFrame(shuffle_results).to_csv(save_path, index=False)
    print(f"  ✓ Saved {len(shuffle_results)} rows → {save_path}\n")

print(f"[DONE] All {N_SHUFFLES} shuffles complete.")
# Out:
# [INFO] Seed loaded: 42 hardcoded replacements.
# [INFO] Seed cumulative PPL increase: -9.9291%
# [INFO] 144 total unique heads, 102 remaining after seed.
# Calculating baseline perplexities...
# Baseline complete. Mean PPL: 43.41
#
# ── Shuffle 1/32 ──────────────────────────────
#   [SEED] k=001 | Head (10, 2) | 'initial_token_attention' | cumul=0.0083%
#   [SEED] k=002 | Head (10, 1) | 'initial_token_attention' | cumul=0.0086%
#   [SEED] k=003 | Head (6, 9) | 'cls_attention' | cumul=-0.6633%
#   [SEED] k=004 | Head (5, 1) | 'cls_attention' | cumul=-0.6252%
#   [SEED] k=005 | Head (7, 2) | 'cls_attention' | cumul=-0.4608%
#   [SEED] k=006 | Head (4, 11) | 'previous_attention' | cumul=-0.1323%
#   [SEED] k=007 | Head (7, 1) | 'initial_token_attention' | cumul=0.1771%
#   [SEED] k=008 | Head (11, 9) | 'initial_token_attention' | cumul=-0.2135%
#   [SEED] k=009 | Head (10, 0) | 'initial_token_attention' | cumul=-0.2058%
#   [SEED] k=010 | Head (11, 2) | 'initial_token_attention' | cumul=1.0039%
#   [SEED] k=011 | Head (7, 7) | 'initial_token_attention' | cumul=0.9243%
#   [SEED] k=012 | Head (5, 5) | 'initial_token_attention' | cumul=0.6362%
#   [SEED] k=013 | Head (6, 6) | 'initial_token_attention' | cumul=0.4550%
#   [SEED] k=014 | Head (10, 8) | 'initial_token_attention' | cumul=0.1011%
#   [SEED] k=015 | Head (3, 0) | 'initial_token_attention' | cumul=-0.0733%
#   [SEED] k=016 | Head (0, 1) | 'repeated_attention' | cumul=-0.0823%
#   [SEED] k=017 | Head (9, 6) | 'initial_token_attention' | cumul=0.0840%
#   [SEED] k=018 | Head (9, 9) | 'sentence_start_dominance' | cumul=0.2021%
#   [SEED] k=019 | Head (9, 5) | 'sentence_initial_dominance' | cumul=-1.7203%
#   [SEED] k=020 | Head (8, 1) | 'initial_token_attention' | cumul=-1.9936%
#   [SEED] k=021 | Head (10, 10) | 'initial_token_attention' | cumul=-1.8115%
#   [SEED] k=022 | Head (9, 11) | 'initial_token_attention' | cumul=-1.4920%
#   [SEED] k=023 | Head (3, 4) | 'initial_token_attention' | cumul=-1.6696%
#   [SEED] k=024 | Head (11, 7) | 'initial_token_attention' | cumul=-0.7345%
#   [SEED] k=025 | Head (11, 5) | 'initial_token_attention' | cumul=-0.2976%
#   [SEED] k=026 | Head (9, 4) | 'initial_token_attention' | cumul=-0.3463%
#   [SEED] k=027 | Head (7, 10) | 'initial_token_attention' | cumul=-0.1648%
#   [SEED] k=028 | Head (6, 10) | 'initial_token_attention' | cumul=0.0257%
#   [SEED] k=029 | Head (9, 8) | 'sentence_initial_dominance' | cumul=-1.4410%
#   [SEED] k=030 | Head (10, 6) | 'initial_token_attention' | cumul=-1.3665%
#   [SEED] k=031 | Head (11, 1) | 'sentence_initial_dominance' | cumul=-3.0456%
#   [SEED] k=032 | Head (7, 11) | 'initial_token_attention' | cumul=-2.9486%
#   [SEED] k=033 | Head (6, 2) | 'sentence_initial_dominance' | cumul=-4.1300%
#   [SEED] k=034 | Head (7, 6) | 'sentence_initial_dominance' | cumul=-5.0680%
#   [SEED] k=035 | Head (8, 3) | 'initial_token_attention' | cumul=-4.9025%
#   [SEED] k=036 | Head (5, 9) | 'sentence_initial_dominance' | cumul=-5.5712%
#   [SEED] k=037 | Head (10, 3) | 'sentence_initial_dominance' | cumul=-7.4502%
#   [SEED] k=038 | Head (5, 0) | 'initial_token_attention' | cumul=-7.1277%
#   [SEED] k=039 | Head (8, 11) | 'sentence_initial_dominance' | cumul=-8.6579%
#   [SEED] k=040 | Head (9, 1) | 'initial_token_attention' | cumul=-8.4641%
#   [SEED] k=041 | Head (8, 0) | 'sentence_initial_dominance' | cumul=-10.0269%
#   [SEED] k=042 | Head (4, 10) | 'initial_token_attention' | cumul=-9.9291%
#   k=043 | Head (10, 7) | Rank-1 'token_reinforcement' | cumul=-2.0847%
#   k=044 | Head (5, 11) | Rank-1 'initial_token_reference_attention' | cumul=-1.3521%
#   k=045 | Head (0, 10) | Rank-1 'uniform_lower_diagonal' | cumul=-1.2336%
#   k=046 | Head (6, 5) | Rank-1 'token_reinforcement' | cumul=-1.4316%
#   k=047 | Head (1, 10) | Rank-1 'uniform_lower_diagonal' | cumul=-1.5220%
#   k=048 | Head (5, 8) | Rank-1 'token_reinforcement' | cumul=-0.9613%
#   k=049 | Head (5, 6) | Rank-1 'token_reinforcement' | cumul=-0.2191%
#   k=050 | Head (6, 1) | Rank-1 'token_reinforcement' | cumul=0.5869%
#   k=051 | Head (9, 0) | Rank-1 'token_reinforcement' | cumul=1.2219%
#   k=052 | Head (2, 0) | Rank-1 'uniform_lower_diagonal' | cumul=0.9442%
#   k=053 | Head (4, 8) | Rank-1 'token_reinforcement' | cumul=1.7003%
#   k=054 | Head (9, 10) | Rank-1 'token_reinforcement' | cumul=2.1267%
#   k=055 | Head (0, 9) | Rank-1 'uniform_lower_diagonal' | cumul=2.1549%
#   k=056 | Head (0, 11) | Rank-1 'uniform_lower_diagonal' | cumul=1.4397%
#   k=057 | Head (8, 9) | Rank-1 'token_reinforcement' | cumul=2.1631%
#   k=058 | Head (8, 6) | Rank-1 'sentence_beginning_salience' | cumul=2.5094%
#   k=059 | Head (11, 4) | Rank-1 'token_reinforcement' | cumul=2.2853%
#   k=060 | Head (7, 3) | Rank-1 'token_reinforcement' | cumul=1.7684%
#   k=061 | Head (7, 9) | Rank-1 'token_reinforcement' | cumul=2.2969%
#   k=062 | Head (10, 4) | Rank-1 'token_reinforcement' | cumul=2.6155%
#   k=063 | Head (6, 4) | Rank-1 'initial_token_reference_attention' | cumul=2.2233%
#   k=064 | Head (3, 10) | Rank-1 'initial_token_reference_attention' | cumul=2.6593%
#   [SPIKE] Head (1, 2) Rank-1 'uniform_lower_diagonal' marginal=72.66%. Trying Rank-2...
#   [SPIKE] Head (1, 2) Rank-2 'sentence_position_preference' marginal=99.11%. Trying Rank-3...
#   [SPIKE] Head (1, 2) Rank-3 'contextual_anchoring' marginal=37.68%. All ranks exhausted.
#   [SKIP] Head (1, 2): all 3 programs spiked.
#   k=065 | Head (2, 11) | Rank-1 'token_reinforcement' | cumul=2.1995%
#   k=066 | Head (9, 7) | Rank-1 'token_reinforcement' | cumul=1.9467%
#   [SPIKE] Head (11, 6) Rank-1 'sentence_beginning_salience' marginal=2072.06%. Trying Rank-2...
#   k=067 | Head (11, 6) | Rank-2 'initial_element_reinforcement' | cumul=1.9467%
#   k=068 | Head (9, 2) | Rank-1 'token_reinforcement' | cumul=1.7214%
#   k=069 | Head (2, 6) | Rank-1 'initial_token_reference_attention' | cumul=1.7847%
#   k=070 | Head (2, 7) | Rank-1 'uniform_lower_diagonal' | cumul=1.7985%
#   k=071 | Head (0, 5) | Rank-1 'lexical_diversity_focus' | cumul=1.7721%
#   k=072 | Head (1, 4) | Rank-1 'uniform_lower_diagonal' | cumul=2.3813%
#   k=073 | Head (7, 4) | Rank-1 'sentence_beginning_salience' | cumul=3.0080%
#   k=074 | Head (4, 2) | Rank-1 'token_reinforcement' | cumul=3.0150%
#   k=075 | Head (10, 5) | Rank-1 'sentence_beginning_salience' | cumul=2.7035%
#   k=076 | Head (7, 8) | Rank-1 'token_reinforcement' | cumul=2.6961%
#   k=077 | Head (11, 0) | Rank-1 'uniform_lower_diagonal' | cumul=2.9570%
#   k=078 | Head (4, 5) | Rank-1 'token_reinforcement' | cumul=3.1314%
#   k=079 | Head (10, 11) | Rank-1 'token_reinforcement' | cumul=3.4537%
#   k=080 | Head (7, 0) | Rank-1 'token_reinforcement' | cumul=4.3915%
#   k=081 | Head (5, 7) | Rank-1 'token_reinforcement' | cumul=4.7460%
#   k=082 | Head (8, 2) | Rank-1 'token_reinforcement' | cumul=4.6127%
#   k=083 | Head (0, 0) | Rank-1 'uniform_lower_diagonal' | cumul=4.1538%
#   k=084 | Head (2, 1) | Rank-1 'token_reinforcement' | cumul=4.9178%
#   k=085 | Head (8, 10) | Rank-1 'token_reinforcement' | cumul=6.0492%
#   k=086 | Head (2, 10) | Rank-1 'uniform_lower_diagonal' | cumul=6.3744%
#   k=087 | Head (5, 10) | Rank-1 'token_reinforcement' | cumul=8.7386%
#   k=088 | Head (1, 7) | Rank-1 'uniform_lower_diagonal' | cumul=8.5223%
#   k=089 | Head (1, 11) | Rank-1 'lexical_diversity_focus' | cumul=8.4421%
#   k=090 | Head (4, 7) | Rank-1 'first_token_dominance' | cumul=9.0208%
#   k=091 | Head (10, 9) | Rank-1 'token_reinforcement' | cumul=10.7233%
#   k=092 | Head (1, 6) | Rank-1 'uniform_lower_diagonal' | cumul=10.7782%
#   k=093 | Head (0, 3) | Rank-1 'rare_word_dominance' | cumul=10.7961%
#   k=094 | Head (3, 5) | Rank-1 'token_reinforcement' | cumul=11.5502%
#   k=095 | Head (2, 5) | Rank-1 'uniform_lower_diagonal' | cumul=11.9859%
#   k=096 | Head (4, 4) | Rank-1 'token_reinforcement' | cumul=12.4188%
#   k=097 | Head (8, 7) | Rank-1 'token_reinforcement' | cumul=13.4471%
#   k=098 | Head (3, 7) | Rank-1 'previous_attention' | cumul=14.9063%
#   k=099 | Head (11, 3) | Rank-1 'token_reinforcement' | cumul=14.8842%
#   k=100 | Head (1, 8) | Rank-1 'uniform_lower_diagonal' | cumul=15.1787%
#   k=101 | Head (7, 5) | Rank-1 'token_reinforcement' | cumul=16.7655%
#   k=102 | Head (4, 0) | Rank-1 'initial_token_reference_attention' | cumul=19.0576%
#   k=103 | Head (11, 10) | Rank-1 'initial_token_reference_attention' | cumul=20.0331%
#   k=104 | Head (3, 3) | Rank-1 'initial_token_reference_attention' | cumul=21.0034%
#   k=105 | Head (6, 3) | Rank-1 'token_reinforcement' | cumul=22.1621%
#   k=106 | Head (8, 5) | Rank-1 'token_reinforcement' | cumul=23.5143%
#   k=107 | Head (0, 6) | Rank-1 'uniform_lower_diagonal' | cumul=24.9211%
#   k=108 | Head (6, 11) | Rank-1 'token_reinforcement' | cumul=26.0055%
#   k=109 | Head (5, 2) | Rank-1 'token_reinforcement' | cumul=26.3171%
#   k=110 | Head (1, 9) | Rank-1 'uniform_lower_diagonal' | cumul=26.9350%
#   k=111 | Head (2, 3) | Rank-1 'uniform_lower_diagonal' | cumul=27.4116%
#   k=112 | Head (0, 8) | Rank-1 'uniform_lower_diagonal' | cumul=28.0894%
#   k=113 | Head (6, 0) | Rank-1 'sentence_position_preference' | cumul=30.7265%
#   k=114 | Head (6, 8) | Rank-1 'token_reinforcement' | cumul=32.3563%
#   k=115 | Head (3, 1) | Rank-1 'initial_token_reference_attention' | cumul=35.2646%
#   k=116 | Head (8, 4) | Rank-1 'token_reinforcement' | cumul=36.0559%
#   k=117 | Head (4, 6) | Rank-1 'token_reinforcement' | cumul=38.6752%
#   k=118 | Head (1, 0) | Rank-1 'uniform_lower_diagonal' | cumul=39.6383%
#   k=119 | Head (6, 7) | Rank-1 'token_reinforcement' | cumul=42.5895%
#   k=120 | Head (3, 9) | Rank-1 'initial_token_reference_attention' | cumul=45.3980%
#   k=121 | Head (8, 8) | Rank-1 'token_reinforcement' | cumul=48.8288%
#   k=122 | Head (2, 9) | Rank-1 'uniform_lower_diagonal' | cumul=52.9375%
#   k=123 | Head (11, 11) | Rank-1 'initial_token_reference_attention' | cumul=53.0212%
#   k=124 | Head (0, 2) | Rank-1 'uniform_lower_diagonal' | cumul=53.9606%
#   k=125 | Head (2, 2) | Rank-1 'previous_attention' | cumul=57.5086%
#   k=126 | Head (1, 3) | Rank-1 'initial_token_reference_attention' | cumul=61.9465%
#   [STOP] Cumulative 69.55% > 66.0%. Ending shuffle 1 early.
#   ✓ Saved 126 rows → ../results/replacement_run/shuffles/gpt2_top3_shuffle_1.csv
#
# ── Shuffle 2/32 ──────────────────────────────
#   [SEED] k=001 | Head (10, 2) | 'initial_token_attention' | cumul=0.0083%
#   [SEED] k=002 | Head (10, 1) | 'initial_token_attention' | cumul=0.0086%
#   [SEED] k=003 | Head (6, 9) | 'cls_attention' | cumul=-0.6633%
#   [SEED] k=004 | Head (5, 1) | 'cls_attention' | cumul=-0.6252%
#   [SEED] k=005 | Head (7, 2) | 'cls_attention' | cumul=-0.4608%
#   [SEED] k=006 | Head (4, 11) | 'previous_attention' | cumul=-0.1323%
#   [SEED] k=007 | Head (7, 1) | 'initial_token_attention' | cumul=0.1771%
#   [SEED] k=008 | Head (11, 9) | 'initial_token_attention' | cumul=-0.2135%
#   [SEED] k=009 | Head (10, 0) | 'initial_token_attention' | cumul=-0.2058%
#   [SEED] k=010 | Head (11, 2) | 'initial_token_attention' | cumul=1.0039%
#   [SEED] k=011 | Head (7, 7) | 'initial_token_attention' | cumul=0.9243%
#   [SEED] k=012 | Head (5, 5) | 'initial_token_attention' | cumul=0.6362%
#   [SEED] k=013 | Head (6, 6) | 'initial_token_attention' | cumul=0.4550%
#   [SEED] k=014 | Head (10, 8) | 'initial_token_attention' | cumul=0.1011%
#   [SEED] k=015 | Head (3, 0) | 'initial_token_attention' | cumul=-0.0733%
#   [SEED] k=016 | Head (0, 1) | 'repeated_attention' | cumul=-0.0823%
#   [SEED] k=017 | Head (9, 6) | 'initial_token_attention' | cumul=0.0840%
#   [SEED] k=018 | Head (9, 9) | 'sentence_start_dominance' | cumul=0.2021%
#   [SEED] k=019 | Head (9, 5) | 'sentence_initial_dominance' | cumul=-1.7203%
#   [SEED] k=020 | Head (8, 1) | 'initial_token_attention' | cumul=-1.9936%
#   [SEED] k=021 | Head (10, 10) | 'initial_token_attention' | cumul=-1.8115%
#   [SEED] k=022 | Head (9, 11) | 'initial_token_attention' | cumul=-1.4920%
#   [SEED] k=023 | Head (3, 4) | 'initial_token_attention' | cumul=-1.6696%
#   [SEED] k=024 | Head (11, 7) | 'initial_token_attention' | cumul=-0.7345%
#   [SEED] k=025 | Head (11, 5) | 'initial_token_attention' | cumul=-0.2976%
#   [SEED] k=026 | Head (9, 4) | 'initial_token_attention' | cumul=-0.3463%
#   [SEED] k=027 | Head (7, 10) | 'initial_token_attention' | cumul=-0.1648%
#   [SEED] k=028 | Head (6, 10) | 'initial_token_attention' | cumul=0.0257%
#   [SEED] k=029 | Head (9, 8) | 'sentence_initial_dominance' | cumul=-1.4410%
#   [SEED] k=030 | Head (10, 6) | 'initial_token_attention' | cumul=-1.3665%
#   [SEED] k=031 | Head (11, 1) | 'sentence_initial_dominance' | cumul=-3.0456%
#   [SEED] k=032 | Head (7, 11) | 'initial_token_attention' | cumul=-2.9486%
#   [SEED] k=033 | Head (6, 2) | 'sentence_initial_dominance' | cumul=-4.1300%
#   [SEED] k=034 | Head (7, 6) | 'sentence_initial_dominance' | cumul=-5.0680%
#   [SEED] k=035 | Head (8, 3) | 'initial_token_attention' | cumul=-4.9025%
#   [SEED] k=036 | Head (5, 9) | 'sentence_initial_dominance' | cumul=-5.5712%
#   [SEED] k=037 | Head (10, 3) | 'sentence_initial_dominance' | cumul=-7.4502%
#   [SEED] k=038 | Head (5, 0) | 'initial_token_attention' | cumul=-7.1277%
#   [SEED] k=039 | Head (8, 11) | 'sentence_initial_dominance' | cumul=-8.6579%
#   [SEED] k=040 | Head (9, 1) | 'initial_token_attention' | cumul=-8.4641%
#   [SEED] k=041 | Head (8, 0) | 'sentence_initial_dominance' | cumul=-10.0269%
#   [SEED] k=042 | Head (4, 10) | 'initial_token_attention' | cumul=-9.9291%
#   [SPIKE] Head (9, 0) Rank-1 'token_reinforcement' marginal=8.22%. Trying Rank-2...
#   [SPIKE] Head (9, 0) Rank-2 'sentence_beginning_salience' marginal=8.31%. Trying Rank-3...
#   k=043 | Head (9, 0) | Rank-3 'initial_element_reinforcement' | cumul=-2.3042%
#   k=044 | Head (0, 9) | Rank-1 'uniform_lower_diagonal' | cumul=-2.2191%
#   k=045 | Head (9, 7) | Rank-1 'token_reinforcement' | cumul=-2.5389%
#   k=046 | Head (11, 4) | Rank-1 'token_reinforcement' | cumul=-2.8761%
#   [SPIKE] Head (1, 2) Rank-1 'uniform_lower_diagonal' marginal=68.71%. Trying Rank-2...
#   [SPIKE] Head (1, 2) Rank-2 'sentence_position_preference' marginal=99.74%. Trying Rank-3...
#   [SPIKE] Head (1, 2) Rank-3 'contextual_anchoring' marginal=35.58%. All ranks exhausted.
#   [SKIP] Head (1, 2): all 3 programs spiked.
#   [SPIKE] Head (11, 6) Rank-1 'sentence_beginning_salience' marginal=1973.77%. Trying Rank-2...
#   k=047 | Head (11, 6) | Rank-2 'initial_element_reinforcement' | cumul=-2.8761%
#   k=048 | Head (0, 10) | Rank-1 'uniform_lower_diagonal' | cumul=-2.8098%
#   k=049 | Head (11, 10) | Rank-1 'initial_token_reference_attention' | cumul=-2.2022%
#   k=050 | Head (3, 10) | Rank-1 'initial_token_reference_attention' | cumul=-1.8450%
#   k=051 | Head (0, 5) | Rank-1 'lexical_diversity_focus' | cumul=-1.8244%
#   k=052 | Head (2, 11) | Rank-1 'token_reinforcement' | cumul=-2.1536%
#   k=053 | Head (6, 5) | Rank-1 'token_reinforcement' | cumul=-2.3169%
#   k=054 | Head (5, 7) | Rank-1 'token_reinforcement' | cumul=-2.1929%
#   k=055 | Head (10, 11) | Rank-1 'token_reinforcement' | cumul=-1.8921%
#   k=056 | Head (1, 4) | Rank-1 'uniform_lower_diagonal' | cumul=-1.3110%
#   k=057 | Head (9, 2) | Rank-1 'token_reinforcement' | cumul=-1.6017%
#   k=058 | Head (10, 4) | Rank-1 'token_reinforcement' | cumul=-1.2840%
#   k=059 | Head (11, 0) | Rank-1 'uniform_lower_diagonal' | cumul=-1.0748%
#   k=060 | Head (4, 2) | Rank-1 'token_reinforcement' | cumul=-1.2950%
#   k=061 | Head (8, 6) | Rank-1 'sentence_beginning_salience' | cumul=-0.9906%
#   k=062 | Head (1, 8) | Rank-1 'uniform_lower_diagonal' | cumul=-1.1017%
#   k=063 | Head (4, 8) | Rank-1 'token_reinforcement' | cumul=-0.3425%
#   k=064 | Head (8, 10) | Rank-1 'token_reinforcement' | cumul=0.5550%
#   k=065 | Head (5, 11) | Rank-1 'initial_token_reference_attention' | cumul=1.5164%
#   k=066 | Head (4, 4) | Rank-1 'token_reinforcement' | cumul=2.0765%
#   k=067 | Head (0, 3) | Rank-1 'rare_word_dominance' | cumul=2.0744%
#   k=068 | Head (7, 0) | Rank-1 'token_reinforcement' | cumul=2.5430%
#   k=069 | Head (10, 7) | Rank-1 'token_reinforcement' | cumul=2.8448%
#   k=070 | Head (7, 9) | Rank-1 'token_reinforcement' | cumul=3.3427%
#   k=071 | Head (0, 6) | Rank-1 'uniform_lower_diagonal' | cumul=3.6292%
#   k=072 | Head (6, 1) | Rank-1 'token_reinforcement' | cumul=4.4473%
#   k=073 | Head (7, 5) | Rank-1 'token_reinforcement' | cumul=5.2969%
#   k=074 | Head (2, 7) | Rank-1 'uniform_lower_diagonal' | cumul=5.3667%
#   k=075 | Head (0, 8) | Rank-1 'uniform_lower_diagonal' | cumul=5.0875%
#   k=076 | Head (8, 7) | Rank-1 'token_reinforcement' | cumul=5.4843%
#   k=077 | Head (10, 5) | Rank-1 'sentence_beginning_salience' | cumul=5.2127%
#   k=078 | Head (7, 4) | Rank-1 'sentence_beginning_salience' | cumul=5.7332%
#   k=079 | Head (4, 6) | Rank-1 'token_reinforcement' | cumul=6.2459%
#   k=080 | Head (4, 9) | Rank-1 'sentence_position_preference' | cumul=6.7788%
#   k=081 | Head (5, 6) | Rank-1 'token_reinforcement' | cumul=8.0113%
#   k=082 | Head (9, 3) | Rank-1 'initial_token_reference_attention' | cumul=8.0605%
#   k=083 | Head (3, 5) | Rank-1 'token_reinforcement' | cumul=8.4673%
#   k=084 | Head (7, 3) | Rank-1 'token_reinforcement' | cumul=7.7487%
#   k=085 | Head (0, 2) | Rank-1 'uniform_lower_diagonal' | cumul=7.8555%
#   k=086 | Head (10, 9) | Rank-1 'token_reinforcement' | cumul=9.1672%
#   k=087 | Head (6, 8) | Rank-1 'token_reinforcement' | cumul=10.0735%
#   k=088 | Head (2, 10) | Rank-1 'uniform_lower_diagonal' | cumul=10.4669%
#   k=089 | Head (5, 8) | Rank-1 'token_reinforcement' | cumul=11.8278%
#   k=090 | Head (2, 6) | Rank-1 'initial_token_reference_attention' | cumul=11.7308%
#   k=091 | Head (3, 11) | Rank-1 'uniform_lower_diagonal' | cumul=12.5612%
#   k=092 | Head (11, 3) | Rank-1 'token_reinforcement' | cumul=12.7814%
#   k=093 | Head (8, 4) | Rank-1 'token_reinforcement' | cumul=12.9713%
#   k=094 | Head (5, 10) | Rank-1 'token_reinforcement' | cumul=15.4470%
#   k=095 | Head (3, 3) | Rank-1 'initial_token_reference_attention' | cumul=16.2174%
#   k=096 | Head (9, 10) | Rank-1 'token_reinforcement' | cumul=17.1712%
#   k=097 | Head (1, 7) | Rank-1 'uniform_lower_diagonal' | cumul=16.9888%
#   k=098 | Head (0, 11) | Rank-1 'uniform_lower_diagonal' | cumul=16.6607%
#   k=099 | Head (3, 6) | Rank-1 'uniform_lower_diagonal' | cumul=18.1403%
#   k=100 | Head (8, 2) | Rank-1 'token_reinforcement' | cumul=18.0803%
#   k=101 | Head (0, 0) | Rank-1 'uniform_lower_diagonal' | cumul=17.6060%
#   k=102 | Head (6, 3) | Rank-1 'token_reinforcement' | cumul=18.3404%
#   k=103 | Head (4, 3) | Rank-1 'initial_token_reference_attention' | cumul=19.8307%
#   k=104 | Head (2, 1) | Rank-1 'token_reinforcement' | cumul=21.5206%
#   k=105 | Head (3, 9) | Rank-1 'initial_token_reference_attention' | cumul=22.8474%
#   k=106 | Head (6, 7) | Rank-1 'token_reinforcement' | cumul=24.9747%
#   k=107 | Head (3, 1) | Rank-1 'initial_token_reference_attention' | cumul=27.3065%
#   k=108 | Head (8, 8) | Rank-1 'token_reinforcement' | cumul=28.9702%
#   k=109 | Head (2, 0) | Rank-1 'uniform_lower_diagonal' | cumul=29.2520%
#   k=110 | Head (6, 0) | Rank-1 'sentence_position_preference' | cumul=31.3846%

# %%
# ============================================================
# Smart-Shuffle Top-3 Backtracking Experiment  (GPT-2 only)
#
# Steps 1-42 are hardcoded from the known-good run that goes
# negative. The shuffled backtracking search picks up from k=43,
# seeded with the real accepted_heads_mapping so hooks are correct.
#
# For each shuffle (steps 43+):
#   - constrained_shuffle the REMAINING heads (those not in seed)
#   - For each head try Rank-1 program (highest mean IOU).
#     If marginal PPL > 10% → try Rank-2 → Rank-3 → skip.
#   - Stop shuffle if cumulative increase > 1000%.
#
# Saves each shuffle to:
#   ../results/replacement_run/shuffles/gpt2_top3_shuffle_{idx}.csv
#
# Depends on (already defined in this notebook):
#   prepare_sentence, constrained_shuffle_df, all_programs, DATA_DIR
# ============================================================

import ast
import io
import pathlib
import numpy as np
import pandas as pd
import torch
import torch.nn.functional as F
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# ── Config ────────────────────────────────────────────────────────────────────
N_SHUFFLES      = 32     # shuffles to run overnight
SPIKE_THRESHOLD = 5.0   # marginal % spike cutoff
CUMUL_LIMIT     = 25.0 # cumulative % that stops a shuffle early
TOP_K           = 5      # ranked fallbacks per head
SIGMA           = 20    # constrained-shuffle noise std-dev
NUM_SENTENCES   = 7
MODEL_KEY       = "gpt2"
# ──────────────────────────────────────────────────────────────────────────────

np.random.seed(42)
pathlib.Path("../results/replacement_run/shuffles").mkdir(parents=True, exist_ok=True)

# ── 1. Hardcoded seed — the 42 known-good replacements ───────────────────────
SEED_CSV = """\
k,head,program,strategy,increase,kl_div
1,"(10, 2)",initial_token_attention,smart,0.008307712197430366,0.001065253290653345
2,"(10, 1)",initial_token_attention,smart,0.008615101288974697,0.002011389515728297
3,"(6, 9)",cls_attention,smart,-0.6633480896656324,0.0035132152349979153
4,"(5, 1)",cls_attention,smart,-0.6251862761961215,0.006047547392081469
5,"(7, 2)",cls_attention,smart,-0.46079214514841105,0.007481090293440502
6,"(4, 11)",previous_attention,smart,-0.13227185889340462,0.008721561353304423
7,"(7, 1)",initial_token_attention,smart,0.17710685905574153,0.010167443108512088
8,"(11, 9)",initial_token_attention,smart,-0.21351424777165198,0.012792042766814121
9,"(10, 0)",initial_token_attention,smart,-0.20580384016925668,0.014605110042029992
10,"(11, 2)",initial_token_attention,smart,1.0038506419448705,0.017880274574272336
11,"(7, 7)",initial_token_attention,smart,0.9243134907948786,0.01833117724279873
12,"(5, 5)",initial_token_attention,smart,0.6361639857461907,0.020740094240172768
13,"(6, 6)",initial_token_attention,smart,0.4549912320044895,0.022376552417408675
14,"(10, 8)",initial_token_attention,smart,0.10113471498162603,0.024186684540472923
15,"(3, 0)",initial_token_attention,smart,-0.07333341108278439,0.024121518884785472
16,"(0, 1)",repeated_attention,smart,-0.08229663632499523,0.02414339571725577
17,"(9, 6)",initial_token_attention,smart,0.08397755045552856,0.02528198662563227
18,"(9, 9)",sentence_start_dominance,smart,0.20214879514749776,0.028346376998815686
19,"(9, 5)",sentence_initial_dominance,smart,-1.720343203993684,0.028143282887758688
20,"(8, 1)",initial_token_attention,smart,-1.9935828405133866,0.03228664654074237
21,"(10, 10)",initial_token_attention,smart,-1.8115494947969548,0.033806850896216926
22,"(9, 11)",initial_token_attention,smart,-1.4920480247818013,0.03443914557225071
23,"(3, 4)",initial_token_attention,smart,-1.6696160646077265,0.03623579588253051
24,"(11, 7)",initial_token_attention,smart,-0.7344831094723496,0.039611174650490286
25,"(11, 5)",initial_token_attention,smart,-0.2976022499177347,0.04332037792075425
26,"(9, 4)",initial_token_attention,smart,-0.3462717356001825,0.043809333558892834
27,"(7, 10)",initial_token_attention,smart,-0.1648400476295224,0.04461271269246936
28,"(6, 10)",initial_token_attention,smart,0.02574922911360261,0.04931675942847505
29,"(9, 8)",sentence_initial_dominance,smart,-1.440972483437424,0.0490389868686907
30,"(10, 6)",initial_token_attention,smart,-1.36646972737408,0.0513438879372552
31,"(11, 1)",sentence_initial_dominance,smart,-3.0456133521445476,0.051345947170630096
32,"(7, 11)",initial_token_attention,smart,-2.9486139101015043,0.054554718919098376
33,"(6, 2)",sentence_initial_dominance,smart,-4.1299547629687,0.05475393987959251
34,"(7, 6)",sentence_initial_dominance,smart,-5.068048806331123,0.054423859217204155
35,"(8, 3)",initial_token_attention,smart,-4.902484822870978,0.05675411381525919
36,"(5, 9)",sentence_initial_dominance,smart,-5.571243742067339,0.056279577629175036
37,"(10, 3)",sentence_initial_dominance,smart,-7.450234561946978,0.05592323972377926
38,"(5, 0)",initial_token_attention,smart,-7.127710350251196,0.06024578050011769
39,"(8, 11)",sentence_initial_dominance,smart,-8.657863908075072,0.060319892903789876
40,"(9, 1)",initial_token_attention,smart,-8.464149821736362,0.06372750320471823
41,"(8, 0)",sentence_initial_dominance,smart,-10.026851892198312,0.06297878146870062
42,"(4, 10)",initial_token_attention,smart,-9.929107592011958,0.06535566914826632\
"""

seed_df = pd.read_csv(io.StringIO(SEED_CSV))

# Build the seed accepted_heads_mapping: list of (head_tuple, prog_name)
# This is what the hook lookup is built from — must match original format exactly.
SEED_MAPPING = [
    (tuple(ast.literal_eval(row["head"])), row["program"])
    for _, row in seed_df.iterrows()
]
SEED_HEADS = set(h for h, _ in SEED_MAPPING)
SEED_PREV_CUMULATIVE = float(seed_df.iloc[-1]["increase"])  # -9.929...

print(f"[INFO] Seed loaded: {len(SEED_MAPPING)} hardcoded replacements.")
print(f"[INFO] Seed cumulative PPL increase: {SEED_PREV_CUMULATIVE:.4f}%")

# ── 2. Build top-3 program mapping from IOU scores ───────────────────────────
iou_csv  = f"{DATA_DIR}/iou_scores_{MODEL_KEY}.csv"
iou_df   = pd.read_csv(iou_csv)
mean_iou = (
    iou_df.groupby(["layer", "head", "program_idx"])["iou_score"]
    .mean()
    .reset_index()
)

head_program_map = {}  # (layer, head) -> [(rank, prog_name), ...]
rank1_rows       = []  # for shuffling — only non-seed heads

for (layer, head), grp in mean_iou.groupby(["layer", "head"]):
    top    = grp.nlargest(TOP_K, "iou_score").reset_index(drop=True)
    ranked = []
    for rank_idx, (_, row) in enumerate(top.iterrows(), start=1):
        p_idx     = int(row["program_idx"])
        prog_name = all_programs[p_idx].__name__
        ranked.append((rank_idx, prog_name))
        if rank_idx == 1 and (int(layer), int(head)) not in SEED_HEADS:
            rank1_rows.append({"layer": layer, "head": head, "iou_score": row["iou_score"]})
    head_program_map[(int(layer), int(head))] = ranked

# Remaining heads (not in seed), ordered by rank-1 IOU desc — this is what we shuffle
remaining_rank1_df = pd.DataFrame(rank1_rows).sort_values("iou_score", ascending=False).reset_index(drop=True)

print(f"[INFO] {len(head_program_map)} total unique heads, {len(remaining_rank1_df)} remaining after seed.")

# ── 3. Baseline (computed once, reused across all shuffles) ───────────────────
tokenizer  = GPT2Tokenizer.from_pretrained("gpt2")
eval_sents = pd.read_json("../data/generic_sentences.json")[0].tolist()[:NUM_SENTENCES]

print("Calculating baseline perplexities...")
_base  = GPT2LMHeadModel.from_pretrained("gpt2").to("cuda" if torch.cuda.is_available() else "cpu")
_base.eval()
device          = next(_base.parameters()).device
baseline_ppls   = []
baseline_logits = []

for sent in eval_sents:
    active = prepare_sentence(sent, mode="last_word")
    toks   = tokenizer(active, return_tensors="pt").to(device)
    with torch.no_grad():
        out = _base(**toks, labels=toks["input_ids"])
        baseline_ppls.append(torch.exp(out.loss).item())
        baseline_logits.append(out.logits[:, -1, :])

del _base
torch.cuda.empty_cache()
print(f"Baseline complete. Mean PPL: {np.mean(baseline_ppls):.2f}\n")

# ── 4. Hook factory — copied verbatim from run_replacement_experiment_gpt2 ────
def make_smart_hook(lookup, programs_list):
    def compound_hook(module, input, output):
        context_layer = output[0]
        batch, seq_len, hidden_dim = context_layer.shape
        num_heads, head_dim = 12, hidden_dim // 12
        modified_layer = context_layer.view(batch, seq_len, num_heads, head_dim).clone()
        current_sent = getattr(module, '_current_sentence', None)
        if current_sent is None:
            return output
        for head_idx in range(num_heads):
            key = (module.layer_id, head_idx)
            if key in lookup:
                prog_name = lookup[key]
                prog = next((p for p in programs_list if p.__name__ == prog_name), None)
                if prog:
                    try:
                        _, hypo_mat = prog(current_sent, tokenizer)
                        if hypo_mat is not None:
                            hypo_tensor = torch.tensor(hypo_mat).to(device, dtype=modified_layer.dtype)
                            modified_layer[:, :, head_idx, :] = torch.matmul(hypo_tensor, modified_layer[:, :, head_idx, :])
                    except Exception:
                        pass
        return (modified_layer.view(batch, seq_len, hidden_dim),) + output[1:]
    return compound_hook

# ── 5. Trial evaluator — inner loop from run_replacement_experiment_gpt2 ──────
def evaluate_candidate(accepted_heads_mapping, candidate_head, candidate_prog):
    """
    Loads a fresh GPT-2, registers hooks for all accepted heads + candidate,
    evaluates, cleans up. Returns (mean_pct_increase, mean_kl_div).

    accepted_heads_mapping: list of (head_tuple, prog_name)
    """
    trial_mapping   = accepted_heads_mapping + [(candidate_head, candidate_prog)]
    trial_lookup    = {tuple(map(int, h)): p for h, p in trial_mapping}
    relevant_layers = set(h[0] for h in trial_lookup)

    model_k = GPT2LMHeadModel.from_pretrained("gpt2").to(device)
    model_k.eval()

    hook_fn      = make_smart_hook(trial_lookup, all_programs)
    hook_handles = []
    for l_idx in range(12):
        target          = model_k.transformer.h[l_idx].attn
        target.layer_id = l_idx
        if l_idx in relevant_layers:
            hook_handles.append(target.register_forward_hook(hook_fn))

    replaced_ppls, kl_divergences = [], []
    for i, sent in enumerate(eval_sents):
        active_sent = prepare_sentence(sent, mode="last_word")
        for l_idx in relevant_layers:
            model_k.transformer.h[l_idx].attn._current_sentence = active_sent
        toks = tokenizer(active_sent, return_tensors="pt").to(device)
        with torch.no_grad():
            out_rep = model_k(**toks, labels=toks["input_ids"])
            replaced_ppls.append(torch.exp(out_rep.loss).item())
            log_probs_new  = F.log_softmax(out_rep.logits[:, -1, :], dim=-1)
            probs_baseline = F.softmax(baseline_logits[i], dim=-1)
            kl_divergences.append(F.kl_div(log_probs_new, probs_baseline, reduction='batchmean').item())

    for handle in hook_handles:
        handle.remove()
    del model_k
    torch.cuda.empty_cache()

    mean_pct = float(np.mean([(r - b) / b * 100 for r, b in zip(replaced_ppls, baseline_ppls)]))
    mean_kl  = float(np.mean(kl_divergences))
    return mean_pct, mean_kl

# ── 6. Outer shuffle loop ─────────────────────────────────────────────────────
for shuffle_idx in range(1, N_SHUFFLES + 1):
    print(f"── Shuffle {shuffle_idx}/{N_SHUFFLES} ──────────────────────────────")

    # Seed results are identical across every shuffle — copy them in directly
    shuffle_results = [
        {
            "k":             int(row["k"]),
            "head":          row["head"],
            "program":       row["program"],
            "accepted_rank": 1,          # seed rows are always rank-1 by definition
            "strategy":      "smart",
            "increase":      float(row["increase"]),
            "kl_div":        float(row["kl_div"]),
            "shuffle_idx":   shuffle_idx,
        }
        for _, row in seed_df.iterrows()
    ]
    for row in shuffle_results:
        print(f"  [SEED] k={row['k']:03d} | Head {row['head']} | '{row['program']}' | cumul={row['increase']:.4f}%")

    # Seed the accepted mapping so hooks include all 42 replacements
    accepted_heads_mapping = list(SEED_MAPPING)   # copy — mutated per shuffle
    k               = len(SEED_MAPPING)           # 42
    prev_cumulative = SEED_PREV_CUMULATIVE        # -9.929...

    # Shuffle only the remaining (non-seed) heads
    shuffled_remaining = constrained_shuffle_df(remaining_rank1_df, sigma=SIGMA)
    head_order = [(int(r["layer"]), int(r["head"])) for _, r in shuffled_remaining.iterrows()]

    for head_tuple in head_order:
        candidates = head_program_map.get(head_tuple, [])
        if not candidates:
            print(f"  [WARN] No candidates for head {head_tuple}. Skipping.")
            continue

        accepted_rank = None
        accepted_prog = None
        mean_pct      = None
        mean_kl       = None

        # ── Backtracking: Rank 1 → 2 → 3 ──────────────────────────────────
        for rank, prog_name in candidates:
            mean_pct, mean_kl = evaluate_candidate(accepted_heads_mapping, head_tuple, prog_name)
            marginal          = mean_pct - prev_cumulative

            if marginal > SPIKE_THRESHOLD:
                n_remaining = len(candidates) - rank
                print(
                    f"  [SPIKE] Head {head_tuple} Rank-{rank} '{prog_name}' "
                    f"marginal={marginal:.2f}%. "
                    + (f"Trying Rank-{rank+1}..." if n_remaining > 0 else "All ranks exhausted.")
                )
                torch.cuda.empty_cache()
                continue

            accepted_rank = rank
            accepted_prog = prog_name
            break

        if accepted_rank is None:
            print(f"  [SKIP] Head {head_tuple}: all {len(candidates)} programs spiked.")
            continue

        if mean_pct > CUMUL_LIMIT:
            print(f"  [STOP] Cumulative {mean_pct:.2f}% > {CUMUL_LIMIT}%. Ending shuffle {shuffle_idx} early.")
            break

        k += 1
        accepted_heads_mapping.append((head_tuple, accepted_prog))
        prev_cumulative = mean_pct

        shuffle_results.append({
            "k":             k,
            "head":          str(head_tuple),
            "program":       accepted_prog,
            "accepted_rank": accepted_rank,
            "strategy":      "smart",
            "increase":      round(mean_pct, 6),
            "kl_div":        round(mean_kl, 6),
            "shuffle_idx":   shuffle_idx,
        })
        print(f"  k={k:03d} | Head {head_tuple} | Rank-{accepted_rank} '{accepted_prog}' | cumul={mean_pct:.4f}%")

    # Save this shuffle
    save_path = f"../results/replacement_run/shuffles/{MODEL_KEY}_top3_shuffle_{shuffle_idx+32}.csv"
    pd.DataFrame(shuffle_results).to_csv(save_path, index=False)
    print(f"  ✓ Saved {len(shuffle_results)} rows → {save_path}\n")

print(f"[DONE] All {N_SHUFFLES} shuffles complete.")
# Out:
# [INFO] Seed loaded: 42 hardcoded replacements.
# [INFO] Seed cumulative PPL increase: -9.9291%
# [INFO] 144 total unique heads, 102 remaining after seed.
# Calculating baseline perplexities...
# Baseline complete. Mean PPL: 44.11
#
# ── Shuffle 1/32 ──────────────────────────────
#   [SEED] k=001 | Head (10, 2) | 'initial_token_attention' | cumul=0.0083%
#   [SEED] k=002 | Head (10, 1) | 'initial_token_attention' | cumul=0.0086%
#   [SEED] k=003 | Head (6, 9) | 'cls_attention' | cumul=-0.6633%
#   [SEED] k=004 | Head (5, 1) | 'cls_attention' | cumul=-0.6252%
#   [SEED] k=005 | Head (7, 2) | 'cls_attention' | cumul=-0.4608%
#   [SEED] k=006 | Head (4, 11) | 'previous_attention' | cumul=-0.1323%
#   [SEED] k=007 | Head (7, 1) | 'initial_token_attention' | cumul=0.1771%
#   [SEED] k=008 | Head (11, 9) | 'initial_token_attention' | cumul=-0.2135%
#   [SEED] k=009 | Head (10, 0) | 'initial_token_attention' | cumul=-0.2058%
#   [SEED] k=010 | Head (11, 2) | 'initial_token_attention' | cumul=1.0039%
#   [SEED] k=011 | Head (7, 7) | 'initial_token_attention' | cumul=0.9243%
#   [SEED] k=012 | Head (5, 5) | 'initial_token_attention' | cumul=0.6362%
#   [SEED] k=013 | Head (6, 6) | 'initial_token_attention' | cumul=0.4550%
#   [SEED] k=014 | Head (10, 8) | 'initial_token_attention' | cumul=0.1011%
#   [SEED] k=015 | Head (3, 0) | 'initial_token_attention' | cumul=-0.0733%
#   [SEED] k=016 | Head (0, 1) | 'repeated_attention' | cumul=-0.0823%
#   [SEED] k=017 | Head (9, 6) | 'initial_token_attention' | cumul=0.0840%
#   [SEED] k=018 | Head (9, 9) | 'sentence_start_dominance' | cumul=0.2021%
#   [SEED] k=019 | Head (9, 5) | 'sentence_initial_dominance' | cumul=-1.7203%
#   [SEED] k=020 | Head (8, 1) | 'initial_token_attention' | cumul=-1.9936%
#   [SEED] k=021 | Head (10, 10) | 'initial_token_attention' | cumul=-1.8115%
#   [SEED] k=022 | Head (9, 11) | 'initial_token_attention' | cumul=-1.4920%
#   [SEED] k=023 | Head (3, 4) | 'initial_token_attention' | cumul=-1.6696%
#   [SEED] k=024 | Head (11, 7) | 'initial_token_attention' | cumul=-0.7345%
#   [SEED] k=025 | Head (11, 5) | 'initial_token_attention' | cumul=-0.2976%
#   [SEED] k=026 | Head (9, 4) | 'initial_token_attention' | cumul=-0.3463%
#   [SEED] k=027 | Head (7, 10) | 'initial_token_attention' | cumul=-0.1648%
#   [SEED] k=028 | Head (6, 10) | 'initial_token_attention' | cumul=0.0257%
#   [SEED] k=029 | Head (9, 8) | 'sentence_initial_dominance' | cumul=-1.4410%
#   [SEED] k=030 | Head (10, 6) | 'initial_token_attention' | cumul=-1.3665%
#   [SEED] k=031 | Head (11, 1) | 'sentence_initial_dominance' | cumul=-3.0456%
#   [SEED] k=032 | Head (7, 11) | 'initial_token_attention' | cumul=-2.9486%
#   [SEED] k=033 | Head (6, 2) | 'sentence_initial_dominance' | cumul=-4.1300%
#   [SEED] k=034 | Head (7, 6) | 'sentence_initial_dominance' | cumul=-5.0680%
#   [SEED] k=035 | Head (8, 3) | 'initial_token_attention' | cumul=-4.9025%
#   [SEED] k=036 | Head (5, 9) | 'sentence_initial_dominance' | cumul=-5.5712%
#   [SEED] k=037 | Head (10, 3) | 'sentence_initial_dominance' | cumul=-7.4502%
#   [SEED] k=038 | Head (5, 0) | 'initial_token_attention' | cumul=-7.1277%
#   [SEED] k=039 | Head (8, 11) | 'sentence_initial_dominance' | cumul=-8.6579%
#   [SEED] k=040 | Head (9, 1) | 'initial_token_attention' | cumul=-8.4641%
#   [SEED] k=041 | Head (8, 0) | 'sentence_initial_dominance' | cumul=-10.0269%
#   [SEED] k=042 | Head (4, 10) | 'initial_token_attention' | cumul=-9.9291%
#   [SPIKE] Head (10, 7) Rank-1 'token_reinforcement' marginal=5.48%. Trying Rank-2...
#   [SPIKE] Head (10, 7) Rank-2 'initial_token_reference_attention' marginal=5.45%. Trying Rank-3...
#   [SPIKE] Head (10, 7) Rank-3 'sentence_beginning_salience' marginal=5.51%. Trying Rank-4...
#   [SPIKE] Head (10, 7) Rank-4 'initial_element_reinforcement' marginal=5.29%. Trying Rank-5...
#   [SPIKE] Head (10, 7) Rank-5 'initial_token_anchoring' marginal=5.51%. All ranks exhausted.
#   [SKIP] Head (10, 7): all 5 programs spiked.
#   [SPIKE] Head (5, 11) Rank-1 'initial_token_reference_attention' marginal=6.10%. Trying Rank-2...
#   [SPIKE] Head (5, 11) Rank-2 'token_reinforcement' marginal=6.17%. Trying Rank-3...
#   [SPIKE] Head (5, 11) Rank-3 'sentence_beginning_salience' marginal=6.29%. Trying Rank-4...
#   [SPIKE] Head (5, 11) Rank-4 'initial_element_reinforcement' marginal=5.29%. Trying Rank-5...
#   [SPIKE] Head (5, 11) Rank-5 'initial_token_anchoring' marginal=6.29%. All ranks exhausted.
#   [SKIP] Head (5, 11): all 5 programs spiked.
#   [SPIKE] Head (0, 10) Rank-1 'uniform_lower_diagonal' marginal=5.33%. Trying Rank-2...
#   [SPIKE] Head (0, 10) Rank-2 'sentence_position_preference' marginal=5.73%. Trying Rank-3...
#   [SPIKE] Head (0, 10) Rank-3 'contextual_anchoring' marginal=5.32%. Trying Rank-4...
#   [SPIKE] Head (0, 10) Rank-4 'quotation_association' marginal=5.13%. Trying Rank-5...
#   [SPIKE] Head (0, 10) Rank-5 'appositive_phrase_attention' marginal=5.13%. All ranks exhausted.
#   [SKIP] Head (0, 10): all 5 programs spiked.
#   [SPIKE] Head (1, 10) Rank-1 'uniform_lower_diagonal' marginal=5.01%. Trying Rank-2...
#   [SPIKE] Head (1, 10) Rank-2 'contextual_anchoring' marginal=5.06%. Trying Rank-3...
#   k=043 | Head (1, 10) | Rank-3 'sentence_position_preference' | cumul=-5.0509%
#   k=044 | Head (5, 8) | Rank-1 'token_reinforcement' | cumul=-4.5968%
#   k=045 | Head (6, 5) | Rank-1 'token_reinforcement' | cumul=-4.6862%
#   k=046 | Head (0, 9) | Rank-1 'uniform_lower_diagonal' | cumul=-4.2482%
#   k=047 | Head (9, 0) | Rank-1 'token_reinforcement' | cumul=-3.6420%
#   k=048 | Head (0, 11) | Rank-1 'uniform_lower_diagonal' | cumul=-3.7703%
#   k=049 | Head (5, 6) | Rank-1 'token_reinforcement' | cumul=-3.1981%
#   k=050 | Head (8, 6) | Rank-1 'sentence_beginning_salience' | cumul=-3.1676%
#   k=051 | Head (4, 8) | Rank-1 'token_reinforcement' | cumul=-2.3439%
#   k=052 | Head (8, 9) | Rank-1 'token_reinforcement' | cumul=-1.7040%
#   k=053 | Head (6, 1) | Rank-1 'token_reinforcement' | cumul=-0.8919%
#   k=054 | Head (11, 4) | Rank-1 'token_reinforcement' | cumul=-1.3375%
#   [SPIKE] Head (11, 6) Rank-1 'sentence_beginning_salience' marginal=2048.20%. Trying Rank-2...
#   k=055 | Head (11, 6) | Rank-2 'initial_element_reinforcement' | cumul=-1.3375%
#   k=056 | Head (7, 9) | Rank-1 'token_reinforcement' | cumul=-0.6601%
#   k=057 | Head (7, 3) | Rank-1 'token_reinforcement' | cumul=-0.5678%
#   k=058 | Head (6, 4) | Rank-1 'initial_token_reference_attention' | cumul=-0.6306%
#   k=059 | Head (3, 10) | Rank-1 'initial_token_reference_attention' | cumul=-0.3737%
#   k=060 | Head (9, 10) | Rank-1 'token_reinforcement' | cumul=-0.0920%
#   k=061 | Head (10, 4) | Rank-1 'token_reinforcement' | cumul=0.3505%
#   k=062 | Head (0, 5) | Rank-1 'lexical_diversity_focus' | cumul=0.3139%
#   [SPIKE] Head (1, 2) Rank-1 'uniform_lower_diagonal' marginal=79.32%. Trying Rank-2...
#   [SPIKE] Head (1, 2) Rank-2 'sentence_position_preference' marginal=110.54%. Trying Rank-3...
#   [SPIKE] Head (1, 2) Rank-3 'contextual_anchoring' marginal=40.38%. Trying Rank-4...
#   [SPIKE] Head (1, 2) Rank-4 'quotation_association' marginal=6.35%. Trying Rank-5...
#   [SPIKE] Head (1, 2) Rank-5 'appositive_phrase_attention' marginal=6.35%. All ranks exhausted.
#   [SKIP] Head (1, 2): all 5 programs spiked.
#   k=063 | Head (9, 7) | Rank-1 'token_reinforcement' | cumul=-0.1468%
#   k=064 | Head (9, 2) | Rank-1 'token_reinforcement' | cumul=-0.1285%
#   k=065 | Head (2, 11) | Rank-1 'token_reinforcement' | cumul=-0.0737%
#   k=066 | Head (4, 2) | Rank-1 'token_reinforcement' | cumul=0.2140%
#   k=067 | Head (2, 0) | Rank-1 'uniform_lower_diagonal' | cumul=0.0113%
#   k=068 | Head (10, 11) | Rank-1 'token_reinforcement' | cumul=0.4341%
#   k=069 | Head (2, 7) | Rank-1 'uniform_lower_diagonal' | cumul=0.6112%
#   k=070 | Head (10, 5) | Rank-1 'sentence_beginning_salience' | cumul=0.4439%
#   k=071 | Head (7, 4) | Rank-1 'sentence_beginning_salience' | cumul=1.3581%
#   k=072 | Head (11, 0) | Rank-1 'uniform_lower_diagonal' | cumul=1.6721%
#   k=073 | Head (1, 4) | Rank-1 'uniform_lower_diagonal' | cumul=2.1085%
#   k=074 | Head (5, 7) | Rank-1 'token_reinforcement' | cumul=2.7632%
#   k=075 | Head (0, 3) | Rank-1 'rare_word_dominance' | cumul=2.7065%
#   k=076 | Head (8, 10) | Rank-1 'token_reinforcement' | cumul=3.5642%
#   k=077 | Head (0, 0) | Rank-1 'uniform_lower_diagonal' | cumul=3.3322%
#   k=078 | Head (2, 1) | Rank-1 'token_reinforcement' | cumul=3.6267%
#   k=079 | Head (4, 4) | Rank-1 'token_reinforcement' | cumul=4.4628%
#   k=080 | Head (8, 2) | Rank-1 'token_reinforcement' | cumul=4.3970%
#   k=081 | Head (7, 8) | Rank-1 'token_reinforcement' | cumul=4.1394%
#   k=082 | Head (7, 0) | Rank-1 'token_reinforcement' | cumul=5.5657%
#   k=083 | Head (2, 6) | Rank-1 'initial_token_reference_attention' | cumul=5.6736%
#   k=084 | Head (2, 10) | Rank-1 'uniform_lower_diagonal' | cumul=6.1725%
#   k=085 | Head (4, 5) | Rank-1 'token_reinforcement' | cumul=6.6721%
#   k=086 | Head (1, 7) | Rank-1 'uniform_lower_diagonal' | cumul=6.7643%
#   k=087 | Head (1, 11) | Rank-1 'lexical_diversity_focus' | cumul=6.7402%
#   k=088 | Head (5, 10) | Rank-1 'token_reinforcement' | cumul=8.5948%
#   k=089 | Head (10, 9) | Rank-1 'token_reinforcement' | cumul=10.0309%
#   k=090 | Head (6, 3) | Rank-1 'token_reinforcement' | cumul=10.8698%
#   k=091 | Head (4, 7) | Rank-1 'first_token_dominance' | cumul=11.5836%
#   k=092 | Head (1, 8) | Rank-1 'uniform_lower_diagonal' | cumul=11.6330%
#   k=093 | Head (1, 6) | Rank-1 'uniform_lower_diagonal' | cumul=11.6790%
#   k=094 | Head (11, 10) | Rank-1 'initial_token_reference_attention' | cumul=12.4370%
#   k=095 | Head (11, 3) | Rank-1 'token_reinforcement' | cumul=12.5918%
#   k=096 | Head (3, 5) | Rank-1 'token_reinforcement' | cumul=13.5539%
#   k=097 | Head (7, 5) | Rank-1 'token_reinforcement' | cumul=14.3475%
#   k=098 | Head (8, 7) | Rank-1 'token_reinforcement' | cumul=15.6427%
#   k=099 | Head (3, 3) | Rank-1 'initial_token_reference_attention' | cumul=15.6886%
#   k=100 | Head (0, 6) | Rank-1 'uniform_lower_diagonal' | cumul=15.6789%
#   k=101 | Head (0, 8) | Rank-1 'uniform_lower_diagonal' | cumul=15.5750%
#   k=102 | Head (2, 5) | Rank-1 'uniform_lower_diagonal' | cumul=16.5426%
#   k=103 | Head (4, 0) | Rank-1 'initial_token_reference_attention' | cumul=18.9841%
#   k=104 | Head (0, 2) | Rank-1 'uniform_lower_diagonal' | cumul=19.4041%
#   k=105 | Head (8, 4) | Rank-1 'token_reinforcement' | cumul=20.2989%
#   k=106 | Head (6, 11) | Rank-1 'token_reinforcement' | cumul=21.4894%
#   k=107 | Head (1, 9) | Rank-1 'uniform_lower_diagonal' | cumul=22.4181%
#   k=108 | Head (3, 7) | Rank-1 'previous_attention' | cumul=24.5519%
#   [STOP] Cumulative 25.82% > 25.0%. Ending shuffle 1 early.
#   ✓ Saved 108 rows → ../results/replacement_run/shuffles/gpt2_top3_shuffle_33.csv
#
# ── Shuffle 2/32 ──────────────────────────────
#   [SEED] k=001 | Head (10, 2) | 'initial_token_attention' | cumul=0.0083%
#   [SEED] k=002 | Head (10, 1) | 'initial_token_attention' | cumul=0.0086%
#   [SEED] k=003 | Head (6, 9) | 'cls_attention' | cumul=-0.6633%
#   [SEED] k=004 | Head (5, 1) | 'cls_attention' | cumul=-0.6252%
#   [SEED] k=005 | Head (7, 2) | 'cls_attention' | cumul=-0.4608%
#   [SEED] k=006 | Head (4, 11) | 'previous_attention' | cumul=-0.1323%
#   [SEED] k=007 | Head (7, 1) | 'initial_token_attention' | cumul=0.1771%
#   [SEED] k=008 | Head (11, 9) | 'initial_token_attention' | cumul=-0.2135%
#   [SEED] k=009 | Head (10, 0) | 'initial_token_attention' | cumul=-0.2058%
#   [SEED] k=010 | Head (11, 2) | 'initial_token_attention' | cumul=1.0039%
#   [SEED] k=011 | Head (7, 7) | 'initial_token_attention' | cumul=0.9243%
#   [SEED] k=012 | Head (5, 5) | 'initial_token_attention' | cumul=0.6362%
#   [SEED] k=013 | Head (6, 6) | 'initial_token_attention' | cumul=0.4550%
#   [SEED] k=014 | Head (10, 8) | 'initial_token_attention' | cumul=0.1011%
#   [SEED] k=015 | Head (3, 0) | 'initial_token_attention' | cumul=-0.0733%
#   [SEED] k=016 | Head (0, 1) | 'repeated_attention' | cumul=-0.0823%
#   [SEED] k=017 | Head (9, 6) | 'initial_token_attention' | cumul=0.0840%
#   [SEED] k=018 | Head (9, 9) | 'sentence_start_dominance' | cumul=0.2021%
#   [SEED] k=019 | Head (9, 5) | 'sentence_initial_dominance' | cumul=-1.7203%
#   [SEED] k=020 | Head (8, 1) | 'initial_token_attention' | cumul=-1.9936%
#   [SEED] k=021 | Head (10, 10) | 'initial_token_attention' | cumul=-1.8115%
#   [SEED] k=022 | Head (9, 11) | 'initial_token_attention' | cumul=-1.4920%
#   [SEED] k=023 | Head (3, 4) | 'initial_token_attention' | cumul=-1.6696%
#   [SEED] k=024 | Head (11, 7) | 'initial_token_attention' | cumul=-0.7345%
#   [SEED] k=025 | Head (11, 5) | 'initial_token_attention' | cumul=-0.2976%
#   [SEED] k=026 | Head (9, 4) | 'initial_token_attention' | cumul=-0.3463%
#   [SEED] k=027 | Head (7, 10) | 'initial_token_attention' | cumul=-0.1648%
#   [SEED] k=028 | Head (6, 10) | 'initial_token_attention' | cumul=0.0257%
#   [SEED] k=029 | Head (9, 8) | 'sentence_initial_dominance' | cumul=-1.4410%
#   [SEED] k=030 | Head (10, 6) | 'initial_token_attention' | cumul=-1.3665%
#   [SEED] k=031 | Head (11, 1) | 'sentence_initial_dominance' | cumul=-3.0456%
#   [SEED] k=032 | Head (7, 11) | 'initial_token_attention' | cumul=-2.9486%
#   [SEED] k=033 | Head (6, 2) | 'sentence_initial_dominance' | cumul=-4.1300%
#   [SEED] k=034 | Head (7, 6) | 'sentence_initial_dominance' | cumul=-5.0680%
#   [SEED] k=035 | Head (8, 3) | 'initial_token_attention' | cumul=-4.9025%
#   [SEED] k=036 | Head (5, 9) | 'sentence_initial_dominance' | cumul=-5.5712%
#   [SEED] k=037 | Head (10, 3) | 'sentence_initial_dominance' | cumul=-7.4502%
#   [SEED] k=038 | Head (5, 0) | 'initial_token_attention' | cumul=-7.1277%
#   [SEED] k=039 | Head (8, 11) | 'sentence_initial_dominance' | cumul=-8.6579%
#   [SEED] k=040 | Head (9, 1) | 'initial_token_attention' | cumul=-8.4641%
#   [SEED] k=041 | Head (8, 0) | 'sentence_initial_dominance' | cumul=-10.0269%
#   [SEED] k=042 | Head (4, 10) | 'initial_token_attention' | cumul=-9.9291%
#   [SPIKE] Head (9, 0) Rank-1 'token_reinforcement' marginal=5.92%. Trying Rank-2...
#   [SPIKE] Head (9, 0) Rank-2 'sentence_beginning_salience' marginal=6.01%. Trying Rank-3...
#   [SPIKE] Head (9, 0) Rank-3 'initial_element_reinforcement' marginal=5.29%. Trying Rank-4...
#   [SPIKE] Head (9, 0) Rank-4 'initial_token_anchoring' marginal=6.01%. Trying Rank-5...
#   [SPIKE] Head (9, 0) Rank-5 'initial_token_centralization' marginal=6.01%. All ranks exhausted.
#   [SKIP] Head (9, 0): all 5 programs spiked.
#   [SPIKE] Head (0, 9) Rank-1 'uniform_lower_diagonal' marginal=5.72%. Trying Rank-2...
#   [SPIKE] Head (0, 9) Rank-2 'sentence_position_preference' marginal=5.78%. Trying Rank-3...
#   [SPIKE] Head (0, 9) Rank-3 'contextual_anchoring' marginal=6.10%. Trying Rank-4...
#   [SPIKE] Head (0, 9) Rank-4 'quotation_association' marginal=5.75%. Trying Rank-5...
#   [SPIKE] Head (0, 9) Rank-5 'appositive_phrase_attention' marginal=5.75%. All ranks exhausted.
#   [SKIP] Head (0, 9): all 5 programs spiked.
#   k=043 | Head (11, 4) | Rank-1 'token_reinforcement' | cumul=-5.0993%
#   k=044 | Head (9, 7) | Rank-1 'token_reinforcement' | cumul=-5.4788%
#   [SPIKE] Head (11, 6) Rank-1 'sentence_beginning_salience' marginal=2000.72%. Trying Rank-2...
#   k=045 | Head (11, 6) | Rank-2 'initial_element_reinforcement' | cumul=-5.4788%
#   [SPIKE] Head (1, 2) Rank-1 'uniform_lower_diagonal' marginal=71.30%. Trying Rank-2...
#   [SPIKE] Head (1, 2) Rank-2 'sentence_position_preference' marginal=108.74%. Trying Rank-3...
#   [SPIKE] Head (1, 2) Rank-3 'contextual_anchoring' marginal=37.87%. Trying Rank-4...
#   k=046 | Head (1, 2) | Rank-4 'quotation_association' | cumul=-0.9455%
#   k=047 | Head (0, 5) | Rank-1 'lexical_diversity_focus' | cumul=-0.9512%
#   k=048 | Head (0, 10) | Rank-1 'uniform_lower_diagonal' | cumul=-0.7834%
#   k=049 | Head (3, 10) | Rank-1 'initial_token_reference_attention' | cumul=-0.5985%
#   k=050 | Head (10, 11) | Rank-1 'token_reinforcement' | cumul=-0.1525%
#   k=051 | Head (11, 10) | Rank-1 'initial_token_reference_attention' | cumul=0.3507%
#   k=052 | Head (9, 2) | Rank-1 'token_reinforcement' | cumul=0.3746%
#   k=053 | Head (4, 2) | Rank-1 'token_reinforcement' | cumul=0.3551%
#   k=054 | Head (8, 6) | Rank-1 'sentence_beginning_salience' | cumul=0.5406%
#   k=055 | Head (2, 11) | Rank-1 'token_reinforcement' | cumul=0.4757%
#   k=056 | Head (0, 3) | Rank-1 'rare_word_dominance' | cumul=0.5207%
#   k=057 | Head (4, 4) | Rank-1 'token_reinforcement' | cumul=1.3192%
#   k=058 | Head (4, 8) | Rank-1 'token_reinforcement' | cumul=2.1620%
#   k=059 | Head (6, 5) | Rank-1 'token_reinforcement' | cumul=2.1115%
#   k=060 | Head (5, 11) | Rank-1 'initial_token_reference_attention' | cumul=3.2529%
#   k=061 | Head (5, 7) | Rank-1 'token_reinforcement' | cumul=3.6854%
#   k=062 | Head (11, 0) | Rank-1 'uniform_lower_diagonal' | cumul=4.0064%
#   k=063 | Head (8, 10) | Rank-1 'token_reinforcement' | cumul=4.5530%
#   k=064 | Head (1, 8) | Rank-1 'uniform_lower_diagonal' | cumul=4.4709%
#   k=065 | Head (1, 4) | Rank-1 'uniform_lower_diagonal' | cumul=4.8628%
#   k=066 | Head (10, 7) | Rank-1 'token_reinforcement' | cumul=5.2697%
#   k=067 | Head (10, 4) | Rank-1 'token_reinforcement' | cumul=5.7341%
#   k=068 | Head (6, 1) | Rank-1 'token_reinforcement' | cumul=6.5185%
#   k=069 | Head (7, 9) | Rank-1 'token_reinforcement' | cumul=7.1915%
#   k=070 | Head (2, 7) | Rank-1 'uniform_lower_diagonal' | cumul=7.1979%
#   k=071 | Head (10, 5) | Rank-1 'sentence_beginning_salience' | cumul=7.1581%
#   k=072 | Head (7, 0) | Rank-1 'token_reinforcement' | cumul=8.4391%
#   k=073 | Head (7, 4) | Rank-1 'sentence_beginning_salience' | cumul=9.7602%
#   k=074 | Head (5, 6) | Rank-1 'token_reinforcement' | cumul=11.0479%
#   k=075 | Head (7, 5) | Rank-1 'token_reinforcement' | cumul=11.3382%
#   k=076 | Head (0, 6) | Rank-1 'uniform_lower_diagonal' | cumul=10.9928%
#   k=077 | Head (0, 8) | Rank-1 'uniform_lower_diagonal' | cumul=10.4286%
#   k=078 | Head (5, 8) | Rank-1 'token_reinforcement' | cumul=11.5771%
#   k=079 | Head (0, 2) | Rank-1 'uniform_lower_diagonal' | cumul=11.5652%
#   k=080 | Head (0, 11) | Rank-1 'uniform_lower_diagonal' | cumul=11.8245%
#   k=081 | Head (7, 3) | Rank-1 'token_reinforcement' | cumul=11.7027%
#   k=082 | Head (8, 7) | Rank-1 'token_reinforcement' | cumul=12.7047%
#   k=083 | Head (10, 9) | Rank-1 'token_reinforcement' | cumul=14.1390%
#   k=084 | Head (2, 10) | Rank-1 'uniform_lower_diagonal' | cumul=14.9065%
#   k=085 | Head (6, 3) | Rank-1 'token_reinforcement' | cumul=15.9120%
#   k=086 | Head (4, 6) | Rank-1 'token_reinforcement' | cumul=16.8142%
#   k=087 | Head (9, 3) | Rank-1 'initial_token_reference_attention' | cumul=17.1688%
#   k=088 | Head (1, 7) | Rank-1 'uniform_lower_diagonal' | cumul=17.0841%
#   k=089 | Head (3, 5) | Rank-1 'token_reinforcement' | cumul=18.0473%
#   k=090 | Head (8, 4) | Rank-1 'token_reinforcement' | cumul=19.1176%
#   k=091 | Head (11, 3) | Rank-1 'token_reinforcement' | cumul=19.3654%
#   k=092 | Head (5, 10) | Rank-1 'token_reinforcement' | cumul=21.3877%
#   k=093 | Head (9, 10) | Rank-1 'token_reinforcement' | cumul=22.3507%
#   k=094 | Head (0, 0) | Rank-1 'uniform_lower_diagonal' | cumul=22.5496%
#   k=095 | Head (4, 9) | Rank-1 'sentence_position_preference' | cumul=23.0352%
#   k=096 | Head (8, 2) | Rank-1 'token_reinforcement' | cumul=23.0282%
#   k=097 | Head (6, 8) | Rank-1 'token_reinforcement' | cumul=24.4511%
#   k=098 | Head (2, 1) | Rank-1 'token_reinforcement' | cumul=24.9421%
#   [STOP] Cumulative 27.05% > 25.0%. Ending shuffle 2 early.
#   ✓ Saved 98 rows → ../results/replacement_run/shuffles/gpt2_top3_shuffle_34.csv
#
# ── Shuffle 3/32 ──────────────────────────────
#   [SEED] k=001 | Head (10, 2) | 'initial_token_attention' | cumul=0.0083%
#   [SEED] k=002 | Head (10, 1) | 'initial_token_attention' | cumul=0.0086%
#   [SEED] k=003 | Head (6, 9) | 'cls_attention' | cumul=-0.6633%
#   [SEED] k=004 | Head (5, 1) | 'cls_attention' | cumul=-0.6252%
#   [SEED] k=005 | Head (7, 2) | 'cls_attention' | cumul=-0.4608%
#   [SEED] k=006 | Head (4, 11) | 'previous_attention' | cumul=-0.1323%
#   [SEED] k=007 | Head (7, 1) | 'initial_token_attention' | cumul=0.1771%
#   [SEED] k=008 | Head (11, 9) | 'initial_token_attention' | cumul=-0.2135%
#   [SEED] k=009 | Head (10, 0) | 'initial_token_attention' | cumul=-0.2058%
#   [SEED] k=010 | Head (11, 2) | 'initial_token_attention' | cumul=1.0039%
#   [SEED] k=011 | Head (7, 7) | 'initial_token_attention' | cumul=0.9243%
#   [SEED] k=012 | Head (5, 5) | 'initial_token_attention' | cumul=0.6362%
#   [SEED] k=013 | Head (6, 6) | 'initial_token_attention' | cumul=0.4550%
#   [SEED] k=014 | Head (10, 8) | 'initial_token_attention' | cumul=0.1011%
#   [SEED] k=015 | Head (3, 0) | 'initial_token_attention' | cumul=-0.0733%
#   [SEED] k=016 | Head (0, 1) | 'repeated_attention' | cumul=-0.0823%
#   [SEED] k=017 | Head (9, 6) | 'initial_token_attention' | cumul=0.0840%
#   [SEED] k=018 | Head (9, 9) | 'sentence_start_dominance' | cumul=0.2021%
#   [SEED] k=019 | Head (9, 5) | 'sentence_initial_dominance' | cumul=-1.7203%
#   [SEED] k=020 | Head (8, 1) | 'initial_token_attention' | cumul=-1.9936%
#   [SEED] k=021 | Head (10, 10) | 'initial_token_attention' | cumul=-1.8115%
#   [SEED] k=022 | Head (9, 11) | 'initial_token_attention' | cumul=-1.4920%
#   [SEED] k=023 | Head (3, 4) | 'initial_token_attention' | cumul=-1.6696%
#   [SEED] k=024 | Head (11, 7) | 'initial_token_attention' | cumul=-0.7345%
#   [SEED] k=025 | Head (11, 5) | 'initial_token_attention' | cumul=-0.2976%
#   [SEED] k=026 | Head (9, 4) | 'initial_token_attention' | cumul=-0.3463%
#   [SEED] k=027 | Head (7, 10) | 'initial_token_attention' | cumul=-0.1648%
#   [SEED] k=028 | Head (6, 10) | 'initial_token_attention' | cumul=0.0257%
#   [SEED] k=029 | Head (9, 8) | 'sentence_initial_dominance' | cumul=-1.4410%
#   [SEED] k=030 | Head (10, 6) | 'initial_token_attention' | cumul=-1.3665%
#   [SEED] k=031 | Head (11, 1) | 'sentence_initial_dominance' | cumul=-3.0456%
#   [SEED] k=032 | Head (7, 11) | 'initial_token_attention' | cumul=-2.9486%
#   [SEED] k=033 | Head (6, 2) | 'sentence_initial_dominance' | cumul=-4.1300%
#   [SEED] k=034 | Head (7, 6) | 'sentence_initial_dominance' | cumul=-5.0680%
#   [SEED] k=035 | Head (8, 3) | 'initial_token_attention' | cumul=-4.9025%
#   [SEED] k=036 | Head (5, 9) | 'sentence_initial_dominance' | cumul=-5.5712%
#   [SEED] k=037 | Head (10, 3) | 'sentence_initial_dominance' | cumul=-7.4502%
#   [SEED] k=038 | Head (5, 0) | 'initial_token_attention' | cumul=-7.1277%
#   [SEED] k=039 | Head (8, 11) | 'sentence_initial_dominance' | cumul=-8.6579%
#   [SEED] k=040 | Head (9, 1) | 'initial_token_attention' | cumul=-8.4641%
#   [SEED] k=041 | Head (8, 0) | 'sentence_initial_dominance' | cumul=-10.0269%
#   [SEED] k=042 | Head (4, 10) | 'initial_token_attention' | cumul=-9.9291%
#   [SPIKE] Head (11, 6) Rank-1 'sentence_beginning_salience' marginal=2002.08%. Trying Rank-2...
#   [SPIKE] Head (11, 6) Rank-2 'initial_element_reinforcement' marginal=5.29%. Trying Rank-3...
#   [SPIKE] Head (11, 6) Rank-3 'initial_token_anchoring' marginal=2013.23%. Trying Rank-4...
#   [SPIKE] Head (11, 6) Rank-4 'initial_token_centralization' marginal=2013.23%. Trying Rank-5...
#   [SPIKE] Head (11, 6) Rank-5 'sentence_start_dominance' marginal=2013.23%. All ranks exhausted.
#   [SKIP] Head (11, 6): all 5 programs spiked.
#   [SPIKE] Head (10, 5) Rank-1 'sentence_beginning_salience' marginal=5.09%. Trying Rank-2...
#   [SPIKE] Head (10, 5) Rank-2 'initial_element_reinforcement' marginal=5.29%. Trying Rank-3...
#   [SPIKE] Head (10, 5) Rank-3 'initial_token_anchoring' marginal=5.09%. Trying Rank-4...
#   [SPIKE] Head (10, 5) Rank-4 'initial_token_centralization' marginal=5.09%. Trying Rank-5...
#   [SPIKE] Head (10, 5) Rank-5 'sentence_start_dominance' marginal=5.09%. All ranks exhausted.
#   [SKIP] Head (10, 5): all 5 programs spiked.
#   [SPIKE] Head (0, 9) Rank-1 'uniform_lower_diagonal' marginal=5.72%. Trying Rank-2...
#   [SPIKE] Head (0, 9) Rank-2 'sentence_position_preference' marginal=5.78%. Trying Rank-3...
#   [SPIKE] Head (0, 9) Rank-3 'contextual_anchoring' marginal=6.10%. Trying Rank-4...
#   [SPIKE] Head (0, 9) Rank-4 'quotation_association' marginal=5.75%. Trying Rank-5...
#   [SPIKE] Head (0, 9) Rank-5 'appositive_phrase_attention' marginal=5.75%. All ranks exhausted.
#   [SKIP] Head (0, 9): all 5 programs spiked.
#   [SPIKE] Head (0, 10) Rank-1 'uniform_lower_diagonal' marginal=5.33%. Trying Rank-2...
#   [SPIKE] Head (0, 10) Rank-2 'sentence_position_preference' marginal=5.73%. Trying Rank-3...
#   [SPIKE] Head (0, 10) Rank-3 'contextual_anchoring' marginal=5.32%. Trying Rank-4...
#   [SPIKE] Head (0, 10) Rank-4 'quotation_association' marginal=5.13%. Trying Rank-5...
#   [SPIKE] Head (0, 10) Rank-5 'appositive_phrase_attention' marginal=5.13%. All ranks exhausted.
#   [SKIP] Head (0, 10): all 5 programs spiked.
#   [SPIKE] Head (5, 7) Rank-1 'token_reinforcement' marginal=5.61%. Trying Rank-2...
#   [SPIKE] Head (5, 7) Rank-2 'initial_token_reference_attention' marginal=5.58%. Trying Rank-3...
#   [SPIKE] Head (5, 7) Rank-3 'sentence_beginning_salience' marginal=5.67%. Trying Rank-4...
#   [SPIKE] Head (5, 7) Rank-4 'initial_element_reinforcement' marginal=5.29%. Trying Rank-5...
#   [SPIKE] Head (5, 7) Rank-5 'initial_token_anchoring' marginal=5.67%. All ranks exhausted.
#   [SKIP] Head (5, 7): all 5 programs spiked.
#   k=043 | Head (0, 6) | Rank-1 'uniform_lower_diagonal' | cumul=-5.0308%
#   k=044 | Head (9, 2) | Rank-1 'token_reinforcement' | cumul=-5.0277%
#   k=045 | Head (1, 10) | Rank-1 'uniform_lower_diagonal' | cumul=-5.2975%
#   k=046 | Head (4, 8) | Rank-1 'token_reinforcement' | cumul=-4.6599%
#   k=047 | Head (5, 11) | Rank-1 'initial_token_reference_attention' | cumul=-3.7473%
#   k=048 | Head (10, 7) | Rank-1 'token_reinforcement' | cumul=-3.5295%
#   k=049 | Head (3, 10) | Rank-1 'initial_token_reference_attention' | cumul=-3.3450%
#   k=050 | Head (6, 3) | Rank-1 'token_reinforcement' | cumul=-3.1131%
#   k=051 | Head (6, 1) | Rank-1 'token_reinforcement' | cumul=-2.3682%
#   k=052 | Head (0, 5) | Rank-1 'lexical_diversity_focus' | cumul=-2.3921%
#   k=053 | Head (0, 3) | Rank-1 'rare_word_dominance' | cumul=-2.4253%
#   k=054 | Head (0, 11) | Rank-1 'uniform_lower_diagonal' | cumul=-2.4239%
#   k=055 | Head (2, 7) | Rank-1 'uniform_lower_diagonal' | cumul=-2.2392%
#   k=056 | Head (11, 10) | Rank-1 'initial_token_reference_attention' | cumul=-1.7147%
#   k=057 | Head (11, 4) | Rank-1 'token_reinforcement' | cumul=-2.1756%
#   k=058 | Head (4, 4) | Rank-1 'token_reinforcement' | cumul=-1.5200%
#   k=059 | Head (7, 5) | Rank-1 'token_reinforcement' | cumul=-1.4158%
#   k=060 | Head (1, 7) | Rank-1 'uniform_lower_diagonal' | cumul=-1.4785%
#   k=061 | Head (1, 8) | Rank-1 'uniform_lower_diagonal' | cumul=-1.5050%
#   k=062 | Head (0, 0) | Rank-1 'uniform_lower_diagonal' | cumul=-1.6568%
#   k=063 | Head (4, 2) | Rank-1 'token_reinforcement' | cumul=-1.4324%
#   k=064 | Head (7, 4) | Rank-1 'sentence_beginning_salience' | cumul=-0.7125%
#   k=065 | Head (8, 9) | Rank-1 'token_reinforcement' | cumul=-0.0108%
#   k=066 | Head (9, 0) | Rank-1 'token_reinforcement' | cumul=0.6424%
#   [SPIKE] Head (1, 2) Rank-1 'uniform_lower_diagonal' marginal=79.05%. Trying Rank-2...
#   [SPIKE] Head (1, 2) Rank-2 'sentence_position_preference' marginal=109.47%. Trying Rank-3...
#   [SPIKE] Head (1, 2) Rank-3 'contextual_anchoring' marginal=39.80%. Trying Rank-4...
#   [SPIKE] Head (1, 2) Rank-4 'quotation_association' marginal=5.68%. Trying Rank-5...
#   [SPIKE] Head (1, 2) Rank-5 'appositive_phrase_attention' marginal=5.68%. All ranks exhausted.
#   [SKIP] Head (1, 2): all 5 programs spiked.
#   k=067 | Head (10, 11) | Rank-1 'token_reinforcement' | cumul=1.0841%
#   k=068 | Head (2, 1) | Rank-1 'token_reinforcement' | cumul=1.2156%
#   k=069 | Head (8, 10) | Rank-1 'token_reinforcement' | cumul=2.1264%
#   k=070 | Head (5, 6) | Rank-1 'token_reinforcement' | cumul=3.0207%
#   k=071 | Head (2, 10) | Rank-1 'uniform_lower_diagonal' | cumul=3.3095%
#   k=072 | Head (10, 9) | Rank-1 'token_reinforcement' | cumul=4.3570%
#   k=073 | Head (7, 8) | Rank-1 'token_reinforcement' | cumul=4.1527%
#   k=074 | Head (6, 5) | Rank-1 'token_reinforcement' | cumul=4.1982%
#   k=075 | Head (8, 7) | Rank-1 'token_reinforcement' | cumul=4.9014%
#   k=076 | Head (6, 4) | Rank-1 'initial_token_reference_attention' | cumul=5.2817%
#   k=077 | Head (7, 0) | Rank-1 'token_reinforcement' | cumul=6.7639%
#   k=078 | Head (9, 3) | Rank-1 'initial_token_reference_attention' | cumul=7.1780%
#   k=079 | Head (2, 2) | Rank-1 'previous_attention' | cumul=6.8977%
#   k=080 | Head (11, 0) | Rank-1 'uniform_lower_diagonal' | cumul=7.2142%
#   k=081 | Head (0, 8) | Rank-1 'uniform_lower_diagonal' | cumul=6.8962%
#   k=082 | Head (5, 10) | Rank-1 'token_reinforcement' | cumul=8.4875%
#   k=083 | Head (5, 3) | Rank-1 'uniform_lower_diagonal' | cumul=9.4711%
#   k=084 | Head (9, 7) | Rank-1 'token_reinforcement' | cumul=9.4910%
#   k=085 | Head (0, 2) | Rank-1 'uniform_lower_diagonal' | cumul=9.6231%
#   k=086 | Head (7, 3) | Rank-1 'token_reinforcement' | cumul=10.1419%
#   k=087 | Head (6, 7) | Rank-1 'token_reinforcement' | cumul=12.2311%
#   k=088 | Head (7, 9) | Rank-1 'token_reinforcement' | cumul=13.9988%
#   k=089 | Head (1, 4) | Rank-1 'uniform_lower_diagonal' | cumul=14.6709%
#   k=090 | Head (2, 6) | Rank-1 'initial_token_reference_attention' | cumul=14.7372%
#   k=091 | Head (4, 7) | Rank-1 'first_token_dominance' | cumul=15.4010%
#   k=092 | Head (1, 3) | Rank-1 'initial_token_reference_attention' | cumul=15.3451%
#   k=093 | Head (1, 6) | Rank-1 'uniform_lower_diagonal' | cumul=15.5393%
#   k=094 | Head (1, 11) | Rank-1 'lexical_diversity_focus' | cumul=15.4710%
#   k=095 | Head (0, 7) | Rank-1 'uniform_lower_diagonal' | cumul=15.6108%
#   k=096 | Head (5, 8) | Rank-1 'token_reinforcement' | cumul=17.1294%
#   k=097 | Head (11, 11) | Rank-1 'initial_token_reference_attention' | cumul=17.0445%
#   k=098 | Head (8, 4) | Rank-1 'token_reinforcement' | cumul=17.5796%
#   k=099 | Head (11, 8) | Rank-1 'uniform_lower_diagonal' | cumul=17.8218%
#   k=100 | Head (1, 5) | Rank-1 'uniform_lower_diagonal' | cumul=18.6344%
#   k=101 | Head (3, 5) | Rank-1 'token_reinforcement' | cumul=19.7627%
#   k=102 | Head (9, 10) | Rank-1 'token_reinforcement' | cumul=20.6400%
#   k=103 | Head (8, 8) | Rank-1 'token_reinforcement' | cumul=22.4602%
#   k=104 | Head (5, 2) | Rank-1 'token_reinforcement' | cumul=23.6399%
#   k=105 | Head (2, 11) | Rank-1 'token_reinforcement' | cumul=24.5523%
#   k=106 | Head (2, 0) | Rank-1 'uniform_lower_diagonal' | cumul=24.6106%
#   [STOP] Cumulative 25.37% > 25.0%. Ending shuffle 3 early.
#   ✓ Saved 106 rows → ../results/replacement_run/shuffles/gpt2_top3_shuffle_35.csv
#
# ── Shuffle 4/32 ──────────────────────────────
#   [SEED] k=001 | Head (10, 2) | 'initial_token_attention' | cumul=0.0083%
#   [SEED] k=002 | Head (10, 1) | 'initial_token_attention' | cumul=0.0086%
#   [SEED] k=003 | Head (6, 9) | 'cls_attention' | cumul=-0.6633%
#   [SEED] k=004 | Head (5, 1) | 'cls_attention' | cumul=-0.6252%
#   [SEED] k=005 | Head (7, 2) | 'cls_attention' | cumul=-0.4608%
#   [SEED] k=006 | Head (4, 11) | 'previous_attention' | cumul=-0.1323%
#   [SEED] k=007 | Head (7, 1) | 'initial_token_attention' | cumul=0.1771%
#   [SEED] k=008 | Head (11, 9) | 'initial_token_attention' | cumul=-0.2135%
#   [SEED] k=009 | Head (10, 0) | 'initial_token_attention' | cumul=-0.2058%
#   [SEED] k=010 | Head (11, 2) | 'initial_token_attention' | cumul=1.0039%
#   [SEED] k=011 | Head (7, 7) | 'initial_token_attention' | cumul=0.9243%
#   [SEED] k=012 | Head (5, 5) | 'initial_token_attention' | cumul=0.6362%
#   [SEED] k=013 | Head (6, 6) | 'initial_token_attention' | cumul=0.4550%
#   [SEED] k=014 | Head (10, 8) | 'initial_token_attention' | cumul=0.1011%
#   [SEED] k=015 | Head (3, 0) | 'initial_token_attention' | cumul=-0.0733%
#   [SEED] k=016 | Head (0, 1) | 'repeated_attention' | cumul=-0.0823%
#   [SEED] k=017 | Head (9, 6) | 'initial_token_attention' | cumul=0.0840%
#   [SEED] k=018 | Head (9, 9) | 'sentence_start_dominance' | cumul=0.2021%
#   [SEED] k=019 | Head (9, 5) | 'sentence_initial_dominance' | cumul=-1.7203%
#   [SEED] k=020 | Head (8, 1) | 'initial_token_attention' | cumul=-1.9936%
#   [SEED] k=021 | Head (10, 10) | 'initial_token_attention' | cumul=-1.8115%
#   [SEED] k=022 | Head (9, 11) | 'initial_token_attention' | cumul=-1.4920%
#   [SEED] k=023 | Head (3, 4) | 'initial_token_attention' | cumul=-1.6696%
#   [SEED] k=024 | Head (11, 7) | 'initial_token_attention' | cumul=-0.7345%
#   [SEED] k=025 | Head (11, 5) | 'initial_token_attention' | cumul=-0.2976%
#   [SEED] k=026 | Head (9, 4) | 'initial_token_attention' | cumul=-0.3463%
#   [SEED] k=027 | Head (7, 10) | 'initial_token_attention' | cumul=-0.1648%
#   [SEED] k=028 | Head (6, 10) | 'initial_token_attention' | cumul=0.0257%
#   [SEED] k=029 | Head (9, 8) | 'sentence_initial_dominance' | cumul=-1.4410%
#   [SEED] k=030 | Head (10, 6) | 'initial_token_attention' | cumul=-1.3665%
#   [SEED] k=031 | Head (11, 1) | 'sentence_initial_dominance' | cumul=-3.0456%
#   [SEED] k=032 | Head (7, 11) | 'initial_token_attention' | cumul=-2.9486%
#   [SEED] k=033 | Head (6, 2) | 'sentence_initial_dominance' | cumul=-4.1300%
#   [SEED] k=034 | Head (7, 6) | 'sentence_initial_dominance' | cumul=-5.0680%
#   [SEED] k=035 | Head (8, 3) | 'initial_token_attention' | cumul=-4.9025%
#   [SEED] k=036 | Head (5, 9) | 'sentence_initial_dominance' | cumul=-5.5712%
#   [SEED] k=037 | Head (10, 3) | 'sentence_initial_dominance' | cumul=-7.4502%
#   [SEED] k=038 | Head (5, 0) | 'initial_token_attention' | cumul=-7.1277%
#   [SEED] k=039 | Head (8, 11) | 'sentence_initial_dominance' | cumul=-8.6579%
#   [SEED] k=040 | Head (9, 1) | 'initial_token_attention' | cumul=-8.4641%
#   [SEED] k=041 | Head (8, 0) | 'sentence_initial_dominance' | cumul=-10.0269%
#   [SEED] k=042 | Head (4, 10) | 'initial_token_attention' | cumul=-9.9291%
#   [SPIKE] Head (0, 9) Rank-1 'uniform_lower_diagonal' marginal=5.72%. Trying Rank-2...
#   [SPIKE] Head (0, 9) Rank-2 'sentence_position_preference' marginal=5.78%. Trying Rank-3...
#   [SPIKE] Head (0, 9) Rank-3 'contextual_anchoring' marginal=6.10%. Trying Rank-4...
#   [SPIKE] Head (0, 9) Rank-4 'quotation_association' marginal=5.75%. Trying Rank-5...
#   [SPIKE] Head (0, 9) Rank-5 'appositive_phrase_attention' marginal=5.75%. All ranks exhausted.
#   [SKIP] Head (0, 9): all 5 programs spiked.
#   [SPIKE] Head (0, 10) Rank-1 'uniform_lower_diagonal' marginal=5.33%. Trying Rank-2...
#   [SPIKE] Head (0, 10) Rank-2 'sentence_position_preference' marginal=5.73%. Trying Rank-3...
#   [SPIKE] Head (0, 10) Rank-3 'contextual_anchoring' marginal=5.32%. Trying Rank-4...
#   [SPIKE] Head (0, 10) Rank-4 'quotation_association' marginal=5.13%. Trying Rank-5...
#   [SPIKE] Head (0, 10) Rank-5 'appositive_phrase_attention' marginal=5.13%. All ranks exhausted.
#   [SKIP] Head (0, 10): all 5 programs spiked.
#   [SPIKE] Head (5, 6) Rank-1 'token_reinforcement' marginal=5.86%. Trying Rank-2...
#   [SPIKE] Head (5, 6) Rank-2 'initial_token_reference_attention' marginal=5.81%. Trying Rank-3...
#   [SPIKE] Head (5, 6) Rank-3 'sentence_beginning_salience' marginal=5.96%. Trying Rank-4...
#   [SPIKE] Head (5, 6) Rank-4 'initial_element_reinforcement' marginal=5.29%. Trying Rank-5...
#   [SPIKE] Head (5, 6) Rank-5 'initial_token_anchoring' marginal=5.96%. All ranks exhausted.
#   [SKIP] Head (5, 6): all 5 programs spiked.
#   [SPIKE] Head (0, 3) Rank-1 'rare_word_dominance' marginal=5.25%. Trying Rank-2...
#   [SPIKE] Head (0, 3) Rank-2 'same_attention' marginal=5.25%. Trying Rank-3...
#   [SPIKE] Head (0, 3) Rank-3 'lexical_diversity_focus' marginal=5.25%. Trying Rank-4...
#   [SPIKE] Head (0, 3) Rank-4 'conjunction_resolution' marginal=5.30%. Trying Rank-5...
#   [SPIKE] Head (0, 3) Rank-5 'repeated_attention' marginal=5.23%. All ranks exhausted.
#   [SKIP] Head (0, 3): all 5 programs spiked.
#   [SPIKE] Head (5, 8) Rank-1 'token_reinforcement' marginal=5.74%. Trying Rank-2...
#   [SPIKE] Head (5, 8) Rank-2 'sentence_beginning_salience' marginal=5.81%. Trying Rank-3...
#   [SPIKE] Head (5, 8) Rank-3 'initial_element_reinforcement' marginal=5.29%. Trying Rank-4...
#   [SPIKE] Head (5, 8) Rank-4 'initial_token_anchoring' marginal=5.81%. Trying Rank-5...
#   [SPIKE] Head (5, 8) Rank-5 'initial_token_centralization' marginal=5.81%. All ranks exhausted.
#   [SKIP] Head (5, 8): all 5 programs spiked.
#   [SPIKE] Head (0, 11) Rank-1 'uniform_lower_diagonal' marginal=5.08%. Trying Rank-2...
#   [SPIKE] Head (0, 11) Rank-2 'sentence_position_preference' marginal=5.48%. Trying Rank-3...
#   k=043 | Head (0, 11) | Rank-3 'contextual_anchoring' | cumul=-5.1544%
#   k=044 | Head (8, 9) | Rank-1 'token_reinforcement' | cumul=-4.4914%
#   k=045 | Head (11, 0) | Rank-1 'uniform_lower_diagonal' | cumul=-4.2669%
#   k=046 | Head (4, 2) | Rank-1 'token_reinforcement' | cumul=-4.1670%
#   k=047 | Head (10, 7) | Rank-1 'token_reinforcement' | cumul=-3.9150%
#   k=048 | Head (11, 10) | Rank-1 'initial_token_reference_attention' | cumul=-3.3935%
#   k=049 | Head (10, 9) | Rank-1 'token_reinforcement' | cumul=-2.5002%
#   k=050 | Head (0, 5) | Rank-1 'lexical_diversity_focus' | cumul=-2.5151%
#   k=051 | Head (8, 10) | Rank-1 'token_reinforcement' | cumul=-1.7817%
#   k=052 | Head (2, 11) | Rank-1 'token_reinforcement' | cumul=-1.7102%
#   k=053 | Head (5, 11) | Rank-1 'initial_token_reference_attention' | cumul=-0.8001%
#   k=054 | Head (1, 8) | Rank-1 'uniform_lower_diagonal' | cumul=-0.9435%
#   k=055 | Head (9, 2) | Rank-1 'token_reinforcement' | cumul=-0.9008%
#   k=056 | Head (6, 4) | Rank-1 'initial_token_reference_attention' | cumul=-0.7809%
#   k=057 | Head (4, 4) | Rank-1 'token_reinforcement' | cumul=-0.1443%
#   k=058 | Head (10, 11) | Rank-1 'token_reinforcement' | cumul=0.3607%
#   k=059 | Head (4, 8) | Rank-1 'token_reinforcement' | cumul=1.1023%
#   k=060 | Head (3, 10) | Rank-1 'initial_token_reference_attention' | cumul=1.3879%
#   k=061 | Head (0, 2) | Rank-1 'uniform_lower_diagonal' | cumul=1.3472%
#   [SPIKE] Head (11, 6) Rank-1 'sentence_beginning_salience' marginal=2107.35%. Trying Rank-2...
#   k=062 | Head (11, 6) | Rank-2 'initial_element_reinforcement' | cumul=1.3472%
#   k=063 | Head (2, 7) | Rank-1 'uniform_lower_diagonal' | cumul=1.4666%
#   k=064 | Head (6, 5) | Rank-1 'token_reinforcement' | cumul=1.3679%
#   k=065 | Head (11, 4) | Rank-1 'token_reinforcement' | cumul=0.8858%
#   k=066 | Head (8, 6) | Rank-1 'sentence_beginning_salience' | cumul=0.8352%
#   k=067 | Head (6, 1) | Rank-1 'token_reinforcement' | cumul=1.6947%
#   k=068 | Head (2, 10) | Rank-1 'uniform_lower_diagonal' | cumul=2.0158%
#   k=069 | Head (7, 3) | Rank-1 'token_reinforcement' | cumul=1.8787%
#   k=070 | Head (9, 10) | Rank-1 'token_reinforcement' | cumul=2.4974%
#   k=071 | Head (3, 1) | Rank-1 'initial_token_reference_attention' | cumul=2.7106%
#   k=072 | Head (9, 0) | Rank-1 'token_reinforcement' | cumul=3.5822%
#   k=073 | Head (7, 4) | Rank-1 'sentence_beginning_salience' | cumul=4.4154%
#   k=074 | Head (1, 10) | Rank-1 'uniform_lower_diagonal' | cumul=4.3284%
#   k=075 | Head (0, 8) | Rank-1 'uniform_lower_diagonal' | cumul=3.8383%
#   k=076 | Head (9, 7) | Rank-1 'token_reinforcement' | cumul=3.6906%
#   k=077 | Head (2, 1) | Rank-1 'token_reinforcement' | cumul=4.1376%
#   k=078 | Head (7, 9) | Rank-1 'token_reinforcement' | cumul=5.0150%
#   k=079 | Head (5, 7) | Rank-1 'token_reinforcement' | cumul=5.6478%
#   k=080 | Head (1, 7) | Rank-1 'uniform_lower_diagonal' | cumul=5.7262%
#   k=081 | Head (6, 3) | Rank-1 'token_reinforcement' | cumul=6.5332%
#   k=082 | Head (1, 11) | Rank-1 'lexical_diversity_focus' | cumul=6.4917%
#   k=083 | Head (8, 4) | Rank-1 'token_reinforcement' | cumul=6.8078%
#   k=084 | Head (5, 10) | Rank-1 'token_reinforcement' | cumul=8.4468%
#   [SPIKE] Head (1, 2) Rank-1 'uniform_lower_diagonal' marginal=86.11%. Trying Rank-2...
#   [SPIKE] Head (1, 2) Rank-2 'sentence_position_preference' marginal=114.41%. Trying Rank-3...
#   [SPIKE] Head (1, 2) Rank-3 'contextual_anchoring' marginal=42.98%. Trying Rank-4...
#   [SPIKE] Head (1, 2) Rank-4 'quotation_association' marginal=7.32%. Trying Rank-5...
#   [SPIKE] Head (1, 2) Rank-5 'appositive_phrase_attention' marginal=7.32%. All ranks exhausted.
#   [SKIP] Head (1, 2): all 5 programs spiked.
#   k=085 | Head (7, 8) | Rank-1 'token_reinforcement' | cumul=8.4370%
#   k=086 | Head (11, 3) | Rank-1 'token_reinforcement' | cumul=8.6088%
#   k=087 | Head (7, 5) | Rank-1 'token_reinforcement' | cumul=8.9248%
#   k=088 | Head (10, 4) | Rank-1 'token_reinforcement' | cumul=9.7631%
#   k=089 | Head (2, 2) | Rank-1 'previous_attention' | cumul=9.5878%
#   k=090 | Head (3, 5) | Rank-1 'token_reinforcement' | cumul=10.3088%
#   k=091 | Head (7, 0) | Rank-1 'token_reinforcement' | cumul=12.2466%
#   k=092 | Head (2, 8) | Rank-1 'uniform_lower_diagonal' | cumul=12.1540%
#   k=093 | Head (0, 7) | Rank-1 'uniform_lower_diagonal' | cumul=12.0734%
#   k=094 | Head (2, 0) | Rank-1 'uniform_lower_diagonal' | cumul=11.9465%
#   k=095 | Head (8, 2) | Rank-1 'token_reinforcement' | cumul=11.9103%
#   k=096 | Head (10, 5) | Rank-1 'sentence_beginning_salience' | cumul=11.8937%
#   k=097 | Head (3, 6) | Rank-1 'uniform_lower_diagonal' | cumul=12.8365%
#   k=098 | Head (8, 7) | Rank-1 'token_reinforcement' | cumul=14.4331%
#   k=099 | Head (3, 9) | Rank-1 'initial_token_reference_attention' | cumul=15.7518%
#   k=100 | Head (1, 0) | Rank-1 'uniform_lower_diagonal' | cumul=15.7244%
#   k=101 | Head (11, 8) | Rank-1 'uniform_lower_diagonal' | cumul=15.9910%
#   k=102 | Head (0, 0) | Rank-1 'uniform_lower_diagonal' | cumul=16.0187%
#   k=103 | Head (4, 5) | Rank-1 'token_reinforcement' | cumul=16.8944%
#   k=104 | Head (11, 11) | Rank-1 'initial_token_reference_attention' | cumul=16.8986%
#   k=105 | Head (4, 7) | Rank-1 'first_token_dominance' | cumul=17.5294%
#   k=106 | Head (1, 3) | Rank-1 'initial_token_reference_attention' | cumul=17.8246%
#   k=107 | Head (1, 6) | Rank-1 'uniform_lower_diagonal' | cumul=18.4666%
#   k=108 | Head (4, 0) | Rank-1 'initial_token_reference_attention' | cumul=20.8676%
#   k=109 | Head (6, 11) | Rank-1 'token_reinforcement' | cumul=22.1921%
#   k=110 | Head (8, 5) | Rank-1 'token_reinforcement' | cumul=23.3633%
#   k=111 | Head (0, 6) | Rank-1 'uniform_lower_diagonal' | cumul=23.4611%
#   k=112 | Head (1, 4) | Rank-1 'uniform_lower_diagonal' | cumul=24.5847%
#   [STOP] Cumulative 25.63% > 25.0%. Ending shuffle 4 early.
#   ✓ Saved 112 rows → ../results/replacement_run/shuffles/gpt2_top3_shuffle_36.csv
#
# ── Shuffle 5/32 ──────────────────────────────
#   [SEED] k=001 | Head (10, 2) | 'initial_token_attention' | cumul=0.0083%
#   [SEED] k=002 | Head (10, 1) | 'initial_token_attention' | cumul=0.0086%
#   [SEED] k=003 | Head (6, 9) | 'cls_attention' | cumul=-0.6633%
#   [SEED] k=004 | Head (5, 1) | 'cls_attention' | cumul=-0.6252%
#   [SEED] k=005 | Head (7, 2) | 'cls_attention' | cumul=-0.4608%
#   [SEED] k=006 | Head (4, 11) | 'previous_attention' | cumul=-0.1323%
#   [SEED] k=007 | Head (7, 1) | 'initial_token_attention' | cumul=0.1771%
#   [SEED] k=008 | Head (11, 9) | 'initial_token_attention' | cumul=-0.2135%
#   [SEED] k=009 | Head (10, 0) | 'initial_token_attention' | cumul=-0.2058%
#   [SEED] k=010 | Head (11, 2) | 'initial_token_attention' | cumul=1.0039%
#   [SEED] k=011 | Head (7, 7) | 'initial_token_attention' | cumul=0.9243%
#   [SEED] k=012 | Head (5, 5) | 'initial_token_attention' | cumul=0.6362%
#   [SEED] k=013 | Head (6, 6) | 'initial_token_attention' | cumul=0.4550%
#   [SEED] k=014 | Head (10, 8) | 'initial_token_attention' | cumul=0.1011%
#   [SEED] k=015 | Head (3, 0) | 'initial_token_attention' | cumul=-0.0733%
#   [SEED] k=016 | Head (0, 1) | 'repeated_attention' | cumul=-0.0823%
#   [SEED] k=017 | Head (9, 6) | 'initial_token_attention' | cumul=0.0840%
#   [SEED] k=018 | Head (9, 9) | 'sentence_start_dominance' | cumul=0.2021%
#   [SEED] k=019 | Head (9, 5) | 'sentence_initial_dominance' | cumul=-1.7203%
#   [SEED] k=020 | Head (8, 1) | 'initial_token_attention' | cumul=-1.9936%
#   [SEED] k=021 | Head (10, 10) | 'initial_token_attention' | cumul=-1.8115%
#   [SEED] k=022 | Head (9, 11) | 'initial_token_attention' | cumul=-1.4920%
#   [SEED] k=023 | Head (3, 4) | 'initial_token_attention' | cumul=-1.6696%
#   [SEED] k=024 | Head (11, 7) | 'initial_token_attention' | cumul=-0.7345%
#   [SEED] k=025 | Head (11, 5) | 'initial_token_attention' | cumul=-0.2976%
#   [SEED] k=026 | Head (9, 4) | 'initial_token_attention' | cumul=-0.3463%
#   [SEED] k=027 | Head (7, 10) | 'initial_token_attention' | cumul=-0.1648%
#   [SEED] k=028 | Head (6, 10) | 'initial_token_attention' | cumul=0.0257%
#   [SEED] k=029 | Head (9, 8) | 'sentence_initial_dominance' | cumul=-1.4410%
#   [SEED] k=030 | Head (10, 6) | 'initial_token_attention' | cumul=-1.3665%
#   [SEED] k=031 | Head (11, 1) | 'sentence_initial_dominance' | cumul=-3.0456%
#   [SEED] k=032 | Head (7, 11) | 'initial_token_attention' | cumul=-2.9486%
#   [SEED] k=033 | Head (6, 2) | 'sentence_initial_dominance' | cumul=-4.1300%
#   [SEED] k=034 | Head (7, 6) | 'sentence_initial_dominance' | cumul=-5.0680%
#   [SEED] k=035 | Head (8, 3) | 'initial_token_attention' | cumul=-4.9025%
#   [SEED] k=036 | Head (5, 9) | 'sentence_initial_dominance' | cumul=-5.5712%
#   [SEED] k=037 | Head (10, 3) | 'sentence_initial_dominance' | cumul=-7.4502%
#   [SEED] k=038 | Head (5, 0) | 'initial_token_attention' | cumul=-7.1277%
#   [SEED] k=039 | Head (8, 11) | 'sentence_initial_dominance' | cumul=-8.6579%
#   [SEED] k=040 | Head (9, 1) | 'initial_token_attention' | cumul=-8.4641%
#   [SEED] k=041 | Head (8, 0) | 'sentence_initial_dominance' | cumul=-10.0269%
#   [SEED] k=042 | Head (4, 10) | 'initial_token_attention' | cumul=-9.9291%
#   [SPIKE] Head (0, 11) Rank-1 'uniform_lower_diagonal' marginal=5.08%. Trying Rank-2...
#   [SPIKE] Head (0, 11) Rank-2 'sentence_position_preference' marginal=5.48%. Trying Rank-3...
#   k=043 | Head (0, 11) | Rank-3 'contextual_anchoring' | cumul=-5.1544%
#   k=044 | Head (0, 3) | Rank-1 'rare_word_dominance' | cumul=-5.2001%
#   k=045 | Head (1, 10) | Rank-1 'uniform_lower_diagonal' | cumul=-5.4009%
#   k=046 | Head (9, 7) | Rank-1 'token_reinforcement' | cumul=-5.7919%
#   k=047 | Head (10, 11) | Rank-1 'token_reinforcement' | cumul=-5.3435%
#   k=048 | Head (1, 8) | Rank-1 'uniform_lower_diagonal' | cumul=-5.5145%
#   k=049 | Head (2, 11) | Rank-1 'token_reinforcement' | cumul=-5.4208%
#   k=050 | Head (7, 4) | Rank-1 'sentence_beginning_salience' | cumul=-4.8613%
#   k=051 | Head (5, 6) | Rank-1 'token_reinforcement' | cumul=-4.2478%
#   k=052 | Head (2, 7) | Rank-1 'uniform_lower_diagonal' | cumul=-4.0920%
#   [SPIKE] Head (11, 6) Rank-1 'sentence_beginning_salience' marginal=2026.59%. Trying Rank-2...
#   k=053 | Head (11, 6) | Rank-2 'initial_element_reinforcement' | cumul=-4.0920%
#   k=054 | Head (5, 11) | Rank-1 'initial_token_reference_attention' | cumul=-3.1221%
#   k=055 | Head (1, 7) | Rank-1 'uniform_lower_diagonal' | cumul=-3.0782%
#   k=056 | Head (0, 9) | Rank-1 'uniform_lower_diagonal' | cumul=-2.5090%
#   k=057 | Head (4, 2) | Rank-1 'token_reinforcement' | cumul=-2.4014%
#   k=058 | Head (8, 9) | Rank-1 'token_reinforcement' | cumul=-1.7296%
#   k=059 | Head (4, 4) | Rank-1 'token_reinforcement' | cumul=-1.0051%
#   k=060 | Head (0, 5) | Rank-1 'lexical_diversity_focus' | cumul=-1.0402%
#   k=061 | Head (7, 8) | Rank-1 'token_reinforcement' | cumul=-1.5474%
#   k=062 | Head (3, 10) | Rank-1 'initial_token_reference_attention' | cumul=-1.3203%
#   k=063 | Head (10, 9) | Rank-1 'token_reinforcement' | cumul=-0.4239%
#   k=064 | Head (1, 11) | Rank-1 'lexical_diversity_focus' | cumul=-0.3984%
#   k=065 | Head (10, 4) | Rank-1 'token_reinforcement' | cumul=0.0696%
#   k=066 | Head (5, 10) | Rank-1 'token_reinforcement' | cumul=1.3050%
#   k=067 | Head (9, 10) | Rank-1 'token_reinforcement' | cumul=1.7972%
#   k=068 | Head (8, 10) | Rank-1 'token_reinforcement' | cumul=2.8436%
#   k=069 | Head (5, 8) | Rank-1 'token_reinforcement' | cumul=3.6031%
#   k=070 | Head (11, 10) | Rank-1 'initial_token_reference_attention' | cumul=4.1855%
#   k=071 | Head (0, 2) | Rank-1 'uniform_lower_diagonal' | cumul=4.3055%
#   k=072 | Head (8, 6) | Rank-1 'sentence_beginning_salience' | cumul=4.4308%
#   k=073 | Head (8, 4) | Rank-1 'token_reinforcement' | cumul=4.7008%
#   k=074 | Head (6, 4) | Rank-1 'initial_token_reference_attention' | cumul=5.4073%
#   k=075 | Head (0, 10) | Rank-1 'uniform_lower_diagonal' | cumul=5.9057%
#   k=076 | Head (7, 9) | Rank-1 'token_reinforcement' | cumul=6.7941%
#   k=077 | Head (4, 8) | Rank-1 'token_reinforcement' | cumul=7.8883%
# ...
#   k=074 | Head (5, 8) | Rank-1 'token_reinforcement' | cumul=2.2383%
#   k=075 | Head (2, 7) | Rank-1 'uniform_lower_diagonal' | cumul=2.5885%
#   k=076 | Head (2, 3) | Rank-1 'uniform_lower_diagonal' | cumul=2.2329%
#   k=077 | Head (7, 3) | Rank-1 'token_reinforcement' | cumul=1.9172%
#   k=078 | Head (1, 9) | Rank-1 'uniform_lower_diagonal' | cumul=2.3222%
#   k=079 | Head (5, 3) | Rank-1 'uniform_lower_diagonal' | cumul=3.1308%
#   k=080 | Head (4, 4) | Rank-1 'token_reinforcement' | cumul=4.0681%
#   k=081 | Head (6, 4) | Rank-1 'initial_token_reference_attention' | cumul=4.6448%
#   k=082 | Head (1, 6) | Rank-1 'uniform_lower_diagonal' | cumul=4.5942%
#   k=083 | Head (6, 3) | Rank-1 'token_reinforcement' | cumul=5.1891%
#   k=084 | Head (8, 9) | Rank-1 'token_reinforcement' | cumul=6.0578%
#   k=085 | Head (5, 10) | Rank-1 'token_reinforcement' | cumul=7.7501%
#   k=086 | Head (10, 7) | Rank-1 'token_reinforcement' | cumul=8.0629%
#   k=087 | Head (8, 2) | Rank-1 'token_reinforcement' | cumul=7.8147%
#   k=088 | Head (0, 2) | Rank-1 'uniform_lower_diagonal' | cumul=8.1539%
#   k=089 | Head (6, 5) | Rank-1 'token_reinforcement' | cumul=8.2920%
#   k=090 | Head (8, 7) | Rank-1 'token_reinforcement' | cumul=9.4250%
#   k=091 | Head (4, 7) | Rank-1 'first_token_dominance' | cumul=10.1221%
#   k=092 | Head (1, 11) | Rank-1 'lexical_diversity_focus' | cumul=10.0739%
#   k=093 | Head (11, 4) | Rank-1 'token_reinforcement' | cumul=9.6392%
#   k=094 | Head (8, 10) | Rank-1 'token_reinforcement' | cumul=10.9298%
#   k=095 | Head (7, 0) | Rank-1 'token_reinforcement' | cumul=12.8315%
#   k=096 | Head (1, 4) | Rank-1 'uniform_lower_diagonal' | cumul=13.4518%
#   k=097 | Head (7, 8) | Rank-1 'token_reinforcement' | cumul=13.4750%
#   k=098 | Head (6, 11) | Rank-1 'token_reinforcement' | cumul=14.4827%
#   k=099 | Head (1, 7) | Rank-1 'uniform_lower_diagonal' | cumul=14.7467%
#   k=100 | Head (11, 3) | Rank-1 'token_reinforcement' | cumul=14.9743%
#   k=101 | Head (10, 9) | Rank-1 'token_reinforcement' | cumul=16.4451%
#   k=102 | Head (8, 4) | Rank-1 'token_reinforcement' | cumul=17.2248%
#   k=103 | Head (8, 8) | Rank-1 'token_reinforcement' | cumul=18.7178%
#   k=104 | Head (7, 9) | Rank-1 'token_reinforcement' | cumul=21.3050%
#   k=105 | Head (3, 5) | Rank-1 'token_reinforcement' | cumul=22.0692%
#   k=106 | Head (1, 3) | Rank-1 'initial_token_reference_attention' | cumul=22.0653%
#   k=107 | Head (11, 11) | Rank-1 'initial_token_reference_attention' | cumul=22.1442%
#   k=108 | Head (2, 5) | Rank-1 'uniform_lower_diagonal' | cumul=22.8973%
#   k=109 | Head (2, 1) | Rank-1 'token_reinforcement' | cumul=24.2101%
#   [STOP] Cumulative 27.61% > 25.0%. Ending shuffle 31 early.
#   ✓ Saved 109 rows → ../results/replacement_run/shuffles/gpt2_top3_shuffle_63.csv
#
# ── Shuffle 32/32 ──────────────────────────────
#   [SEED] k=001 | Head (10, 2) | 'initial_token_attention' | cumul=0.0083%
#   [SEED] k=002 | Head (10, 1) | 'initial_token_attention' | cumul=0.0086%
#   [SEED] k=003 | Head (6, 9) | 'cls_attention' | cumul=-0.6633%
#   [SEED] k=004 | Head (5, 1) | 'cls_attention' | cumul=-0.6252%
#   [SEED] k=005 | Head (7, 2) | 'cls_attention' | cumul=-0.4608%
#   [SEED] k=006 | Head (4, 11) | 'previous_attention' | cumul=-0.1323%
#   [SEED] k=007 | Head (7, 1) | 'initial_token_attention' | cumul=0.1771%
#   [SEED] k=008 | Head (11, 9) | 'initial_token_attention' | cumul=-0.2135%
#   [SEED] k=009 | Head (10, 0) | 'initial_token_attention' | cumul=-0.2058%
#   [SEED] k=010 | Head (11, 2) | 'initial_token_attention' | cumul=1.0039%
#   [SEED] k=011 | Head (7, 7) | 'initial_token_attention' | cumul=0.9243%
#   [SEED] k=012 | Head (5, 5) | 'initial_token_attention' | cumul=0.6362%
#   [SEED] k=013 | Head (6, 6) | 'initial_token_attention' | cumul=0.4550%
#   [SEED] k=014 | Head (10, 8) | 'initial_token_attention' | cumul=0.1011%
#   [SEED] k=015 | Head (3, 0) | 'initial_token_attention' | cumul=-0.0733%
#   [SEED] k=016 | Head (0, 1) | 'repeated_attention' | cumul=-0.0823%
#   [SEED] k=017 | Head (9, 6) | 'initial_token_attention' | cumul=0.0840%
#   [SEED] k=018 | Head (9, 9) | 'sentence_start_dominance' | cumul=0.2021%
#   [SEED] k=019 | Head (9, 5) | 'sentence_initial_dominance' | cumul=-1.7203%
#   [SEED] k=020 | Head (8, 1) | 'initial_token_attention' | cumul=-1.9936%
#   [SEED] k=021 | Head (10, 10) | 'initial_token_attention' | cumul=-1.8115%
#   [SEED] k=022 | Head (9, 11) | 'initial_token_attention' | cumul=-1.4920%
#   [SEED] k=023 | Head (3, 4) | 'initial_token_attention' | cumul=-1.6696%
#   [SEED] k=024 | Head (11, 7) | 'initial_token_attention' | cumul=-0.7345%
#   [SEED] k=025 | Head (11, 5) | 'initial_token_attention' | cumul=-0.2976%
#   [SEED] k=026 | Head (9, 4) | 'initial_token_attention' | cumul=-0.3463%
#   [SEED] k=027 | Head (7, 10) | 'initial_token_attention' | cumul=-0.1648%
#   [SEED] k=028 | Head (6, 10) | 'initial_token_attention' | cumul=0.0257%
#   [SEED] k=029 | Head (9, 8) | 'sentence_initial_dominance' | cumul=-1.4410%
#   [SEED] k=030 | Head (10, 6) | 'initial_token_attention' | cumul=-1.3665%
#   [SEED] k=031 | Head (11, 1) | 'sentence_initial_dominance' | cumul=-3.0456%
#   [SEED] k=032 | Head (7, 11) | 'initial_token_attention' | cumul=-2.9486%
#   [SEED] k=033 | Head (6, 2) | 'sentence_initial_dominance' | cumul=-4.1300%
#   [SEED] k=034 | Head (7, 6) | 'sentence_initial_dominance' | cumul=-5.0680%
#   [SEED] k=035 | Head (8, 3) | 'initial_token_attention' | cumul=-4.9025%
#   [SEED] k=036 | Head (5, 9) | 'sentence_initial_dominance' | cumul=-5.5712%
#   [SEED] k=037 | Head (10, 3) | 'sentence_initial_dominance' | cumul=-7.4502%
#   [SEED] k=038 | Head (5, 0) | 'initial_token_attention' | cumul=-7.1277%
#   [SEED] k=039 | Head (8, 11) | 'sentence_initial_dominance' | cumul=-8.6579%
#   [SEED] k=040 | Head (9, 1) | 'initial_token_attention' | cumul=-8.4641%
#   [SEED] k=041 | Head (8, 0) | 'sentence_initial_dominance' | cumul=-10.0269%
#   [SEED] k=042 | Head (4, 10) | 'initial_token_attention' | cumul=-9.9291%
#   [SPIKE] Head (0, 3) Rank-1 'rare_word_dominance' marginal=5.25%. Trying Rank-2...
#   [SPIKE] Head (0, 3) Rank-2 'same_attention' marginal=5.25%. Trying Rank-3...
#   [SPIKE] Head (0, 3) Rank-3 'lexical_diversity_focus' marginal=5.25%. Trying Rank-4...
#   [SPIKE] Head (0, 3) Rank-4 'conjunction_resolution' marginal=5.30%. Trying Rank-5...
#   [SPIKE] Head (0, 3) Rank-5 'repeated_attention' marginal=5.23%. All ranks exhausted.
#   [SKIP] Head (0, 3): all 5 programs spiked.
#   [SPIKE] Head (0, 5) Rank-1 'lexical_diversity_focus' marginal=5.26%. Trying Rank-2...
#   [SPIKE] Head (0, 5) Rank-2 'repeated_attention' marginal=5.26%. Trying Rank-3...
#   [SPIKE] Head (0, 5) Rank-3 'rare_word_dominance' marginal=5.29%. Trying Rank-4...
#   [SPIKE] Head (0, 5) Rank-4 'same_attention' marginal=5.29%. Trying Rank-5...
#   [SPIKE] Head (0, 5) Rank-5 'conjunction_resolution' marginal=12.59%. All ranks exhausted.
#   [SKIP] Head (0, 5): all 5 programs spiked.
#   [SPIKE] Head (4, 8) Rank-1 'token_reinforcement' marginal=5.95%. Trying Rank-2...
#   [SPIKE] Head (4, 8) Rank-2 'sentence_beginning_salience' marginal=6.05%. Trying Rank-3...
#   [SPIKE] Head (4, 8) Rank-3 'initial_element_reinforcement' marginal=5.29%. Trying Rank-4...
#   [SPIKE] Head (4, 8) Rank-4 'initial_token_anchoring' marginal=6.05%. Trying Rank-5...
#   [SPIKE] Head (4, 8) Rank-5 'initial_token_centralization' marginal=6.05%. All ranks exhausted.
#   [SKIP] Head (4, 8): all 5 programs spiked.
#   [SPIKE] Head (5, 11) Rank-1 'initial_token_reference_attention' marginal=6.10%. Trying Rank-2...
#   [SPIKE] Head (5, 11) Rank-2 'token_reinforcement' marginal=6.17%. Trying Rank-3...
#   [SPIKE] Head (5, 11) Rank-3 'sentence_beginning_salience' marginal=6.29%. Trying Rank-4...
#   [SPIKE] Head (5, 11) Rank-4 'initial_element_reinforcement' marginal=5.29%. Trying Rank-5...
#   [SPIKE] Head (5, 11) Rank-5 'initial_token_anchoring' marginal=6.29%. All ranks exhausted.
#   [SKIP] Head (5, 11): all 5 programs spiked.
#   [SPIKE] Head (0, 9) Rank-1 'uniform_lower_diagonal' marginal=5.72%. Trying Rank-2...
#   [SPIKE] Head (0, 9) Rank-2 'sentence_position_preference' marginal=5.78%. Trying Rank-3...
#   [SPIKE] Head (0, 9) Rank-3 'contextual_anchoring' marginal=6.10%. Trying Rank-4...
#   [SPIKE] Head (0, 9) Rank-4 'quotation_association' marginal=5.75%. Trying Rank-5...
#   [SPIKE] Head (0, 9) Rank-5 'appositive_phrase_attention' marginal=5.75%. All ranks exhausted.
#   [SKIP] Head (0, 9): all 5 programs spiked.
#   [SPIKE] Head (9, 0) Rank-1 'token_reinforcement' marginal=5.92%. Trying Rank-2...
#   [SPIKE] Head (9, 0) Rank-2 'sentence_beginning_salience' marginal=6.01%. Trying Rank-3...
#   [SPIKE] Head (9, 0) Rank-3 'initial_element_reinforcement' marginal=5.29%. Trying Rank-4...
#   [SPIKE] Head (9, 0) Rank-4 'initial_token_anchoring' marginal=6.01%. Trying Rank-5...
#   [SPIKE] Head (9, 0) Rank-5 'initial_token_centralization' marginal=6.01%. All ranks exhausted.
#   [SKIP] Head (9, 0): all 5 programs spiked.
#   [SPIKE] Head (11, 6) Rank-1 'sentence_beginning_salience' marginal=2002.08%. Trying Rank-2...
#   [SPIKE] Head (11, 6) Rank-2 'initial_element_reinforcement' marginal=5.29%. Trying Rank-3...
#   [SPIKE] Head (11, 6) Rank-3 'initial_token_anchoring' marginal=2013.23%. Trying Rank-4...
#   [SPIKE] Head (11, 6) Rank-4 'initial_token_centralization' marginal=2013.23%. Trying Rank-5...
#   [SPIKE] Head (11, 6) Rank-5 'sentence_start_dominance' marginal=2013.23%. All ranks exhausted.
#   [SKIP] Head (11, 6): all 5 programs spiked.
#   [SPIKE] Head (9, 2) Rank-1 'token_reinforcement' marginal=5.28%. Trying Rank-2...
#   [SPIKE] Head (9, 2) Rank-2 'sentence_beginning_salience' marginal=5.30%. Trying Rank-3...
#   [SPIKE] Head (9, 2) Rank-3 'initial_element_reinforcement' marginal=5.29%. Trying Rank-4...
#   [SPIKE] Head (9, 2) Rank-4 'initial_token_anchoring' marginal=5.30%. Trying Rank-5...
#   [SPIKE] Head (9, 2) Rank-5 'initial_token_centralization' marginal=5.30%. All ranks exhausted.
#   [SKIP] Head (9, 2): all 5 programs spiked.
#   [SPIKE] Head (6, 4) Rank-1 'initial_token_reference_attention' marginal=5.35%. Trying Rank-2...
#   [SPIKE] Head (6, 4) Rank-2 'token_reinforcement' marginal=5.35%. Trying Rank-3...
#   [SPIKE] Head (6, 4) Rank-3 'sentence_beginning_salience' marginal=5.40%. Trying Rank-4...
#   [SPIKE] Head (6, 4) Rank-4 'initial_element_reinforcement' marginal=5.29%. Trying Rank-5...
#   [SPIKE] Head (6, 4) Rank-5 'initial_token_anchoring' marginal=5.40%. All ranks exhausted.
#   [SKIP] Head (6, 4): all 5 programs spiked.
#   [SPIKE] Head (0, 11) Rank-1 'uniform_lower_diagonal' marginal=5.08%. Trying Rank-2...
#   [SPIKE] Head (0, 11) Rank-2 'sentence_position_preference' marginal=5.48%. Trying Rank-3...
#   k=043 | Head (0, 11) | Rank-3 'contextual_anchoring' | cumul=-5.1544%
#   k=044 | Head (7, 9) | Rank-1 'token_reinforcement' | cumul=-4.7179%
#   k=045 | Head (6, 3) | Rank-1 'token_reinforcement' | cumul=-4.4363%
#   k=046 | Head (10, 7) | Rank-1 'token_reinforcement' | cumul=-4.2015%
#   k=047 | Head (10, 11) | Rank-1 'token_reinforcement' | cumul=-3.7408%
#   k=048 | Head (3, 10) | Rank-1 'initial_token_reference_attention' | cumul=-3.5432%
#   k=049 | Head (5, 7) | Rank-1 'token_reinforcement' | cumul=-3.1626%
#   k=050 | Head (4, 4) | Rank-1 'token_reinforcement' | cumul=-2.4284%
#   k=051 | Head (11, 4) | Rank-1 'token_reinforcement' | cumul=-2.9391%
#   k=052 | Head (7, 4) | Rank-1 'sentence_beginning_salience' | cumul=-2.2708%
#   k=053 | Head (8, 6) | Rank-1 'sentence_beginning_salience' | cumul=-2.3689%
#   k=054 | Head (9, 7) | Rank-1 'token_reinforcement' | cumul=-2.6881%
#   k=055 | Head (0, 2) | Rank-1 'uniform_lower_diagonal' | cumul=-2.8325%
#   [SPIKE] Head (1, 2) Rank-1 'uniform_lower_diagonal' marginal=77.18%. Trying Rank-2...
#   [SPIKE] Head (1, 2) Rank-2 'sentence_position_preference' marginal=108.60%. Trying Rank-3...
#   [SPIKE] Head (1, 2) Rank-3 'contextual_anchoring' marginal=39.50%. Trying Rank-4...
#   [SPIKE] Head (1, 2) Rank-4 'quotation_association' marginal=5.53%. Trying Rank-5...
#   [SPIKE] Head (1, 2) Rank-5 'appositive_phrase_attention' marginal=5.53%. All ranks exhausted.
#   [SKIP] Head (1, 2): all 5 programs spiked.
#   k=056 | Head (11, 11) | Rank-1 'initial_token_reference_attention' | cumul=-2.8852%
#   k=057 | Head (4, 2) | Rank-1 'token_reinforcement' | cumul=-2.7421%
#   k=058 | Head (2, 10) | Rank-1 'uniform_lower_diagonal' | cumul=-2.4578%
#   k=059 | Head (9, 10) | Rank-1 'token_reinforcement' | cumul=-2.0648%
#   k=060 | Head (8, 9) | Rank-1 'token_reinforcement' | cumul=-1.1469%
#   k=061 | Head (10, 5) | Rank-1 'sentence_beginning_salience' | cumul=-1.2971%
#   k=062 | Head (3, 5) | Rank-1 'token_reinforcement' | cumul=-0.5587%
#   k=063 | Head (10, 4) | Rank-1 'token_reinforcement' | cumul=-0.0721%
#   k=064 | Head (1, 7) | Rank-1 'uniform_lower_diagonal' | cumul=-0.1129%
#   k=065 | Head (0, 10) | Rank-1 'uniform_lower_diagonal' | cumul=0.1346%
#   k=066 | Head (2, 1) | Rank-1 'token_reinforcement' | cumul=0.3791%
#   k=067 | Head (5, 8) | Rank-1 'token_reinforcement' | cumul=1.0077%
#   k=068 | Head (0, 6) | Rank-1 'uniform_lower_diagonal' | cumul=0.7592%
#   k=069 | Head (5, 6) | Rank-1 'token_reinforcement' | cumul=1.4116%
#   k=070 | Head (7, 0) | Rank-1 'token_reinforcement' | cumul=2.5723%
#   k=071 | Head (7, 3) | Rank-1 'token_reinforcement' | cumul=2.7960%
#   k=072 | Head (11, 0) | Rank-1 'uniform_lower_diagonal' | cumul=3.0914%
#   k=073 | Head (7, 8) | Rank-1 'token_reinforcement' | cumul=3.0579%
#   k=074 | Head (2, 7) | Rank-1 'uniform_lower_diagonal' | cumul=3.2955%
#   k=075 | Head (6, 1) | Rank-1 'token_reinforcement' | cumul=4.4093%
#   k=076 | Head (11, 10) | Rank-1 'initial_token_reference_attention' | cumul=5.0774%
#   k=077 | Head (8, 8) | Rank-1 'token_reinforcement' | cumul=6.1545%
#   k=078 | Head (6, 5) | Rank-1 'token_reinforcement' | cumul=6.3636%
#   k=079 | Head (1, 9) | Rank-1 'uniform_lower_diagonal' | cumul=6.5950%
#   k=080 | Head (6, 8) | Rank-1 'token_reinforcement' | cumul=7.4410%
#   k=081 | Head (1, 3) | Rank-1 'initial_token_reference_attention' | cumul=7.2677%
#   k=082 | Head (1, 11) | Rank-1 'lexical_diversity_focus' | cumul=7.1957%
#   k=083 | Head (1, 8) | Rank-1 'uniform_lower_diagonal' | cumul=7.1624%
#   k=084 | Head (6, 7) | Rank-1 'token_reinforcement' | cumul=8.9166%
#   k=085 | Head (1, 10) | Rank-1 'uniform_lower_diagonal' | cumul=8.9963%
#   k=086 | Head (4, 9) | Rank-1 'sentence_position_preference' | cumul=9.3495%
#   k=087 | Head (11, 8) | Rank-1 'uniform_lower_diagonal' | cumul=9.6964%
#   k=088 | Head (8, 4) | Rank-1 'token_reinforcement' | cumul=10.1272%
#   k=089 | Head (4, 6) | Rank-1 'token_reinforcement' | cumul=11.1804%
#   k=090 | Head (1, 4) | Rank-1 'uniform_lower_diagonal' | cumul=11.8906%
#   k=091 | Head (8, 10) | Rank-1 'token_reinforcement' | cumul=13.3338%
#   k=092 | Head (0, 0) | Rank-1 'uniform_lower_diagonal' | cumul=13.2657%
#   k=093 | Head (9, 3) | Rank-1 'initial_token_reference_attention' | cumul=13.7826%
#   k=094 | Head (10, 9) | Rank-1 'token_reinforcement' | cumul=15.3662%
#   k=095 | Head (8, 2) | Rank-1 'token_reinforcement' | cumul=15.3194%
#   k=096 | Head (4, 5) | Rank-1 'token_reinforcement' | cumul=16.1528%
#   k=097 | Head (5, 2) | Rank-1 'token_reinforcement' | cumul=17.0055%
#   k=098 | Head (1, 6) | Rank-1 'uniform_lower_diagonal' | cumul=17.2888%
#   k=099 | Head (11, 3) | Rank-1 'token_reinforcement' | cumul=17.4846%
#   k=100 | Head (2, 2) | Rank-1 'previous_attention' | cumul=17.2045%
#   k=101 | Head (8, 7) | Rank-1 'token_reinforcement' | cumul=19.0772%
#   k=102 | Head (2, 11) | Rank-1 'token_reinforcement' | cumul=19.5058%
#   k=103 | Head (3, 9) | Rank-1 'initial_token_reference_attention' | cumul=21.0773%
#   k=104 | Head (0, 7) | Rank-1 'uniform_lower_diagonal' | cumul=21.3147%
#   k=105 | Head (1, 0) | Rank-1 'uniform_lower_diagonal' | cumul=21.2726%
#   k=106 | Head (5, 4) | Rank-1 'token_reinforcement' | cumul=22.8637%
#   k=107 | Head (3, 1) | Rank-1 'initial_token_reference_attention' | cumul=23.9306%
#   [STOP] Cumulative 25.36% > 25.0%. Ending shuffle 32 early.
#   ✓ Saved 107 rows → ../results/replacement_run/shuffles/gpt2_top3_shuffle_64.csv
#
# [DONE] All 32 shuffles complete.

# %%
# read the 72 shuffles from paper_results\results\replacement_run\shuffles\gpt2_top3_shuffle_1.csv and plot their increase on same plot, alpha 0.5, with a line for the mean increase across shuffles at each k, and a shaded area for the std deviation across shuffles at each k. Save the plot as gpt2_top3_shuffles.png

from pathlib import Path
import matplotlib.pyplot as plt

# Read all shuffle CSVs
shuffle_dir = Path("../results/replacement_run/shuffles")
shuffle_files = list(shuffle_dir.glob("gpt2_top3_shuffle_*.csv"))
all_shuffles = []
for file in shuffle_files:
    df = pd.read_csv(file)
    all_shuffles.append(df)

# Concatenate all shuffles into a single DataFrame
shuffles_df = pd.concat(all_shuffles, ignore_index=True)
# Group by 'k' to calculate mean and std deviation
grouped = shuffles_df.groupby('k')['increase'].agg(['mean', 'std']).reset_index()
# Plotting
plt.figure(figsize=(12, 6))
# Plot each shuffle with low alpha
for shuffle_idx in shuffles_df['shuffle_idx'].unique():
    subset = shuffles_df[shuffles_df['shuffle_idx'] == shuffle_idx]
    plt.plot(subset['k'], subset['increase'], alpha=0.5, label=f'Shuffle {shuffle_idx}')
# Plot mean increase with std deviation shaded area
# plt.plot(grouped['k'], grouped['mean'], color='black', label='Mean Increase', linewidth=2)
# plt.fill_between(grouped['k'], grouped['mean'] - grouped['std'], grouped['mean'] + grouped['std'], color='gray', alpha=0.3, label='Std Deviation')
plt.xlabel('k (Number of Replacements)')
plt.ylabel('Perplexity Increase (%)')
plt.title('Perplexity Increase Across GPT-2 Top-3 Shuffles')
# plt.legend()
plt.grid()

# plt.savefig("gpt2_top3_shuffles.png")
plt.show()

# %%
from pathlib import Path
import ast
import copy
import numpy as np
import pandas as pd
import torch
import torch.nn.functional as F
from transformers import AutoModelForCausalLM, AutoTokenizer, BertForMaskedLM, GPT2LMHeadModel, GPT2Tokenizer

import logging
from transformers import logging as transformers_logging
transformers_logging.set_verbosity_error()

shuffle_dir = Path("../results/replacement_run/shuffles")
best_fits_folder = Path("../results")

# file, number of heads still needed to reach 100% replacement
get_to_100percent_replacements = [
    (shuffle_dir / "gpt2_smart_shuffle_8.csv", 3),
    (shuffle_dir / "bert_smart_shuffle_5.csv", 35),
    (shuffle_dir / "tinyllama_smart_shuffle_2.csv", 454),
]

head_counts = {
    "bert": 144,
    "gpt2": 144,
    "tinyllama": 704,
}

SPIKE_THRESHOLD = 100.0
TAIL_HEADS_TO_SEARCH = 104
TAIL_CANDIDATE_LIMIT = 3
NUM_SENTENCES = 5
TINYLLAMA_MODEL_ID = "TinyLlama/TinyLlama-1.1B-intermediate-step-1431k-3T"


def _parse_model_key(csv_path: Path) -> str:
    return csv_path.name.split("_")[0].lower()


def _parse_head(raw_head):
    if isinstance(raw_head, tuple):
        return (int(raw_head[0]), int(raw_head[1]))
    if isinstance(raw_head, list):
        return (int(raw_head[0]), int(raw_head[1]))
    if isinstance(raw_head, str):
        parsed = ast.literal_eval(raw_head)
        return (int(parsed[0]), int(parsed[1]))
    raise ValueError(f"Unrecognized head format: {raw_head}")


def _load_eval_sentences():
    return pd.read_json("../data/generic_sentences.json")[0].tolist()[:NUM_SENTENCES]


def _mean_sequence_kl(logits_new, logits_base):
    return F.kl_div(
        F.log_softmax(logits_new, dim=-1),
        F.softmax(logits_base, dim=-1),
        reduction="batchmean",
    ).item()


def _build_seed_mapping(seed_df):
    return [(_parse_head(row["head"]), str(row["program"])) for _, row in seed_df.iterrows()]


def _build_head_program_candidates(model_key, top_k=TAIL_CANDIDATE_LIMIT):
    iou_csv = Path(DATA_DIR) / f"iou_scores_{model_key}.csv"
    iou_df = pd.read_csv(iou_csv)
    mean_iou = (
        iou_df.groupby(["layer", "head", "program_idx"])["iou_score"]
        .mean()
        .reset_index()
    )

    head_program_candidates = {}
    for (layer, head), grp in mean_iou.groupby(["layer", "head"]):
        top = grp.nlargest(top_k, "iou_score").reset_index(drop=True)
        head_program_candidates[(int(layer), int(head))] = [
            all_programs[int(row["program_idx"])].__name__
            for _, row in top.iterrows()
        ]
    return head_program_candidates


def _finalize_and_save(rows, seed_df, save_path):
    final_df = pd.DataFrame(rows)
    for column in seed_df.columns:
        if column not in final_df.columns:
            final_df[column] = pd.NA
    final_df = final_df.reindex(columns=list(seed_df.columns))
    final_df.to_csv(save_path, index=False)
    return final_df


def _full_perplexity(sentence, model, tokenizer, device):
    inputs = tokenizer(sentence, return_tensors="pt").to(device)
    input_ids = inputs["input_ids"]
    seq_len = input_ids.shape[1]
    log_probs = []
    for i in range(1, seq_len - 1):
        masked = input_ids.clone()
        masked[0, i] = tokenizer.mask_token_id
        with torch.no_grad():
            logits = model(masked).logits
        prob = torch.log_softmax(logits[0, i], dim=-1)[input_ids[0, i]]
        log_probs.append(prob)
    return torch.exp(-torch.stack(log_probs).mean()).item()


def _choose_tail_candidate(accepted_heads_mapping, head_tuple, candidate_programs, evaluate_candidate, prev_cumulative):
    candidate_programs = list(dict.fromkeys(candidate_programs))[:TAIL_CANDIDATE_LIMIT]
    best_choice = None

    for rank, prog_name in enumerate(candidate_programs, start=1):
        mean_pct, mean_kl = evaluate_candidate(accepted_heads_mapping, head_tuple, prog_name)
        marginal = mean_pct - prev_cumulative

        if best_choice is None or mean_pct < best_choice["mean_pct"]:
            best_choice = {
                "rank": rank,
                "prog_name": prog_name,
                "mean_pct": mean_pct,
                "mean_kl": mean_kl,
                "marginal": marginal,
            }

        print(f"  [TAIL-TRY] Head {head_tuple} Rank-{rank} '{prog_name}' | marginal={marginal:.2f}%")

        if marginal <= SPIKE_THRESHOLD:
            return {
                "rank": rank,
                "prog_name": prog_name,
                "mean_pct": mean_pct,
                "mean_kl": mean_kl,
                "marginal": marginal,
            }

    print(f"  [TAIL] Head {head_tuple}: no candidate cleared {SPIKE_THRESHOLD:.0f}%; using best of {len(candidate_programs)} candidates.")
    return best_choice


def _continue_gpt2(seed_df, remaining_df, save_path):
    eval_sents = _load_eval_sentences()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
    head_program_candidates = _build_head_program_candidates("gpt2")

    print("[INFO] GPT2: calculating baseline perplexities...")
    base_model = GPT2LMHeadModel.from_pretrained("gpt2").to(device)
    base_model.eval()
    baseline_ppls = []
    baseline_logits = []
    for sent in eval_sents:
        active_sent = prepare_sentence(sent, mode="last_word")
        toks = tokenizer(active_sent, return_tensors="pt").to(device)
        with torch.no_grad():
            out = base_model(**toks, labels=toks["input_ids"])
            baseline_ppls.append(torch.exp(out.loss).item())
            baseline_logits.append(out.logits[:, -1, :])
    del base_model
    torch.cuda.empty_cache()

    def make_smart_hook(lookup, programs_list):
        def compound_hook(module, input, output):
            context_layer = output[0]
            batch, seq_len, hidden_dim = context_layer.shape
            num_heads, head_dim = 12, hidden_dim // 12
            modified_layer = context_layer.view(batch, seq_len, num_heads, head_dim).clone()
            current_sent = getattr(module, "_current_sentence", None)
            if current_sent is None:
                return output
            for head_idx in range(num_heads):
                key = (module.layer_id, head_idx)
                if key in lookup:
                    prog_name = lookup[key]
                    prog = next((p for p in programs_list if p.__name__ == prog_name), None)
                    if prog:
                        try:
                            _, hypo_mat = prog(current_sent, tokenizer)
                            if hypo_mat is not None:
                                hypo_tensor = torch.tensor(hypo_mat).to(device, dtype=modified_layer.dtype)
                                modified_layer[:, :, head_idx, :] = torch.matmul(hypo_tensor, modified_layer[:, :, head_idx, :])
                        except Exception:
                            pass
            return (modified_layer.view(batch, seq_len, hidden_dim),) + output[1:]
        return compound_hook

    def evaluate_candidate(accepted_heads_mapping, candidate_head, candidate_prog):
        trial_mapping = accepted_heads_mapping + [(candidate_head, candidate_prog)]
        trial_lookup = {tuple(map(int, h)): p for h, p in trial_mapping}
        relevant_layers = set(h[0] for h in trial_lookup)

        model_k = GPT2LMHeadModel.from_pretrained("gpt2").to(device)
        model_k.eval()

        hook_fn = make_smart_hook(trial_lookup, all_programs)
        hook_handles = []
        for l_idx in range(12):
            target = model_k.transformer.h[l_idx].attn
            target.layer_id = l_idx
            if l_idx in relevant_layers:
                hook_handles.append(target.register_forward_hook(hook_fn))

        replaced_ppls, kl_divergences = [], []
        for i, sent in enumerate(eval_sents):
            active_sent = prepare_sentence(sent, mode="last_word")
            for l_idx in relevant_layers:
                model_k.transformer.h[l_idx].attn._current_sentence = active_sent
            toks = tokenizer(active_sent, return_tensors="pt").to(device)
            with torch.no_grad():
                out_rep = model_k(**toks, labels=toks["input_ids"])
                replaced_ppls.append(torch.exp(out_rep.loss).item())
                kl_divergences.append(_mean_sequence_kl(out_rep.logits[:, -1, :], baseline_logits[i]))

        for handle in hook_handles:
            handle.remove()
        del model_k
        torch.cuda.empty_cache()

        mean_pct = float(np.mean([(r - b) / b * 100 for r, b in zip(replaced_ppls, baseline_ppls)]))
        mean_kl = float(np.mean(kl_divergences))
        return mean_pct, mean_kl

    accepted_heads_mapping = _build_seed_mapping(seed_df)
    rows = seed_df.to_dict(orient="records")
    current_k = int(seed_df.iloc[-1]["k"])
    prev_cumulative = float(seed_df.iloc[-1]["increase"])

    total_remaining = len(remaining_df)
    for idx, (_, row) in enumerate(remaining_df.iterrows()):
        head_tuple = (int(row["layer"]), int(row["head"]))
        default_prog = all_programs[int(row["program_idx"])].__name__

        if total_remaining - idx <= TAIL_HEADS_TO_SEARCH:
            candidate_programs = head_program_candidates.get(head_tuple, [])
            if default_prog not in candidate_programs:
                candidate_programs = [default_prog] + candidate_programs
            choice = _choose_tail_candidate(
                accepted_heads_mapping,
                head_tuple,
                candidate_programs,
                evaluate_candidate,
                prev_cumulative,
            )
            prog_name = choice["prog_name"]
            mean_pct = choice["mean_pct"]
            mean_kl = choice["mean_kl"]
            marginal = choice["marginal"]
            accepted_rank = choice["rank"]
        else:
            prog_name = default_prog
            mean_pct, mean_kl = evaluate_candidate(accepted_heads_mapping, head_tuple, prog_name)
            marginal = mean_pct - prev_cumulative
            accepted_rank = 1

        current_k += 1
        accepted_heads_mapping.append((head_tuple, prog_name))

        new_row = {
            "k": current_k,
            "head": str(head_tuple),
            "program": prog_name,
            "strategy": "smart",
            "increase": round(mean_pct, 6),
            "spike": bool(marginal > SPIKE_THRESHOLD),
        }
        if "kl_div" in seed_df.columns:
            new_row["kl_div"] = round(mean_kl, 6)
        rows.append(new_row)
        prev_cumulative = mean_pct
        print(f"  [APPEND] k={current_k:03d} | Head {head_tuple} | Rank-{accepted_rank} '{prog_name}' | cumul={mean_pct:.4f}%")

    return _finalize_and_save(rows, seed_df, save_path)


def _continue_bert(seed_df, remaining_df, save_path):
    eval_sents = _load_eval_sentences()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
    head_program_candidates = _build_head_program_candidates("bert")

    print("[INFO] BERT: calculating baseline pseudo-perplexities...")
    base_model = BertForMaskedLM.from_pretrained("bert-base-uncased").to(device)
    base_model.eval()
    baseline_ppls = [_full_perplexity(sent, base_model, tokenizer, device) for sent in eval_sents]
    del base_model
    torch.cuda.empty_cache()

    def make_smart_hook(lookup, programs_list):
        def compound_hook(module, input, output):
            context_layer = output[0]
            batch, seq_len, hidden_dim = context_layer.shape
            num_heads, head_dim = 12, hidden_dim // 12
            modified_layer = context_layer.view(batch, seq_len, num_heads, head_dim).clone()
            current_sent = getattr(module, "_current_sentence", None)
            if current_sent is None:
                return output
            for head_idx in range(num_heads):
                key = (module.layer_id, head_idx)
                if key in lookup:
                    prog_name = lookup[key]
                    prog = next((p for p in programs_list if p.__name__ == prog_name), None)
                    if prog:
                        try:
                            _, hypo_mat = prog(current_sent, tokenizer)
                            if hypo_mat is not None:
                                hypo_tensor = torch.tensor(hypo_mat).to(device, dtype=modified_layer.dtype)
                                modified_layer[:, :, head_idx, :] = torch.matmul(hypo_tensor, modified_layer[:, :, head_idx, :])
                        except Exception:
                            pass
            return (modified_layer.view(batch, seq_len, hidden_dim),) + output[1:]
        return compound_hook

    def evaluate_candidate(accepted_heads_mapping, candidate_head, candidate_prog):
        trial_mapping = accepted_heads_mapping + [(candidate_head, candidate_prog)]
        trial_lookup = {tuple(map(int, h)): p for h, p in trial_mapping}
        relevant_layers = set(h[0] for h in trial_lookup)

        model_k = BertForMaskedLM.from_pretrained("bert-base-uncased").to(device)
        model_k.eval()

        hook_fn = make_smart_hook(trial_lookup, all_programs)
        hook_handles = []
        for l_idx in range(12):
            target = model_k.bert.encoder.layer[l_idx].attention.self
            target.layer_id = l_idx
            if l_idx in relevant_layers:
                hook_handles.append(target.register_forward_hook(hook_fn))

        replaced_ppls = []
        for sent in eval_sents:
            active_sent = prepare_sentence(sent, mode="last_word")
            for l_idx in relevant_layers:
                model_k.bert.encoder.layer[l_idx].attention.self._current_sentence = active_sent
            replaced_ppls.append(_full_perplexity(active_sent, model_k, tokenizer, device))

        for handle in hook_handles:
            handle.remove()
        del model_k
        torch.cuda.empty_cache()

        mean_pct = float(np.mean([(r - b) / b * 100 for r, b in zip(replaced_ppls, baseline_ppls)]))
        return mean_pct, None

    accepted_heads_mapping = _build_seed_mapping(seed_df)
    rows = seed_df.to_dict(orient="records")
    current_k = int(seed_df.iloc[-1]["k"])
    prev_cumulative = float(seed_df.iloc[-1]["increase"])

    total_remaining = len(remaining_df)
    for idx, (_, row) in enumerate(remaining_df.iterrows()):
        head_tuple = (int(row["layer"]), int(row["head"]))
        default_prog = all_programs[int(row["program_idx"])].__name__

        if total_remaining - idx <= TAIL_HEADS_TO_SEARCH:
            candidate_programs = head_program_candidates.get(head_tuple, [])
            if default_prog not in candidate_programs:
                candidate_programs = [default_prog] + candidate_programs
            choice = _choose_tail_candidate(
                accepted_heads_mapping,
                head_tuple,
                candidate_programs,
                evaluate_candidate,
                prev_cumulative,
            )
            prog_name = choice["prog_name"]
            mean_pct = choice["mean_pct"]
            mean_kl = choice["mean_kl"]
            marginal = choice["marginal"]
            accepted_rank = choice["rank"]
        else:
            prog_name = default_prog
            mean_pct, mean_kl = evaluate_candidate(accepted_heads_mapping, head_tuple, prog_name)
            marginal = mean_pct - prev_cumulative
            accepted_rank = 1

        current_k += 1
        accepted_heads_mapping.append((head_tuple, prog_name))

        new_row = {
            "k": current_k,
            "head": str(head_tuple),
            "program": prog_name,
            "strategy": "smart",
            "increase": round(mean_pct, 6),
            "spike": bool(marginal > SPIKE_THRESHOLD),
        }
        rows.append(new_row)
        prev_cumulative = mean_pct
        print(f"  [APPEND] k={current_k:03d} | Head {head_tuple} | Rank-{accepted_rank} '{prog_name}' | cumul={mean_pct:.4f}%")

    return _finalize_and_save(rows, seed_df, save_path)


def _continue_tinyllama(seed_df, remaining_df, save_path):
    eval_sents = _load_eval_sentences()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    tokenizer = AutoTokenizer.from_pretrained(TINYLLAMA_MODEL_ID)
    head_program_candidates = _build_head_program_candidates("tinyllama")

    print("[INFO] TinyLlama: loading reference model and calculating baseline perplexities...")
    ref_model = AutoModelForCausalLM.from_pretrained(TINYLLAMA_MODEL_ID).to(device)
    ref_model.eval()

    baseline_ppls, baseline_logits = [], []
    for sent in eval_sents:
        active_sent = prepare_sentence(sent, mode="last_word")
        toks = tokenizer(active_sent, return_tensors="pt").to(device)
        with torch.no_grad():
            out = ref_model(**toks, labels=toks["input_ids"])
            baseline_ppls.append(torch.exp(out.loss).item())
            baseline_logits.append(out.logits[:, -1, :])

    def make_smart_hook(lookup, programs_list):
        def compound_hook(module, input, output):
            context_layer = output[0]
            batch, seq_len, hidden_dim = context_layer.shape
            num_heads, head_dim = 32, hidden_dim // 32
            modified_layer = context_layer.view(batch, seq_len, num_heads, head_dim).clone()
            current_sent = getattr(module, "_current_sentence", None)
            if current_sent is None:
                return output
            for head_idx in range(num_heads):
                key = (module.layer_id, head_idx)
                if key in lookup:
                    prog_name = lookup[key]
                    prog = next((p for p in programs_list if p.__name__ == prog_name), None)
                    if prog:
                        try:
                            _, hypo_mat = prog(current_sent, tokenizer)
                            if hypo_mat is not None:
                                hypo_tensor = torch.tensor(hypo_mat).to(device, dtype=modified_layer.dtype)
                                modified_layer[:, :, head_idx, :] = torch.matmul(hypo_tensor, modified_layer[:, :, head_idx, :])
                        except Exception:
                            pass
            return (modified_layer.view(batch, seq_len, hidden_dim),) + output[1:]
        return compound_hook

    def evaluate_candidate(accepted_heads_mapping, candidate_head, candidate_prog):
        trial_mapping = accepted_heads_mapping + [(candidate_head, candidate_prog)]
        trial_lookup = {tuple(map(int, h)): p for h, p in trial_mapping}
        relevant_layers = set(h[0] for h in trial_lookup)

        model_k = copy.deepcopy(ref_model)
        model_k.eval()

        hook_fn = make_smart_hook(trial_lookup, all_programs)
        hook_handles = []
        for l_idx in range(22):
            target = model_k.model.layers[l_idx].self_attn
            target.layer_id = l_idx
            if l_idx in relevant_layers:
                hook_handles.append(target.register_forward_hook(hook_fn))

        replaced_ppls, kl_divergences = [], []
        for i, sent in enumerate(eval_sents):
            active_sent = prepare_sentence(sent, mode="last_word")
            for l_idx in relevant_layers:
                model_k.model.layers[l_idx].self_attn._current_sentence = active_sent
            toks = tokenizer(active_sent, return_tensors="pt").to(device)
            with torch.no_grad():
                out_rep = model_k(**toks, labels=toks["input_ids"])
                replaced_ppls.append(torch.exp(out_rep.loss).item())
                kl_divergences.append(_mean_sequence_kl(out_rep.logits[:, -1, :], baseline_logits[i]))

        for handle in hook_handles:
            handle.remove()
        del model_k
        torch.cuda.empty_cache()

        mean_pct = float(np.mean([(r - b) / b * 100 for r, b in zip(replaced_ppls, baseline_ppls)]))
        mean_kl = float(np.mean(kl_divergences))
        return mean_pct, mean_kl

    accepted_heads_mapping = _build_seed_mapping(seed_df)
    rows = seed_df.to_dict(orient="records")
    current_k = int(seed_df.iloc[-1]["k"])
    prev_cumulative = float(seed_df.iloc[-1]["increase"])

    total_remaining = len(remaining_df)
    for idx, (_, row) in enumerate(remaining_df.iterrows()):
        head_tuple = (int(row["layer"]), int(row["head"]))
        default_prog = all_programs[int(row["program_idx"])].__name__

        if total_remaining - idx <= TAIL_HEADS_TO_SEARCH:
            candidate_programs = head_program_candidates.get(head_tuple, [])
            if default_prog not in candidate_programs:
                candidate_programs = [default_prog] + candidate_programs
            choice = _choose_tail_candidate(
                accepted_heads_mapping,
                head_tuple,
                candidate_programs,
                evaluate_candidate,
                prev_cumulative,
            )
            prog_name = choice["prog_name"]
            mean_pct = choice["mean_pct"]
            mean_kl = choice["mean_kl"]
            marginal = choice["marginal"]
            accepted_rank = choice["rank"]
        else:
            prog_name = default_prog
            mean_pct, mean_kl = evaluate_candidate(accepted_heads_mapping, head_tuple, prog_name)
            marginal = mean_pct - prev_cumulative
            accepted_rank = 1

        current_k += 1
        accepted_heads_mapping.append((head_tuple, prog_name))

        new_row = {
            "k": current_k,
            "head": str(head_tuple),
            "program": prog_name,
            "strategy": "smart",
            "increase": round(mean_pct, 6),
            "kl_div": round(mean_kl, 6),
            "spike": bool(marginal > SPIKE_THRESHOLD),
        }
        rows.append(new_row)
        prev_cumulative = mean_pct
        print(f"  [APPEND] k={current_k:03d} | Head {head_tuple} | Rank-{accepted_rank} '{prog_name}' | cumul={mean_pct:.4f}%")

    del ref_model
    torch.cuda.empty_cache()
    return _finalize_and_save(rows, seed_df, save_path)


for shuffle_csv, expected_remaining in get_to_100percent_replacements:
    shuffle_csv = Path(shuffle_csv)
    model_key = _parse_model_key(shuffle_csv)

    print(f"\n[INFO] Processing {model_key}: {shuffle_csv.name}")

    if model_key not in head_counts:
        print(f"[WARN] Unknown model key '{model_key}' from {shuffle_csv.name}; skipping.")
        continue

    if not shuffle_csv.exists():
        print(f"[WARN] Missing shuffle csv: {shuffle_csv}")
        continue

    best_fits_csv = best_fits_folder / f"best_fits_{model_key}.csv"
    if not best_fits_csv.exists():
        print(f"[WARN] Missing best_fits csv: {best_fits_csv}")
        continue

    seed_df = pd.read_csv(shuffle_csv).sort_values("k").reset_index(drop=True)
    if seed_df.empty:
        print(f"[WARN] Empty shuffle csv: {shuffle_csv}; skipping.")
        continue

    replaced_heads = {
        _parse_head(r["head"])
        for _, r in seed_df.iterrows()
    }

    best_fits_df = pd.read_csv(best_fits_csv)
    best_fits_df = best_fits_df.sort_values(by="iou_score", ascending=False).reset_index(drop=True)
    remaining_df = best_fits_df[
        ~best_fits_df.apply(lambda r: (int(r["layer"]), int(r["head"])) in replaced_heads, axis=1)
    ].copy()

    print(f"[INFO] {model_key}: seed replacements={len(seed_df)}, remaining={len(remaining_df)}, expected_remaining={expected_remaining}")

    if len(remaining_df) == 0:
        print(f"[WARN] {model_key}: no remaining heads to evaluate.")
        continue

    if model_key == "bert":
        final_df = _continue_bert(seed_df, remaining_df, str(shuffle_csv))
    elif model_key == "gpt2":
        final_df = _continue_gpt2(seed_df, remaining_df, str(shuffle_csv))
    elif model_key == "tinyllama":
        final_df = _continue_tinyllama(seed_df, remaining_df, str(shuffle_csv))
    else:
        print(f"[WARN] No continuation handler for {model_key}; skipping.")
        continue

    final_k = int(final_df["k"].max()) if not final_df.empty else 0
    final_inc = float(final_df.iloc[-1]["increase"]) if not final_df.empty else float("nan")
    print(f"[DONE] {model_key}: wrote {len(final_df)} rows to {shuffle_csv.name} (final k={final_k}, final increase={final_inc:.4f}%).")

print("\n[DONE] Completion runs finished for all requested models.")
# Out:
# [INFO] Processing gpt2: gpt2_smart_shuffle_8.csv
# [INFO] gpt2: seed replacements=144, remaining=0, expected_remaining=3
# [WARN] gpt2: no remaining heads to evaluate.
#
# [INFO] Processing bert: bert_smart_shuffle_5.csv
# [INFO] bert: seed replacements=144, remaining=0, expected_remaining=35
# [WARN] bert: no remaining heads to evaluate.
#
# [INFO] Processing tinyllama: tinyllama_smart_shuffle_2.csv
# [INFO] tinyllama: seed replacements=505, remaining=199, expected_remaining=454
# [INFO] TinyLlama: loading reference model and calculating baseline perplexities...
#   [APPEND] k=506 | Head (6, 1) | Rank-1 'initial_token_reference_attention' | cumul=279.3573%
#   [APPEND] k=507 | Head (15, 11) | Rank-1 'initial_token_reference_attention' | cumul=282.1102%
#   [APPEND] k=508 | Head (14, 30) | Rank-1 'previous_attention' | cumul=283.9847%
#   [APPEND] k=509 | Head (13, 21) | Rank-1 'initial_token_reference_attention' | cumul=289.6705%
#   [APPEND] k=510 | Head (6, 14) | Rank-1 'initial_token_reference_attention' | cumul=288.4059%
#   [APPEND] k=511 | Head (14, 8) | Rank-1 'initial_token_reference_attention' | cumul=283.9412%
#   [APPEND] k=512 | Head (14, 19) | Rank-1 'initial_token_reference_attention' | cumul=282.7830%
#   [APPEND] k=513 | Head (16, 9) | Rank-1 'initial_token_reference_attention' | cumul=285.7713%
#   [APPEND] k=514 | Head (16, 14) | Rank-1 'initial_token_reference_attention' | cumul=289.8359%
#   [APPEND] k=515 | Head (15, 29) | Rank-1 'initial_token_reference_attention' | cumul=293.0209%
#   [APPEND] k=516 | Head (21, 7) | Rank-1 'initial_token_reference_attention' | cumul=289.9299%
#   [APPEND] k=517 | Head (13, 23) | Rank-1 'initial_token_reference_attention' | cumul=292.5787%
#   [APPEND] k=518 | Head (10, 4) | Rank-1 'initial_token_reference_attention' | cumul=299.5346%
#   [APPEND] k=519 | Head (10, 29) | Rank-1 'sentence_beginning_salience' | cumul=299.3615%
#   [APPEND] k=520 | Head (12, 17) | Rank-1 'initial_token_reference_attention' | cumul=294.4636%
#   [APPEND] k=521 | Head (12, 2) | Rank-1 'initial_token_reference_attention' | cumul=294.2567%
#   [APPEND] k=522 | Head (8, 2) | Rank-1 'initial_token_reference_attention' | cumul=293.9220%
#   [APPEND] k=523 | Head (13, 5) | Rank-1 'initial_token_reference_attention' | cumul=295.7740%
#   [APPEND] k=524 | Head (9, 4) | Rank-1 'initial_token_reference_attention' | cumul=302.3913%
#   [APPEND] k=525 | Head (1, 31) | Rank-1 'sentence_position_preference' | cumul=310.7836%
#   [APPEND] k=526 | Head (14, 18) | Rank-1 'initial_token_reference_attention' | cumul=315.3000%
#   [APPEND] k=527 | Head (6, 5) | Rank-1 'sentence_beginning_salience' | cumul=340.7173%
#   [APPEND] k=528 | Head (10, 20) | Rank-1 'sentence_beginning_salience' | cumul=346.4909%
#   [APPEND] k=529 | Head (11, 4) | Rank-1 'initial_token_reference_attention' | cumul=350.1130%
#   [APPEND] k=530 | Head (18, 29) | Rank-1 'initial_token_reference_attention' | cumul=354.5771%
#   [APPEND] k=531 | Head (16, 4) | Rank-1 'sentence_beginning_salience' | cumul=355.7432%
#   [APPEND] k=532 | Head (11, 30) | Rank-1 'initial_token_reference_attention' | cumul=356.9429%
#   [APPEND] k=533 | Head (16, 8) | Rank-1 'sentence_beginning_salience' | cumul=350.5784%
#   [APPEND] k=534 | Head (12, 15) | Rank-1 'initial_token_reference_attention' | cumul=355.1254%
#   [APPEND] k=535 | Head (7, 23) | Rank-1 'sentence_beginning_salience' | cumul=352.7103%
#   [APPEND] k=536 | Head (9, 11) | Rank-1 'initial_token_reference_attention' | cumul=354.5069%
#   [APPEND] k=537 | Head (9, 5) | Rank-1 'initial_token_reference_attention' | cumul=357.9874%
#   [APPEND] k=538 | Head (18, 11) | Rank-1 'initial_token_reference_attention' | cumul=364.5007%
#   [APPEND] k=539 | Head (20, 31) | Rank-1 'initial_token_reference_attention' | cumul=368.9489%
#   [APPEND] k=540 | Head (16, 5) | Rank-1 'initial_token_reference_attention' | cumul=372.2630%
#   [APPEND] k=541 | Head (13, 14) | Rank-1 'initial_token_reference_attention' | cumul=370.8234%
#   [APPEND] k=542 | Head (19, 28) | Rank-1 'initial_token_reference_attention' | cumul=374.4177%
#   [APPEND] k=543 | Head (11, 10) | Rank-1 'sentence_beginning_salience' | cumul=380.7198%
#   [APPEND] k=544 | Head (15, 5) | Rank-1 'initial_token_reference_attention' | cumul=381.6087%
#   [APPEND] k=545 | Head (7, 20) | Rank-1 'initial_token_reference_attention' | cumul=387.7070%
#   [APPEND] k=546 | Head (9, 20) | Rank-1 'initial_token_reference_attention' | cumul=383.8537%
#   [APPEND] k=547 | Head (11, 19) | Rank-1 'sentence_beginning_salience' | cumul=382.9095%
#   [APPEND] k=548 | Head (0, 19) | Rank-1 'sentence_position_preference' | cumul=388.9683%
#   [APPEND] k=549 | Head (8, 6) | Rank-1 'sentence_beginning_salience' | cumul=398.2985%
#   [APPEND] k=550 | Head (12, 19) | Rank-1 'initial_token_reference_attention' | cumul=400.0937%
#   [APPEND] k=551 | Head (17, 9) | Rank-1 'initial_token_reference_attention' | cumul=401.8869%
#   [APPEND] k=552 | Head (16, 6) | Rank-1 'initial_token_reference_attention' | cumul=411.8841%
#   [APPEND] k=553 | Head (18, 25) | Rank-1 'initial_token_reference_attention' | cumul=414.3227%
#   [APPEND] k=554 | Head (2, 4) | Rank-1 'sentence_position_preference' | cumul=414.7283%
#   [APPEND] k=555 | Head (13, 0) | Rank-1 'initial_token_reference_attention' | cumul=417.6033%
#   [APPEND] k=556 | Head (20, 3) | Rank-1 'first_token_dominance' | cumul=418.4386%
#   [APPEND] k=557 | Head (12, 12) | Rank-1 'initial_token_reference_attention' | cumul=429.5532%
#   [APPEND] k=558 | Head (20, 28) | Rank-1 'initial_token_reference_attention' | cumul=430.7230%
#   [APPEND] k=559 | Head (20, 11) | Rank-1 'initial_token_reference_attention' | cumul=429.7703%
#   [APPEND] k=560 | Head (1, 14) | Rank-1 'contextual_anchoring' | cumul=432.7980%
#   [APPEND] k=561 | Head (5, 3) | Rank-1 'initial_token_reference_attention' | cumul=442.2334%
#   [APPEND] k=562 | Head (13, 22) | Rank-1 'initial_token_reference_attention' | cumul=449.6664%
#   [APPEND] k=563 | Head (20, 4) | Rank-1 'initial_token_reference_attention' | cumul=452.1972%
#   [APPEND] k=564 | Head (16, 18) | Rank-1 'initial_token_reference_attention' | cumul=455.7683%
#   [APPEND] k=565 | Head (21, 11) | Rank-1 'initial_token_reference_attention' | cumul=451.3202%
#   [APPEND] k=566 | Head (21, 5) | Rank-1 'first_token_dominance' | cumul=448.8856%
#   [APPEND] k=567 | Head (10, 7) | Rank-1 'initial_token_reference_attention' | cumul=456.8742%
#   [APPEND] k=568 | Head (20, 27) | Rank-1 'initial_token_reference_attention' | cumul=463.1340%
#   [APPEND] k=569 | Head (16, 22) | Rank-1 'initial_token_reference_attention' | cumul=463.9273%
#   [APPEND] k=570 | Head (17, 18) | Rank-1 'initial_token_reference_attention' | cumul=467.7140%
#   [APPEND] k=571 | Head (21, 27) | Rank-1 'sentence_beginning_salience' | cumul=473.8905%
#   [APPEND] k=572 | Head (0, 21) | Rank-1 'contextual_anchoring' | cumul=477.7126%
#   [APPEND] k=573 | Head (10, 27) | Rank-1 'initial_token_reference_attention' | cumul=481.6772%
#   [APPEND] k=574 | Head (11, 16) | Rank-1 'initial_token_reference_attention' | cumul=480.8596%
#   [APPEND] k=575 | Head (1, 30) | Rank-1 'previous_attention' | cumul=479.3875%
#   [APPEND] k=576 | Head (0, 26) | Rank-1 'contextual_anchoring' | cumul=484.9729%
#   [APPEND] k=577 | Head (19, 21) | Rank-1 'initial_token_reference_attention' | cumul=487.0676%
#   [APPEND] k=578 | Head (13, 25) | Rank-1 'initial_token_reference_attention' | cumul=492.3197%
#   [APPEND] k=579 | Head (10, 25) | Rank-1 'initial_token_reference_attention' | cumul=487.5348%
#   [APPEND] k=580 | Head (21, 22) | Rank-1 'initial_token_reference_attention' | cumul=483.6360%
#   [APPEND] k=581 | Head (19, 10) | Rank-1 'sentence_beginning_salience' | cumul=485.4641%
#   [APPEND] k=582 | Head (16, 29) | Rank-1 'initial_token_reference_attention' | cumul=490.7859%
#   [APPEND] k=583 | Head (15, 7) | Rank-1 'initial_token_reference_attention' | cumul=501.2483%
#   [APPEND] k=584 | Head (13, 6) | Rank-1 'initial_token_reference_attention' | cumul=508.3267%
#   [APPEND] k=585 | Head (2, 0) | Rank-1 'contextual_anchoring' | cumul=513.7741%
#   [APPEND] k=586 | Head (13, 27) | Rank-1 'initial_token_reference_attention' | cumul=508.1743%
#   [APPEND] k=587 | Head (15, 6) | Rank-1 'initial_token_reference_attention' | cumul=512.8493%
#   [APPEND] k=588 | Head (8, 10) | Rank-1 'initial_token_reference_attention' | cumul=516.2390%
#   [APPEND] k=589 | Head (21, 16) | Rank-1 'initial_token_reference_attention' | cumul=522.0465%
#   [APPEND] k=590 | Head (19, 3) | Rank-1 'initial_token_reference_attention' | cumul=525.7745%
#   [APPEND] k=591 | Head (14, 28) | Rank-1 'initial_token_reference_attention' | cumul=523.3831%
#   [APPEND] k=592 | Head (13, 16) | Rank-1 'initial_token_reference_attention' | cumul=521.2729%
#   [APPEND] k=593 | Head (12, 24) | Rank-1 'initial_token_reference_attention' | cumul=533.5412%
#   [APPEND] k=594 | Head (15, 4) | Rank-1 'initial_token_reference_attention' | cumul=530.3435%
#   [APPEND] k=595 | Head (20, 6) | Rank-1 'initial_token_reference_attention' | cumul=529.1744%
#   [APPEND] k=596 | Head (2, 5) | Rank-1 'contextual_anchoring' | cumul=533.7325%
#   [APPEND] k=597 | Head (17, 13) | Rank-1 'initial_token_reference_attention' | cumul=536.4176%
#   [APPEND] k=598 | Head (21, 30) | Rank-1 'initial_token_reference_attention' | cumul=530.6226%
#   [APPEND] k=599 | Head (1, 8) | Rank-1 'contextual_anchoring' | cumul=540.8431%
#   [APPEND] k=600 | Head (0, 16) | Rank-1 'contextual_anchoring' | cumul=557.1393%
#   [TAIL-TRY] Head (2, 14) Rank-1 'sentence_position_preference' | marginal=8.93%
#   [APPEND] k=601 | Head (2, 14) | Rank-1 'sentence_position_preference' | cumul=566.0686%
#   [TAIL-TRY] Head (1, 5) Rank-1 'sentence_position_preference' | marginal=17.59%
#   [APPEND] k=602 | Head (1, 5) | Rank-1 'sentence_position_preference' | cumul=583.6607%
#   [TAIL-TRY] Head (9, 13) Rank-1 'initial_token_reference_attention' | marginal=-0.60%
#   [APPEND] k=603 | Head (9, 13) | Rank-1 'initial_token_reference_attention' | cumul=583.0631%
#   [TAIL-TRY] Head (21, 26) Rank-1 'initial_token_reference_attention' | marginal=4.08%
#   [APPEND] k=604 | Head (21, 26) | Rank-1 'initial_token_reference_attention' | cumul=587.1409%
#   [TAIL-TRY] Head (3, 28) Rank-1 'initial_token_reference_attention' | marginal=25.76%
#   [APPEND] k=605 | Head (3, 28) | Rank-1 'initial_token_reference_attention' | cumul=612.8979%
#   [TAIL-TRY] Head (12, 8) Rank-1 'initial_token_reference_attention' | marginal=-13.57%
#   [APPEND] k=606 | Head (12, 8) | Rank-1 'initial_token_reference_attention' | cumul=599.3276%
#   [TAIL-TRY] Head (0, 17) Rank-1 'contextual_anchoring' | marginal=4.00%
#   [APPEND] k=607 | Head (0, 17) | Rank-1 'contextual_anchoring' | cumul=603.3235%
#   [TAIL-TRY] Head (15, 0) Rank-1 'initial_token_reference_attention' | marginal=3.14%
#   [APPEND] k=608 | Head (15, 0) | Rank-1 'initial_token_reference_attention' | cumul=606.4657%
#   [TAIL-TRY] Head (11, 12) Rank-1 'sentence_beginning_salience' | marginal=-21.99%
#   [APPEND] k=609 | Head (11, 12) | Rank-1 'sentence_beginning_salience' | cumul=584.4764%
#   [TAIL-TRY] Head (1, 13) Rank-1 'contextual_anchoring' | marginal=6.45%
#   [APPEND] k=610 | Head (1, 13) | Rank-1 'contextual_anchoring' | cumul=590.9256%
#   [TAIL-TRY] Head (18, 26) Rank-1 'initial_token_reference_attention' | marginal=6.38%
#   [APPEND] k=611 | Head (18, 26) | Rank-1 'initial_token_reference_attention' | cumul=597.3045%
#   [TAIL-TRY] Head (11, 9) Rank-1 'sentence_beginning_salience' | marginal=9.96%
#   [APPEND] k=612 | Head (11, 9) | Rank-1 'sentence_beginning_salience' | cumul=607.2615%
#   [TAIL-TRY] Head (17, 8) Rank-1 'initial_token_reference_attention' | marginal=12.39%
#   [APPEND] k=613 | Head (17, 8) | Rank-1 'initial_token_reference_attention' | cumul=619.6509%
#   [TAIL-TRY] Head (17, 16) Rank-1 'initial_token_reference_attention' | marginal=-2.73%
#   [APPEND] k=614 | Head (17, 16) | Rank-1 'initial_token_reference_attention' | cumul=616.9214%
#   [TAIL-TRY] Head (10, 28) Rank-1 'initial_token_reference_attention' | marginal=-3.88%
#   [APPEND] k=615 | Head (10, 28) | Rank-1 'initial_token_reference_attention' | cumul=613.0389%
#   [TAIL-TRY] Head (17, 11) Rank-1 'initial_token_reference_attention' | marginal=12.38%
#   [APPEND] k=616 | Head (17, 11) | Rank-1 'initial_token_reference_attention' | cumul=625.4197%
#   [TAIL-TRY] Head (14, 21) Rank-1 'initial_token_reference_attention' | marginal=2.55%
#   [APPEND] k=617 | Head (14, 21) | Rank-1 'initial_token_reference_attention' | cumul=627.9678%
#   [TAIL-TRY] Head (7, 29) Rank-1 'initial_token_reference_attention' | marginal=19.00%
#   [APPEND] k=618 | Head (7, 29) | Rank-1 'initial_token_reference_attention' | cumul=646.9646%
#   [TAIL-TRY] Head (9, 29) Rank-1 'initial_token_reference_attention' | marginal=-4.31%
#   [APPEND] k=619 | Head (9, 29) | Rank-1 'initial_token_reference_attention' | cumul=642.6506%
#   [TAIL-TRY] Head (2, 6) Rank-1 'contextual_anchoring' | marginal=14.65%
#   [APPEND] k=620 | Head (2, 6) | Rank-1 'contextual_anchoring' | cumul=657.2960%
#   [TAIL-TRY] Head (12, 13) Rank-1 'initial_token_reference_attention' | marginal=32.19%
#   [APPEND] k=621 | Head (12, 13) | Rank-1 'initial_token_reference_attention' | cumul=689.4824%
#   [TAIL-TRY] Head (0, 30) Rank-1 'contextual_anchoring' | marginal=2.05%
#   [APPEND] k=622 | Head (0, 30) | Rank-1 'contextual_anchoring' | cumul=691.5275%
#   [TAIL-TRY] Head (9, 24) Rank-1 'initial_token_reference_attention' | marginal=3.06%
#   [APPEND] k=623 | Head (9, 24) | Rank-1 'initial_token_reference_attention' | cumul=694.5844%
#   [TAIL-TRY] Head (13, 4) Rank-1 'initial_token_reference_attention' | marginal=0.44%
#   [APPEND] k=624 | Head (13, 4) | Rank-1 'initial_token_reference_attention' | cumul=695.0266%
#   [TAIL-TRY] Head (14, 5) Rank-1 'initial_token_reference_attention' | marginal=-3.70%
#   [APPEND] k=625 | Head (14, 5) | Rank-1 'initial_token_reference_attention' | cumul=691.3232%
#   [TAIL-TRY] Head (2, 7) Rank-1 'contextual_anchoring' | marginal=10.44%
#   [APPEND] k=626 | Head (2, 7) | Rank-1 'contextual_anchoring' | cumul=701.7678%
#   [TAIL-TRY] Head (13, 8) Rank-1 'initial_token_reference_attention' | marginal=2.06%
#   [APPEND] k=627 | Head (13, 8) | Rank-1 'initial_token_reference_attention' | cumul=703.8238%
#   [TAIL-TRY] Head (2, 11) Rank-1 'sentence_position_preference' | marginal=21.35%
#   [APPEND] k=628 | Head (2, 11) | Rank-1 'sentence_position_preference' | cumul=725.1690%
#   [TAIL-TRY] Head (16, 16) Rank-1 'initial_token_reference_attention' | marginal=5.71%
#   [APPEND] k=629 | Head (16, 16) | Rank-1 'initial_token_reference_attention' | cumul=730.8776%
#   [TAIL-TRY] Head (13, 18) Rank-1 'initial_token_reference_attention' | marginal=4.32%
#   [APPEND] k=630 | Head (13, 18) | Rank-1 'initial_token_reference_attention' | cumul=735.1928%
#   [TAIL-TRY] Head (7, 19) Rank-1 'initial_token_reference_attention' | marginal=26.76%
#   [APPEND] k=631 | Head (7, 19) | Rank-1 'initial_token_reference_attention' | cumul=761.9534%
#   [TAIL-TRY] Head (2, 8) Rank-1 'sentence_position_preference' | marginal=-7.18%
#   [APPEND] k=632 | Head (2, 8) | Rank-1 'sentence_position_preference' | cumul=754.7711%
#   [TAIL-TRY] Head (10, 31) Rank-1 'initial_token_reference_attention' | marginal=-3.48%
#   [APPEND] k=633 | Head (10, 31) | Rank-1 'initial_token_reference_attention' | cumul=751.2901%
#   [TAIL-TRY] Head (1, 15) Rank-1 'contextual_anchoring' | marginal=21.90%
#   [APPEND] k=634 | Head (1, 15) | Rank-1 'contextual_anchoring' | cumul=773.1875%
#   [TAIL-TRY] Head (16, 7) Rank-1 'initial_token_reference_attention' | marginal=0.16%
#   [APPEND] k=635 | Head (16, 7) | Rank-1 'initial_token_reference_attention' | cumul=773.3483%
#   [TAIL-TRY] Head (13, 1) Rank-1 'initial_token_reference_attention' | marginal=4.40%
#   [APPEND] k=636 | Head (13, 1) | Rank-1 'initial_token_reference_attention' | cumul=777.7484%
#   [TAIL-TRY] Head (13, 20) Rank-1 'first_token_dominance' | marginal=0.08%
#   [APPEND] k=637 | Head (13, 20) | Rank-1 'first_token_dominance' | cumul=777.8310%
#   [TAIL-TRY] Head (14, 20) Rank-1 'initial_token_reference_attention' | marginal=6.51%
#   [APPEND] k=638 | Head (14, 20) | Rank-1 'initial_token_reference_attention' | cumul=784.3399%
#   [TAIL-TRY] Head (16, 12) Rank-1 'initial_token_reference_attention' | marginal=39.01%
#   [APPEND] k=639 | Head (16, 12) | Rank-1 'initial_token_reference_attention' | cumul=823.3495%
#   [TAIL-TRY] Head (1, 12) Rank-1 'contextual_anchoring' | marginal=-1.10%
#   [APPEND] k=640 | Head (1, 12) | Rank-1 'contextual_anchoring' | cumul=822.2480%
#   [TAIL-TRY] Head (10, 2) Rank-1 'initial_token_reference_attention' | marginal=1.84%
#   [APPEND] k=641 | Head (10, 2) | Rank-1 'initial_token_reference_attention' | cumul=824.0898%
#   [TAIL-TRY] Head (7, 6) Rank-1 'initial_token_reference_attention' | marginal=19.28%
#   [APPEND] k=642 | Head (7, 6) | Rank-1 'initial_token_reference_attention' | cumul=843.3700%
#   [TAIL-TRY] Head (12, 29) Rank-1 'initial_token_reference_attention' | marginal=0.98%
#   [APPEND] k=643 | Head (12, 29) | Rank-1 'initial_token_reference_attention' | cumul=844.3515%
#   [TAIL-TRY] Head (2, 2) Rank-1 'contextual_anchoring' | marginal=20.76%
#   [APPEND] k=644 | Head (2, 2) | Rank-1 'contextual_anchoring' | cumul=865.1129%
#   [TAIL-TRY] Head (2, 15) Rank-1 'sentence_position_preference' | marginal=12.62%
#   [APPEND] k=645 | Head (2, 15) | Rank-1 'sentence_position_preference' | cumul=877.7316%
#   [TAIL-TRY] Head (2, 10) Rank-1 'sentence_position_preference' | marginal=13.29%
#   [APPEND] k=646 | Head (2, 10) | Rank-1 'sentence_position_preference' | cumul=891.0189%
#   [TAIL-TRY] Head (2, 9) Rank-1 'sentence_position_preference' | marginal=32.92%
#   [APPEND] k=647 | Head (2, 9) | Rank-1 'sentence_position_preference' | cumul=923.9394%
#   [TAIL-TRY] Head (16, 2) Rank-1 'initial_token_reference_attention' | marginal=20.25%
#   [APPEND] k=648 | Head (16, 2) | Rank-1 'initial_token_reference_attention' | cumul=944.1866%
#   [TAIL-TRY] Head (1, 10) Rank-1 'contextual_anchoring' | marginal=22.61%
#   [APPEND] k=649 | Head (1, 10) | Rank-1 'contextual_anchoring' | cumul=966.7982%
#   [TAIL-TRY] Head (12, 1) Rank-1 'initial_token_reference_attention' | marginal=2.81%
#   [APPEND] k=650 | Head (12, 1) | Rank-1 'initial_token_reference_attention' | cumul=969.6037%
#   [TAIL-TRY] Head (1, 4) Rank-1 'sentence_position_preference' | marginal=753.22%
#   [TAIL-TRY] Head (1, 4) Rank-2 'contextual_anchoring' | marginal=53.84%
#   [APPEND] k=651 | Head (1, 4) | Rank-2 'contextual_anchoring' | cumul=1023.4426%
#   [TAIL-TRY] Head (2, 12) Rank-1 'contextual_anchoring' | marginal=30.15%
#   [APPEND] k=652 | Head (2, 12) | Rank-1 'contextual_anchoring' | cumul=1053.5931%
#   [TAIL-TRY] Head (14, 2) Rank-1 'initial_token_reference_attention' | marginal=10.45%
#   [APPEND] k=653 | Head (14, 2) | Rank-1 'initial_token_reference_attention' | cumul=1064.0440%
#   [TAIL-TRY] Head (15, 9) Rank-1 'initial_token_reference_attention' | marginal=-8.53%
#   [APPEND] k=654 | Head (15, 9) | Rank-1 'initial_token_reference_attention' | cumul=1055.5121%
#   [TAIL-TRY] Head (1, 0) Rank-1 'sentence_position_preference' | marginal=3331.60%
#   [TAIL-TRY] Head (1, 0) Rank-2 'contextual_anchoring' | marginal=25.30%
#   [APPEND] k=655 | Head (1, 0) | Rank-2 'contextual_anchoring' | cumul=1080.8088%
#   [TAIL-TRY] Head (13, 11) Rank-1 'initial_token_reference_attention' | marginal=-6.49%
#   [APPEND] k=656 | Head (13, 11) | Rank-1 'initial_token_reference_attention' | cumul=1074.3223%
#   [TAIL-TRY] Head (2, 13) Rank-1 'contextual_anchoring' | marginal=11.56%
#   [APPEND] k=657 | Head (2, 13) | Rank-1 'contextual_anchoring' | cumul=1085.8828%
#   [TAIL-TRY] Head (1, 25) Rank-1 'sentence_position_preference' | marginal=295.34%
#   [TAIL-TRY] Head (1, 25) Rank-2 'contextual_anchoring' | marginal=32.53%
#   [APPEND] k=658 | Head (1, 25) | Rank-2 'contextual_anchoring' | cumul=1118.4129%
#   [TAIL-TRY] Head (1, 24) Rank-1 'contextual_anchoring' | marginal=23.92%
#   [APPEND] k=659 | Head (1, 24) | Rank-1 'contextual_anchoring' | cumul=1142.3317%
#   [TAIL-TRY] Head (14, 25) Rank-1 'sentence_position_preference' | marginal=3.70%
#   [APPEND] k=660 | Head (14, 25) | Rank-1 'sentence_position_preference' | cumul=1146.0341%
#   [TAIL-TRY] Head (1, 7) Rank-1 'sentence_position_preference' | marginal=3945.16%
#   [TAIL-TRY] Head (1, 7) Rank-2 'contextual_anchoring' | marginal=33.75%
#   [APPEND] k=661 | Head (1, 7) | Rank-2 'contextual_anchoring' | cumul=1179.7870%
#   [TAIL-TRY] Head (12, 4) Rank-1 'initial_token_reference_attention' | marginal=6.04%
#   [APPEND] k=662 | Head (12, 4) | Rank-1 'initial_token_reference_attention' | cumul=1185.8233%
#   [TAIL-TRY] Head (15, 27) Rank-1 'initial_token_reference_attention' | marginal=-9.32%
#   [APPEND] k=663 | Head (15, 27) | Rank-1 'initial_token_reference_attention' | cumul=1176.5010%
#   [TAIL-TRY] Head (1, 3) Rank-1 'contextual_anchoring' | marginal=43.57%
#   [APPEND] k=664 | Head (1, 3) | Rank-1 'contextual_anchoring' | cumul=1220.0718%
#   [TAIL-TRY] Head (1, 27) Rank-1 'sentence_position_preference' | marginal=163.10%
#   [TAIL-TRY] Head (1, 27) Rank-2 'contextual_anchoring' | marginal=18.45%
#   [APPEND] k=665 | Head (1, 27) | Rank-2 'contextual_anchoring' | cumul=1238.5231%
#   [TAIL-TRY] Head (1, 1) Rank-1 'sentence_position_preference' | marginal=54.31%
#   [APPEND] k=666 | Head (1, 1) | Rank-1 'sentence_position_preference' | cumul=1292.8300%
#   [TAIL-TRY] Head (13, 17) Rank-1 'initial_token_reference_attention' | marginal=-7.23%
#   [APPEND] k=667 | Head (13, 17) | Rank-1 'initial_token_reference_attention' | cumul=1285.6049%
#   [TAIL-TRY] Head (2, 3) Rank-1 'contextual_anchoring' | marginal=26.48%
#   [APPEND] k=668 | Head (2, 3) | Rank-1 'contextual_anchoring' | cumul=1312.0895%
#   [TAIL-TRY] Head (1, 6) Rank-1 'sentence_position_preference' | marginal=82.07%
#   [APPEND] k=669 | Head (1, 6) | Rank-1 'sentence_position_preference' | cumul=1394.1632%
#   [TAIL-TRY] Head (18, 16) Rank-1 'initial_token_reference_attention' | marginal=-3.02%
#   [APPEND] k=670 | Head (18, 16) | Rank-1 'initial_token_reference_attention' | cumul=1391.1452%
#   [TAIL-TRY] Head (1, 2) Rank-1 'contextual_anchoring' | marginal=1.98%
#   [APPEND] k=671 | Head (1, 2) | Rank-1 'contextual_anchoring' | cumul=1393.1216%
#   [TAIL-TRY] Head (1, 29) Rank-1 'contextual_anchoring' | marginal=6.86%
#   [APPEND] k=672 | Head (1, 29) | Rank-1 'contextual_anchoring' | cumul=1399.9787%
#   [TAIL-TRY] Head (2, 16) Rank-1 'contextual_anchoring' | marginal=35.16%
#   [APPEND] k=673 | Head (2, 16) | Rank-1 'contextual_anchoring' | cumul=1435.1425%
#   [TAIL-TRY] Head (0, 22) Rank-1 'contextual_anchoring' | marginal=100.17%
#   [TAIL-TRY] Head (0, 22) Rank-2 'sentence_position_preference' | marginal=5715.24%
#   [TAIL-TRY] Head (0, 22) Rank-3 'pos_alignment' | marginal=22.05%
#   [APPEND] k=674 | Head (0, 22) | Rank-3 'pos_alignment' | cumul=1457.1904%
#   [TAIL-TRY] Head (2, 23) Rank-1 'contextual_anchoring' | marginal=-11.91%
#   [APPEND] k=675 | Head (2, 23) | Rank-1 'contextual_anchoring' | cumul=1445.2827%
#   [TAIL-TRY] Head (21, 28) Rank-1 'initial_token_reference_attention' | marginal=-4.10%
#   [APPEND] k=676 | Head (21, 28) | Rank-1 'initial_token_reference_attention' | cumul=1441.1815%
#   [TAIL-TRY] Head (1, 26) Rank-1 'contextual_anchoring' | marginal=49.43%
#   [APPEND] k=677 | Head (1, 26) | Rank-1 'contextual_anchoring' | cumul=1490.6120%
#   [TAIL-TRY] Head (2, 17) Rank-1 'contextual_anchoring' | marginal=28.30%
#   [APPEND] k=678 | Head (2, 17) | Rank-1 'contextual_anchoring' | cumul=1518.9091%
#   [TAIL-TRY] Head (2, 20) Rank-1 'sentence_position_preference' | marginal=25.98%
#   [APPEND] k=679 | Head (2, 20) | Rank-1 'sentence_position_preference' | cumul=1544.8853%
#   [TAIL-TRY] Head (2, 27) Rank-1 'contextual_anchoring' | marginal=39.39%
#   [APPEND] k=680 | Head (2, 27) | Rank-1 'contextual_anchoring' | cumul=1584.2771%
#   [TAIL-TRY] Head (0, 20) Rank-1 'contextual_anchoring' | marginal=-2.44%
#   [APPEND] k=681 | Head (0, 20) | Rank-1 'contextual_anchoring' | cumul=1581.8325%
#   [TAIL-TRY] Head (2, 19) Rank-1 'sentence_position_preference' | marginal=39.80%
#   [APPEND] k=682 | Head (2, 19) | Rank-1 'sentence_position_preference' | cumul=1621.6278%
#   [TAIL-TRY] Head (1, 28) Rank-1 'contextual_anchoring' | marginal=46.54%
#   [APPEND] k=683 | Head (1, 28) | Rank-1 'contextual_anchoring' | cumul=1668.1651%
#   [TAIL-TRY] Head (0, 23) Rank-1 'contextual_anchoring' | marginal=-7.82%
#   [APPEND] k=684 | Head (0, 23) | Rank-1 'contextual_anchoring' | cumul=1660.3442%
#   [TAIL-TRY] Head (2, 25) Rank-1 'sentence_position_preference' | marginal=55.83%
#   [APPEND] k=685 | Head (2, 25) | Rank-1 'sentence_position_preference' | cumul=1716.1747%
#   [TAIL-TRY] Head (2, 1) Rank-1 'contextual_anchoring' | marginal=-2.24%
#   [APPEND] k=686 | Head (2, 1) | Rank-1 'contextual_anchoring' | cumul=1713.9381%
#   [TAIL-TRY] Head (2, 24) Rank-1 'sentence_position_preference' | marginal=80.79%
#   [APPEND] k=687 | Head (2, 24) | Rank-1 'sentence_position_preference' | cumul=1794.7239%
#   [TAIL-TRY] Head (2, 31) Rank-1 'contextual_anchoring' | marginal=51.46%
#   [APPEND] k=688 | Head (2, 31) | Rank-1 'contextual_anchoring' | cumul=1846.1805%
#   [TAIL-TRY] Head (1, 9) Rank-1 'contextual_anchoring' | marginal=82.11%
#   [APPEND] k=689 | Head (1, 9) | Rank-1 'contextual_anchoring' | cumul=1928.2938%
#   [TAIL-TRY] Head (2, 29) Rank-1 'contextual_anchoring' | marginal=-7.13%
#   [APPEND] k=690 | Head (2, 29) | Rank-1 'contextual_anchoring' | cumul=1921.1609%
#   [TAIL-TRY] Head (2, 28) Rank-1 'contextual_anchoring' | marginal=50.62%
#   [APPEND] k=691 | Head (2, 28) | Rank-1 'contextual_anchoring' | cumul=1971.7764%
#   [TAIL-TRY] Head (2, 26) Rank-1 'contextual_anchoring' | marginal=49.79%
#   [APPEND] k=692 | Head (2, 26) | Rank-1 'contextual_anchoring' | cumul=2021.5654%
#   [TAIL-TRY] Head (2, 22) Rank-1 'contextual_anchoring' | marginal=76.27%
#   [APPEND] k=693 | Head (2, 22) | Rank-1 'contextual_anchoring' | cumul=2097.8313%
#   [TAIL-TRY] Head (2, 18) Rank-1 'contextual_anchoring' | marginal=29.52%
#   [APPEND] k=694 | Head (2, 18) | Rank-1 'contextual_anchoring' | cumul=2127.3506%
#   [TAIL-TRY] Head (2, 21) Rank-1 'sentence_position_preference' | marginal=52.69%
#   [APPEND] k=695 | Head (2, 21) | Rank-1 'sentence_position_preference' | cumul=2180.0450%
#   [TAIL-TRY] Head (2, 30) Rank-1 'contextual_anchoring' | marginal=19.48%
#   [APPEND] k=696 | Head (2, 30) | Rank-1 'contextual_anchoring' | cumul=2199.5248%
#   [TAIL-TRY] Head (1, 19) Rank-1 'previous_attention' | marginal=44.36%
#   [APPEND] k=697 | Head (1, 19) | Rank-1 'previous_attention' | cumul=2243.8894%
#   [TAIL-TRY] Head (1, 20) Rank-1 'contextual_anchoring' | marginal=48.09%
#   [APPEND] k=698 | Head (1, 20) | Rank-1 'contextual_anchoring' | cumul=2291.9819%
#   [TAIL-TRY] Head (1, 22) Rank-1 'contextual_anchoring' | marginal=271.89%
#   [TAIL-TRY] Head (1, 22) Rank-2 'sentence_position_preference' | marginal=3651.17%
#   [TAIL-TRY] Head (1, 22) Rank-3 'previous_attention' | marginal=93.47%
#   [APPEND] k=699 | Head (1, 22) | Rank-3 'previous_attention' | cumul=2385.4485%
#   [TAIL-TRY] Head (1, 16) Rank-1 'contextual_anchoring' | marginal=-83.38%
#   [APPEND] k=700 | Head (1, 16) | Rank-1 'contextual_anchoring' | cumul=2302.0732%
#   [TAIL-TRY] Head (1, 23) Rank-1 'contextual_anchoring' | marginal=-5.16%
#   [APPEND] k=701 | Head (1, 23) | Rank-1 'contextual_anchoring' | cumul=2296.9134%
#   [TAIL-TRY] Head (1, 21) Rank-1 'contextual_anchoring' | marginal=44.16%
#   [APPEND] k=702 | Head (1, 21) | Rank-1 'contextual_anchoring' | cumul=2341.0736%
#   [TAIL-TRY] Head (1, 17) Rank-1 'contextual_anchoring' | marginal=-10.28%
#   [APPEND] k=703 | Head (1, 17) | Rank-1 'contextual_anchoring' | cumul=2330.7890%
#   [TAIL-TRY] Head (1, 18) Rank-1 'contextual_anchoring' | marginal=36.84%
#   [APPEND] k=704 | Head (1, 18) | Rank-1 'contextual_anchoring' | cumul=2367.6300%
# [DONE] tinyllama: wrote 704 rows to tinyllama_smart_shuffle_2.csv (final k=704, final increase=2367.6300%).
#
# [DONE] Completion runs finished for all requested models.

# %%
# ============================================================================
# FINAL CELL: Evaluate Models on 6 Benchmarks + Plot
# ============================================================================

import os
import json
import random
import torch
import torch.nn.functional as F
from transformers import (
    GPT2Tokenizer, GPT2LMHeadModel,
    AutoTokenizer, AutoModelForCausalLM
)
from datasets import load_dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ── Device Setup ──
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# ── Load Programs ──
try:
    if 'all_programs' not in globals():
        import inspect
        import golden_programs
        all_programs = [obj for name, obj in inspect.getmembers(golden_programs)
                        if inspect.isfunction(obj)]
    print(f"Loaded {len(all_programs)} program functions")
except:
    print("WARNING: Could not load programs. Make sure all_programs or golden_programs is available.")
    all_programs = []

# ── Configuration ──
N_SAMPLES = 200
REPLACEMENT_LEVELS = [0.05, 0.10, 0.15, 0.20, 0.25, 0.30, 0.40, 0.50, 0.75, 1.00]
HEAD_COUNTS = {
    "gpt2":      144,   # 12 layers × 12 heads
    "tinyllama": 704    # 22 layers × 32 heads
}
hardcoded_files = {
    "gpt2":      "../results/replacement_run/shuffles/gpt2_smart_shuffle_8.csv",
    "tinyllama": "../results/replacement_run/shuffles/tinyllama_smart_shuffle_2.csv"
}
OPENBOOKQA_SEED = 42  # fixed seed for binary distractor sampling

# ── Model Loading ──

def load_model_and_tokenizer(model_name):
    if model_name == "gpt2":
        tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
        tokenizer.pad_token = tokenizer.eos_token
        model = GPT2LMHeadModel.from_pretrained("gpt2").to(device)
    elif model_name == "tinyllama":
        tokenizer = AutoTokenizer.from_pretrained(
            "TinyLlama/TinyLlama-1.1B-intermediate-step-1431k-3T"
        )
        tokenizer.pad_token = tokenizer.eos_token
        model = AutoModelForCausalLM.from_pretrained(
            "TinyLlama/TinyLlama-1.1B-intermediate-step-1431k-3T"
        ).to(device)
    else:
        raise ValueError(f"Unknown model: {model_name}")
    model.eval()
    return model, tokenizer


# ── Hook Builders ──

def build_replaced_model_gpt2(csv_file, replacement_pct):
    df = pd.read_csv(csv_file)
    target_heads = int(HEAD_COUNTS["gpt2"] * replacement_pct)
    print(f"Applying GPT-2 head replacement for {int(replacement_pct * 100)}% -> {target_heads} heads")

    if "k" not in df.columns:
        raise ValueError("Shuffle CSV is missing the 'k' column.")

    df["k"] = df["k"].astype(int)
    df = df.sort_values(by="k").head(target_heads).reset_index(drop=True)

    head_mapping = {}
    for _, row in df.iterrows():
        head_tuple = tuple(map(int, str(row["head"]).strip("()").split(",")))
        head_mapping[head_tuple] = row["program"]

    relevant_layers = set(layer for layer, _ in head_mapping.keys())
    model, tokenizer = load_model_and_tokenizer("gpt2")

    def make_smart_hook(lookup, programs_list):
        def compound_hook(module, input, output):
            context_layer = output[0]
            batch, seq_len, hidden_dim = context_layer.shape
            num_heads, head_dim = 12, hidden_dim // 12
            modified_layer = context_layer.view(batch, seq_len, num_heads, head_dim).clone()
            current_sent = getattr(module, '_current_sentence', None)
            if current_sent is None:
                return output
            for head_idx in range(num_heads):
                key = (module.layer_id, head_idx)
                if key in lookup:
                    prog_name = lookup[key]
                    prog = next((p for p in programs_list if p.__name__ == prog_name), None)
                    if prog:
                        try:
                            _, hypo_mat = prog(current_sent, tokenizer)
                            if hypo_mat is not None:
                                hypo_tensor = torch.tensor(hypo_mat).to(device, dtype=modified_layer.dtype)
                                modified_layer[:, :, head_idx, :] = torch.matmul(
                                    hypo_tensor, modified_layer[:, :, head_idx, :]
                                )
                        except Exception:
                            pass
            return (modified_layer.view(batch, seq_len, hidden_dim),) + output[1:]
        return compound_hook

    hook_fn = make_smart_hook(head_mapping, all_programs)
    handles = []
    for l_idx in range(12):
        target = model.transformer.h[l_idx].attn
        target.layer_id = l_idx
        if l_idx in relevant_layers:
            handles.append(target.register_forward_hook(hook_fn))

    return model, tokenizer, relevant_layers, handles, head_mapping


def build_replaced_model_tinyllama(csv_file, replacement_pct):
    df = pd.read_csv(csv_file)
    target_heads = int(HEAD_COUNTS["tinyllama"] * replacement_pct)
    print(f"Applying TinyLlama head replacement for {int(replacement_pct * 100)}% -> {target_heads} heads")

    if "k" not in df.columns:
        raise ValueError("Shuffle CSV is missing the 'k' column.")

    df["k"] = df["k"].astype(int)
    df = df.sort_values(by="k").head(target_heads).reset_index(drop=True)

    head_mapping = {}
    for _, row in df.iterrows():
        head_tuple = tuple(map(int, str(row["head"]).strip("()").split(",")))
        head_mapping[head_tuple] = row["program"]

    relevant_layers = set(layer for layer, _ in head_mapping.keys())
    model, tokenizer = load_model_and_tokenizer("tinyllama")

    NUM_HEADS   = 32
    NUM_LAYERS  = 22
    HIDDEN_SIZE = 2048
    HEAD_DIM    = HIDDEN_SIZE // NUM_HEADS

    def make_smart_hook(lookup, programs_list):
        def compound_hook(module, input, output):
            context_layer = output[0].contiguous()  # CRITICAL for TinyLlama
            batch, seq_len, hidden_dim = context_layer.shape
            modified_layer = context_layer.view(batch, seq_len, NUM_HEADS, HEAD_DIM).clone()
            current_sent = getattr(module, '_current_sentence', None)
            if current_sent is None:
                return output
            for head_idx in range(NUM_HEADS):
                key = (module.layer_id, head_idx)
                if key in lookup:
                    prog_name = lookup[key]
                    prog = next((p for p in programs_list if p.__name__ == prog_name), None)
                    if prog:
                        try:
                            _, hypo_mat = prog(current_sent, tokenizer)
                            if hypo_mat is not None:
                                hypo_tensor = torch.tensor(hypo_mat).to(device, dtype=modified_layer.dtype)
                                modified_layer[:, :, head_idx, :] = torch.matmul(
                                    hypo_tensor, modified_layer[:, :, head_idx, :]
                                )
                        except Exception:
                            pass
            return (modified_layer.view(batch, seq_len, hidden_dim),) + output[1:]
        return compound_hook

    hook_fn = make_smart_hook(head_mapping, all_programs)
    handles = []
    for l_idx in range(NUM_LAYERS):
        target = model.model.layers[l_idx].self_attn
        target.layer_id = l_idx
        if l_idx in relevant_layers:
            handles.append(target.register_forward_hook(hook_fn))

    return model, tokenizer, relevant_layers, handles, head_mapping


def set_sentence(model, model_name, relevant_layers, sentence):
    if model_name == "gpt2":
        for l_idx in relevant_layers:
            model.transformer.h[l_idx].attn._current_sentence = sentence
    elif model_name == "tinyllama":
        for l_idx in relevant_layers:
            model.model.layers[l_idx].self_attn._current_sentence = sentence


# ── Scoring ──

def score_completion(model, tokenizer, model_name, context, completion, relevant_layers=None):
    """Mean log-probability over completion tokens given context."""
    if relevant_layers:
        set_sentence(model, model_name, relevant_layers, context + " " + completion)

    full_text = context + " " + completion
    enc     = tokenizer(full_text, return_tensors="pt").to(device)
    ctx_enc = tokenizer(context,   return_tensors="pt").to(device)
    ctx_len = ctx_enc["input_ids"].shape[1]

    with torch.no_grad():
        outputs = model(**enc, labels=enc["input_ids"])
        logits  = outputs.logits

    log_probs = F.log_softmax(logits[0], dim=-1)
    input_ids = enc["input_ids"][0]
    scores = [log_probs[i - 1, input_ids[i]].item()
              for i in range(ctx_len, len(input_ids))]

    return np.mean(scores) if scores else -np.inf


# ── Benchmark Evaluation Functions ──

def evaluate_sciq(model, tokenizer, model_name, relevant_layers=None, n=200):
    """4-way MC: distractor1/2/3 + correct_answer (always placed at idx 3)."""
    dataset = load_dataset("sciq", split="validation")
    correct = 0
    for ex in dataset.select(range(min(n, len(dataset)))):
        choices = [ex["distractor1"], ex["distractor2"], ex["distractor3"], ex["correct_answer"]]
        scores  = [score_completion(model, tokenizer, model_name, ex["question"], c, relevant_layers)
                   for c in choices]
        if int(np.argmax(scores)) == 3:
            correct += 1
    return correct / min(n, len(dataset))


def evaluate_hellaswag(model, tokenizer, model_name, relevant_layers=None, n=200):
    """4-way MC: ctx + one of four sentence endings."""
    dataset = load_dataset("Rowan/hellaswag", split="validation")
    correct = 0
    for ex in dataset.select(range(min(n, len(dataset)))):
        scores = [score_completion(model, tokenizer, model_name, ex["ctx"], e, relevant_layers)
                  for e in ex["endings"]]
        if int(np.argmax(scores)) == int(ex["label"]):
            correct += 1
    return correct / min(n, len(dataset))


def evaluate_piqa(model, tokenizer, model_name, relevant_layers=None, n=200):
    """2-way MC from local JSONL: goal + sol1/sol2, label 0 or 1."""
    dataset = []
    with open("../data/evaluations/piqa_val.jsonl", "r") as f:
        for line in f:
            dataset.append(json.loads(line))
            if len(dataset) >= n:
                break
    correct = 0
    for ex in dataset:
        choices = [ex["sol1"], ex["sol2"]]
        label   = int(ex["label"])
        scores  = [score_completion(model, tokenizer, model_name, ex["goal"], c, relevant_layers)
                   for c in choices]
        if int(np.argmax(scores)) == label:
            correct += 1
    return correct / len(dataset)


def evaluate_arc_easy(model, tokenizer, model_name, relevant_layers=None, n=200):
    """
    4-way MC elementary science questions.
    Dataset : allenai/ai2_arc  (config: ARC-Easy, split: validation)
    Fields  : question, choices['text'], choices['label'], answerKey (letter)
    Label   : index of answerKey in choices['label'] — handles both letter and
              numeric label styles; skips malformed examples.
    """
    dataset = load_dataset("allenai/ai2_arc", "ARC-Easy", split="validation")
    correct, count = 0, 0
    for ex in dataset.select(range(min(n, len(dataset)))):
        choice_texts  = ex["choices"]["text"]
        choice_labels = ex["choices"]["label"]
        answer_key    = ex["answerKey"]
        if answer_key not in choice_labels:
            continue
        label  = choice_labels.index(answer_key)
        scores = [score_completion(model, tokenizer, model_name, ex["question"], c, relevant_layers)
                  for c in choice_texts]
        if int(np.argmax(scores)) == label:
            correct += 1
        count += 1
    return correct / count if count > 0 else 0.0


def evaluate_social_iqa(model, tokenizer, model_name, relevant_layers=None, n=200):
    """
    3-way MC social reasoning using local JSONL file.
    Local Fields: context, question, answerA, answerB, answerC, correct (A/B/C)
    """
    import json
    dataset = []
    # Path to the file you have highlighted in your screenshot
    local_path = "../data/evaluations/socialIQa_v1.4/socialIQa_v1.4_dev.jsonl" 
    try:
        with open(local_path, "r", encoding="utf-8") as f:
            for line in f:
                dataset.append(json.loads(line))
                if len(dataset) >= n:
                    break
    except FileNotFoundError:
        print(f"ERROR: Could not find {local_path}")
        return 0.0
    label_map = {"A": 0, "B": 1, "C": 2}
    correct = 0
    for ex in dataset:
        prompt = ex["context"].strip() + " " + ex["question"].strip()
        choices = [ex["answerA"], ex["answerB"], ex["answerC"]]
        # Map "C" -> 2, etc.
        label = label_map.get(ex["correct"])
        if label is None:
            continue
        scores = [score_completion(model, tokenizer, model_name, prompt, c, relevant_layers)
                  for c in choices]
        if int(np.argmax(scores)) == label:
            correct += 1
    return correct / len(dataset) if dataset else 0.0


def evaluate_openbookqa(model, tokenizer, model_name, relevant_layers=None, n=200):
    """
    Binary MC science-fact reasoning — correct answer vs 1 random distractor.
    Dataset : allenai/openbookqa  (split: validation)
    Fields  : question_stem, choices['text'], choices['label'], answerKey
    Random baseline : 0.50

    Rationale: GPT-2-scale models score near chance on the full 4-way task
    because individually plausible distractors are indistinguishable at this
    scale. Reducing to binary (correct vs one randomly sampled incorrect choice)
    recovers a usable signal while still probing the same knowledge. A fixed
    seed + random position assignment (0 or 1) eliminates positional bias and
    ensures identical distractor draws across baseline and all replacement levels.
    """
    dataset = load_dataset("allenai/openbookqa", split="validation")
    rng = random.Random(OPENBOOKQA_SEED)
    correct, count = 0, 0

    for ex in dataset.select(range(min(n, len(dataset)))):
        choice_texts  = ex["choices"]["text"]
        choice_labels = ex["choices"]["label"]
        answer_key    = ex["answerKey"]
        if answer_key not in choice_labels:
            continue

        correct_idx  = choice_labels.index(answer_key)
        correct_text = choice_texts[correct_idx]
        distractors  = [choice_texts[i] for i in range(len(choice_texts)) if i != correct_idx]
        distractor   = rng.choice(distractors)

        # Randomise position to avoid positional bias
        if rng.random() < 0.5:
            choices, label = [correct_text, distractor], 0
        else:
            choices, label = [distractor, correct_text], 1

        scores = [score_completion(model, tokenizer, model_name, ex["question_stem"], c, relevant_layers)
                  for c in choices]
        if int(np.argmax(scores)) == label:
            correct += 1
        count += 1

    return correct / count if count > 0 else 0.0


# ── Evaluation Suite ──

BENCHMARKS = [
    # ("HellaSwag",   evaluate_hellaswag),
    # ("PIQA",        evaluate_piqa),
    # ("SciQ",        evaluate_sciq),
    ("ARC-Easy",    evaluate_arc_easy),
    # ("Social IQA",  evaluate_social_iqa),
    # ("OpenBookQA",  evaluate_openbookqa),
]

def run_evaluation_suite(model_name, csv_file=None, replacement_pct=None, n_samples=200):
    print(f"\n{'='*70}")
    print(f"Evaluating: {model_name.upper()}")
    if csv_file:
        print(f"Config: {os.path.basename(csv_file)} ({int(replacement_pct*100)}% replacement)")
    else:
        print("Config: BASELINE")
    print(f"{'='*70}")

    if csv_file is None:
        model, tokenizer = load_model_and_tokenizer(model_name)
        relevant_layers, handles = None, []
    else:
        if replacement_pct is None:
            raise ValueError("replacement_pct must be provided when csv_file is set")
        if model_name == "gpt2":
            model, tokenizer, relevant_layers, handles, head_mapping = \
                build_replaced_model_gpt2(csv_file, replacement_pct)
        elif model_name == "tinyllama":
            model, tokenizer, relevant_layers, handles, head_mapping = \
                build_replaced_model_tinyllama(csv_file, replacement_pct)
        print(f"Replaced {len(head_mapping)} heads across {len(relevant_layers)} layers")

    results = {}
    for name, fn in BENCHMARKS:
        print(f"\nRunning {name}...")
        results[name] = fn(model, tokenizer, model_name, relevant_layers, n_samples)
        print(f"  Accuracy: {results[name]:.4f}")

    print(f"\n{'='*70}")
    for name, val in results.items():
        print(f"  {name}: {val:.4f}")
    print(f"{'='*70}")

    for h in handles:
        h.remove()
    del model
    torch.cuda.empty_cache()
    return results


# ── Run All Evaluations ──

all_results = []

# for model_name in ["gpt2", "tinyllama"]:
for model_name in ["gpt2", "tinyllama"]:
    print(f"\n{'#'*70}")
    print(f"# MODEL: {model_name.upper()}")
    print(f"{'#'*70}")

    # Baseline (0% replacement)
    baseline_results = run_evaluation_suite(model_name, csv_file=None, n_samples=N_SAMPLES)
    all_results.append({
        "model": model_name,
        "replacement_pct": 0,
        "csv_file": "baseline",
        "shuffle_idx": "baseline",
        **baseline_results
    })

    # Replacement levels
    # best_file = hardcoded_files[model_name]
    # for pct in REPLACEMENT_LEVELS:
    #     replaced_results = run_evaluation_suite(
    #         model_name,
    #         csv_file=best_file,
    #         replacement_pct=pct,
    #         n_samples=N_SAMPLES
    #     )
    #     all_results.append({
    #         "model": model_name,
    #         "replacement_pct": int(pct * 100),
    #         "csv_file": best_file,
    #         "shuffle_idx": "hardcoded",
    #         **replaced_results
    #     })

# ── Save Results ──

results_df = pd.DataFrame(all_results)
print("\n" + "="*70)
print("ALL RESULTS:")
print(results_df.to_string())

os.makedirs("../results", exist_ok=True)
results_df.to_csv("../results/downstream_task_results.csv", index=False)
print("\nResults saved to: ../results/downstream_task_results.csv")

# ── Build eval_results dict (compatible with plotting code) ──
#
# Shape: eval_results[model_name][benchmark] = {
#     "baseline": <random_chance_float>,   # dashed horizontal line
#     "x":        [0, 5, 10, ...],         # % heads replaced (int)
#     "y":        [acc_0, acc_5, ...]      # accuracy at each level
# }

RANDOM_BASELINES = {
    "HellaSwag":  0.25,   # 4-way
    "PIQA":       0.50,   # 2-way
    "SciQ":       0.25,   # 4-way
    "ARC-Easy":   0.25,   # 4-way
    "Social IQA": 0.33,   # 3-way  (≈ 1/3)
    "OpenBookQA": 0.50,   # binary (1 correct vs 1 distractor)
}

x_levels = sorted(results_df["replacement_pct"].unique().tolist())

eval_results = {}
for model_name in ["gpt2", "tinyllama"]:
    eval_results[model_name] = {}
    model_df = results_df[results_df["model"] == model_name].sort_values("replacement_pct")
    for benchmark, _ in BENCHMARKS:
        if benchmark not in model_df.columns:
            continue
        x_vals, y_vals = [], []
        for pct in x_levels:
            row = model_df[model_df["replacement_pct"] == pct]
            if not row.empty:
                x_vals.append(pct)
                y_vals.append(float(row[benchmark].values[0]))
        eval_results[model_name][benchmark] = {
            "baseline": RANDOM_BASELINES.get(benchmark, 0.25),
            "x": x_vals,
            "y": y_vals,
        }

# ── Plot (matches figure_4_4 layout) ──

plt.rcParams["font.family"] = "serif"
plt.rcParams["mathtext.fontset"] = "dejavuserif"

meta_info = {
    "HellaSwag":  {"desc": "Common Sense Inference",    "n": "10k"},
    "PIQA":       {"desc": "Physical Reasoning",         "n": "1.8k"},
    "SciQ":       {"desc": "Science Understanding",      "n": "1k"},
    "ARC-Easy":   {"desc": "Elementary Science",         "n": "2.3k"},
    "Social IQA": {"desc": "Social Interaction",         "n": "1.9k"},
    "OpenBookQA": {"desc": "Scientific Facts (binary)",  "n": "500"},
}

ROW_COLORS = {
    "gpt2":      {"box": "#e07070", "line": "#c0392b"},
    "tinyllama": {"box": "#7fb3d5", "line": "#1f77b4"},
}

fig, axes = plt.subplots(2, 3, figsize=(15, 8), constrained_layout=True)
axes_flat = axes.flatten()

for i, metric in enumerate(meta_info.keys()):
    ax = axes_flat[i]

    # Random-chance baseline dashed line
    baseline_val = RANDOM_BASELINES.get(metric, 0.25)
    ax.axhline(y=baseline_val, color="black", linestyle="--",
               dashes=(10, 5), linewidth=1.2, label="Random Guessing")

    for model_name in ["gpt2", "tinyllama"]:
        data = eval_results.get(model_name, {}).get(metric)
        if data is None:
            continue
        marker = "o" if model_name == "gpt2" else "s"
        label  = "GPT-2" if model_name == "gpt2" else "TinyLlama 1.1B"
        ax.plot(data["x"], data["y"],
                marker=marker, linestyle="-", linewidth=1.8, markersize=5.5,
                color=ROW_COLORS[model_name]["line"],
                markerfacecolor=ROW_COLORS[model_name]["box"],
                label=label)

    ax.set_title(metric, fontweight="bold", fontsize=13, pad=25)
    subtitle = f"{meta_info[metric]['desc']} ($N={meta_info[metric]['n']}$)"
    ax.text(0.5, 1.02, subtitle, transform=ax.transAxes,
            ha="center", va="bottom", fontsize=9.5, color="#333333")

    ax.legend(fontsize=8, frameon=False, loc="upper right")

    if i >= 3:
        ax.set_xlabel("% Attention Heads Replaced", fontsize=11)
    if i % 3 == 0:
        ax.set_ylabel("Accuracy", fontsize=11)

    ax.set_ylim(0, 1.0)
    ax.grid(True, linestyle=":", alpha=0.4)

plt.savefig("figure_4_4.pdf", bbox_inches="tight")
plt.show()
print("\nPlot saved to figure_4_4.pdf")
# Out:
# Using device: cpu
# Loaded 71 program functions
#
# ######################################################################
# # MODEL: GPT2
# ######################################################################
#
# ======================================================================
# Evaluating: GPT2
# Config: BASELINE
# ======================================================================
#
# Running ARC-Easy...
#   Accuracy: 0.3450
#
# ======================================================================
#   ARC-Easy: 0.3450
# ======================================================================
#
# ######################################################################
# # MODEL: TINYLLAMA
# ######################################################################
#
# ======================================================================
# Evaluating: TINYLLAMA
# Config: BASELINE
# ======================================================================
#
# Running ARC-Easy...
#   Accuracy: 0.5300
#
# ======================================================================
#   ARC-Easy: 0.5300
# ======================================================================
#
# ======================================================================
# ALL RESULTS:
#        model  replacement_pct  csv_file shuffle_idx  ARC-Easy
# 0       gpt2                0  baseline    baseline     0.345
# 1  tinyllama                0  baseline    baseline     0.530
#
# Results saved to: ../results/downstream_task_results.csv
# Plot saved to figure_4_4.pdf

# %%
# Using device: cpu
# Loaded 71 program functions

# ######################################################################
# # MODEL: GPT2
# ######################################################################

# ======================================================================
# Evaluating: GPT2
# Config: gpt2_smart_shuffle_8.csv (5% replacement)
# ======================================================================
# Applying GPT-2 head replacement for 5% -> 7 heads
# Replaced 7 heads across 5 layers

# Running ARC-Easy...
#   Accuracy: 0.3450

# Running Social IQA...
#   Accuracy: 0.4200

# Running OpenBookQA...
#   Accuracy: 0.4800

# ======================================================================
#   ARC-Easy: 0.3450
#   Social IQA: 0.4200
#   OpenBookQA: 0.4800
# ======================================================================

# ======================================================================
# Evaluating: GPT2
# Config: gpt2_smart_shuffle_8.csv (10% replacement)
# ======================================================================
# Applying GPT-2 head replacement for 10% -> 14 heads
# Replaced 14 heads across 8 layers

# Running ARC-Easy...
#   Accuracy: 0.3300

# Running Social IQA...
#   Accuracy: 0.4100

# Running OpenBookQA...
#   Accuracy: 0.4950

# ======================================================================
#   ARC-Easy: 0.3300
#   Social IQA: 0.4100
#   OpenBookQA: 0.4950
# ======================================================================

# ======================================================================
# Evaluating: GPT2
# Config: gpt2_smart_shuffle_8.csv (15% replacement)
# ======================================================================
# Applying GPT-2 head replacement for 15% -> 21 heads
# Replaced 21 heads across 10 layers

# Running ARC-Easy...
#   Accuracy: 0.3450

# Running Social IQA...
#   Accuracy: 0.4250

# Running OpenBookQA...
#   Accuracy: 0.4850

# ======================================================================
#   ARC-Easy: 0.3450
#   Social IQA: 0.4250
#   OpenBookQA: 0.4850
# ======================================================================

# ======================================================================
# Evaluating: GPT2
# Config: gpt2_smart_shuffle_8.csv (20% replacement)
# ======================================================================
# Applying GPT-2 head replacement for 20% -> 28 heads
# Replaced 28 heads across 10 layers

# Running ARC-Easy...
#   Accuracy: 0.3350

# Running Social IQA...
#   Accuracy: 0.4100

# Running OpenBookQA...
#   Accuracy: 0.4850

# ======================================================================
#   ARC-Easy: 0.3350
#   Social IQA: 0.4100
#   OpenBookQA: 0.4850
# ======================================================================

# ======================================================================
# Evaluating: GPT2
# Config: gpt2_smart_shuffle_8.csv (25% replacement)
# ======================================================================
# Applying GPT-2 head replacement for 25% -> 36 heads
# Replaced 36 heads across 10 layers

# Running ARC-Easy...
#   Accuracy: 0.3450

# Running Social IQA...
#   Accuracy: 0.4250

# Running OpenBookQA...
#   Accuracy: 0.4850

# ======================================================================
#   ARC-Easy: 0.3450
#   Social IQA: 0.4250
#   OpenBookQA: 0.4850
# ======================================================================

# ======================================================================
# Evaluating: GPT2
# Config: gpt2_smart_shuffle_8.csv (30% replacement)
# ======================================================================
# Applying GPT-2 head replacement for 30% -> 43 heads
# Replaced 43 heads across 10 layers

# Running ARC-Easy...
#   Accuracy: 0.3550

# Running Social IQA...
#   Accuracy: 0.4150

# Running OpenBookQA...
#   Accuracy: 0.4950

# ======================================================================
#   ARC-Easy: 0.3550
#   Social IQA: 0.4150
#   OpenBookQA: 0.4950
# ======================================================================

# ======================================================================
# Evaluating: GPT2
# Config: gpt2_smart_shuffle_8.csv (40% replacement)
# ======================================================================
# Applying GPT-2 head replacement for 40% -> 57 heads
# Replaced 57 heads across 10 layers

# Running ARC-Easy...
#   Accuracy: 0.3400

# Running Social IQA...
#   Accuracy: 0.3950

# Running OpenBookQA...
#   Accuracy: 0.4750

# ======================================================================
#   ARC-Easy: 0.3400
#   Social IQA: 0.3950
#   OpenBookQA: 0.4750
# ======================================================================

# ======================================================================
# Evaluating: GPT2
# Config: gpt2_smart_shuffle_8.csv (50% replacement)
# ======================================================================
# Applying GPT-2 head replacement for 50% -> 72 heads
# Replaced 72 heads across 12 layers

# Running ARC-Easy...
#   Accuracy: 0.3100

# Running Social IQA...
#   Accuracy: 0.4100

# Running OpenBookQA...
#   Accuracy: 0.4850

# ======================================================================
#   ARC-Easy: 0.3100
#   Social IQA: 0.4100
#   OpenBookQA: 0.4850
# ======================================================================

# ======================================================================
# Evaluating: GPT2
# Config: gpt2_smart_shuffle_8.csv (75% replacement)
# ======================================================================
# Applying GPT-2 head replacement for 75% -> 108 heads
# Replaced 108 heads across 12 layers

# Running ARC-Easy...
#   Accuracy: 0.2950

# Running Social IQA...
#   Accuracy: 0.4100

# Running OpenBookQA...
#   Accuracy: 0.4850

# ======================================================================
#   ARC-Easy: 0.2950
#   Social IQA: 0.4100
#   OpenBookQA: 0.4850
# ======================================================================

# ======================================================================
# Evaluating: GPT2
# Config: gpt2_smart_shuffle_8.csv (100% replacement)
# ======================================================================
# Applying GPT-2 head replacement for 100% -> 144 heads
# Replaced 144 heads across 12 layers

# Running ARC-Easy...
#   Accuracy: 0.2700

# Running Social IQA...
#   Accuracy: 0.4100

# Running OpenBookQA...
#   Accuracy: 0.4500

# ======================================================================
#   ARC-Easy: 0.2700
#   Social IQA: 0.4100
#   OpenBookQA: 0.4500
# ======================================================================

# Using device: cpu
# Loaded 71 program functions

# ######################################################################
# # MODEL: TINYLLAMA
# ######################################################################

# ======================================================================
# Evaluating: TINYLLAMA
# Config: tinyllama_smart_shuffle_2.csv (5% replacement)
# ======================================================================
# Applying TinyLlama head replacement for 5% -> 35 heads
# Replaced 35 heads across 13 layers

# Running ARC-Easy...
#   Accuracy: 0.5050

# ======================================================================
#   ARC-Easy: 0.5050
# ======================================================================

# ======================================================================
# Evaluating: TINYLLAMA
# Config: tinyllama_smart_shuffle_2.csv (10% replacement)
# ======================================================================
# Applying TinyLlama head replacement for 10% -> 70 heads
# Replaced 70 heads across 16 layers

# Running ARC-Easy...
#   Accuracy: 0.5050

# ======================================================================
#   ARC-Easy: 0.5050
# ======================================================================

# ======================================================================
# Evaluating: TINYLLAMA
# Config: tinyllama_smart_shuffle_2.csv (15% replacement)
# ======================================================================
# Applying TinyLlama head replacement for 15% -> 105 heads
# Replaced 105 heads across 18 layers

# Running ARC-Easy...
#   Accuracy: 0.4900

# ======================================================================
#   ARC-Easy: 0.4900
# ======================================================================

# ======================================================================
# Evaluating: TINYLLAMA
# Config: tinyllama_smart_shuffle_2.csv (20% replacement)
# ======================================================================
# Applying TinyLlama head replacement for 20% -> 140 heads
# Replaced 140 heads across 19 layers

# Running ARC-Easy...
#   Accuracy: 0.4700

# ======================================================================
#   ARC-Easy: 0.4700
# ======================================================================

# ======================================================================
# Evaluating: TINYLLAMA
# Config: tinyllama_smart_shuffle_2.csv (25% replacement)
# ======================================================================
# Applying TinyLlama head replacement for 25% -> 176 heads
# Replaced 176 heads across 19 layers

# Running ARC-Easy...
#   Accuracy: 0.4500

# ======================================================================
#   ARC-Easy: 0.4500
# ======================================================================

# ======================================================================
# Evaluating: TINYLLAMA
# Config: tinyllama_smart_shuffle_2.csv (30% replacement)
# ======================================================================
# Applying TinyLlama head replacement for 30% -> 211 heads
# Replaced 211 heads across 20 layers

# Running ARC-Easy...
#   Accuracy: 0.4400

# ======================================================================
#   ARC-Easy: 0.4400
# ======================================================================

# ======================================================================
# Evaluating: TINYLLAMA
# Config: tinyllama_smart_shuffle_2.csv (40% replacement)
# ======================================================================
# Applying TinyLlama head replacement for 40% -> 281 heads
# Replaced 281 heads across 20 layers

# Running ARC-Easy...
#   Accuracy: 0.4150

# ======================================================================
#   ARC-Easy: 0.4150
# ======================================================================

# ======================================================================
# Evaluating: TINYLLAMA
# Config: tinyllama_smart_shuffle_2.csv (50% replacement)
# ======================================================================
# Applying TinyLlama head replacement for 50% -> 352 heads
# Replaced 352 heads across 20 layers

# Running ARC-Easy...
#   Accuracy: 0.3850

# ======================================================================
#   ARC-Easy: 0.3850
# ======================================================================

# ======================================================================
# Evaluating: TINYLLAMA
# Config: tinyllama_smart_shuffle_2.csv (75% replacement)
# ======================================================================
# Applying TinyLlama head replacement for 75% -> 528 heads
# Replaced 528 heads across 21 layers

# Running ARC-Easy...
#   Accuracy: 0.3200

# ======================================================================
#   ARC-Easy: 0.3200
# ======================================================================

# ======================================================================
# Evaluating: TINYLLAMA
# Config: tinyllama_smart_shuffle_2.csv (100% replacement)
# ======================================================================
# Applying TinyLlama head replacement for 100% -> 704 heads
# Replaced 704 heads across 22 layers

# Running ARC-Easy...
#   Accuracy: 0.2400

# ======================================================================
#   ARC-Easy: 0.2400
# ======================================================================

# ======================================================================
# ALL RESULTS:
#        model  replacement_pct                                                           csv_file shuffle_idx  ARC-Easy
# 0  tinyllama                5  ../results/replacement_run/shuffles/tinyllama_smart_shuffle_2.csv   hardcoded     0.505
# 1  tinyllama               10  ../results/replacement_run/shuffles/tinyllama_smart_shuffle_2.csv   hardcoded     0.505
# 2  tinyllama               15  ../results/replacement_run/shuffles/tinyllama_smart_shuffle_2.csv   hardcoded     0.490
# 3  tinyllama               20  ../results/replacement_run/shuffles/tinyllama_smart_shuffle_2.csv   hardcoded     0.470
# 4  tinyllama               25  ../results/replacement_run/shuffles/tinyllama_smart_shuffle_2.csv   hardcoded     0.450
# 5  tinyllama               30  ../results/replacement_run/shuffles/tinyllama_smart_shuffle_2.csv   hardcoded     0.440
# 6  tinyllama               40  ../results/replacement_run/shuffles/tinyllama_smart_shuffle_2.csv   hardcoded     0.415
# 7  tinyllama               50  ../results/replacement_run/shuffles/tinyllama_smart_shuffle_2.csv   hardcoded     0.385
# 8  tinyllama               75  ../results/replacement_run/shuffles/tinyllama_smart_shuffle_2.csv   hardcoded     0.320
# 9  tinyllama              100  ../results/replacement_run/shuffles/tinyllama_smart_shuffle_2.csv   hardcoded     0.240

# Results saved to: ../results/downstream_task_results.csv

# %%
# Try this if the above fails
dataset = load_dataset("json", data_files="https://huggingface.co/datasets/allenai/social_i_qa/resolve/main/data/validation-00000-of-00001.parquet", split="train")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Try this if the above fails
# ----> 2 dataset = load_dataset("json", data_files="https://huggingface.co/datasets/allenai/social_i_qa/resolve/main/data/validation-00000-of-00001.parquet", split="train")
#
# File c:\Users\amkah\anaconda3\Lib\site-packages\datasets\load.py:1392, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1387 verification_mode = VerificationMode(
#    1388     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1389 )
#    1391 # Create a dataset builder
# -> 1392 builder_instance = load_dataset_builder(
#    1393     path=path,
#    1394     name=name,
#    1395     data_dir=data_dir,
#    1396     data_files=data_files,
#    1397     cache_dir=cache_dir,
#    1398     features=features,
#    1399     download_config=download_config,
#    1400     download_mode=download_mode,
#    1401     revision=revision,
#    1402     token=token,
#    1403     storage_options=storage_options,
#    1404     **config_kwargs,
#    1405 )
#    1407 # Return iterable dataset in case of streaming
#    1408 if streaming:
#
# File c:\Users\amkah\anaconda3\Lib\site-packages\datasets\load.py:1132, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, **config_kwargs)
#    1130 if features is not None:
#    1131     features = _fix_for_backward_compatible_features(features)
# -> 1132 dataset_module = dataset_module_factory(
#    1133     path,
#    1134     revision=revision,
#    1135     download_config=download_config,
#    1136     download_mode=download_mode,
#    1137     data_dir=data_dir,
#    1138     data_files=data_files,
#    1139     cache_dir=cache_dir,
#    1140 )
#    1141 # Get dataset builder class
#    1142 builder_kwargs = dataset_module.builder_kwargs
#
# File c:\Users\amkah\anaconda3\Lib\site-packages\datasets\load.py:912, in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#     889 # We have several ways to get a dataset builder:
#     890 #
#     891 # - if path is the name of a packaged dataset module
#    (...)    903
#     904 # Try packaged
#     905 if path in _PACKAGED_DATASETS_MODULES:
#     906     return PackagedDatasetModuleFactory(
#     907         path,
#     908         data_dir=data_dir,
#     909         data_files=data_files,
#     910         download_config=download_config,
#     911         download_mode=download_mode,
# --> 912     ).get_module()
#     913 # Try locally
#     914 elif path.endswith(filename):
#
# File c:\Users\amkah\anaconda3\Lib\site-packages\datasets\load.py:526, in PackagedDatasetModuleFactory.get_module(self)
#     520 base_path = Path(self.data_dir or "").expanduser().resolve().as_posix()
#     521 patterns = (
#     522     sanitize_patterns(self.data_files)
#     523     if self.data_files is not None
#     524     else get_data_patterns(base_path, download_config=self.download_config)
#     525 )
# --> 526 data_files = DataFilesDict.from_patterns(
#     527     patterns,
#     528     download_config=self.download_config,
#     529     base_path=base_path,
#     530 )
#     532 module_path, hash = _PACKAGED_DATASETS_MODULES[self.name]
#     534 builder_kwargs = {
#     535     "data_files": data_files,
#     536     "dataset_name": self.name,
#     537 }
#
# File c:\Users\amkah\anaconda3\Lib\site-packages\datasets\data_files.py:689, in DataFilesDict.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     684 out = cls()
#     685 for key, patterns_for_key in patterns.items():
#     686     out[key] = (
#     687         patterns_for_key
#     688         if isinstance(patterns_for_key, DataFilesList)
# --> 689         else DataFilesList.from_patterns(
#     690             patterns_for_key,
#     691             base_path=base_path,
#     692             allowed_extensions=allowed_extensions,
#     693             download_config=download_config,
#     694         )
#     695     )
#     696 return out
#
# File c:\Users\amkah\anaconda3\Lib\site-packages\datasets\data_files.py:582, in DataFilesList.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     579 for pattern in patterns:
#     580     try:
#     581         data_files.extend(
# --> 582             resolve_pattern(
#     583                 pattern,
#     584                 base_path=base_path,
#     585                 allowed_extensions=allowed_extensions,
#     586                 download_config=download_config,
#     587             )
#     588         )
#     589     except FileNotFoundError:
#     590         if not has_magic(pattern):
#
# File c:\Users\amkah\anaconda3\Lib\site-packages\datasets\data_files.py:383, in resolve_pattern(pattern, base_path, allowed_extensions, download_config)
#     381     if allowed_extensions is not None:
#     382         error_msg += f" with any supported extension {list(allowed_extensions)}"
# --> 383     raise FileNotFoundError(error_msg)
#     384 return out
#
# FileNotFoundError: Unable to find 'hf://datasets/allenai/social_i_qa@main/data/validation-00000-of-00001.parquet'

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

plt.rcParams["font.family"] = "serif"
plt.rcParams["mathtext.fontset"] = "dejavuserif"

# 1. DATA DICTIONARY
eval_results = {
    "gpt2": {
        "HellaSwag": {
            "baseline": 0.25,
            "x": [0, 5, 10, 15, 20, 25, 30, 40, 50, 75, 100],
            "y": [0.310, 0.325, 0.330, 0.325, 0.320, 0.315, 0.340, 0.315, 0.300, 0.270, 0.250]
        },
        "PIQA": {
            "baseline": 0.50, 
            "x": [0, 5, 10, 15, 20, 25, 30, 40, 50, 75, 100],
            "y": [0.635, 0.640, 0.630, 0.620, 0.630, 0.630, 0.630, 0.605, 0.610, 0.590, 0.570]
        },
        "SciQ": {
            "baseline": 0.25,
            "x": [0, 5, 10, 15, 20, 25, 30, 40, 50, 75, 100],
            "y": [0.475, 0.465, 0.445, 0.450, 0.425, 0.430, 0.420, 0.400, 0.380, 0.325, 0.350]
        },
        "ARC-Easy": {
            "baseline": 0.25, 
            "x": [0, 5, 10, 15, 20, 25, 30, 40, 50, 75, 100], 
            "y": [0.345, 0.345, 0.330, 0.345, 0.335, 0.345, 0.355, 0.340, 0.310, 0.295, 0.270]
        },
        "Social IQA": {"baseline": 0.33, "x": [0, 5, 10, 15, 20, 25, 30, 40, 50, 75, 100], "y": [0.0]*11},
        "OpenBookQA": {"baseline": 0.25, "x": [0, 5, 10, 15, 20, 25, 30, 40, 50, 75, 100], "y": [0.0]*11}
    },
    "tinyllama": {
        "HellaSwag": {
            "baseline": 0.25,
            "x": [0, 5, 10, 15, 20, 25, 30, 40, 50, 75, 100],
            "y": [0.475, 0.465, 0.460, 0.445, 0.435, 0.435, 0.410, 0.400, 0.335, 0.300, 0.250]
        },
        "PIQA": {
            "baseline": 0.25,
            "x": [0, 5, 10, 15, 20, 25, 30, 40, 50, 75, 100],
            "y": [0.700, 0.700, 0.695, 0.700, 0.695, 0.695, 0.660, 0.635, 0.635, 0.550, 0.505]
        },
        "SciQ": {
            "baseline": 0.25,
            "x": [0, 5, 10, 15, 20, 25, 30, 40, 50, 75, 100],
            "y": [0.525, 0.515, 0.510, 0.510, 0.495, 0.500, 0.485, 0.435, 0.415, 0.340, 0.255]
        },
        "ARC-Easy": {
            "baseline": 0.25, 
            "x": [0, 5, 10, 15, 20, 25, 30, 40, 50, 75, 100], 
            "y": [0.530, 0.505, 0.505, 0.490, 0.470, 0.450, 0.440, 0.415, 0.385, 0.320, 0.240]
        },
        "Social IQA": {"baseline": 0.33, "x": [0, 5, 10, 15, 20, 25, 30, 40, 50, 75, 100], "y": [0.0]*11},
        "OpenBookQA": {"baseline": 0.25, "x": [0, 5, 10, 15, 20, 25, 30, 40, 50, 75, 100], "y": [0.0]*11}
    },
    # ── Llama-3.2-3B ── fill in y-values after running downstream evals
    "llama3b": {
        "HellaSwag":  {"baseline": 0.25, "x": [0, 5, 10, 15, 20, 25, 30, 40, 50, 75, 100], "y": [0.0]*11},
        "PIQA":       {"baseline": 0.50, "x": [0, 5, 10, 15, 20, 25, 30, 40, 50, 75, 100], "y": [0.0]*11},
        "SciQ":       {"baseline": 0.25, "x": [0, 5, 10, 15, 20, 25, 30, 40, 50, 75, 100], "y": [0.0]*11},
        "ARC-Easy":   {"baseline": 0.25, "x": [0, 5, 10, 15, 20, 25, 30, 40, 50, 75, 100], "y": [0.0]*11},
        "Social IQA": {"baseline": 0.33, "x": [0, 5, 10, 15, 20, 25, 30, 40, 50, 75, 100], "y": [0.0]*11},
        "OpenBookQA": {"baseline": 0.25, "x": [0, 5, 10, 15, 20, 25, 30, 40, 50, 75, 100], "y": [0.0]*11}
    }
}

# Metadata for labels
meta_info = {
    "HellaSwag":  {"desc": "Common Sense Inference", "n": "10k"},
    "PIQA":       {"desc": "Physical Reasoning", "n": "1.8k"},
    "SciQ":       {"desc": "Elemeentary cience", "n": "1k"},
    "ARC-Easy":   {"desc": "Simple Logic", "n": "2.3k"},
    "Social IQA": {"desc": "Social Interaction", "n": "1.9k"},
    "OpenBookQA": {"desc": "Scientific Facts", "n": "500"}
}

ROW_COLORS = {
    "gpt2":      {"box": "#e07070", "line": "#c0392b"},
    "tinyllama": {"box": "#7fb3d5", "line": "#1f77b4"},
    "llama3b":   {"box": "#b5ead7", "line": "#2a9d8f"},  # teal
}

# 2. PLOTTING LOGIC
fig, axes = plt.subplots(2, 3, figsize=(15, 8), sharey=True, constrained_layout=True)
axes_flat = axes.flatten()

for i, metric in enumerate(meta_info.keys()):
    ax = axes_flat[i]
    
    # Plot random baseline first
    baseline_val = eval_results["gpt2"][metric]["baseline"]
    ax.axhline(y=baseline_val, color='black', linestyle='--', 
               dashes=(10, 5), linewidth=1.2, label="Random Guessing")
    
    for model_name in ["gpt2", "tinyllama", "llama3b"]:
        data = eval_results[model_name][metric]
        marker = "o" if model_name == "gpt2" else ("s" if model_name == "tinyllama" else "^")
        label  = "GPT-2" if model_name == "gpt2" else ("TinyLlama 1.1B" if model_name == "tinyllama" else "Llama-3.2-3B")
        
        ax.plot(data["x"], data["y"], marker=marker, linestyle='-', linewidth=1.8, 
                markersize=5.5, color=ROW_COLORS[model_name]["line"], 
                markerfacecolor=ROW_COLORS[model_name]["box"], label=label)
    
    # Subtitle and Title formatting
    ax.set_title(metric, fontweight='bold', fontsize=13, pad=25)
    subtitle_text = f"{meta_info[metric]['desc']} ($N={meta_info[metric]['n']}$)"
    ax.text(0.5, 1.02, subtitle_text, transform=ax.transAxes, ha='center', 
            va='bottom', fontsize=9.5, fontweight='normal', color='#333333')
    
    # Legend per plot
    ax.legend(fontsize=8, frameon=False, loc='upper right')
    
    # Axis formatting
    if i >= 3: ax.set_xlabel("% Attention Heads Replaced", fontsize=11)
    if i % 3 == 0: ax.set_ylabel("Accuracy Score", fontsize=11)
    ax.set_ylim(0, 1.0)
    ax.grid(True, linestyle=':', alpha=0.4)

plt.savefig("figure_4_4.pdf")
plt.show()

# %%
import pandas as pd

# Pull the validation split from the processed parquet mirror
# This version definitely has labels
df = pd.read_parquet("hf://datasets/ybisk/piqa@refs/convert/parquet/plain_text/validation/0000.parquet")

# Save it to your local repo
df.to_json("../data/evaluations/piqa_val.jsonl", orient="records", lines=True)
print("Saved 1,838 labeled examples to data/evaluations/piqa_val.jsonl")
# Out:
# Saved 1,838 labeled examples to data/evaluations/piqa_val.jsonl
